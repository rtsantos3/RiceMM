# %%
import sys
sys.path.append("../src/") 
import os

import model_manipulation as mm
import cobra
import cplex 
import libsbml
import pandas as pd
import copy
from pathlib import Path
from tabulate import tabulate
import csv
import pytest

# %%
#Read 2-cell model
model = cobra.io.read_sbml_model("../model/ios2164_2cell.xml")
#Estimate inf
inf = 1e6
#Set model solver
model.solver = 'gurobi'
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-06-12

# %%
#This codeblock is to define some functions that will be used for modelling.


#Define linear relationship between PPFD and Cellular maintainance costs
#This formula comes from Topfer et al (2020) where she defined NGAM in a linear relationship with incident light
def compute_ngam_atp(ppfd):
    v_atp = 0.0049*ppfd + 2.7851
    return v_atp


#This function is used to set the inputs to the model used. 
def define_model_medium(model, co2, o2, ppfd, 
                        medium_dir='../misc/photo_medium.csv', no3=inf, h2o=inf, h=inf, 
                        nh4=inf, pi=inf):
    model_photo_media = mm.read_medium_csv(medium_dir, model)
    model_photo_media['EX_no3(e)'] = no3
    model_photo_media['EX_h2o(e)'] = h2o
    model_photo_media['EX_h(e)'] = h
    model_photo_media['EX_nh4(e)'] = nh4
    model_photo_media['EX_co2(e)'] = co2
    model_photo_media['EX_o2(e)'] = o2
    model_photo_media['EX_photonVis(e)'] = ppfd
    model_photo_media['EX_pi(e)'] = pi
    #Set set model medium as model
    print('Added model medium')
    return model_photo_media

    
def turn_off_cofac_cycles(model, inact_dir='../misc/leaf_inactivated.tsv'):
    file = csv.reader(open(inact_dir), delimiter='\t')
    leaf_inactive_rxns = list()
    for rows in file:
        row_m = str()
        row_bs = str()
        for rxns in rows:
            row_m += str(rxns) + "_M"
            row_bs += str(rxns) + "_BS"
        leaf_inactive_rxns.append(row_m)
        leaf_inactive_rxns.append(row_bs)
        
    for rxns in model.reactions:
        if rxns.id in leaf_inactive_rxns:
            rxns.bounds = (0,0)
    print('Successfully turned off cofactor-cycling reactions')

    
# #Add constraints to model
#This code block contains constraints that would simulate the assimilation rates of bs and m cells in a two-cell system (such as those seen near the midvein region of rice leaves)
# #BS photon flux must be the same/less than M flux (Adapted from B&B, 2019)
# photon_import = model.reactions.get_by_id("EX_photonVis(e)")
def add_tissue_constraints(model):
    BS_photon_import = model.reactions.PRISM_white_LED_BS
    M_photon_import = model.reactions.PRISM_white_LED_M

    #Set photon flux ratio to 10:1
    photon_flux = mm.set_fix_flux_ratio({M_photon_import.id:10, BS_photon_import.id:1},model)
    model.add_cons_vars(photon_flux)

    co2tex_m = model.reactions.CO2tex_M
    co2tex_bs = model.reactions.CO2tex_BS

    #CO2 Uptake must be constrained to A (Net assimilation rate) which is around 29 +- 1.2 umol CO2 m-2 s-1 for wild type rice
    #CO2 BS intake must be limited owing to its position in the leaf tissue

    # # #CO2 intake needs to be mostly in the M cells. Not sure of the exact value:
    # # Values from Von Caemmerer (2000) in intermediate C3-C4 photosynthetic plants is 1 mmol CO2 m-2 s-1 per 20 CO2 m-2 s-1, which puts it at 20:1 ratio
    # # #try checking Danila et al. (2016) on ratio of surface area of M cell to BS cell
    # # #I'll assume that the ratio is at 20:1 in the meantime, meaning that there is minimal gas exchange into the BS cell that would equate to around ~1 umol CO2 m-2s-1
    co2_ratio_cons = mm.set_fix_flux_ratio({co2tex_m.id:10, co2tex_bs.id:1},model)
    co2_ratio_cons.name = 'co2_ratio_cons'
    model.add_cons_vars(co2_ratio_cons)

    #o2 ratio constraint
    o2tex_bs = model.reactions.O2tex_BS
    o2tex_m = model.reactions.O2tex_M

    o2_ratio_cons = mm.set_fix_flux_ratio({o2tex_m.id:10, o2tex_bs.id:1},model)
    o2_ratio_cons.name = 'o2_ratio_cons'
    model.add_cons_vars(o2_ratio_cons)

    #no tissue-specific constraints will be set for Nitrates, h2o and other inorganic cofactors as 
    #they are transported via the apoplastic pathway rather than the symplast

# #This code block contains constraints specific for enzyme rate constraints
#This approach is derived from Bogart & Myers (2016) where they constrained the enzyme rate 
#fluxes in each of the 2-cell segments to a specific upper bound while keeping the lower bound
#At 0. For reversible reactions the lower bounds are set to the same value

def add_enzyme_constraints(model):
    #Maximum values for constraints
    wt_pepc = 0 #umol m-2 s-1 #Note: Need to constrain it to 0 pala since no PEPC was detected in either cell type
    wt_mdh = 11.18 #umol m-2 s-1
    wt_nadp_me = 0.14 #umol m-2 s-1
    wt_ppdk = 0.31 #umol m-2 s-1
    wt_CA = 7.5 #umol m-2  s-1 bar-1 (Constrained to CO2 amounting to 400-500 mbar) (1 bar = 15.74 umol m-2 s-1 CA activity)

    #PEPC constraint (Reaction id: PPCc)
    #Need to constrain it to 0 since reaction is only detected in Vascular tissue
    pepc_BS = model.reactions.PPCc_BS
    pepc_M = model.reactions.PPCc_M

    wt_pepc_cons = model.problem.Constraint(pepc_BS.flux_expression 
                                            + pepc_M.flux_expression, 
                                            lb = 0, ub = wt_pepc)
    wt_pepc_cons.name = 'wt_pepc_cons'
    model.add_cons_vars(wt_pepc_cons)

    #PPDK constraints (Reaction id: PPDKs) (note that this is found in the chloroplast?) 
    #Not detected via immunolocalization but enzyme activity is detected

    ppdks_BS = model.reactions.PPDKs_BS
    ppdks_M = model.reactions.PPDKs_M
    wt_ppdks_cons = model.problem.Constraint(ppdks_BS.flux_expression 
                                             + ppdks_M.flux_expression, 
                                             lb = 0, ub = wt_ppdk)
    wt_ppdks_cons.name = 'wt_ppdks_cons'
    model.add_cons_vars(wt_ppdks_cons)
    #Malate Dehydrogenase 
    #Only mitochondrial in WT Rice M cells
    mdhm_M = model.reactions.MDHm_M


    wt_mdh_cons = model.problem.Constraint(mdhm_M.flux_expression,
                                           lb= 0, ub=wt_mdh)
    wt_mdh_cons.name = "wt_mdh_cons"
    model.add_cons_vars(wt_mdh_cons)

    #NADP-ME (Since no signal is detected in WT, no locational constraints are imposed)
    #Let's see if I can force it to have a small amount of flux 
    nadp_me_M = model.reactions.MDHys_M
    nadp_me_BS = model.reactions.MDHys_BS

    wt_nadpme_cons = model.problem.Constraint(nadp_me_M.flux_expression
                                             + nadp_me_BS.flux_expression,
                                             lb= 0, ub=wt_nadp_me)
    wt_nadpme_cons.name = "wt_nadpme_cons"
    model.add_cons_vars(wt_nadpme_cons)
    #Weird, it causes the activity of RBCL to significantly vary from the actual values


    #I should add constraints for Carbonic Anhydrase
    #I should constrain it to 0.4 ubar, which would constitute ambient CO2 partial pressure
    #Flux is reversible so constraints are bi-directional


    hco3es_m = model.reactions.HCO3Es_M.flux_expression
    hco3ec_m = model.reactions.HCO3Ec_M.flux_expression
    hco3em_m = model.reactions.HCO3Em_M.flux_expression
    hco3es_bs = model.reactions.HCO3Es_BS.flux_expression
    hco3ec_bs = model.reactions.HCO3Ec_BS.flux_expression
    hco3em_bs = model.reactions.HCO3Em_BS.flux_expression

    ca_cons = model.problem.Constraint(hco3es_m + hco3ec_m + hco3em_m 
                                       + hco3es_bs + hco3ec_bs + hco3em_bs,
                                      lb = -wt_CA, ub = wt_CA)
    ca_cons.name = 'Carbonic_anhydrase_constraint'
    model.add_cons_vars(ca_cons)
    #Rbcl constaints
    #Retrieve flux expressions oof each RBCl reaction
    rbpc_M = model.reactions.RBPCs_M.flux_expression
    rbpc_BS = model.reactions.RBPCs_BS.flux_expression
    rbpo_M = model.reactions.RBPOs_M.flux_expression
    rbpo_BS = model.reactions.RBPOs_BS.flux_expression

    #Constraint such that it is limited to 132 umol m-2 s-1
    rbcl_vcmax_cons = model.problem.Constraint(rbpc_M + rbpc_BS, lb = 0, ub= 132)
    rbcl_vcmax_cons.name='rbcl_vcmax_cons'
    model.add_cons_vars(rbcl_vcmax_cons)
    #Constraints for rbcl flux such that v_c/v_o = 3 or higher.
    rbcl_vcvo = model.problem.Constraint(3*(rbpo_M + rbpo_BS) 
                                         - 1*(rbpc_M + rbpc_BS),
                                         lb=0,ub=1000)
    rbcl_vcvo.name = 'rbcl_vc/vo_ratio'
    model.add_cons_vars(rbcl_vcvo)
    
#     rbcl_vcvo1 = model.problem.Constraint(3*(rbpo_M) 
#                                          - 1*(rbpc_M),
#                                          lb=0,ub=1000)
#     rbcl_vcvo1.name = 'rbcl_vc/vo_ratio_M'
#     model.add_cons_vars(rbcl_vcvo1)
    
# #     rbcl_vcvo2 = model.problem.Constraint(3*(rbpo_BS) 
# #                                          - 1*(rbpc_BS),
# #                                          lb=0,ub=1000)
# #     rbcl_vcvo2.name = 'rbcl_vc/vo_ratio_BS'
# #     model.add_cons_vars(rbcl_vcvo2)
    
    
    #Turn off the RBPC2s reactions since we already defined the constraints above
    model.reactions.RBPC2s_M.bounds = (0,0)
    model.reactions.RBPC2s_BS.bounds = (0,0)
    
    
    
    #What if I simply constrained that of the M cell one to 3:1?
    #This constraint is pretty good actually. 
    #This allows the system to be set at a specific Vc/Vo rate while still allowing local variation 
    #wherein Rubisco may act in an uncoupled fashion and may have favorable internal vc/vo rates.
# #This code block is to set a constraint such that M-to-BS cell NGAM ratio is 10-to-1 
# #Similar to what Moreno-Villena (2021) (preprint) had done 

#This function takes two arguments: the model and the maximal  ppfd input to the system
def add_ngam_cons(model, ppfd): 
    ngam_atp_m = mm.get_rxn(model, 'ngam_atp_c_M')
    ngam_atp_bs = mm.get_rxn(model, 'ngam_atp_c_BS')
    ngam_atp_m.bounds = (0,1000)
    ngam_atp_bs.bounds = (0,1000)
    ngam_ratio = mm.set_fix_flux_ratio({ngam_atp_m.id:10, ngam_atp_bs.id:1}, model)
    ngam_ratio.name = 'ngam_BS/M_ratio'
    model.add_cons_vars(ngam_ratio)

    #Retrieve NGAM reactions
    ngam_nadphox_c_M = mm.get_rxn(model, 'ngam_nadphox_c_M')
    ngam_nadphox_s_M = mm.get_rxn(model, 'ngam_nadphox_s_M')
    ngam_nadphox_m_M = mm.get_rxn(model, 'ngam_nadphox_m_M')
    ngam_nadphox_c_BS = mm.get_rxn(model, 'ngam_nadphox_c_BS')
    ngam_nadphox_s_BS = mm.get_rxn(model, 'ngam_nadphox_s_BS')
    ngam_nadphox_m_BS = mm.get_rxn(model, 'ngam_nadphox_m_BS')


    #Set Fixed fluxes
    nadphox_c_s_M = mm.set_fix_flux_ratio({ngam_nadphox_c_M.id:1, ngam_nadphox_s_M.id:1},model)
    nadphox_c_s_M.name = "nadphox_cs_ratio_M"
    nadphox_s_m_M = mm.set_fix_flux_ratio({ngam_nadphox_s_M.id:1, ngam_nadphox_m_M.id:1}, model)
    nadphox_s_m_M.name = "nadphox_sm_ratio_M"

    nadphox_c_s_BS = mm.set_fix_flux_ratio({ngam_nadphox_c_BS.id:1, ngam_nadphox_s_BS.id:1},model)
    nadphox_c_s_BS.name = "nadphox_cs_ratio_BS"
    nadphox_s_m_BS = mm.set_fix_flux_ratio({ngam_nadphox_s_BS.id:1, ngam_nadphox_m_BS.id:1}, model)
    nadphox_s_m_BS.name = "nadphox_sm_ratio_BS"

    #Add constraints
    model.add_cons_vars(nadphox_c_s_M)
    model.add_cons_vars(nadphox_s_m_M)
    model.add_cons_vars(nadphox_c_s_BS)
    model.add_cons_vars(nadphox_s_m_BS)

    #Retrieve flux expressionns
    fex_nadphox_c_M =  mm.get_flux_exp(model, ngam_nadphox_c_M)
    fex_nadphox_s_M = mm.get_flux_exp(model, ngam_nadphox_s_M)
    fex_nadphox_m_M = mm.get_flux_exp(model, ngam_nadphox_m_M)

    fex_nadphox_c_BS =  mm.get_flux_exp(model, ngam_nadphox_c_BS)
    fex_nadphox_s_BS =  mm.get_flux_exp(model, ngam_nadphox_s_BS)
    fex_nadphox_m_BS =  mm.get_flux_exp(model, ngam_nadphox_m_BS)

    fex_atp_c_M = mm.get_flux_exp(model, ngam_atp_m)
    fex_atp_c_BS =  mm.get_flux_exp(model, ngam_atp_bs)

    #Set the constraint between ATP:NADPH NGAM to 3:1
    nadphox_atpase = model.problem.Constraint(3*(fex_nadphox_c_M + fex_nadphox_s_M + fex_nadphox_m_M
                                                       + fex_nadphox_c_BS + fex_nadphox_s_BS + fex_nadphox_m_BS) 
                                         - 1*(fex_atp_c_M + fex_atp_c_BS),
                                         lb=0,ub=0)
    nadphox_atpase.name = "nadphox_atpase_ratio"
    model.add_cons_vars(nadphox_atpase)
    
    
    
    ngam_value = compute_ngam_atp(ppfd)
    ngam_cons = model.problem.Constraint(fex_atp_c_M + 
                                        fex_atp_c_BS, lb=ngam_value, ub=ngam_value)
    ngam_cons.name = 'NGAM_constraint'
    model.add_cons_vars(ngam_cons)
    
#This code  block gives a snapshot of the relevant fluxes on each of the cell types based on the saved sample_fluxes values above

def print_summary(sample_fluxes_df):
    print('rbcl M cell: ', sample_fluxes['RBPCs_M'], 'rbcl BS cell: ',sample_fluxes['RBPCs_BS'])
    print('rbcl M cell (photorespiration)', sample_fluxes['RBPOs_M'], 'rbcl BS cell (PR)', sample_fluxes['RBPOs_BS'])
    print('vc/vo M:', sample_fluxes['RBPCs_M']/sample_fluxes['RBPOs_M'], 'vc/vo BS:', sample_fluxes['RBPCs_BS']/sample_fluxes['RBPOs_BS'])
    print('RBPC2s_M', sample_fluxes['RBPC2s_M'], 'RBPC2s_BS', sample_fluxes['RBPC2s_BS'])
    print('PEPC M', sample_fluxes['PPCc_M'], 'PEPC BS', sample_fluxes['PPCc_BS'])
    print('Carbonic Anhydrase (Cytosolic) M', sample_fluxes['HCO3Ec_M'], 'Carbonic Anhydrase (Cytosolic) BS', sample_fluxes['HCO3Ec_BS'])
    print('NADP-ME M', sample_fluxes['MDHys_M'], 'NADP-ME BS', sample_fluxes['MDHys_BS'])
    print('Biomass M: ', sample_fluxes['Straw_Biomass_M'], 'Biomass BS', sample_fluxes['Straw_Biomass_BS'])
    print('Phloem M: ', sample_fluxes['DM_Phloem_M'], 'Phloem BS', sample_fluxes['DM_Phloem_BS'])
    print('co2 consumption M', sample_fluxes['CO2tex_M'], 'co2 consumption BS', sample_fluxes['CO2tex_BS'])
    print('o2 consumption M', sample_fluxes['O2tex_M'], 'o2 consumption BS', sample_fluxes['O2tex_BS'])
    print('Photosystem II M', sample_fluxes['PSIINC_M'], 'PSII BS', sample_fluxes['PSIINC_BS'])
    print('PSI M', sample_fluxes['PSIMR_M'], 'PSI BS', sample_fluxes['PSIMR_BS'])
    print('PPFD M: ', sample_fluxes['PRISM_white_LED_M'], 'PPFD BS: ', sample_fluxes['PRISM_white_LED_BS'])
    print('ATP synthesis (stromal) M', sample_fluxes['ATPSs_M'], 'ATP synthase (mit) M', sample_fluxes['ATPSm_M'])
    pd_rxn = [x for x in model.reactions if "pd" in x.id and "h2o" not in x.id]
    pd_abs_flux = 0
    for pds in pd_rxn:
        pd_abs_flux += abs(sample_fluxes[pds.id])
    
    print('pd_abs_flux: ', pd_abs_flux)

# %% [markdown]
# This code block is to add the constraints for ngam nadphox, which for some reason doesn't save when it was generated using the curation script

# %%
#May 5, 2022

# This code block is to test whether a single iteration works. Maybe I should implement the kinetic constraints by Von Caemmerer to obtain proper 
#proper values? I think that would be a better approach, I think.


with model as m1:

    m1.medium = define_model_medium(m1, co2=29, o2=2.216, ppfd=0, h=inf, nh4=inf, no3=inf)
    turn_off_cofac_cycles(m1)
    add_tissue_constraints(m1)
    add_enzyme_constraints(m1)
    add_ngam_cons(m1, 0)
    
    #Let's try turning off nga yung RBPC2s


#Constrain O2 intake to 3.312 mmol O2 gcw -1 d-1 ~~ 2.2618 umol O2 m-2 s-1 (from Lakshmanan et al. 2016)
    #Change objective function to mature leaf
    m1.reactions.get_by_id('Straw_Biomass_M').objective_coefficient = 0
    m1.reactions.get_by_id('Straw_Biomass_BS').objective_coefficient = 0
    mm.get_rxn(m1,'DM_Phloem_BS').objective_coefficient = 1
    
    
    sample_fluxes = cobra.flux_analysis.pfba(m1).fluxes
#     sample_fluxes = model.optimize().fluxes
    #Remove thermodynamically infeasible loops
    sample_fluxes = cobra.flux_analysis.loopless_solution(m1, sample_fluxes)
    
    sample_fluxes_df = sample_fluxes.to_frame()

print_summary(sample_fluxes_df)
# Out:
# Added model medium
# Successfully turned off cofactor-cycling reactions
# rbcl M cell:  2.20619335601691 rbcl BS cell:  0.21616242940832464
# rbcl M cell (photorespiration) 0.7619835787259059 rbcl BS cell (PR) 0.04546834974917235
# vc/vo M: 2.895329266420455 vc/vo BS: 4.754129644044523
# RBPC2s_M 0.0 RBPC2s_BS 0.0
# PEPC M 0.0 PEPC BS 0.0
# Carbonic Anhydrase (Cytosolic) M -0.00310988434095934 Carbonic Anhydrase (Cytosolic) BS 0.0
# NADP-ME M 0.0 NADP-ME BS 0.0
# Biomass M:  0.0 Biomass BS 0.0
# Phloem M:  0.0 Phloem BS 0.032462258256360545
# co2 consumption M 1.8325847826717823 co2 consumption BS 0.18325847826717823
# o2 consumption M 2.0145454545454546 o2 consumption BS 0.20145454545454547
# Photosystem II M 0.0 PSII BS 0.0
# PSI M 0.0 PSI BS 0.0
# PPFD M:  0.0 PPFD BS:  0.0
# ATP synthesis (stromal) M 0.0 ATP synthase (mit) M 13.763720584637356
# pd_abs_flux:  0.526876538153413

# %%
#

# %% [markdown]
# I think the model can now be used as is.
# Some notable behavior that I'm noticing:
#     - After turning off cofactor cycling none of the following artifacts are observed:
#         - Erroneous ATP generation (w/c continues to be produced beyond 1000 ppfd)
#         - Rubisco activity not plateauing beyond 1000 ppfd
#         - Erroneous water and nitrate intake at higher ppfd
#         - ATP generation now plateaus to around ~150 umol m2/s as opposed to linearly increasing beyond that amount
#             - Atp synthase for mitochondria peaks at lower levels and afterwards is offset by
#         - Oxygen consumption now falls within reasonable levels and does not linearly increase with increased ppfd. No more futile cycling that generates more ATP.
#             - furthermore, Oxygen consumption now caps at around 45 umol m2/s if unbound and then drops sharply with increased ppfd (due to the production of o2 from light reactions)
#             - however, unbinding oxygen consumption causes also a proportional increase in CO2 assimilation and since the objective function I'm using is for the production of photosynthate the model erroneously sets the production too high.
#             -based on Caemmerer's modelling it is expected that O2 consumption could reach that point. However, I'm still confused why increasing Oxygen doesn't correspond with decreased photosynthate output considering that O2 competes with CO2 for Rubisco. I think this is attributable to the fixed constraint that I've used for the vc/vo ratio that isn't linked to PEPC and to other enzymes for example.
#                 - I think it would be more prudent to just set it at the consumption rate set by Lakshmanan et al (2016) which is around 2.216 umol/m-2s. I need to consult with professor Topfer regarding that.
#
# $    -Some other observations include the following:
#         - Sole use of NH4 versus only NO3.
#             - When NO3 is turned off vs NH4 no carbon fixation happens. Bakit kaya?
#             - Multiple lits mention that Rice plants  prefer NH4 vs NO3. However I think it's because I've turned off a nitrogen specific reaction dun sa model to prevent co-factor cycling.
#
#
# - I'll tweak it sometime later. However, the model is perfectly useable as is now
#     - Wala palang subsystems yung model ko. I need to add it in dun sa model curation script. I also need to fix any remaining broken names there to make it uniform.

# %%
#May 6 2022
#I think I need to identify which of the reactions cause the blockage of NO3. 
#I can do this by running the instance above and afterwards using the checked_blocked_reactions function to generate a list of blocked reactions.
#Then afterwards I can compare it with the list of reactions with NO3 as a reactant.

#May 5, 2022

# This code block is to test whether a single iteration works. Maybe I should implement the kinetic constraints by Von Caemmerer to obtain proper 
#proper values? I think that would be a better approach, I think.


with model as m1:

    m1.medium = define_model_medium(m1, co2=29, o2=2.216, ppfd=1000, h=inf, nh4=0, no3=inf)
    turn_off_cofac_cycles(m1)
    add_tissue_constraints(m1)
    add_enzyme_constraints(m1)
    add_ngam_cons(m1, 1000)
    
    #Let's try turning off nga yung RBPC2s


#Constrain O2 intake to 3.312 mmol O2 gcw -1 d-1 ~~ 2.2618 umol O2 m-2 s-1 (from Lakshmanan et al. 2016)
    #Change objective function to mature leaf
    m1.reactions.get_by_id('Straw_Biomass_M').objective_coefficient = 0
    m1.reactions.get_by_id('Straw_Biomass_BS').objective_coefficient = 0
    mm.get_rxn(m1,'DM_Phloem_BS').objective_coefficient = 1
    
    
    sample_fluxes = cobra.flux_analysis.pfba(m1).fluxes
#     sample_fluxes = model.optimize().fluxes
    #Remove thermodynamically infeasible loops
    sample_fluxes = cobra.flux_analysis.loopless_solution(m1, sample_fluxes)
    blocked_rxns = cobra.flux_analysis.find_blocked_reactions(model)
# Out:
# Added model medium
# Successfully turned off cofactor-cycling reactions
# /home/rtsantos3/anaconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# Could not get flux for reaction DCMPKc_BS, setting it to NaN. This is usually due to numerical instability.
# /home/rtsantos3/anaconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# Could not get flux for reaction UDPACGLPc_BS, setting it to NaN. This is usually due to numerical instability.
# /home/rtsantos3/anaconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# Could not get flux for reaction LGTHLc_M, setting it to NaN. This is usually due to numerical instability.
# /home/rtsantos3/anaconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# Could not get flux for reaction ARGSSc_M, setting it to NaN. This is usually due to numerical instability.
# /home/rtsantos3/anaconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# Could not get flux for reaction CTPtr_BS, setting it to NaN. This is usually due to numerical instability.
# /home/rtsantos3/anaconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# Could not get flux for reaction PCHOLPPs_BS, setting it to NaN. This is usually due to numerical instability.
# /home/rtsantos3/anaconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# Could not get flux for reaction SERtr_M, setting it to NaN. This is usually due to numerical instability.
# /home/rtsantos3/anaconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# Could not get flux for reaction ATPSm_M, setting it to NaN. This is usually due to numerical instability.
# Could not get flux for reaction PGLYCPs_BS, setting it to NaN. This is usually due to numerical instability.
# Could not get flux for reaction CATs_BS, setting it to NaN. This is usually due to numerical instability.
# Could not get flux for reaction CMPs_M, setting it to NaN. This is usually due to numerical instability.
# Could not get flux for reaction ATPRc_BS, setting it to NaN. This is usually due to numerical instability.
# Could not get flux for reaction ATDCDc_M, setting it to NaN. This is usually due to numerical instability.
# Could not get flux for reaction ARGDc_BS, setting it to NaN. This is usually due to numerical instability.
# Could not get flux for reaction ADSALs_M, setting it to NaN. This is usually due to numerical instability.

# %%
#May 6 2022
#I think I need to identify which of the reactions cause the blockage of NO3. 
#I can do this by running the instance above and afterwards using the checked_blocked_reactions function to generate a list of blocked reactions.
#Then afterwards I can compare it with the list of reactions with NO3 as a reactant.

#May 5, 2022

# This code block is to test whether a single iteration works. Maybe I should implement the kinetic constraints by Von Caemmerer to obtain proper 
#proper values? I think that would be a better approach, I think.


with model as m1:

    m1.medium = define_model_medium(m1, co2=29, o2=2.216, ppfd=1000, h=inf, nh4=0, no3=inf)
#     turn_off_cofac_cycles(m1)
    add_tissue_constraints(m1)
    add_enzyme_constraints(m1)
    add_ngam_cons(m1, 1000)
    
    #Let's try turning off nga yung RBPC2s


#Constrain O2 intake to 3.312 mmol O2 gcw -1 d-1 ~~ 2.2618 umol O2 m-2 s-1 (from Lakshmanan et al. 2016)
    #Change objective function to mature leaf
    m1.reactions.get_by_id('Straw_Biomass_M').objective_coefficient = 0
    m1.reactions.get_by_id('Straw_Biomass_BS').objective_coefficient = 0
    mm.get_rxn(m1,'DM_Phloem_BS').objective_coefficient = 1
    
    
    sample_fluxes = cobra.flux_analysis.pfba(m1).fluxes
#     sample_fluxes = model.optimize().fluxes
    #Remove thermodynamically infeasible loops
    sample_fluxes = cobra.flux_analysis.loopless_solution(m1, sample_fluxes)
    blocked_rxns_w_cofac = cobra.flux_analysis.find_blocked_reactions(model)
# Out:
# Added model medium
# /home/rtsantos3/anaconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# Could not get flux for reaction FA182r_M, setting it to NaN. This is usually due to numerical instability.
# /home/rtsantos3/anaconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# Could not get flux for reaction FACOAL140x_BS, setting it to NaN. This is usually due to numerical instability.
# /home/rtsantos3/anaconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /home/rtsantos3/anaconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# Could not get flux for reaction SHMTs_M, setting it to NaN. This is usually due to numerical instability.
# Could not get flux for reaction THRts_BS, setting it to NaN. This is usually due to numerical instability.
# Could not get flux for reaction PTORc_BS, setting it to NaN. This is usually due to numerical instability.
# Could not get flux for reaction DM_CYTC(m)_BS, setting it to NaN. This is usually due to numerical instability.
# /home/rtsantos3/anaconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# Could not get flux for reaction PHENMUTc_BS, setting it to NaN. This is usually due to numerical instability.
# /home/rtsantos3/anaconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# Could not get flux for reaction CHOLPCTr_M, setting it to NaN. This is usually due to numerical instability.
# /home/rtsantos3/anaconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# Could not get flux for reaction GLUKAc_M, setting it to NaN. This is usually due to numerical instability.
# /home/rtsantos3/anaconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# Could not get flux for reaction DM_BRSNL(c)_M, setting it to NaN. This is usually due to numerical instability.
# Could not get flux for reaction DICtm_BS, setting it to NaN. This is usually due to numerical instability.
# /home/rtsantos3/anaconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# Could not get flux for reaction AGPATr_BS, setting it to NaN. This is usually due to numerical instability.
# /home/rtsantos3/anaconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# Could not get flux for reaction VALATm_BS, setting it to NaN. This is usually due to numerical instability.
# Could not get flux for reaction PPASc_BS, setting it to NaN. This is usually due to numerical instability.
# Could not get flux for reaction H2Stm_M, setting it to NaN. This is usually due to numerical instability.
# Could not get flux for reaction PPCDCc_M, setting it to NaN. This is usually due to numerical instability.
# Could not get flux for reaction ATPAPc_BS, setting it to NaN. This is usually due to numerical instability.
# Could not get flux for reaction DM_COUMN(c)_BS, setting it to NaN. This is usually due to numerical instability.
# /home/rtsantos3/anaconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# Could not get flux for reaction CYTDc_M, setting it to NaN. This is usually due to numerical instability.
# Could not get flux for reaction APPRTs_BS, setting it to NaN. This is usually due to numerical instability.
# Could not get flux for reaction DCMPKc_M, setting it to NaN. This is usually due to numerical instability.
# Could not get flux for reaction FACOAL183r_M, setting it to NaN. This is usually due to numerical instability.
# Could not get flux for reaction SOXs_M, setting it to NaN. This is usually due to numerical instability.
# Could not get flux for reaction MI14PPc_M, setting it to NaN. This is usually due to numerical instability.

# %%
print_summary(sample_fluxes.to_frame())
# Out:
# rbcl M cell:  0.0 rbcl BS cell:  0.0
# rbcl M cell (photorespiration) 0.0 rbcl BS cell (PR) 0.0
# vc/vo M: nan vc/vo BS: nan
# RBPC2s_M 0.0 RBPC2s_BS 0.0
# PEPC M 0.0 PEPC BS 0.0
# Carbonic Anhydrase (Cytosolic) M 0.0 Carbonic Anhydrase (Cytosolic) BS 0.0
# NADP-ME M 0.0 NADP-ME BS 0.0
# Biomass M:  0.0 Biomass BS 0.0
# Phloem M:  0.0 Phloem BS 0.0
# co2 consumption M 0.0 co2 consumption BS 0.0
# o2 consumption M 1.9406818181818177 o2 consumption BS 0.19406818181818178
# Photosystem II M 0.776272727272727 PSII BS 0.0776272727272727
# PSI M 0.776272727272727 PSI BS 0.07762727272727271
# PPFD M:  6.4233527893932125 PPFD BS:  0.6423352789393213
# ATP synthesis (stromal) M 1.0350303030303027 ATP synthase (mit) M 6.727696969696971
# pd_abs_flux:  0.0
# <ipython-input-3-883c58f7d54c>:271: RuntimeWarning: invalid value encountered in double_scalars
#   print('vc/vo M:', sample_fluxes['RBPCs_M']/sample_fluxes['RBPOs_M'], 'vc/vo BS:', sample_fluxes['RBPCs_BS']/sample_fluxes['RBPOs_BS'])

# %%
print('with cofactor-cycling reactions: ', len(blocked_rxns_w_cofac))
print('w/o cofactor-cycling reactions: ', len(blocked_rxns))
# Out:
# with cofactor-cycling reactions:  1600
# w/o cofactor-cycling reactions:  2529

# %%
# Out:
# ['22HCAM43Rc_BS',
#  '22HCAM43Rc_M',
#  '22HCAMHc_BS',
#  '22HCAMHc_M',
#  '23DDHBDHs_BS',
#  '23DDHBDHs_M',
#  '26dap-Mts_BS',
#  '26dap-Mts_M',
#  '2AHHMPtm_BS',
#  '2AHHMPtm_M',
#  '2OXOADPTm_BS',
#  '2OXOADPTm_M',
#  '3DSPHRr_BS',
#  '3DSPHRr_M',
#  '3HAD100m_BS',
#  '3HAD100m_M',
#  '3HAD120m_BS',
#  '3HAD120m_M',
#  '3HAD140m_BS',
#  '3HAD140m_M',
#  '3HAD160m_BS',
#  '3HAD160m_M',
#  '3HAD180m_BS',
#  '3HAD180m_M',
#  '3HAD40m_BS',
#  '3HAD40m_M',
#  '3HAD60m_BS',
#  '3HAD60m_M',
#  '3HAD80m_BS',
#  '3HAD80m_M',
#  '3HCD100m_BS',
#  '3HCD100m_M',
#  '3HCD120m_BS',
#  '3HCD120m_M',
#  '3HCD140m_BS',
#  '3HCD140m_M',
#  '3HCD160m_BS',
#  '3HCD160m_M',
#  '3HCD280cr_BS',
#  '3HCD280cr_M',
#  '3HCD300r_BS',
#  '3HCD300r_M',
#  '3HCD60m_BS',
#  '3HCD60m_M',
#  '3HCD80m_BS',
#  '3HCD80m_M',
#  '3HGMELc_BS',
#  '3HGMELc_M',
#  '3HGNORc_BS',
#  '3HGNORc_M',
#  '3HPCOAHYDc_BS',
#  '3HPCOAHYDc_M',
#  '3HPCOAtm_BS',
#  '3HPCOAtm_M',
#  '3HPPDc_BS',
#  '3HPPDc_M',
#  '3OAR100m_BS',
#  '3OAR100m_M',
#  '3OAR120m_BS',
#  '3OAR120m_M',
#  '3OAR140m_BS',
#  '3OAR140m_M',
#  '3OAR160m_BS',
#  '3OAR160m_M',
#  '3OAR180m_BS',
#  '3OAR180m_M',
#  '3OAR40m_BS',
#  '3OAR40m_M',
#  '3OAR60m_BS',
#  '3OAR60m_M',
#  '3OAR80m_BS',
#  '3OAR80m_M',
#  '3OAS100m_BS',
#  '3OAS100m_M',
#  '3OAS120m_BS',
#  '3OAS120m_M',
#  '3OAS140m_BS',
#  '3OAS140m_M',
#  '3OAS160m_BS',
#  '3OAS160m_M',
#  '3OAS180m_BS',
#  '3OAS180m_M',
#  '3OAS60m_BS',
#  '3OAS60m_M',
#  '3OAS80m_BS',
#  '3OAS80m_M',
#  '3OCR100m_BS',
#  '3OCR100m_M',
#  '3OCR120m_BS',
#  '3OCR120m_M',
#  '3OCR140m_BS',
#  '3OCR140m_M',
#  '3OCR160m_BS',
#  '3OCR160m_M',
#  '3OCR280r_BS',
#  '3OCR280r_M',
#  '3OCR300r_BS',
#  '3OCR300r_M',
#  '3OCR60m_BS',
#  '3OCR60m_M',
#  '3OCR80m_BS',
#  '3OCR80m_M',
#  '3OCS100m_BS',
#  '3OCS100m_M',
#  '3OCS120m_BS',
#  '3OCS120m_M',
#  '3OCS140m_BS',
#  '3OCS140m_M',
#  '3OCS160m_BS',
#  '3OCS160m_M',
#  '3OCS280r_BS',
#  '3OCS280r_M',
#  '3OCS300r_BS',
#  '3OCS300r_M',
#  '3OCS60m_BS',
#  '3OCS60m_M',
#  '3OCS80m_BS',
#  '3OCS80m_M',
#  '3OOPCOALx_BS',
#  '3OOPCOALx_M',
#  '3OPHBH1m_BS',
#  '3OPHBH1m_M',
#  '3OPHBH2m_BS',
#  '3OPHBH2m_M',
#  '3SPYRSPm_BS',
#  '3SPYRSPm_M',
#  '3SPYRSPs_BS',
#  '3SPYRSPs_M',
#  '4ABZtm_BS',
#  '4ABZtm_M',
#  '4ABZts_BS',
#  '4ABZts_M',
#  '4HTHBPTHLc_BS',
#  '4HTHBPTHLc_M',
#  '5FTHFtm_BS',
#  '5FTHFtm_M',
#  '5FTHFts_BS',
#  '5FTHFts_M',
#  '5MTHFts_BS',
#  '5MTHFts_M',
#  '7DHCSRc_BS',
#  '7DHCSRc_M',
#  'AASADc_BS',
#  'AASADc_M',
#  'AATAc_BS',
#  'AATAc_M',
#  'AATCm_BS',
#  'AATCm_M',
#  'AATCs_BS',
#  'AATCs_M',
#  'AAs_BS',
#  'AAs_M',
#  'ABSALDOs_BS',
#  'ABSALDOs_M',
#  'ABSH1s_BS',
#  'ABSH1s_M',
#  'ABSH2s_BS',
#  'ABSH2s_M',
#  'ABTA2m_BS',
#  'ABTA2m_M',
#  'ACACTm_BS',
#  'ACACTm_M',
#  'ACACTs_BS',
#  'ACACTs_M',
#  'ACACt2m_BS',
#  'ACACt2m_M',
#  'ACAROTORs_BS',
#  'ACAROTORs_M',
#  'ACCATm_BS',
#  'ACCATm_M',
#  'ACCOAC_OSAc_BS',
#  'ACCOAC_OSAc_M',
#  'ACDOc_BS',
#  'ACDOc_M',
#  'ACGAM6PSic_BS',
#  'ACGAM6PSic_M',
#  'ACGPIDc_BS',
#  'ACGPIDc_M',
#  'ACHBSs_BS',
#  'ACHBSs_M',
#  'ACHMSSCc_BS',
#  'ACHMSSCc_M',
#  'ACHMSSCs_BS',
#  'ACHMSSCs_M',
#  'ACHYSLc_BS',
#  'ACHYSLc_M',
#  'ACNMLc_BS',
#  'ACNMLc_M',
#  'ACOATAm_BS',
#  'ACOATAm_M',
#  'ACPCDAc_BS',
#  'ACPCDAc_M',
#  'ACPCSc_BS',
#  'ACPCSc_M',
#  'ACPC_OSm_BS',
#  'ACPC_OSm_M',
#  'ACPC_OSs_BS',
#  'ACPC_OSs_M',
#  'ACRSPc_BS',
#  'ACRSPc_M',
#  'ACSERLc_BS',
#  'ACSERLc_M',
#  'ACSERLs_BS',
#  'ACSERLs_M',
#  'ACSERtmi_BS',
#  'ACSERtmi_M',
#  'ADCLs_BS',
#  'ADCLs_M',
#  'ADCSs_BS',
#  'ADCSs_M',
#  'ADECYCc_BS',
#  'ADECYCc_M',
#  'ADENm_BS',
#  'ADENm_M',
#  'ADK1m_BS',
#  'ADK1m_M',
#  'ADMATs_BS',
#  'ADMATs_M',
#  'ADPARTs_BS',
#  'ADPARTs_M',
#  'ADSALs_BS',
#  'ADSALs_M',
#  'ADSKc_BS',
#  'ADSKc_M',
#  'ADSSs_BS',
#  'ADSSs_M',
#  'AGATs_BS',
#  'AGATs_M',
#  'AGATx_BS',
#  'AGATx_M',
#  'AGMTc_BS',
#  'AGMTc_M',
#  'AGPATm_BS',
#  'AGPATm_M',
#  'AGPATs_BS',
#  'AGPATs_M',
#  'AHCYSNc_BS',
#  'AHCYSNc_M',
#  'AHSLs_BS',
#  'AHSLs_M',
#  'AIALs_BS',
#  'AIALs_M',
#  'AKGCITtm_BS',
#  'AKGCITtm_M',
#  'AKGDHam1m_BS',
#  'AKGDHam1m_M',
#  'AKGDHam2m_BS',
#  'AKGDHam2m_M',
#  'AKGDHe2m_BS',
#  'AKGDHe2m_M',
#  'AKGICITtm_BS',
#  'AKGICITtm_M',
#  'ALAALAc_BS',
#  'ALAALAc_M',
#  'ALAATm_BS',
#  'ALAATm_M',
#  'ALAATs_BS',
#  'ALAATs_M',
#  'ALABATc_BS',
#  'ALABATc_M',
#  'ALARc_BS',
#  'ALARc_M',
#  'ALATc_BS',
#  'ALATc_M',
#  'ALATm_BS',
#  'ALATm_M',
#  'ALATs_BS',
#  'ALATs_M',
#  'ALAtx_BS',
#  'ALAtx_M',
#  'ALCD25c_BS',
#  'ALCD25c_M',
#  'ALCDx2c_BS',
#  'ALCDx2c_M',
#  'ALFAACT200r_BS',
#  'ALFAACT200r_M',
#  'ALFAACT220r_BS',
#  'ALFAACT220r_M',
#  'ALFACOAR200r_BS',
#  'ALFACOAR200r_M',
#  'ALFACOAR220r_BS',
#  'ALFACOAR220r_M',
#  'ALFACOAR280r_BS',
#  'ALFACOAR280r_M',
#  'ALFACOAR300r_BS',
#  'ALFACOAR300r_M',
#  'ALOCs_BS',
#  'ALOCs_M',
#  'ALTNDAc_BS',
#  'ALTNDAc_M',
#  'AMCLc_BS',
#  'AMCLc_M',
#  'AMCPCOc_BS',
#  'AMCPCOc_M',
#  'AMETAOTc_BS',
#  'AMETAOTc_M',
#  'AMETJASMTc_BS',
#  'AMETJASMTc_M',
#  'AMETt2m_BS',
#  'AMETt2m_M',
#  'AMETt2r_BS',
#  'AMETt2r_M',
#  'AMID3c_BS',
#  'AMID3c_M',
#  'AMPORc_BS',
#  'AMPORc_M',
#  'ANTPPTs_BS',
#  'ANTPPTs_M',
#  'AONSc_BS',
#  'AONSc_M',
#  'AOOAs_BS',
#  'AOOAs_M',
#  'APLm_BS',
#  'APLm_M',
#  'APLs_BS',
#  'APLs_M',
#  'APPRTs_BS',
#  'APPRTs_M',
#  'ARAB5PIc_BS',
#  'ARAB5PIc_M',
#  'ARABFv_BS',
#  'ARABFv_M',
#  'ARG2MO_BS',
#  'ARG2MO_M',
#  'ARGCAVs_BS',
#  'ARGCAVs_M',
#  'ARGDc_BS',
#  'ARGNc_BS',
#  'ARGNc_M',
#  'ARGOAT1s_BS',
#  'ARGOAT1s_M',
#  'ARGSL2s_BS',
#  'ARGSL2s_M',
#  'ARGSSc_M',
#  'ARGTc_BS',
#  'ARGTc_M',
#  'ARGTs_BS',
#  'ARGTs_M',
#  'ARGt2s_BS',
#  'ARGt2s_M',
#  'ASNS1c_BS',
#  'ASNS1c_M',
#  'ASNS1s_BS',
#  'ASNS1s_M',
#  'ASNTLc_BS',
#  'ASNTLc_M',
#  'ASNTLm_BS',
#  'ASNTLm_M',
#  'ASNTLs_BS',
#  'ASNTLs_M',
#  'ASNtm_BS',
#  'ASNtm_M',
#  'ASPALs_BS',
#  'ASPALs_M',
#  'ASPCT1c_BS',
#  'ASPCT1c_M',
#  'ASPCT2s_BS',
#  'ASPCT2s_M',
#  'ASPO1s_BS',
#  'ASPO1s_M',
#  'ASPTAm_BS',
#  'ASPTAm_M',
#  'ASPTLc_BS',
#  'ASPTLc_M',
#  'ASPTLm_BS',
#  'ASPTLm_M',
#  'ASPTLs_BS',
#  'ASPTLs_M',
#  'ATAHc_BS',
#  'ATAHc_M',
#  'ATDADc_BS',
#  'ATDADc_M',
#  'ATDAMc_BS',
#  'ATDAMc_M',
#  'ATDCDc_M',
#  'ATDGDc_BS',
#  'ATDGDc_M',
#  'ATDGMc_BS',
#  'ATDGMc_M',
#  'ATDTDc_BS',
#  'ATDTDc_M',
#  'ATNAHc_BS',
#  'ATNAHc_M',
#  'ATNSs_BS',
#  'ATNSs_M',
#  'ATP2ts_BS',
#  'ATP2ts_M',
#  'ATPRc_BS',
#  'ATPRc_M',
#  'ATPSm_M',
#  'ATPSv_BS',
#  'ATPSv_M',
#  'ATSc_BS',
#  'ATSc_M',
#  'ATUDv_BS',
#  'ATUDv_M',
#  'AUNORs_BS',
#  'AUNORs_M',
#  'AUSs_BS',
#  'AUSs_M',
#  'AVESTSc_BS',
#  'AVESTSc_M',
#  'B2COAtx_BS',
#  'B2COAtx_M',
#  'B3GALT3c_BS',
#  'B3GALT3c_M',
#  'BCAROTHs_BS',
#  'BCAROTHs_M',
#  'BCPTXANHs_BS',
#  'BCPTXANHs_M',
#  'BCTA3m_BS',
#  'BCTA3m_M',
#  'BCTA3s_BS',
#  'BCTA3s_M',
#  'BDMTc_BS',
#  'BDMTc_M',
#  'BETAHHs_BS',
#  'BETAHHs_M',
#  'BETALDDHc_BS',
#  'BETALDDHc_M',
#  'BETHCYSs_BS',
#  'BETHCYSs_M',
#  'BFFSv_BS',
#  'BFFSv_M',
#  'BG1c_BS',
#  'BG1c_M',
#  'BG2c_BS',
#  'BG2c_M',
#  'BRS1c_BS',
#  'BRS1c_M',
#  'BRS2c_BS',
#  'BRS2c_M',
#  'BRS3c_BS',
#  'BRS3c_M',
#  'BRS4c_BS',
#  'BRS4c_M',
#  'BRS5c_BS',
#  'BRS5c_M',
#  'BTNSc_BS',
#  'BTNSc_M',
#  'C14STRc_BS',
#  'C14STRc_M',
#  'C22SDc_BS',
#  'C22SDc_M',
#  'C3STDH1c_BS',
#  'C3STDH1c_M',
#  'C3STDH2c_BS',
#  'C3STDH2c_M',
#  'C3STKR1c_BS',
#  'C3STKR1c_M',
#  'C3STKR2c_BS',
#  'C3STKR2c_M',
#  'C4STMO1c_BS',
#  'C4STMO1c_M',
#  'C4STMO2c_BS',
#  'C4STMO2c_M',
#  'C8STIc_BS',
#  'C8STIc_M',
#  'CAAPc_BS',
#  'CAAPc_M',
#  'CAGHc_BS',
#  'CAGHc_M',
#  'CALANc_BS',
#  'CALANc_M',
#  'CALASc_BS',
#  'CALASc_M',
#  'CAM43Rc_BS',
#  'CAM43Rc_M',
#  'CAMPST43EHc_BS',
#  'CAMPST43EHc_M',
#  'CAMPSTFTc_BS',
#  'CAMPSTFTc_M',
#  'CAMPSTHc_BS',
#  'CAMPSTHc_M',
#  'CAMPSTLHc_BS',
#  'CAMPSTLHc_M',
#  'CAMPSTc_BS',
#  'CAMPSTc_M',
#  'CAROTDSs_BS',
#  'CAROTDSs_M',
#  'CAROTEMOs_BS',
#  'CAROTEMOs_M',
#  'CATs_BS',
#  'CAVNS2s_BS',
#  'CAVNS2s_M',
#  'CBGL1s_BS',
#  'CBGL1s_M',
#  'CBGL2s_BS',
#  'CBGL2s_M',
#  'CDPDAGSm_BS',
#  'CDPDAGSm_M',
#  'CDPDAGtm_BS',
#  'CDPDAGtm_M',
#  'CDPDAGtr_BS',
#  'CDPDAGtr_M',
#  'CDPMEKs_BS',
#  'CDPMEKs_M',
#  'CHITNc_BS',
#  'CHITNc_M',
#  'CHLAOs_BS',
#  'CHLAOs_M',
#  'CHLASEs_BS',
#  'CHLASEs_M',
#  'CHLASNs_BS',
#  'CHLASNs_M',
#  'CHLBSEs_BS',
#  'CHLBSEs_M',
#  'CHLBSNs_BS',
#  'CHLBSNs_M',
#  'CHLDAOs_BS',
#  'CHLDAOs_M',
#  'CHLOR410s_BS',
#  'CHLOR410s_M',
#  'CHLOR430s_BS',
#  'CHLOR430s_M',
#  'CHLOR450s_BS',
#  'CHLOR450s_M',
#  'CHLOR470s_BS',
#  'CHLOR470s_M',
#  'CHLOR490s_BS',
#  'CHLOR490s_M',
#  'CHLOR510s_BS',
#  'CHLOR510s_M',
#  'CHLOR530s_BS',
#  'CHLOR530s_M',
#  'CHLOR550s_BS',
#  'CHLOR550s_M',
#  'CHLOR570s_BS',
#  'CHLOR570s_M',
#  'CHLOR590s_BS',
#  'CHLOR590s_M',
#  'CHLOR610s_BS',
#  'CHLOR610s_M',
#  'CHLOR630s_BS',
#  'CHLOR630s_M',
#  'CHLOR650s_BS',
#  'CHLOR650s_M',
#  'CHLOR670s_BS',
#  'CHLOR670s_M',
#  'CHLOR690s_BS',
#  'CHLOR690s_M',
#  'CHLSDDIc_BS',
#  'CHLSDDIc_M',
#  'CHLSTIc_BS',
#  'CHLSTIc_M',
#  'CHLSTRc_BS',
#  'CHLSTRc_M',
#  'CHOLMOs_BS',
#  'CHOLMOs_M',
#  'CHOLPCTs_BS',
#  'CHOLPCTs_M',
#  'CHOLtr_BS',
#  'CHOLtr_M',
#  'CHOLts_BS',
#  'CHOLts_M',
#  'CHORLm_BS',
#  'CHORLm_M',
#  'CHORtm_BS',
#  'CHORtm_M',
#  'CHORts_BS',
#  'CHORts_M',
#  'CHUMSc_BS',
#  'CHUMSc_M',
#  'CINNOHDHc_BS',
#  'CINNOHDHc_M',
#  'CITRtm_BS',
#  'CITRtm_M',
#  'CKDH1c_BS',
#  'CKDH1c_M',
#  'CKDH2c_BS',
#  'CKDH2c_M',
#  'CKDH3c_BS',
#  'CKDH3c_M',
#  'CKDOtm_BS',
#  'CKDOtm_M',
#  'CKGT1c_BS',
#  'CKGT1c_M',
#  'CKGT2c_BS',
#  'CKGT2c_M',
#  'CKGT3c_BS',
#  'CKGT3c_M',
#  'CKGT4c_BS',
#  'CKGT4c_M',
#  'CKGT5c_BS',
#  'CKGT5c_M',
#  'CKGT6c_BS',
#  'CKGT6c_M',
#  'CKGT7c_BS',
#  'CKGT7c_M',
#  'CKGT8c_BS',
#  'CKGT8c_M',
#  'CKOGT1c_BS',
#  'CKOGT1c_M',
#  'CKOGT2c_BS',
#  'CKOGT2c_M',
#  'CKOGT3c_BS',
#  'CKOGT3c_M',
#  'CKPc_BS',
#  'CKPc_M',
#  'CKTHs_BS',
#  'CKTHs_M',
#  'CLPNSm_BS',
#  'CLPNSm_M',
#  'CMPKs_BS',
#  'CMPKs_M',
#  'CMPSASc_BS',
#  'CMPSASc_M',
#  'CMPs_M',
#  'CNLNSs_BS',
#  'CNLNSs_M',
#  'COA(h)ts_BS',
#  'COA(h)ts_M',
#  'COA(h)tx_BS',
#  'COA(h)tx_M',
#  'COAtm_BS',
#  'COAtm_M',
#  'CONCMTc_BS',
#  'CONCMTc_M',
#  'CONOHDHc_BS',
#  'CONOHDHc_M',
#  'COQ3m_BS',
#  'COQ3m_M',
#  'COQ5m_BS',
#  'COQ5m_M',
#  'COQ6m_BS',
#  'COQ6m_M',
#  'COQ7m_BS',
#  'COQ7m_M',
#  'CPP1Os_BS',
#  'CPP1Os_M',
#  'CPPPGOs_BS',
#  'CPPPGOs_M',
#  'CPTXANORs_BS',
#  'CPTXANORs_M',
#  'CSTLIc_BS',
#  'CSTLIc_M',
#  'CTPCHc_BS',
#  'CTPCHc_M',
#  'CTPtm_BS',
#  'CTPtm_M',
#  'CTPtr_BS',
#  'CYARTMTc_BS',
#  'CYARTMTc_M',
#  'CYECYCIc_BS',
#  'CYECYCIc_M',
#  'CYEUOLSc_BS',
#  'CYEUOLSc_M',
#  'CYSATm_BS',
#  'CYSATm_M',
#  'CYSATs_BS',
#  'CYSATs_M',
#  'CYSGLYv_BS',
#  'CYSGLYv_M',
#  'CYSSc_BS',
#  'CYSSc_M',
#  'CYSSm_BS',
#  'CYSSm_M',
#  'CYSSs_BS',
#  'CYSSs_M',
#  'CYSTGLs_BS',
#  'CYSTGLs_M',
#  'CYSTLc_BS',
#  'CYSTLc_M',
#  'CYSTLm_BS',
#  'CYSTLm_M',
#  'CYSTLs_BS',
#  'CYSTLs_M',
#  'CYSTS_Gs_BS',
#  'CYSTS_Gs_M',
#  'CYSt2m_BS',
#  'CYSt2m_M',
#  'CYSts_BS',
#  'CYSts_M',
#  'CYStv_BS',
#  'CYStv_M',
#  'CYTTHs_BS',
#  'CYTTHs_M',
#  'Coleoptile_Biomass_BS',
#  'Coleoptile_Biomass_M',
#  'D24STR1c_BS',
#  'D24STR1c_M',
#  'D24STRc_BS',
#  'D24STRc_M',
#  'DADTc_BS',
#  'DADTc_M',
#  'DAGCPs_BS',
#  'DAGCPs_M',
#  'DAMPHc_BS',
#  'DAMPHc_M',
#  'DAPATs_BS',
#  'DAPATs_M',
#  'DAPDCs_BS',
#  'DAPDCs_M',
#  'DAPEPs_BS',
#  'DAPEPs_M',
#  'DCMPKc_BS',
#  'DEDOLDPSATc_BS',
#  'DEDOLDPSATc_M',
#  'DEDOLDPSc_BS',
#  'DEDOLDPSc_M',
#  'DGDGSs_BS',
#  'DGDGSs_M',
#  'DGDTc_BS',
#  'DGDTc_M',
#  'DGSNHc_BS',
#  'DGSNHc_M',
#  'DGSNPP_BS',
#  'DGSNPP_M',
#  'DGSNTTPc_BS',
#  'DGSNTTPc_M',
#  'DHAD-bs_BS',
#  'DHAD-bs_M',
#  'DHAD-ps_BS',
#  'DHAD-ps_M',
#  'DHADm_BS',
#  'DHADm_M',
#  'DHAVESTRc_BS',
#  'DHAVESTRc_M',
#  'DHAVESTSc_BS',
#  'DHAVESTSc_M',
#  'DHDPSs_BS',
#  'DHDPSs_M',
#  'DHDXSTNOc_BS',
#  'DHDXSTNOc_M',
#  'DHEPISTRc_BS',
#  'DHEPISTRc_M',
#  'DHEPISTSc_BS',
#  'DHEPISTSc_M',
#  'DHFRc_BS',
#  'DHFRc_M',
#  'DHFRm_BS',
#  'DHFRm_M',
#  'DHFSm_BS',
#  'DHFSm_M',
#  'DHNPTAc_BS',
#  'DHNPTAc_M',
#  'DHOPBMTm_BS',
#  'DHOPBMTm_M',
#  'DHPAHs_BS',
#  'DHPAHs_M',
#  'DHPRs_BS',
#  'DHPRs_M',
#  'DHPRys_BS',
#  'DHPRys_M',
#  'DHPSm_BS',
#  'DHPSm_M',
#  'DHRT(2mbcoa)_BS',
#  'DHRT(2mbcoa)_M',
#  'DHRT(ibcoa)_BS',
#  'DHRT(ibcoa)_M',
#  'DHRT(ivcoa)_BS',
#  'DHRT(ivcoa)_M',
#  'DHYDRO1016tr_BS',
#  'DHYDRO1016tr_M',
#  'DHYDRO1018tr_BS',
#  'DHYDRO1018tr_M',
#  'DHZts_BS',
#  'DHZts_M',
#  'DKSTIc_BS',
#  'DKSTIc_M',
#  'DLDLBTs_BS',
#  'DLDLBTs_M',
#  'DMATTm_BS',
#  'DMATTm_M',
#  'DMPPS1s_BS',
#  'DMPPS1s_M',
#  'DMPPS2s_BS',
#  'DMPPS2s_M',
#  'DMTGDHs_BS',
#  'DMTGDHs_M',
#  'DM_12O9DD(s)_BS',
#  'DM_12O9DD(s)_M',
#  'DM_ACRTNL(s)_BS',
#  'DM_ACRTNL(s)_M',
#  'DM_ADE(s)_BS',
#  'DM_ADE(s)_M',
#  'DM_AMOB(c)_BS',
#  'DM_AMOB(c)_M',
#  'DM_AMYGD(c)_BS',
#  'DM_AMYGD(c)_M',
#  'DM_BILIVERD(s)_BS',
#  'DM_BILIVERD(s)_M',
#  'DM_BRSNL(c)_BS',
#  'DM_BRSNL(c)_M',
#  'DM_BTN(c)_BS',
#  'DM_BTN(c)_M',
#  'DM_C-ZTN7G(c)_BS',
#  'DM_C-ZTN7G(c)_M',
#  'DM_C-ZTN9G(c)_BS',
#  'DM_C-ZTN9G(c)_M',
#  'DM_CADAVERINE(s)_BS',
#  'DM_CADAVERINE(s)_M',
#  'DM_CAMP(c)_BS',
#  'DM_CAMP(c)_M',
#  'DM_CAMPSTFER(c)_BS',
#  'DM_CAMPSTFER(c)_M',
#  'DM_CHSTEROL(c)_BS',
#  'DM_CHSTEROL(c)_M',
#  'DM_CHUMU(c)_BS',
#  'DM_CHUMU(c)_M',
#  'DM_CPP1(s)_BS',
#  'DM_CPP1(s)_M',
#  'DM_CYTC(m)_BS',
#  'DM_CYTC(m)_M',
#  'DM_CYTC(s)_BS',
#  'DM_CYTC(s)_M',
#  'DM_DHBZCAROT(s)_BS',
#  'DM_DHBZCAROT(s)_M',
#  'DM_DHZ7G(c)_BS',
#  'DM_DHZ7G(c)_M',
#  'DM_DHZ9G(c)_BS',
#  'DM_DHZ9G(c)_M',
#  'DM_DHZG(c)_BS',
#  'DM_DHZG(c)_M',
#  'DM_DVCHLDA(s)_BS',
#  'DM_DVCHLDA(s)_M',
#  'DM_ENTB(s)_BS',
#  'DM_ENTB(s)_M',
#  'DM_ERGTOL(c)_BS',
#  'DM_ERGTOL(c)_M',
#  'DM_ETHYLENE(c)_BS',
#  'DM_ETHYLENE(c)_M',
#  'DM_HUMU(c)_BS',
#  'DM_HUMU(c)_M',
#  'DM_IPADNE7G(c)_BS',
#  'DM_IPADNE7G(c)_M',
#  'DM_IPADNE9G(c)_BS',
#  'DM_IPADNE9G(c)_M',
#  'DM_JASILE(c)_BS',
#  'DM_JASILE(c)_M',
#  'DM_JASLEU(c)_BS',
#  'DM_JASLEU(c)_M',
#  'DM_JASVAL(c)_BS',
#  'DM_JASVAL(c)_M',
#  'DM_LACXAN(s)_BS',
#  'DM_LACXAN(s)_M',
#  'DM_LUTEIN(c)_BS',
#  'DM_LUTEIN(c)_M',
#  'DM_PHAS(s)_BS',
#  'DM_PHAS(s)_M',
#  'DM_PHOM(c)_BS',
#  'DM_PHOM(c)_M',
#  'DM_Phloem_BS',
#  'DM_Phloem_M',
#  'DM_SCLGN(c)_BS',
#  'DM_SCLGN(c)_M',
#  'DM_SQ12DGR_OS(s)_BS',
#  'DM_SQ12DGR_OS(s)_M',
#  'DM_SRNTN(c)_BS',
#  'DM_SRNTN(c)_M',
#  'DM_STCSD(c)_BS',
#  'DM_STCSD(c)_M',
#  'DM_T-ZTN7G(c)_BS',
#  'DM_T-ZTN7G(c)_M',
#  'DM_T-ZTN9G(c)_BS',
#  'DM_T-ZTN9G(c)_M',
#  'DM_T-ZTNG(c)_BS',
#  'DM_T-ZTNG(c)_M',
#  'DM_T-ZTNR(c)_BS',
#  'DM_T-ZTNR(c)_M',
#  'DM_TRPN(c)_BS',
#  'DM_TRPN(c)_M',
#  'DM_ZTNG(c)_BS',
#  'DM_ZTNG(c)_M',
#  'DNMPPAc_BS',
#  'DNMPPAc_M',
#  'DNTPPAc_BS',
#  'DNTPPAc_M',
#  'DOLASNTc_BS',
#  'DOLASNTc_M',
#  'DOLDPPc_BS',
#  'DOLDPPc_M',
#  'DOLKc_BS',
#  'DOLKc_M',
#  'DOLPGT1c_BS',
#  'DOLPGT1c_M',
#  'DOLPGT2c_BS',
#  'DOLPGT2c_M',
#  'DOLPGT3c_BS',
#  'DOLPGT3c_M',
#  'DOLPMT1c_BS',
#  'DOLPMT1c_M',
#  'DOLPMTc_BS',
#  'DOLPMTc_M',
#  'DPCOAKc_BS',
#  'DPCOAKc_M',
#  'DPRm_BS',
#  'DPRm_M',
#  'DSTRc_BS',
#  'DSTRc_M',
#  'DTBTSc_BS',
#  'DTBTSc_M',
#  'DTDPDHRRc_BS',
#  'DTDPDHRRc_M',
#  'DTMPKc_BS',
#  'DTMPKc_M',
#  'DVCHLDRs_BS',
#  'DVCHLDRs_M',
#  'DVCHLOR410s_BS',
#  'DVCHLOR410s_M',
#  'DVCHLOR430s_BS',
#  'DVCHLOR430s_M',
#  'DVCHLOR450s_BS',
#  'DVCHLOR450s_M',
#  'DVCHLOR470s_BS',
#  'DVCHLOR470s_M',
#  'DVCHLOR490s_BS',
#  'DVCHLOR490s_M',
#  'DVCHLOR510s_BS',
#  'DVCHLOR510s_M',
#  'DVCHLOR530s_BS',
#  'DVCHLOR530s_M',
#  'DVCHLOR550s_BS',
#  'DVCHLOR550s_M',
#  'DVCHLOR570s_BS',
#  'DVCHLOR570s_M',
#  'DVCHLOR590s_BS',
#  'DVCHLOR590s_M',
#  'DVCHLOR610s_BS',
#  'DVCHLOR610s_M',
#  'DVCHLOR630s_BS',
#  'DVCHLOR630s_M',
#  'DVCHLOR650s_BS',
#  'DVCHLOR650s_M',
#  'DVCHLOR670s_BS',
#  'DVCHLOR670s_M',
#  'DVCHLOR690s_BS',
#  'DVCHLOR690s_M',
#  'DVPCHLDRs_BS',
#  'DVPCHLDRs_M',
#  'DXCSTNMOc_BS',
#  'DXCSTNMOc_M',
#  'DXPRIis_BS',
#  'DXPRIis_M',
#  'DXPSs_BS',
#  'DXPSs_M',
#  'DXSTNORc_BS',
#  'DXSTNORc_M',
#  'DXSTNOc_BS',
#  'DXSTNOc_M',
#  'DXTSTOc_BS',
#  'DXTSTOc_M',
#  'DXTSTc_BS',
#  'DXTSTc_M',
#  'EAR100ym_BS',
#  'EAR100ym_M',
#  'EAR120ym_BS',
#  'EAR120ym_M',
#  'EAR140ym_BS',
#  'EAR140ym_M',
#  'EAR160ym_BS',
#  'EAR160ym_M',
#  'EAR180ym_BS',
#  'EAR180ym_M',
#  'EAR40ym_BS',
#  'EAR40ym_M',
#  'EAR60ym_BS',
#  'EAR60ym_M',
#  'EAR80ym_BS',
#  'EAR80ym_M',
#  'ECAROTHs_BS',
#  'ECAROTHs_M',
#  'ECH1m_BS',
#  'ECH1m_M',
#  'ECH2m_BS',
#  'ECH2m_M',
#  'ECR100ym_BS',
#  'ECR100ym_M',
#  'ECR120ym_BS',
#  'ECR120ym_M',
#  'ECR140ym_BS',
#  'ECR140ym_M',
#  'ECR160ym_BS',
#  'ECR160ym_M',
#  'ECR280yr_BS',
#  'ECR280yr_M',
#  'ECR300yr_BS',
#  'ECR300yr_M',
#  'ECR60ym_BS',
#  'ECR60ym_M',
#  'ECR80ym_BS',
#  'ECR80ym_M',
#  'EECAROTLHs_BS',
#  'EECAROTLHs_M',
#  'ENTBSs_BS',
#  'ENTBSs_M',
#  'EPCDOs_BS',
#  'EPCDOs_M',
#  'ETHAKr_BS',
#  'ETHAKr_M',
#  'ETHAKs_BS',
#  'ETHAKs_M',
#  'ETHAPTr_BS',
#  'ETHAPTr_M',
#  'EX_ala-L(e)',
#  'EX_arg-L(e)',
#  'EX_asn-L(e)',
#  'EX_asp-L(e)',
#  'EX_cys-L(e)',
#  'EX_fe2(e)',
#  ...]

# %%
#Blocked reactions are off


with model:
    
    for item in model.metabolites.nh4_c0.reactions:
        if item.id in blocked_rxns:
            print(item.id, item.bounds)
# Out:
# PAOc_M (0.0, 1000000.0)
# FORAc_M (-1000000.0, 0.0)
# CALANc_M (-1000000.0, 0.0)
# ACPCDAc_M (-1000000.0, 1000000.0)
# TALc_M (0.0, 1000000.0)
# SELCYSTLc_M (0.0, 1000000.0)
# ALTNDAc_M (0.0, 1000000.0)
# NNAMc_M (0.0, 1000000.0)
# GABUTAHc_M (0.0, 1000000.0)
# SELMETLs_M (-1000000.0, 1000000.0)
# NTRLASEc_M (0.0, 1000000.0)
# AMID3c_M (0.0, 1000000.0)
# ASNS1c_M (0.0, 1000000.0)
# METLc_M (-1000000.0, 1000000.0)
# NADS(nh4)c_M (0.0, 1000000.0)
# GUADc_M (0.0, 1000000.0)
# UREASEc_M (0.0, 1000000.0)
# URDGLAHc_M (-1000000.0, 1000000.0)
# NMNDAc_M (0.0, 1000000.0)
# GSNDc_M (0.0, 1000000.0)

# %%
#Blocked reactions on
with model:
    turn_off_cofac_cycles(model)
    
    for item in model.metabolites.nh4_c0.reactions:
        if item.id in blocked_rxns:
            print(item.id, item.bounds)
# Out:
# Successfully turned off cofactor-cycling reactions
# PAOc_M (0.0, 1000000.0)
# FORAc_M (0, 0)
# CALANc_M (0, 0)
# ACPCDAc_M (-1000000.0, 1000000.0)
# TALc_M (0.0, 1000000.0)
# SELCYSTLc_M (0.0, 1000000.0)
# ALTNDAc_M (0, 0)
# NNAMc_M (0.0, 1000000.0)
# GABUTAHc_M (0.0, 1000000.0)
# SELMETLs_M (-1000000.0, 1000000.0)
# NTRLASEc_M (0.0, 1000000.0)
# AMID3c_M (0.0, 1000000.0)
# ASNS1c_M (0, 0)
# METLc_M (-1000000.0, 1000000.0)
# NADS(nh4)c_M (0.0, 1000000.0)
# GUADc_M (0.0, 1000000.0)
# UREASEc_M (0, 0)
# URDGLAHc_M (-1000000.0, 1000000.0)
# NMNDAc_M (0.0, 1000000.0)
# GSNDc_M (0.0, 1000000.0)

# %%
with model:
    turn_off_cofac_cycles(model)
    
    for item in model.metabolites.nh4_c0.reactions:
        if item.id in blocked_rxns:
            print(item.id, item.bounds)

# %% [markdown]
# May 6, 2022
# Results for Benchmarking Nitrogen assimilation
#
# Set-up:
#     - Medium: Autotrophic medium, NO3 as sole N source,
#     - Blocked reactions were identified using the Blocked_reactions list
#     - Turned off cofactor-cycling reactions
# - There wasn't any turned off reactions involving NO3 in particular.

# %%
#This is to show a single instance of the script shown above

from tabulate import tabulate
print(tabulate(sample_fluxes_df, headers='keys', tablefmt='psql'))
# Out:
# +-----------------------+---------------+-----------------+
# |                       |        fluxes |   reduced_costs |
# |-----------------------+---------------+-----------------|
# | Coleoptile_Biomass_M  |   0           |  1632.23        |
# | Straw_Biomass_M       |   0           |  1518.7         |
# | ACCOAC_OSAc_M         |   0           |    -1           |
# | ACCOAC_OSAr_M         |   0           |    -1           |
# | ACPC_OSs_M            |   0           |   149.756       |
# | ACPC_OSm_M            |   0           |    -1           |
# | FAC_Osc_M             |   0           |    -1           |
# | FAC_Osr_M             |   0           |    -1           |
# | EX_co2(e)             |  -2.01584     |  -594.837       |
# | EX_h2o(e)             |   7.77649     |   -23.818       |
# | EX_h(e)               | -81.1929      |    -1.5         |
# | EX_no3(e)             |  -0.000104853 | -3514.58        |
# | EX_o2(e)              |  -2.216       |   205.5         |
# | EX_pi(e)              |   0           |    19.8289      |
# | EX_sucr(e)            |   0           |  -376.322       |
# | EX_fru-B(e)           |   0           |  -201.07        |
# | EX_glc-A(e)           |   0           |  -203.07        |
# | EX_so4(e)             |   0           | -1503.81        |
# | EX_hco3(e)            |   0           |  -614.549       |
# | EX_so3(e)             |   0           | -1231           |
# | EX_h2s(e)             |   0           | -1351.04        |
# | EX_nh4(e)             |  -0.0582026   |   296.917       |
# | EX_asn-L(e)           |   0           |   669.661       |
# | EX_gln-L(e)           |   0           |  1747.46        |
# | EX_etoh(e)            |   0           |     2           |
# | EX_ac(e)              |   0           |   252.045       |
# | EX_lac-L(e)           |   0           |  -228.535       |
# | EX_tsul(e)            |   0           | -2681.67        |
# | EX_fe2(e)             |   0           |    -4           |
# | EX_fe3(e)             |   0           |   -43           |
# | EX_mg2(e)             |   0           |    -4           |
# | EX_ala-L(e)           |   0           |   160.7         |
# | EX_arg-L(e)           |   0           |  2170.57        |
# | EX_asp-L(e)           |   0           |   270.926       |
# | EX_cys-L(e)           |   0           | -1256.48        |
# | EX_glu-L(e)           |   0           |  1386.73        |
# | EX_gly(e)             |   0           |   -88.0632      |
# | EX_his-L(e)           |   0           |   163.665       |
# | EX_ile-L(e)           |   0           |   878.687       |
# | EX_leu-L(e)           |   0           |  1433.82        |
# | EX_lys-L(e)           |   0           |  1113.1         |
# | EX_met-L(e)           |   0           | -1027.67        |
# | EX_phe-L(e)           |   0           |   725.606       |
# | EX_pro-L(e)           |   0           |  1488.86        |
# | EX_ser-L(e)           |   0           |   208.438       |
# | EX_thr-L(e)           |   0           |  1253.57        |
# | EX_trp-L(e)           |   0           |  1273.02        |
# | EX_tyr-L(e)           |   0           |   715.288       |
# | EX_val-L(e)           |   0           |   506.381       |
# | EX_photonVis(e)       |   0           |    96.9947      |
# | PRISM_blue_LED_M      |   0           |    -1.80922     |
# | PRISM_red_LED_M       |   0           |     1.77964     |
# | PRISM_white_LED_M     |   0           |    -1           |
# | PRISM_green_LED_M     |   0           |     2.77954     |
# | PRISM_solar_litho_M   |   0           |   -13.3626      |
# | RPSI_410(u)_M         |   0           |    -1           |
# | RPSI_430(u)_M         |   0           |    -1           |
# | RPSI_450(u)_M         |   0           |     1.29108     |
# | RPSI_470(u)_M         |   0           |    -0.0886477   |
# | RPSI_490(u)_M         |   0           |     0.0733685   |
# | RPSI_510(u)_M         |   0           |    -0.0984036   |
# | RPSI_530(u)_M         |   0           |    -0.594666    |
# | RPSI_550(u)_M         |   0           |    -0.792867    |
# | RPSI_570(u)_M         |   0           |     0.266045    |
# | RPSI_590(u)_M         |   0           |     0.834548    |
# | RPSI_610(u)_M         |   0           |     2.58952     |
# | RPSI_630(u)_M         |   0           |     3.36313     |
# | RPSI_650(u)_M         |   0           |     2.18709     |
# | RPSI_670(u)_M         |   0           |    -0.0186042   |
# | RPSI_690(u)_M         |   0           |     0.803361    |
# | RPSII_410(u)_M        |   0           |    -1           |
# | RPSII_430(u)_M        |   0           |    -0.862459    |
# | RPSII_450(u)_M        |   0           |     0.594055    |
# | RPSII_470(u)_M        |   0           |    -0.764391    |
# | RPSII_490(u)_M        |   0           |    -1           |
# | RPSII_510(u)_M        |   0           |    -1           |
# | RPSII_530(u)_M        |   0           |    -1           |
# | RPSII_550(u)_M        |   0           |    -1           |
# | RPSII_570(u)_M        |   0           |     0.326729    |
# | RPSII_590(u)_M        |   0           |     0.796277    |
# | RPSII_610(u)_M        |   0           |     2.78476     |
# | RPSII_630(u)_M        |   0           |     3.70192     |
# | RPSII_650(u)_M        |   0           |     3.52466     |
# | RPSII_670(u)_M        |   0           |    -0.745232    |
# | RPSII_690(u)_M        |   0           |    -1           |
# | CO2tex_M              |   1.83258     |    -1           |
# | H2Otex_M              |  -6.88757     |     1           |
# | Htex_M                |  65.5633      |    -1           |
# | NO3tex_M              |   0           |    -1           |
# | O2tex_M               |   2.01455     |    -1           |
# | Pitex_M               |   0           |    -1           |
# | SUCRtex_M             |   0           |     1           |
# | FRUtex_M              |   0           |    -1           |
# | GLCtex_M              |   0           |    -1           |
# | SO4tex_M              |   0           |    -1           |
# | SO3tex_M              |   0           |    85           |
# | HCO3tex_M             |   0           |     3.66667     |
# | H2Stex_M              |   0           |   219.136       |
# | NH4tex_M              |   0.0391585   |    -1           |
# | ASNtex_M              |   0           |     0.555556    |
# | GLNtex_M              |   0           |     0.777778    |
# | ETOHtex_M             |   0           |    -1           |
# | ACtex_M               |   0           |    -1           |
# | LACtex_M              |   0           |    -1           |
# | TSULtex_M             |   0           |    -1           |
# | FE2tex_M              |   0           |    -1           |
# | FE3tex_M              |   0           |    -1           |
# | MG2tex_M              |   0           |    -1           |
# | ALAtex_M              |   0           |     1           |
# | ARGtex_M              |   0           |     1           |
# | ASPtex_M              |   0           |     0.555556    |
# | CYStex_M              |   0           |     1           |
# | GLUtex_M              |   0           |     0.777778    |
# | GLYtex_M              |   0           |     0.111111    |
# | HIStex_M              |   0           |     1           |
# | ILEtex_M              |   0           |     1           |
# | LEUtex_M              |   0           |     1           |
# | LYStex_M              |   0           |     1           |
# | METtex_M              |   0           |     1           |
# | PHEtex_M              |   0           |     1           |
# | PROtex_M              |   0           |     0.777778    |
# | SERtex_M              |   0           |     0.555556    |
# | THRtex_M              |   0           |    -1           |
# | TRPtex_M              |   0           |    -1           |
# | TYRtex_M              |   0           |     1           |
# | VALtex_M              |   0           |     1           |
# | PPASc_M               |   2.44966     |    -1           |
# | PPASs_M               |   0           |    -1           |
# | PPASm_M               |   0           |   857.284       |
# | PPASx_M               |   0           |    -1           |
# | PPASv_M               |   0           |    -1           |
# | PPAIcxc_M             |   0.2977      |    -1           |
# | PPAIcvc_M             |   0           |    -1           |
# | APLs_M                |   0.00196072  |    -1           |
# | APLm_M                |   0           |    -1           |
# | CATv_M                |   0           |   407.136       |
# | CATs_M                |   0           |    -1           |
# | CATx_M                |   0.380992    |    -1           |
# | CATm_M                |   0           |   415.136       |
# | GLUSfm_M              |   0           |    -1           |
# | GLUSfs_M              |   0           |  1321.54        |
# | RBPCs_M               |   2.20619     |    -1           |
# | RBPC2s_M              |   0           |    -7.18199     |
# | CYOO6m_M              |   0.0764554   |    -1           |
# | NO3Rm_M               |   0           |    -1           |
# | AOXm_M                |   0           |   144.568       |
# | ATPPHc_M              |   0           |    35           |
# | ATPPHm_M              |   0           |    22.5         |
# | ATPPHs_M              |   0           |    85.5         |
# | ATPSs_M               |   0           |    -1           |
# | ATPSm_M               |  13.7637      |    -1           |
# | ATPSv_M               |   0           |    -1           |
# | GLUSs_M               |   0           |    19           |
# | GLUSys_M              |   0.405148    |    -1           |
# | GTHRc_M               |   0           |    -1           |
# | GTHRs_M               |   0           |    -1           |
# | GTHRm_M               |   0           |   259.068       |
# | ADK1c_M               |   2.7273      |    -1           |
# | ADK1m_M               |   0           |    -1           |
# | ADK1s_M               |   0           |    77.5         |
# | ATPAPc_M              |   0           |    44.682       |
# | ADPAc_M               |   0           |    37           |
# | GAL1PUTc_M            |   0           |    -1           |
# | DPCOAKc_M             |   0           |    -1           |
# | URIKGc_M              |   0           |    37           |
# | URIKGs_M              |   0           |     1           |
# | DHDHc_M               |  -0.0432917   |     1           |
# | BUPNc_M               |   0.0432917   |    -1           |
# | DHPDc_M               |   0.0432917   |    -1           |
# | TMDSc_M               |   0           |    -1           |
# | CYTDc_M               |   0           |   185.147       |
# | GTPCYTDPTc_M          |   0           |    37.5         |
# | GTPCYTDPTs_M          |   0           |    83.5         |
# | DCTPDAc_M             |   0           |     2.5         |
# | CTPRc_M               |   0           |    -1           |
# | UTPRc_M               |   0           |     1           |
# | ATPRc_M               |   0           |    -1           |
# | GTPRc_M               |   0           |    -1           |
# | DCAHc_M               |   0           |    -1           |
# | UPRTs_M               |   0.0432917   |    -1           |
# | UPRTc_M               |   0           |    -1           |
# | UPHc_M                |   0           |    73           |
# | UPHs_M                |  -0.0432917   |     1           |
# | DURIKc_M              |   0           |    37           |
# | TMDKc_M               |   0           |    37           |
# | ATCYc_M               |   0           |    37           |
# | ATCYs_M               |   0           |    87.5         |
# | AUPTc_M               |   0           |    37           |
# | AUPTs_M               |   0.0432917   |    -1           |
# | DGSNHc_M              |   0           |    -1           |
# | TPHc_M                |   0           |    -1           |
# | TPHs_M                |   0           |    -1           |
# | DUMPc_M               |   0.0432917   |    -1           |
# | DCMPc_M               |   0           |    -1           |
# | CMPc_M                |   0           |    -1           |
# | CMPs_M                |   0           |    -1           |
# | UMPc_M                |   0           |    -1           |
# | UMPs_M                |   0           |    87.5         |
# | CTPSc_M               |   0           |    71           |
# | DUTNHc_M              |   0           |    71           |
# | DCDTc_M               |   0           |   181.147       |
# | DUDTc_M               |   0.0432917   |    -1           |
# | TDSRs_M               |   0           |    -1           |
# | TDSRc_M               |   0.0432917   |    -1           |
# | TDSRm_M               |   0           |    -1           |
# | ATDTDc_M              |   0           |    -1           |
# | DTMPKc_M              |   0           |    -1           |
# | ATDUDc_M              |   0           |    -1           |
# | DUMPKc_M              |  -0.0432917   |     1           |
# | ATDCDc_M              |   0           |    -1           |
# | DCMPKc_M              |   0           |    -1           |
# | ATCDc_M               |   0           |   183.147       |
# | ATCDs_M               |   0           |    -1           |
# | CMPKc_M               |   0           |    -1           |
# | CMPKs_M               |   0           |    -1           |
# | ATUDc_M               |   0.0200617   |    -1           |
# | ATUDs_M               |   0           |    -1           |
# | ATUDv_M               |   0           |    -1           |
# | UMPKc_M               |   0.0432917   |    -1           |
# | MATc_M                |   0           |    -1           |
# | AMPDc_M               |   0           |    37.5         |
# | AMPPc_M               |   0           |    37           |
# | ADNKc_M               |   0           |    -1           |
# | APPRTc_M              |   0           |    -1           |
# | APPRTs_M              |   0           |    -1           |
# | ADSHc_M               |   0           |    -1           |
# | PEPSs_M               |   0           |    -1           |
# | PYKc_M                |   0           |    41.5         |
# | PYKs_M                |   3.16659     |    -1           |
# | PPDKs_M               |   0           |     7           |
# | PPDKc_M               |   2.6809      |    -1           |
# | MDH2c_M               |   0           |   705.068       |
# | MDH2s_M               |   0           |   737.068       |
# | PDCm_M                |   0           |    -1           |
# | PDCs_M                |   0           |    81.5         |
# | ACSc_M                |   0.0432917   |    -1           |
# | ACSx_M                |   0           |    -1           |
# | ACSs_M                |   0           |    11           |
# | GLU5Kc_M              |   0.00310988  |    -1           |
# | GLU5Ks_M              |   0           |    -1           |
# | GDHym_M               |   0           |    70.568       |
# | GDHm_M                |   0           |    85.568       |
# | PYR5CDm_M             |   0           |   142.068       |
# | PYR5CDs_M             |   0           |    69.5         |
# | PYR5CDym_M            |   0           |   127.068       |
# | PYR5CDys_M            |   0           |    89.5         |
# | GALc_M                |   0.00310988  |    -1           |
# | GALm_M                |   0           |    -1           |
# | GALs_M                |   0.405148    |    -1           |
# | AGATm_M               |   0.355884    |    -1           |
# | AGATx_M               |   0           |     1.5         |
# | AGATs_M               |   0           |    25           |
# | ALAATc_M              |  -0.376315    |     1           |
# | ALAATm_M              |   0           |    93.5         |
# | ALAATs_M              |   0           |    -1           |
# | AAATc_M               |   0           |    40           |
# | ARGDs_M               |   0           |    -1           |
# | ARGDc_M               |   0           |    -1           |
# | ARGDm_M               |   0           |     5.5         |
# | ASPCLc_M              |  -0.0432917   |     1           |
# | ICDHc_M               |   0           |  -235.136       |
# | ICDHm_M               |   0.00310988  |    -1           |
# | GTHPs_M               |   0           |   110.568       |
# | GTHPc_M               |   0           |   340.636       |
# | GTHPm_M               |   0           |    -1           |
# | UPGCDc_M              |   0           |    74.5         |
# | GALKc_M               |   0           |    16           |
# | UGLTc_M               |   0           |     1           |
# | THAc_M                |   0           |    -1           |
# | THPc_M                |   0           |    -1           |
# | TPSc_M                |   0           |   115           |
# | GLCNSc_M              |   0           |    -1           |
# | GLCNGBc_M             |   0           |   156           |
# | GLCNGBv_M             |   0           |    -1           |
# | GLCNGAc_M             |   0           |    44           |
# | GLCNGAv_M             |   0           |    -1           |
# | GALUic_M              |   0.0200617   |    -1           |
# | GALUiv_M              |   0           |    -1           |
# | MTGHc_M               |   0           |    -1           |
# | MGHAc_M               |   0           |    -1           |
# | MGHBc_M               |   0           |    55           |
# | SFHc_M                |   0           |    -1           |
# | RGHc_M                |   0           |    -1           |
# | SYGHc_M               |   0           |    -1           |
# | GRGTc_M               |   0           |    -1           |
# | RAFFINSc_M            |   0           |    -1           |
# | IAGTc_M               |   0           |    64           |
# | UDPG4Ec_M             |   0           |    -1           |
# | ATGDc_M               |   0           |     1           |
# | ATGDs_M               |   0           |    -1           |
# | GTPDPKs_M             |   0           |   180           |
# | GBDPs_M               |   0           |    -1           |
# | GDTPs_M               |   0           |    -1           |
# | UMPKs_M               |   0           |    -1           |
# | ATDADc_M              |   0           |    -1           |
# | ATDGDc_M              |   0           |    -1           |
# | PPCKc_M               |   0           |   664.568       |
# | MDHys_M               |   0           |    23           |
# | MDHs_M                |  -0.0131125   |     1           |
# | MDHc_M                |   0           |    -1           |
# | MDHx_M                |   0.0330748   |    -1           |
# | MDHm_M                |   0.00310988  |    -1           |
# | MDHv_M                |   0           |    -1           |
# | PPCc_M                |   0           |    -1           |
# | ATPCSc_M              |   0.0105931   |    -1           |
# | CSx_M                 |   0.0251083   |    -1           |
# | CSm_M                 |   0.00310988  |    -1           |
# | OXAACc_M              |   0           |   710.568       |
# | OXAODc_M              |   0           |    -1           |
# | ASPO1s_M              |   0           |    -1           |
# | NNDPRs_M              |   0           |    -1           |
# | NNATc_M               |   0           |    -1           |
# | NADS(nh4)c_M          |   0           |    -1           |
# | NADS(gln-L)c_M        |   0           |    35           |
# | QULNSs_M              |   0           |    -1           |
# | NAMNPPc_M             |   0           |   186.5         |
# | NNAMc_M               |   0           |    -1           |
# | NMNDAc_M              |   0           |    74.5         |
# | NMNNc_M               |   0           |    -1           |
# | NMNATc_M              |   0           |    -1           |
# | N2PHs_M               |   0           |    -1           |
# | N2PHc_M               |   0           |    -1           |
# | NADKc_M               |   0           |    33           |
# | NADKs_M               |   0           |    83.5         |
# | NADKm_M               |   0           |    14           |
# | NADHKc_M              |   0           |    35           |
# | NADHKs_M              |   0           |   103.5         |
# | NADHKm_M              |   0           |    -1           |
# | ASPTAc_M              |  -0.00544717  |     1           |
# | ASPTAm_M              |   0           |  -105.568       |
# | ASPTAs_M              |   0           |    -1           |
# | GLYTAx_M              |   0           |    -0.5         |
# | SUCL(GDP)m_M          |   0           |    -1           |
# | SUCL(ADP)m_M          |   0           |    -1           |
# | CTPCHc_M              |   0           |    -1           |
# | LYSDCs_M              |   0           |    -1           |
# | AASADc_M              |   0           |    -1           |
# | SACCDyc_M             |   0           |    -1           |
# | SACCDc_M              |   0           |    -1           |
# | AATAc_M               |   0           |    -1           |
# | PDHam1m_M             |   0           |    75.5         |
# | PDHam2m_M             |   0           |  -613.419       |
# | PDHe2m_M              |   0           |   445.419       |
# | PDHe3m_M              |   0           |   197.568       |
# | PDHam1s_M             |   0.00262295  |    -1           |
# | PDHam2s_M             |   0           |    -1           |
# | PDHe2s_M              |   0           |    -1           |
# | PDHe3s_M              |   0           |    -1           |
# | AKGDHam1m_M           |   0           |    -1           |
# | AKGDHam2m_M           |   0           |    -1           |
# | AKGDHe2m_M            |   0           |    -1           |
# | OXADH1m_M             |   0           |    -1           |
# | OXADH2m_M             |   0           |    -1           |
# | DAPDCs_M              |   0.00167505  |    -1           |
# | MALSs_M               |   0           |    -1           |
# | MALSx_M               |   0.0251083   |    -1           |
# | GOXx_M                |   0.761984    |    -1           |
# | ICLx_M                |   0           |    -1           |
# | AMOx_M                |   0           |   872.636       |
# | AOBUTDx_M             |   0           |    -1           |
# | THR3DHx_M             |   0           |   985.379       |
# | GLYATx_M              |   0           |    -1           |
# | ASPKs_M               |   0.00233728  |    -1           |
# | ASPALs_M              |   0           |    -1           |
# | ASPALc_M              |   0           |    -1           |
# | ASNNc_M               |   0           |    75           |
# | FDHm_M                |   0           |    -1           |
# | FDHNc_M               |   0           |  -555.652       |
# | SULOx_M               |   0           |    -1           |
# | SULOm_M               |   0           |     2.5         |
# | SUATc_M               |   0           |    -1           |
# | SUATs_M               |   0           |    -1           |
# | ARGNc_M               |   0           |    -1           |
# | PTORc_M               |   0           |    -1           |
# | PAOc_M                |   0           |    -1           |
# | AMPORc_M              |   0           |    -1           |
# | SPMDDHc_M             |   0           |    -1           |
# | ABORc_M               |   0           |    39           |
# | ARG2MO_M              |   0           |   376.636       |
# | GABUTAHc_M            |   0           |    -1           |
# | GABUTNAHc_M           |   0           |    -1           |
# | CMPAc_M               |   0           |   263           |
# | AGDIc_M               |   0           |    -1           |
# | AGMTc_M               |   0           |    -1           |
# | ARDCc_M               |   0           |    -1           |
# | NOSc_M                |   0           |  4409.82        |
# | ARGDIc_M              |   0           |   151.5         |
# | HCGALc_M              |   0.00310988  |    -1           |
# | ASNS1c_M              |   0           |    37           |
# | ASNS1s_M              |   0           |    85.5         |
# | PSPs_M                |   0.0125541   |    -1           |
# | CYSTGLs_M             |   0.00066223  |    -1           |
# | CYSTBSs_M             |   0           |   156           |
# | SATc_M                |   0           |    -1           |
# | SATs_M                |   0           |    -1           |
# | SATm_M                |   0           |     7.5         |
# | SGATs_M               |   0           |   101.5         |
# | SGATx_M               |   0.380992    |    -1           |
# | METSMTc_M             |   0           |    -1           |
# | HCYSMTc_M             |   0           |   113           |
# | AMETAHYCSTc_M         |   0           |    57.5         |
# | HCYSMT2c_M            |   0           |   115.5         |
# | MSx_M                 |   0           |    -1           |
# | MSv_M                 |   0           |    -1           |
# | MSc_M                 |   0           |    -1           |
# | ACDOc_M               |   0           |  1549.86        |
# | METLc_M               |   0           |    -1           |
# | ACHYSLc_M             |   0           |    -1           |
# | MOTAc_M               |   0           |    -1           |
# | M5TRKc_M              |   0           |    -1           |
# | MTANc_M               |   0           |    -1           |
# | SPRMSc_M              |   0           |    -1           |
# | ORDCc_M               |   0           |    -1           |
# | SPMSc_M               |   0           |    -1           |
# | AMCLc_M               |   0           |   188.636       |
# | ACPCSc_M              |   0           |    -1           |
# | AMCPCOc_M             |   0           |    -1           |
# | M5TRPIc_M             |   0           |    -1           |
# | M5TRPHc_M             |   0           |    -1           |
# | ACRSPc_M              |   0           |    -1           |
# | ENOc_M                |  -2.6809      |     1           |
# | ENOs_M                |   3.16722     |    -1           |
# | ORNTAm_M              |   0           |    -1           |
# | ORNTAc_M              |  -0.00310988  |     1           |
# | TRPMOc_M              |   0           |    -1           |
# | IAOc_M                |   0           |    -1           |
# | TOORc_M               |   0           |    -1           |
# | TRPTAc_M              |   0           |    -1           |
# | ALAADc_M              |   0           |    -1           |
# | INDPYRDc_M            |   0           |     1           |
# | IAOHLc_M              |   0           |    -1           |
# | TRYPTORc_M            |   0           |    -1           |
# | NTRLASEc_M            |   0           |   674.272       |
# | TRP2MOc_M             |   0           |   405.136       |
# | AMID3c_M              |   0           |    -1           |
# | IAAGTc_M              |   0           |    81.5         |
# | IAAINOSTc_M           |   0           |    -1           |
# | IAAIGSc_M             |   0           |    -1           |
# | IAAIASc_M             |   0           |    -1           |
# | IAAALASc_M            |   0           |    75           |
# | IAALEUSc_M            |   0           |    75           |
# | IAAASPSc_M            |   0           |    -1           |
# | IAAGLUSc_M            |   0           |    -1           |
# | IAAGLNSc_M            |   0           |    -1           |
# | IAAALAHc_M            |   0           |    -1           |
# | IAALEUHc_M            |   0           |    -1           |
# | IAAAMYHc_M            |   0           |    -1           |
# | SERHs_M               |   0           |    -1           |
# | TRPS2s_M              |   0           |     1           |
# | PPDHc_M               |   0           |     5.5         |
# | PPDHs_M               |   0           |    -1           |
# | LDH_Lc_M              |   0           |    -1           |
# | MALCOADCc_M           |   0           |   311.022       |
# | MALSADHm_M            |   0           |   799.136       |
# | MALSADHym_M           |   0           |   784.136       |
# | ICHDxm_M              |   0           |    14           |
# | ACALDHc_M             |   0.0432917   |    -1           |
# | ACALDHs_M             |   0           |    -1           |
# | ACALDHm_M             |   0           |   108.068       |
# | GLYCRORc_M            |   0           |    -1           |
# | GLYCORc_M             |   0           |     1           |
# | SSNOm_M               |   0           |   997.772       |
# | TYRDCc_M              |   0           |    -1           |
# | 34HPPORc_M            |   0           |    -1           |
# | 34HPPORs_M            |   0           |     1.5         |
# | HGDOc_M               |   0           |   729.272       |
# | PPORs_M               |   0           |    -1           |
# | TYRTAc_M              |   0           |    -1           |
# | TYRTAs_M              |   0           |     3           |
# | FAAc_M                |   0           |    -1           |
# | MAAIc_M               |   0           |    -1           |
# | ARGDHTs_M             |   0.000139588 |    -1           |
# | ARGOAT1s_M            |   0           |    -3           |
# | ARGOAT2s_M            |   0.000314559 |    -1           |
# | ARGDHs_M              |   0.000174972 |    -1           |
# | ALCDx2c_M             |   0           |    -1           |
# | BETALDDHc_M           |   0           |    -1           |
# | BETHCYSs_M            |   0           |    -1           |
# | DMTGDHs_M             |   0           |    -1           |
# | SARCOs_M              |   0           |    -1           |
# | GLYDHDm_M             |   0.368438    |    -1           |
# | DHLDHm_M              |   0.368438    |    -1           |
# | MTAMnh4m_M            |   0.368438    |    -1           |
# | THRAc_M               |   0           |  1063.38        |
# | ALCDx1c_M             |   0           |   287.363       |
# | MAN6PIc_M             |   0           |    -1           |
# | PMANMc_M              |   0           |    -1           |
# | MANKINc_M             |   0           |    -1           |
# | MDHARc_M              |   0           |     1           |
# | MDHARs_M              |   0           |    27           |
# | MDHARm_M              |   0           |    -1           |
# | MDHARyc_M             |   0           |    -1           |
# | MDHARys_M             |   0           |     7           |
# | MDHARym_M             |   0           |    14           |
# | ASCOXc_M              |   0           |   274.136       |
# | ASCPO1c_M             |   0           |   341.636       |
# | ASCPO1s_M             |   0           |    90.568       |
# | ASCPO2c_M             |   0           |     4           |
# | ASCPO2s_M             |   0           |    -1           |
# | GGT1v_M               |   0           |    -1           |
# | GGT2c_M               |   0           |    -1           |
# | GGLUCTc_M             |   0           |    -1           |
# | OPAHirc_M             |   0           |    -1           |
# | CYSGLYv_M             |   0           |    -1           |
# | GLUCYSs_M             |   0           |    -1           |
# | GLUCYSm_M             |   0           |    -1           |
# | GTHSs_M               |   0           |    -1           |
# | GTHSm_M               |   0           |    -1           |
# | GTHDHc_M              |   0           |    -1           |
# | GTHDHs_M              |   0           |    -1           |
# | GALLDHm_M             |   0           |    -1           |
# | GALDHc_M              |   0           |    -1           |
# | GDPGPc_M              |   0           |    -1           |
# | GDPME1c_M             |   0           |    -1           |
# | GDPME3c_M             |   0           |    -1           |
# | GAMPGc_M              |   0           |   125.5         |
# | GMANDc_M              |   0           |    -1           |
# | GOFUCRc_M             |   0           |    -1           |
# | FUCPGTc_M             |   0           |    -1           |
# | LACDHc_M              |   0           |    -1           |
# | FCPAc_M               |   0           |    -1           |
# | FCKc_M                |   0           |    -1           |
# | FCIc_M                |   0           |    -1           |
# | FUKc_M                |   0           |    -1           |
# | FBPc_M                |   0.0401234   |    -1           |
# | FBPs_M                |   1.00403     |    -1           |
# | SPSc_M                |   0.0200617   |    -1           |
# | SPSv_M                |   0           |    -1           |
# | PGI1c_M               |  -0.0200617   |     1           |
# | PGI1s_M               |   0           |    -1           |
# | PGI2c_M               |   0           |     5           |
# | PGI2s_M               |   0           |     1           |
# | NO2Rs_M               |   0           |    -1           |
# | NODOx_M               |   0           |     1           |
# | NODOy_M               |   0           |    -1           |
# | NITRc_M               |   0           |   100.568       |
# | NITRv_M               |   0           |    -1           |
# | BFFSc_M               |   0           |    17           |
# | BFFSv_M               |   0           |    -1           |
# | INVc_M                |   0           |    -1           |
# | INVv_M                |   0           |     7           |
# | SPPc_M                |   0.0200617   |    -1           |
# | SPPv_M                |   0           |    -1           |
# | SUSc_M                |   0           |    23           |
# | SUSv_M                |   0           |    -1           |
# | MI3PSc_M              |   0           |    -1           |
# | SULRs_M               |   0           |  2336.94        |
# | XYL2c_M               |   0           |    -1           |
# | XYL2v_M               |   0           |    -1           |
# | UDPACGEc_M            |   0           |    -1           |
# | UDPACGLPc_M           |   0           |    77.5         |
# | ACGAMPMc_M            |   0           |    -1           |
# | ACGAM6PSic_M          |   0           |   304.595       |
# | GAMPTc_M              |   0           |  -306.595       |
# | GAMACTc_M             |   0           |    -1           |
# | ACGAMKc_M             |   0           |    -1           |
# | CAGHc_M               |   0           |    -1           |
# | CHITNc_M              |   0           |    -1           |
# | ACGAM2Ec_M            |   0           |    -1           |
# | UAG2EMAic_M           |   0           |    -1           |
# | ACNMLc_M              |   0           |    -1           |
# | CMPSASc_M             |   0           |    -1           |
# | GF6PTAc_M             |   0           |    -1           |
# | FKc_M                 |   0           |    61           |
# | MCPSTm_M              |   0           |    -1           |
# | TSSTm_M               |   0           |    -1           |
# | MCPSTs_M              |   0           |    -1           |
# | TSSTs_M               |   0           |    -1           |
# | SOXs_M                |   0           |   293.568       |
# | CYSATs_M              |   0           |    -1           |
# | CYSATm_M              |   0           |    -1           |
# | AATCs_M               |   0           |    -1           |
# | AATCm_M               |   0           |   171           |
# | 3SPYRSPs_M            |   0           |    -1           |
# | 3SPYRSPm_M            |   0           |    -1           |
# | LCYSTSs_M             |   0           |    -1           |
# | LCYSTSm_M             |   0           |    -1           |
# | CYSSc_M               |   0           |    -1           |
# | CYSSm_M               |   0           |    -1           |
# | CYSSs_M               |   0           |    -1           |
# | ALABATc_M             |   0           |    -1           |
# | DHFRc_M               |   0           |    -1           |
# | DHFRm_M               |   0           |    -1           |
# | FPGSc_M               |   0           |    -1           |
# | FTHFLc_M              |   0           |    37           |
# | FTHFLm_M              |   0           |    -1           |
# | FTHFLs_M              |   0           |    64.5         |
# | CALANc_M              |   0           |   280.405       |
# | CALASc_M              |   0           |    -1           |
# | MANITL_M              |   0           |    -1           |
# | BG1c_M                |   0           |    -1           |
# | BG2c_M                |   0           |    -1           |
# | FORAc_M               |   0           |   909.383       |
# | FORMHLc_M             |   0           |    -1           |
# | FTHDFc_M              |   0           |    -1           |
# | FTHDFm_M              |   0           |    24.5         |
# | FTHDFs_M              |   0           |    22           |
# | SHMTs_M               |   0           | -1485.36        |
# | SHMTm_M               |   0.368438    |    -1           |
# | MLTHFRc_M             |   0           |    -1           |
# | MLTHFRs_M             |   0           | -1299.54        |
# | METSc_M               |   0           | -1120.48        |
# | METSs_M               |   0           |   160.556       |
# | MLTHFR_Fs_M           |   0           |    -1           |
# | MLTHFR_Fc_M           |   0           |    -1           |
# | GLPATs_M              |   0           |    -1           |
# | HCGALm_M              |   0           |    -1           |
# | ORPDCs_M              |   0.0432917   |    -1           |
# | ATNSs_M               |   0           |    -1           |
# | TALc_M                |   0           |   695.243       |
# | TPIc_M                |  -5.73728     |     1           |
# | TPIs_M                |   3.68941     |    -1           |
# | RPDPKc_M              |   0           |    -1           |
# | RPDPKs_M              |   0           |     3           |
# | PPMc_M                |   0           |    -1           |
# | PPMs_M                |   0.0432917   |    -1           |
# | RBKc_M                |   0           |    77           |
# | RBKs_M                |   0           |    95.5         |
# | AUNORs_M              |   0           |    -1           |
# | RIBFSs_M              |   0           |    -1           |
# | RIBFKc_M              |   0           |    -1           |
# | FMNATs_M              |   0           |    -1           |
# | FMNATc_M              |   0           |    -1           |
# | FMNATm_M              |   0           |    -1           |
# | GTPDHs_M              |   0           |    -1           |
# | DHPAHs_M              |   0           |    -1           |
# | R5PFLs_M              |   0           |    -1           |
# | DLDLBTs_M             |   0           |    -1           |
# | AUSs_M                |   0           |    -1           |
# | RPIc_M                |   0           |    -1           |
# | RPIs_M                |   0.960426    |    -1           |
# | GAPDHys_M             |   0           |    81.5         |
# | GAPDH1c_M             |   0           |    39           |
# | GAPDH2s_M             |   0           |    61.5         |
# | GAPDHc_M              |  -5.73411     |     1           |
# | GAPDH1ys_M            |   0.677624    |    -1           |
# | KHKc_M                |   0           |   101           |
# | FBA2c_M               |   0           |    -1           |
# | FALDTKc_M             |   0           |    -1           |
# | FALDTKs_M             |   0           |    -1           |
# | GLYCNKc_M             |   0           |    -1           |
# | GLYCNKs_M             |   0           |    -1           |
# | FBAc_M                |  -0.0401234   |     1           |
# | FBAs_M                |  -1.00403     |     1           |
# | HDCs_M                |   0           |    -1           |
# | ADPARTs_M             |   0           |    -1           |
# | PRDPARs_M             |   0           |    -1           |
# | ANTPPTs_M             |   0           |    -1           |
# | FUMm_M                |  -0.00310988  |     1           |
# | ADSALc_M              |   0           |    -1           |
# | ADSALs_M              |   0           |    -1           |
# | ARGSL1c_M             |   0.00310988  |    -1           |
# | LATs_M                |  -0.000558351 |     1           |
# | LATm_M                |   0           |    -1           |
# | GSNPc_M               |   0           |    39           |
# | ADNPc_M               |   0           |    39           |
# | INSPc_M               |   0           |    39           |
# | ADNDAc_M              |   0           |    -0.5         |
# | IMPc_M                |   0           |    -1           |
# | GMPRc_M               |   0           |    -1           |
# | IMPCs_M               |   0           |    -1           |
# | GMPS2c_M              |   0           |    35           |
# | GMPS1c_M              |   0           |    -1           |
# | GDKc_M                |   0           |    -1           |
# | ATDGMc_M              |   0           |    -1           |
# | ATDAMc_M              |   0           |    -1           |
# | DGDTc_M               |   0           |    -1           |
# | DADTc_M               |   0           |    -1           |
# | IMPDc_M               |   0           |    75           |
# | INSKc_M               |   0           |    37           |
# | HXPRTc_M              |   0           |    37           |
# | ADSSc_M               |   0           |    75           |
# | ADSSs_M               |   0           |    -1           |
# | MIOORc_M              |   0           |    -1           |
# | PI45PLCc_M            |   0           |    -1           |
# | PI5P4Kc_M             |   0           |    -1           |
# | PI4P5Kc_M             |   0           |    -1           |
# | PIK4c_M               |   0           |    -1           |
# | PIK3c_M               |   0           |    -1           |
# | PI3P5Kc_M             |   0           |    -1           |
# | MI34Pc_M              |   0           |    -1           |
# | MI346Pc_M             |   0           |    56.9996      |
# | MI3456Pc_M            |   0           |    -1           |
# | IBPHc_M               |   0           |    37.5         |
# | MI14PPc_M             |   0           |    -1           |
# | MI134PPc_M            |   0           |    -1           |
# | MI145PPc_M            |   0           |    20.5004      |
# | MI1456PKc_M           |   0           |    -1           |
# | MI145PKc_M            |   0           |    19.0004      |
# | MI134PK1c_M           |   0           |    36           |
# | MI134PK2c_M           |   0           |    17.9996      |
# | MI1346PK1c_M          |   0           |    -1           |
# | MI1346PK2c_M          |   0           |    -1           |
# | IPKK2c_M              |   0           |    -1           |
# | IPKK5c_M              |   0           |    -1           |
# | IPKK4c_M              |   0           |    36           |
# | IPKK6c_M              |   0           |    36           |
# | PHYTASEc_M            |   0           |    -1           |
# | MIHPPc_M              |   0           |    -1           |
# | MI1345PPc_M           |   0           |    15.9996      |
# | MI1345PP2c_M          |   0           |    -1           |
# | ITK1Kc_M              |   0           |    -1           |
# | MI4PPc_M              |   0           |    -1           |
# | MI3PPc_M              |   0           |    -1           |
# | DHAD-bs_M             |   0.00196072  |    -1           |
# | HMGCOASc_M            |   0           |    -1           |
# | HMGCOASm_M            |   0           |    -1           |
# | GCOADx_M              |   0           |  3743.35        |
# | GCOADCx_M             |   0           |    -1           |
# | ACACTx_M              |   0           |  3034.28        |
# | ACACTs_M              |   0           |    -1           |
# | ACACTc_M              |   0           |  1085.13        |
# | ACACTm_M              |   0           |    -1           |
# | IPMSs_M               |   0.000558351 |    -1           |
# | HMNOm_M               |   0           |    -1           |
# | MOD_M                 |   0           |    -1           |
# | MOD(2mhop)_M          |   0           |    -1           |
# | DHRT(ibcoa)_M         |   0           |    -1           |
# | MMSDm_M               |   0           |    -1           |
# | MCDH1m_M              |   0           |    -1           |
# | HIBHm_M               |   0           |   713.704       |
# | ECH1m_M               |   0           |    -1           |
# | DHADm_M               |   0           |    -1           |
# | VALATs_M              |  -0.00140237  |     1           |
# | VALATm_M              |   0           |   204.568       |
# | MTHFDm_M              |   0           |  1035.77        |
# | MTHFDs_M              |   0           |    -1           |
# | MTHFDc_M              |   0           |    -3           |
# | FTHFCLc_M             |   0           |    28.509       |
# | FTHFCLm_M             |   0           |    -1           |
# | FTHFCLs_M             |   0           |    -1           |
# | MTHFDym_M             |   0           |  1020.77        |
# | MTHFDys_M             |   0           |    19           |
# | MTHFDyc_M             |   0           |    -1           |
# | MOHMTm_M              |   0           |    -1           |
# | GMPc_M                |   0           |    37           |
# | GNSKc_M               |   0           |    -1           |
# | GUAPRTc_M             |   0           |    -1           |
# | DAD2DAc_M             |   0           |    -0.5         |
# | DGSNPP_M              |   0           |    -1           |
# | DINSPc_M              |   0           |    -1           |
# | DURIPP_M              |   0.0432917   |    -1           |
# | DAD2NPc_M             |   0           |    -1           |
# | DAMPHc_M              |   0           |    -1           |
# | ADEDAc_M              |   0           |    -1           |
# | ADNRHc_M              |   0           |    -1           |
# | GTPDPKc_M             |   0           |    -1           |
# | PPPGPPPc_M            |   0           |    -1           |
# | PRODHm_M              |   0           |    -1           |
# | P5CRc_M               |   0           |     1           |
# | P5CRs_M               |   0           |    19           |
# | P5CRyc_M              |   0           |    -1           |
# | P5CRys_M              |   0           |    -1           |
# | CYSTALs_M             |   0           |    -1           |
# | GCALDDc_M             |   0           |    -1           |
# | PGLYCPs_M             |   0.761984    |    -1           |
# | GLCRPUic_M            |   0           |    -1           |
# | XYLXYLc_M             |   0           |    -1           |
# | XSc_M                 |   0           |    -1           |
# | UGEc_M                |   0           |    -1           |
# | UG46DHc_M             |   0           |    -1           |
# | PECTNc_M              |   0           |    -1           |
# | UDDGEc_M              |   0           |    -1           |
# | URMNORc_M             |   0           |    -1           |
# | UGDCc_M               |   0           |    -1           |
# | HPRs_M                |   0           |    19           |
# | HPRx_M                |   0.0330748   |    -1           |
# | HPRys_M               |   0           |    -1           |
# | HPRyx_M               |   0.347917    |    -1           |
# | ASPCT1c_M             |   0           |    -1           |
# | THRSs_M               |   0           |    -1           |
# | AAPTc_M               |   0           |    39           |
# | UTPUc_M               |   0           |    37           |
# | UMPUc_M               |   0           |    -1           |
# | ARABFv_M              |   0           |    -1           |
# | ARABFc_M              |   0           |    -1           |
# | UA4Ec_M               |   0           |    -0.333333    |
# | GLCURKc_M             |   0           |   385.636       |
# | PGKc_M                |  -5.73411     |     1           |
# | PGKs_M                |   0.677624    |    -1           |
# | PGLYDHs_M             |   0.0125541   |    -1           |
# | GLYK1s_M              |   0.380992    |    -1           |
# | GLYK2s_M              |   0           |    -3           |
# | PGMc_M                |  -2.6809      |     1           |
# | PGMs_M                |   3.16722     |    -1           |
# | G6PEc_M               |   0           |    -1           |
# | G6PEs_M               |   0           |    -1           |
# | PRUKs_M               |   2.96818     |    -1           |
# | GLNKc_M               |   0           |    -1           |
# | GLNKs_M               |   0           |    -1           |
# | GNDc_M                |   0           |   294           |
# | GNDs_M                |   0           |   573.568       |
# | XYLIc_M               |   0           |    -1           |
# | XYLKc_M               |   0           |   291           |
# | RPEc_M                |   0           |    -1           |
# | RPEs_M                |  -2.00775     |     1           |
# | 3HPPDc_M              |   0           |    -1           |
# ...
# | FA180COAabcx_BS       |   0           |    -1           |
# | FA181COAabcx_BS       |   0           |    -1           |
# | FA182COAabcx_BS       |   0           |   230.136       |
# | FA183COAabcx_BS       |   0           |   339.704       |
# | ATP2tx_BS             |   0           |    -1           |
# | ATPtx_BS              |   0           |    -1           |
# | GLYtx_BS              |  -0.0227342   |     1           |
# | SERtx_BS              |   0.0227342   |    -1           |
# | GLYCLTtx_BS           |   0.0454683   |    -1           |
# | MALOAAtx_BS           |   0           |     2.55556     |
# | H2Otx_BS              |  -0.0396745   |     1           |
# | CITx_BS               |  -0.00289693  |     1           |
# | CO2tx_BS              |   0           |    -1           |
# | O2tx_BS               |   0.0227342   |    -1           |
# | PItx_BS               |   0           |    -1           |
# | CITtcx_BS             |   0           |    -1           |
# | ACtx_BS               |   0           |    -1           |
# | ALAtx_BS              |   0           |    -1           |
# | PYRt2x_BS             |   0           |    -1           |
# | SUCCtx_BS             |   0           |     0.111111    |
# | NH4tx_BS              |   0           |    -1           |
# | THRtx_BS              |   0           |    -1           |
# | ACCOAtx_BS            |   0.00579386  |    -1           |
# | COA(h)tx_BS           |   0           |    -1           |
# | GLXtx_BS              |  -0.0198372   |     1           |
# | GLUtx_BS              |   0           |    -1           |
# | AKGtx_BS              |   0           |    -1           |
# | GCOAtx_BS             |   0           |    -1           |
# | GLYCRtx_BS            |   0.0227342   |    -1           |
# | FADH2tx_BS            |   0           |   124.375       |
# | FADtx_BS              |   0           |    -1           |
# | NADPH2tx_BS           |   0.0198372   |    -1           |
# | NADPtx_BS             |  -0.0198372   |     1           |
# | MTHGXLtx_BS           |   0           |    -1           |
# | B2COAtx_BS            |   0           |    -1           |
# | FA40COAtx_BS          |   0           |    -1           |
# | JAStx_BS              |   0           |    -1           |
# | OPDAtx_BS             |   0           |    -1           |
# | SO4tx_BS              |   0           |    -1           |
# | FA140CoAr_BS          |   0           |    -1           |
# | FA160CoAr_BS          |   0           |  -146.621       |
# | FA161CoAr_BS          |   0           |    -1           |
# | FA180CoAr_BS          |   0           |    -1           |
# | FA181CoAr_BS          |   0           |    -1           |
# | FA182CoAr_BS          |   0           |    -1           |
# | FA183CoAr_BS          |   0           |    -1           |
# | FA140r_BS             |   0           |    -1           |
# | FA160r_BS             |   0           |    -1           |
# | FA161r_BS             |   0           |    -1           |
# | FA180r_BS             |   0           |    -1           |
# | FA181r_BS             |   0           |    -1           |
# | FA182r_BS             |   0           |    -1           |
# | FA183r_BS             |   0           |    -1           |
# | NADPH2tr_BS           |   0           |    -1           |
# | NADPtr_BS             |   0           |   282.729       |
# | UDPGr_BS              |   0           |    -1           |
# | GLUSIDEr_BS           |   0           |    -1           |
# | HYDRO16tr_BS          |   0           |    -1           |
# | HYDRO18tr_BS          |   0           |    -1           |
# | DHYDRO1016tr_BS       |   0           |    -1           |
# | DHYDRO1018tr_BS       |   0           |    -1           |
# | THYDRO91018tr_BS      |   0           |    -1           |
# | AMETt2r_BS            |   0           |    -1           |
# | ATPtr_BS              |   0           |    -1           |
# | ATP2tr_BS             |   0           |    -1           |
# | H2Otr_BS              |   0           |    38.2499      |
# | CO2tr_BS              |   0           |    -1           |
# | O2tr_BS               |   0           |    -1           |
# | MALCOAtr_BS           |   0           |    -1           |
# | Pitr_BS               |   0           |    31.5         |
# | SERtr_BS              |   0           |    -1           |
# | COA(h)tr_BS           |   0           |    -1           |
# | GLYC3Ptr_BS           |   0           |    -1           |
# | TRIGLYCtr_BS          |   0           |    -1           |
# | CTPtr_BS              |   0           |    -1           |
# | CMPtr_BS              |   0           |    -1           |
# | CDPDAGtr_BS           |   0           |    -1           |
# | PTD1INOtr_BS          |   0           |    -1           |
# | PEtr_BS               |   0           |    -1           |
# | PStr_BS               |   0           |    -1           |
# | PGPtr_BS              |   0           |    -1           |
# | PCtr_BS               |   0           |    -1           |
# | CHOLtr_BS             |   0           |    -1           |
# | INOSTtr_BS            |   0           |    -1           |
# | FADH2tr_BS            |   0           |    -1           |
# | FADtr_BS              |   0           |    -1           |
# | O2tu_BS               |   0           |    -1           |
# | H2Otu_BS              |   0           |    -1           |
# | DM_12O9DD(s)_BS       |   0           |  -574.602       |
# | DM_3-NON(s)_BS        |   0           |   241.136       |
# | DM_3-NOND(s)_BS       |   0           |     0           |
# | DM_9-NONAN(s)_BS      |   0           |  -574.602       |
# | DM_ACRTNL(s)_BS       |   0           |     0           |
# | DM_ACT(s)_BS          |   0           |  4207.06        |
# | DM_ADE(s)_BS          |   0           | -1103.21        |
# | DM_AFZL(c)_BS         |   0           |   817.749       |
# | DM_AMOB(c)_BS         |   0           |     0           |
# | DM_AMYGD(c)_BS        |   0           |  -456.504       |
# | DM_APGNNP(c)_BS       |   0           |  -356.752       |
# | DM_AVITE1(s)_BS       |   0           |  8839.9         |
# | DM_BGPTN(c)_BS        |   0           |     0           |
# | DM_BILIVERD(s)_BS     |   0           |   639.954       |
# | DM_BRSNL(c)_BS        |   0           |  2551.59        |
# | DM_BTN(c)_BS          |   0           | -2636.5         |
# | DM_BUTIN(c)_BS        |   0           |   -90.066       |
# | DM_CADAVERINE(s)_BS   |   0           |  1705.84        |
# | DM_CAMP(c)_BS         |   0           | -1007.65        |
# | DM_CAMPSTFER(c)_BS    |   0           |  2120.51        |
# | DM_CATCN(c)_BS        |   0           |  1057.07        |
# | DM_CERDT(r)_BS        |   0           |  -432.354       |
# | DM_CEROOL(r)_BS       |   0           |   212.402       |
# | DM_CHSTEROL(c)_BS     |   0           |  1613.14        |
# | DM_CHUMU(c)_BS        |   0           |  2278.16        |
# | DM_CNDM35DG(c)_BS     |   0           |  1919.01        |
# | DM_COA(c)_BS          |   0           |  -813.952       |
# | DM_COUMN(c)_BS        |   0           |   782.825       |
# | DM_COUMOH(c)_BS       |   0           |   532.189       |
# | DM_CPP1(s)_BS         |   0           |  2364.92        |
# | DM_CRPE(c)_BS         |   0           |  5392.91        |
# | DM_CYARTFER(c)_BS     |   0           | 11796.1         |
# | DM_CYTC(m)_BS         |   0           |     0           |
# | DM_CYTC(s)_BS         |   0           |     0           |
# | DM_C-ZTN7G(c)_BS      |   0           |     0           |
# | DM_C-ZTN9G(c)_BS      |   0           |     0           |
# | DM_ZTNG(c)_BS         |   0           |     0           |
# | DM_DHBZCAROT(s)_BS    |   0           |  1279.29        |
# | DM_DHZ7G(c)_BS        |   0           |   599.194       |
# | DM_DHZ9G(c)_BS        |   0           |   599.194       |
# | DM_DHZG(c)_BS         |   0           |   599.194       |
# | DM_DVCHLDA(s)_BS      |   0           | -7093.88        |
# | DM_EIHKAUR(c)_BS      |   0           |  7402.7         |
# | DM_ELM(c)_BS          |   0           |  5392.91        |
# | DM_ENTB(s)_BS         |   0           |  1619.5         |
# | DM_EPCTCN(c)_BS       |   0           |  2211.02        |
# | DM_EPLZN(c)_BS        |   0           |  1971.7         |
# | DM_ERGTOL(c)_BS       |   0           |  1341.5         |
# | DM_ETHYLENE(c)_BS     |   0           |  1293.61        |
# | DM_GA13(c)_BS         |   0           | 13236.3         |
# | DM_GA17(c)_BS         |   0           | 13236.3         |
# | DM_GA29CAT(c)_BS      |   0           | 16105.8         |
# | DM_GA34(c)_BS         |   0           | 14967.1         |
# | DM_GA51CAT(c)_BS      |   0           | 14966.6         |
# | DM_GA8CAT(c)_BS       |   0           | 17245.9         |
# | DM_GA98(c)_BS         |   0           | 12072.8         |
# | DM_GENTDP(c)_BS       |   0           |  3291.78        |
# | DM_HUML(c)_BS         |   0           |  5392.91        |
# | DM_HUMU(c)_BS         |   0           |     0           |
# | DM_IORNTN2GCOUM(c)_BS |   0           |   371.937       |
# | DM_IPADNE7G(c)_BS     |   0           |  -351.388       |
# | DM_IPADNE9G(c)_BS     |   0           |  -351.388       |
# | DM_ISCPRN2GCOUM(c)_BS |   0           |   375.437       |
# | DM_ISCPRN2GFER(c)_BS  |   0           |   618.255       |
# | DM_IVTXN2GFER(c)_BS   |   0           |   375.937       |
# | DM_JASILE(c)_BS       |   0           |  -203.505       |
# | DM_JASLEU(c)_BS       |   0           |   351.631       |
# | DM_JASVAL(c)_BS       |   0           |  -575.812       |
# | DM_JASKMPFL3G(c)_BS   |   0           |  1795.63        |
# | DM_LACXAN(s)_BS       |   0           | -2085.94        |
# | DM_LGNCOL(r)_BS       |   0           |    -0.660429    |
# | DM_LGNDT(r)_BS        |   0           |  -645.416       |
# | DM_LIM(s)_BS          |   0           |  3582.94        |
# | DM<NNP(c)_BS          |   0           |  -117.434       |
# | DM_LUTEIN(c)_BS       |   0           |   432.636       |
# | DM_MNQNNE(s)_BS       |   0           | 16691.7         |
# | DM_MOMA(s)_BS         |   0           |  7815.39        |
# | DM_ORNTN(c)_BS        |   0           |     0           |
# | DM_OZLN-C(c)_BS       |   0           |  8171.79        |
# | DM_OZLN-E(c)_BS       |   0           |  7641.52        |
# | DM_OZLN-F(c)_BS       |   0           |  7641.52        |
# | DM_OZLN-S(c)_BS       |   0           |  7641.52        |
# | DM_PHAS(s)_BS         |   0           |  1014.01        |
# | DM_PHOM(c)_BS         |   0           |   476.891       |
# | DM_photonDrain(u)_BS  |   0           |    71.3161      |
# | DM_PHTC-A(c)_BS       |   0           |  8410.61        |
# | DM_PHTC-B(c)_BS       |   0           |  8384.29        |
# | DM_PHTC-D(c)_BS       |   0           |  8410.61        |
# | DM_PHTC-E(c)_BS       |   0           |  8410.61        |
# | DM_PINBAN(c)_BS       |   0           |   780.249       |
# | DM_PLAST(s)_BS        |   0           | 17826.2         |
# | DM_PLGNG(c)_BS        |   0           |  1828.45        |
# | DM_PQNNE(s)_BS        |   0           |  9479.83        |
# | DM_PRIMARDN(s)_BS     |   0           |  7165.88        |
# | DM_QRCTN3G(c)_BS      |   0           |  2034.95        |
# | DM_SCLGN(c)_BS        |   0           | -1897.57        |
# | DM_SQ12DGR_OS(s)_BS   |   0           | -3326.13        |
# | DM_SRNTN(c)_BS        |   0           |  2108.57        |
# | DM_STCSD(c)_BS        |   0           |     0           |
# | DM_TRICING(c)_BS      |   0           |   392.07        |
# | DM_TRPN(c)_BS         |   0           |     0           |
# | DM_T-ZTN7G(c)_BS      |   0           |  -578.1         |
# | DM_T-ZTN9G(c)_BS      |   0           |  -578.1         |
# | DM_T-ZTNG(c)_BS       |   0           |  -578.1         |
# | DM_T-ZTNR(c)_BS       |   0           |   624.539       |
# | DM_VTXN(c)_BS         |   0           |  -240.318       |
# | DM_YVITE(s)_BS        |   0           |  8831.9         |
# | DM_PSI_BS             |   0           |    48           |
# | DM_PSII_BS            |   0           |   103.256       |
# | RBPOs_BS              |   0.0454683   |    -1           |
# | ngam_atp_c_BS         |   0.253191    |    -1           |
# | ngam_atp_s_BS         |   0           |   103.318       |
# | ngam_atp_x_BS         |   0           |    61.318       |
# | ngam_atp_m_BS         |   0           |    44.318       |
# | DM_Phloem_BS          |   0.0324623   |    -1           |
# | ngam_nadphox_c_BS     |   0.0444173   |    -1           |
# | ngam_nadphox_s_BS     |   0.0444173   |    -1           |
# | ngam_nadphox_m_BS     |   0.0444173   |    -1           |
# | DM_o2(c)_BS           |   0           |   207.5         |
# | ala-L_pd              |   0.0204313   |    -1           |
# | arg-L_pd              |   0.00310988  |    -1           |
# | asp-L_pd              |   0           |    -0.555556    |
# | cys-L_pd              |   0           |    -1           |
# | glu-L_pd              |   0           |    -0.777778    |
# | gly_pd                |   0           |    -0.111111    |
# | his-L_pd              |   0           |    -1           |
# | ile-L_pd              |   0.00066223  |    -1           |
# | leu-L_pd              |   0.000558351 |    -1           |
# | lys-L_pd              |   0.00167505  |    -1           |
# | met-L_pd              |   0           |    -1           |
# | phe-L_pd              |   0.000139588 |    -1           |
# | pro-L_pd              |   0           |    -0.777778    |
# | ser-L_pd              |   0           |    -0.555556    |
# | thr-L_pd              |   0           |   822.824       |
# | trp-L_pd              |   0           |     1           |
# | tyr-L_pd              |   0.000174972 |    -1           |
# | val-L_pd              |   0.00140237  |    -1           |
# | glc-A_pd              |   0           |    27           |
# | sucr_pd               |   0.0200617   |    -1           |
# | fru-B_pd              |   0           |    27           |
# | udparab_pd            |   0           |    -1           |
# | udpxyl_pd             |   0           |    -0.333333    |
# | udpgal_pd             |   0           |    -1           |
# | udpg_pd               |   0           |    -1           |
# | udpglcur_pd           |   0           |    -1           |
# | co2_pd                |   0           |     0.333333    |
# | h2o_pd                |   0           |     1           |
# | o2_pd                 |   0           |     1           |
# | pep_pd                |   0           |     1           |
# | pyr_pd                |   0.459       |    -1           |
# | mal-L_pd              |   0.00514592  |    -1           |
# | accoa_pd              |   0           |    -1           |
# | glu5p_pd              |   0           |     1.22222     |
# | akg_pd                |   0           |    -0.777778    |
# | icit_pd               |   0           |    -1           |
# | gal_pd                |   0           |    14           |
# | g1p_pd                |   0           |    -1           |
# | tre_pd                |   0           |    -1           |
# | glc-B_pd              |   0           |     0           |
# | tre6p_pd              |   0           |    -1           |
# | g6p-A_pd              |   0           |    -1           |
# | b-glucan_pd           |   0           |    -1           |
# | mnt_pd                |   0           |    -1           |
# | melib_pd              |   0           |    40           |
# | stc_pd                |   0           |    25           |
# | raffin_pd             |   0           |    12           |
# | 1Dgali_pd             |   0           |    -1           |
# | inost_pd              |   0           |    -2.84217e-14 |
# | cit_pd                |   0.0145152   |    -1           |
# | oxa_pd                |   0           |     1.66667     |
# | 2pg_pd                |   0           |     1           |
# | dhap_pd               |   0           |     1           |
# | g3p_pd                |   0           |     1           |
# | 3pg_pd                |   0           |     1           |
# | glyclt_pd             |   0           |    -0.111111    |
# | acon-C_pd             |   0           |    -1           |
# | succ_pd               |   0           |    -1           |
# +-----------------------+---------------+-----------------+

# %%
# #This code block is to generate flux values thru the network given a set of constraints to PPFD

# ppfd_solns_2cell_fba = pd.DataFrame(index=list(i.id for i in model.reactions))
# ppfd_solns_2cell_fva  = pd.DataFrame(index=list(i.id for i in model.reactions))

# #Iterate from range 0 to 2000 w/ increments of 50 (max ppfd)
   
# for i in range(0,2100,50):
#     with model:
#         ppfd = i 
#         #Set medium to change photon flux and other things and re-add to model
#         model_media['EX_photonVis(e)'] = ppfd
#         model_media['EX_co2(e)'] = 29
#         model_media['EX_o2(e)'] = 2.2618 #umol/m^2 s O2
#         model.medium = model_media

#         model.reactions.get_by_id('Straw_Biomass_M').objective_coefficient = 1
#         model.reactions.get_by_id('Straw_Biomass_BS').objective_coefficient = 1



#         #perform pFBA & convert to dataframe
#         tc_soln = cobra.flux_analysis.pfba(model).to_frame()
# #         tc_summary = model.summary(fva=0.95).to_frame()
#         tc_soln = pd.DataFrame({ppfd:tc_soln['fluxes']}, index=list(tc_soln.index))
#         print("PPFD:", ppfd, " RBPC_M cell flux:", tc_soln[ppfd]['RBPCs_M'])
#         #Append to Dataframe
#         ppfd_solns_2cell_fba[ppfd] = tc_soln
#        # ppfd_solns_2cell_fva[ppfd] = 

# #Code now works

# %%
#Constraining O2 consumption to around 3.312 forces water to be consumed by the system, unlike when O2 is unconstrained.
#However, the same behavior when it comes to CO2 assimilation still is being produced.
#Constraining O2 consumption also forces Nitrate consumption to be constrained to realistic levels (when compared to non-constrained O2 where consumption was 10-fold )
#I suspect that this is definitely due to how PPFD flux is structured. 
#A cop-out to this would be to double PPFD per run and measuring PPFD flux in the specific reactions instead.

# %%
#I can probably do the benchmarking right now. The model behaves quite interestingly actually

# %%
#Note: Turning off other prism reactions (red, green, blue, etc) while retaining only white light reactions lowers net carbon assimilation
#I think this is in consideration on how white light is partitioned to several wavelengths, which prevents it from being fully utilized.

# %%
#Other artifacts as of the moment include the following:
#model doesn't produce any Oxygen. Maybe I should add a specific demand reaction for it?
#Based on FVA, the model now produces some oxygen via the demand reaction.

# %%
#Model also facilitates transfer of metabolites unlike before.

# %%
#Questions:
#Should I restrict Nutrient flow to the Bundle Sheath Cell only or should I allow flux to both the M and BS cell?
#Apparently kasi dito only the Bundle sheath cells produce any biomass
#This is to ensure that only CO2 and Light flux are the only limiting constraints to the system.
