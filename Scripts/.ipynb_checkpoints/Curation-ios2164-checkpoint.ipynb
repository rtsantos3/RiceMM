# %%
import cobra
import libsbml
import escher
from cobra import Model, Reaction, Metabolite
import csv
import pandas as pd

# %%
ios2164_orig = cobra.io.read_sbml_model("../model/iOS2164_rewritten.xml")
ios2164_m = cobra.io.read_sbml_model("../model/iOS2164_rewritten.xml")
ios2164_bs = cobra.io.read_sbml_model("../model/iOS2164_rewritten.xml")

# %%
#initialize empty cobra model for 2-cell
ios2164_2cell = Model()

# %%
for item in ios2164_m.metabolites:
    item.id = str(item.id) + '0'
    item.compartment = str(item.compartment) + '0'

for item in ios2164_m.reactions:
    item.id = str(item.id) + '_M'
    

ios2164_m.compartments = {
 'c0': 'M Cell Cytoplasm',
 's0': 'M Cell Plastid',
 'r0': 'M Cell Endoplasmic_reticulum',
 'm0': 'M Cell Mitochondrion',
 'e0': 'M Cell Extracellular',
 'u0': 'M Cell Thylakoid',
 'x0': 'M Cell Peroxisome',
 'v0': 'M Cell Vacuole'}

# %%
for item in ios2164_bs.metabolites:
    item.id = str(item.id) + '1'
    item.compartment = str(item.compartment) + '1'
    
for item in ios2164_bs.reactions:
    item.id = str(item.id)  + '_BS'
    

ios2164_bs.compartments = {
 'c1': 'BS Cell Cytoplasm',
 's1': 'BS Cell Plastid',
 'r1': 'BS Cell Endoplasmic_reticulum',
 'm1': 'BS Cell Mitochondrion',
 'e1': 'BS Cell Extracellular',
 'u1': 'BS Cell Thylakoid',
 'x1': 'BS Cell Peroxisome',
 'v1': 'BS Cell Vacuole'}

# %%
#Merging the BS and M Cells
ios2164_2cell = ios2164_m.merge(ios2164_bs, objective = "sum", inplace =  1)

# %%
ios2164_2cell.summary()
#Ok it works na, just need to put linker fluxes
# Out:
# <h3>Objective</h3><p>1.0 Straw_Biomass_M + 1.0 Straw_Biomass_BS = 176.53829358159678</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>arg_DASH_L_e1</td>
#       <td>EX_arg_DASH_L_LPAREN_e_RPAREN__BS</td>
#       <td>1.086</td>
#       <td>6</td>
#       <td>0.02%</td>
#     </tr>
#     <tr>
#       <td>arg_DASH_L_e0</td>
#       <td>EX_arg_DASH_L_LPAREN_e_RPAREN__M</td>
#       <td>1.086</td>
#       <td>6</td>
#       <td>0.02%</td>
#     </tr>
#     <tr>
#       <td>cys_DASH_L_e1</td>
#       <td>EX_cys_DASH_L_LPAREN_e_RPAREN__BS</td>
#       <td>547.5</td>
#       <td>3</td>
#       <td>4.28%</td>
#     </tr>
#     <tr>
#       <td>cys_DASH_L_e0</td>
#       <td>EX_cys_DASH_L_LPAREN_e_RPAREN__M</td>
#       <td>547.5</td>
#       <td>3</td>
#       <td>4.28%</td>
#     </tr>
#     <tr>
#       <td>gln_DASH_L_e1</td>
#       <td>EX_gln_DASH_L_LPAREN_e_RPAREN__BS</td>
#       <td>63.13</td>
#       <td>5</td>
#       <td>0.82%</td>
#     </tr>
#     <tr>
#       <td>gln_DASH_L_e0</td>
#       <td>EX_gln_DASH_L_LPAREN_e_RPAREN__M</td>
#       <td>63.13</td>
#       <td>5</td>
#       <td>0.82%</td>
#     </tr>
#     <tr>
#       <td>glu_DASH_L_e1</td>
#       <td>EX_glu_DASH_L_LPAREN_e_RPAREN__BS</td>
#       <td>1000</td>
#       <td>5</td>
#       <td>13.04%</td>
#     </tr>
#     <tr>
#       <td>glu_DASH_L_e0</td>
#       <td>EX_glu_DASH_L_LPAREN_e_RPAREN__M</td>
#       <td>1000</td>
#       <td>5</td>
#       <td>13.04%</td>
#     </tr>
#     <tr>
#       <td>h_e1</td>
#       <td>EX_h_LPAREN_e_RPAREN__BS</td>
#       <td>233.2</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>h_e0</td>
#       <td>EX_h_LPAREN_e_RPAREN__M</td>
#       <td>233.2</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>his_DASH_L_e1</td>
#       <td>EX_his_DASH_L_LPAREN_e_RPAREN__BS</td>
#       <td>5.031</td>
#       <td>6</td>
#       <td>0.08%</td>
#     </tr>
#     <tr>
#       <td>his_DASH_L_e0</td>
#       <td>EX_his_DASH_L_LPAREN_e_RPAREN__M</td>
#       <td
</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>coa_c1</td>
#       <td>DM_COA_LPAREN_c_RPAREN__BS</td>
#       <td>-0.0008912</td>
#       <td>21</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>coa_c0</td>
#       <td>DM_COA_LPAREN_c_RPAREN__M</td>
#       <td>-0.0008912</td>
#       <td>21</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>photonDrain_u1</td>
#       <td>DM_photonDrain_LPAREN_u_RPAREN__BS</td>
#       <td>-321.2</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>photonDrain_u0</td>
#       <td>DM_photonDrain_LPAREN_u_RPAREN__M</td>
#       <td>-321.2</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>ac_e1</td>
#       <td>EX_ac_LPAREN_e_RPAREN__BS</td>
#       <td>-814.7</td>
#       <td>2</td>
#       <td>5.29%</td>
#     </tr>
#     <tr>
#       <td>ac_e0</td>
#       <td>EX_ac_LPAREN_e_RPAREN__M</td>
#       <td>-814.7</td>
#       <td>2</td>
#       <td>5.29%</td>
#     </tr>
#     <tr>
#       <td>ala_DASH_L_e1</td>
#       <td>EX_ala_DASH_L_LPAREN_e_RPAREN__BS</td>
#       <td>-1000</td>
#       <td>3</td>

# %%
ios2164_2cell.metabolites.glc_DASH_A_c1
# Out:
# <Metabolite glc_DASH_A_c1 at 0x7f2985b357f0>

# %% [markdown]
# From Blatke & Brautigam (2019):
#
# "The mesophyll and bundle sheath networks are connected by a range of cytosolic transport metabolites including amino acids, sugars (glucose, fructose, sucrose, trehalose, ribose), single phosphorylated sugar (glucose-6-phosphate, glucose-1-phosphate, fructose-6-phosphate, sucrose-6-phosphate), mono-/di-/tri-carboxylic acids (phosphoenolpyruvate, pyruvate, citrate, cis-aconitate, isocitrate, α-ketoglutarate, succinate, fumarate, malate), glyceric acids (2-Phosphoglycerate, 3-Phosphoglycerate), glycolate, glycerate, glyceraldehyde-3-phosphate, di-hydroxyacetone-phosphate and CO2.
#
# Nucleotides, NAD/NADH, NADP/NADPH, pyrophosphate, inorganic phosphate are not considered as transport metabolites.
#
# Oxaloacetate has been excluded as transport metabolite since concentrations of oxaloacetate are very low in vivo and it is reasonably unstable in aqueous solutions.
#
# Other small molecules that can be imported by the bundle sheath from the environment, as well as protons and HCO3-, are not exchanged between the two cell types.
#
# #So bale yung mga organic na soluble lang with reasonably long cellular half-lives.

# %%
#Open the initial curated list to get the metabolite ids
transport_rxns = pd.read_csv('../model/initial_list_transport_rxns.csv')
#Ok it gets the reactions now
type(transport_rxns)
for item in ios2164_orig.metabolites:
    if item.compartment == "c":
        if item.id in transport_rxns.id.values:
            pd_rxn = Reaction()
            #Generate reaction name
            pd_rxn.id = str(item.id[:-2] + '_pd') #Replaces suffix with '_pd'
            pd_rxn.name = str('Plasmodesmatal transport of ' + item.name)
            pd_rxn.subsystem = str('PD Transport Reaction')
            #Reaction is reversible
            pd_rxn.lower_bound = -1000
            pd_rxn.upper_bound = 1000
            ios2164_2cell.add_reaction(pd_rxn)
            
            #Generate metabolite names
            met_mcell = str(item.id) + '0'
            met_bcell = str(item.id) + '1'
# Out:
# Ignoring reaction 'ala_DASH_L_pd' since it already exists.
# Ignoring reaction 'arg_DASH_L_pd' since it already exists.
# Ignoring reaction 'asp_DASH_L_pd' since it already exists.
# Ignoring reaction 'cys_DASH_L_pd' since it already exists.
# Ignoring reaction 'glu_DASH_L_pd' since it already exists.
# Ignoring reaction 'gly_pd' since it already exists.
# Ignoring reaction 'his_DASH_L_pd' since it already exists.
# Ignoring reaction 'ile_DASH_L_pd' since it already exists.
# Ignoring reaction 'leu_DASH_L_pd' since it already exists.
# Ignoring reaction 'lys_DASH_L_pd' since it already exists.
# Ignoring reaction 'met_DASH_L_pd' since it already exists.
# Ignoring reaction 'phe_DASH_L_pd' since it already exists.
# Ignoring reaction 'pro_DASH_L_pd' since it already exists.
# Ignoring reaction 'ser_DASH_L_pd' since it already exists.
# Ignoring reaction 'thr_DASH_L_pd' since it already exists.
# Ignoring reaction 'trp_DASH_L_pd' since it already exists.
# Ignoring reaction 'tyr_DASH_L_pd' since it already exists.
# Ignoring reaction 'val_DASH_L_pd' since it already exists.
# Ignoring reaction 'glc_DASH_A_pd' since it already exists.
# Ignoring reaction 'sucr_pd' since it already exists.
# Ignoring reaction 'fru_DASH_B_pd' since it already exists.
# Ignoring reaction 'udparab_pd' since it already exists.
# Ignoring reaction 'udpxyl_pd' since it already exists.
# Ignoring reaction 'udpgal_pd' since it already exists.
# Ignoring reaction 'udpg_pd' since it already exists.
# Ignoring reaction 'udpglcur_pd' since it already exists.
# Ignoring reaction 'co2_pd' since it already exists.
# Ignoring reaction 'h2o_pd' since it already exists.
# Ignoring reaction 'o2_pd' since it already exists.
# Ignoring reaction 'pep_pd' since it already exists.
# Ignoring reaction 'pyr_pd' since it already exists.
# Ignoring reaction 'mal_DASH_L_pd' since it already exists.
# Ignoring reaction 'accoa_pd' since it already exists.
# Ignoring reaction 'glu5p_pd' since it already exists.
# Ignoring reaction 'akg_pd' since it already exists.
# Ignoring reaction 'icit_pd' since it already exists.
# Ignoring reaction 'gal_pd' since it already exists.
# Ignoring reaction 'g1p_pd' since it already exists.
# Ignoring reaction 'tre_pd' since it already exists.
# Ignoring reaction 'glc_DASH_B_pd' since it already exists.
# Ignoring reaction 'tre6p_pd' since it already exists.
# Ignoring reaction 'g6p_DASH_A_pd' since it already exists.
# Ignoring reaction 'b_DASH_glucan_pd' since it already exists.
# Ignoring reaction 'mnt_pd' since it already exists.
# Ignoring reaction 'melib_pd' since it already exists.
# Ignoring reaction 'stc_pd' since it already exists.
# Ignoring reaction 'raffin_pd' since it already exists.
# Ignoring reaction '1Dgali_pd' since it already exists.
# Ignoring reaction 'inost_pd' since it already exists.
# Ignoring reaction 'cit_pd' since it already exists.
# Ignoring reaction 'oxa_pd' since it already exists.
# Ignoring reaction '2pg_pd' since it already exists.
# Ignoring reaction 'dhap_pd' since it already exists.
# Ignoring reaction 'g3p_pd' since it already exists.
# Ignoring reaction '3pg_pd' since it already exists.
# Ignoring reaction 'glyclt_pd' since it already exists.
# Ignoring reaction 'acon_DASH_C_pd' since it already exists.
# Ignoring reaction 'succ_pd' since it already exists.

# %%
            
            
            
#             met
# #             met_mcell = ios2164_2cell.metabolites.get_by_id(met_mcell)
# #             met_bcell = ios2164_2cell.metabolites.get_by_id(met_bcell)
#             pd_rxn.add_metabolites = ({met_mcell: -1.0, met_bcell: 1.0})
#
# Out:
# Ignoring reaction 'ala_DASH_L_pd' since it already exists.
# Ignoring reaction 'arg_DASH_L_pd' since it already exists.
# Ignoring reaction 'asp_DASH_L_pd' since it already exists.
# Ignoring reaction 'cys_DASH_L_pd' since it already exists.
# Ignoring reaction 'glu_DASH_L_pd' since it already exists.
# Ignoring reaction 'gly_pd' since it already exists.
# Ignoring reaction 'his_DASH_L_pd' since it already exists.
# Ignoring reaction 'ile_DASH_L_pd' since it already exists.
# Ignoring reaction 'leu_DASH_L_pd' since it already exists.
# Ignoring reaction 'lys_DASH_L_pd' since it already exists.
# Ignoring reaction 'met_DASH_L_pd' since it already exists.
# Ignoring reaction 'phe_DASH_L_pd' since it already exists.
# Ignoring reaction 'pro_DASH_L_pd' since it already exists.
# Ignoring reaction 'ser_DASH_L_pd' since it already exists.
# Ignoring reaction 'thr_DASH_L_pd' since it already exists.
# Ignoring reaction 'trp_DASH_L_pd' since it already exists.
# Ignoring reaction 'tyr_DASH_L_pd' since it already exists.
# Ignoring reaction 'val_DASH_L_pd' since it already exists.
# Ignoring reaction 'glc_DASH_A_pd' since it already exists.
# Ignoring reaction 'sucr_pd' since it already exists.
# Ignoring reaction 'fru_DASH_B_pd' since it already exists.
# Ignoring reaction 'udparab_pd' since it already exists.
# Ignoring reaction 'udpxyl_pd' since it already exists.
# Ignoring reaction 'udpgal_pd' since it already exists.
# Ignoring reaction 'udpg_pd' since it already exists.
# Ignoring reaction 'udpglcur_pd' since it already exists.
# Ignoring reaction 'co2_pd' since it already exists.
# Ignoring reaction 'h2o_pd' since it already exists.
# Ignoring reaction 'o2_pd' since it already exists.
# Ignoring reaction 'pep_pd' since it already exists.
# Ignoring reaction 'pyr_pd' since it already exists.
# Ignoring reaction 'mal_DASH_L_pd' since it already exists.
# Ignoring reaction 'accoa_pd' since it already exists.
# Ignoring reaction 'glu5p_pd' since it already exists.
# Ignoring reaction 'akg_pd' since it already exists.
# Ignoring reaction 'icit_pd' since it already exists.
# Ignoring reaction 'gal_pd' since it already exists.
# Ignoring reaction 'g1p_pd' since it already exists.
# Ignoring reaction 'tre_pd' since it already exists.
# Ignoring reaction 'glc_DASH_B_pd' since it already exists.
# Ignoring reaction 'tre6p_pd' since it already exists.
# Ignoring reaction 'g6p_DASH_A_pd' since it already exists.
# Ignoring reaction 'b_DASH_glucan_pd' since it already exists.
# Ignoring reaction 'mnt_pd' since it already exists.
# Ignoring reaction 'melib_pd' since it already exists.
# Ignoring reaction 'stc_pd' since it already exists.
# Ignoring reaction 'raffin_pd' since it already exists.
# Ignoring reaction '1Dgali_pd' since it already exists.
# Ignoring reaction 'inost_pd' since it already exists.
# Ignoring reaction 'cit_pd' since it already exists.
# Ignoring reaction 'oxa_pd' since it already exists.
# Ignoring reaction '2pg_pd' since it already exists.
# Ignoring reaction 'dhap_pd' since it already exists.
# Ignoring reaction 'g3p_pd' since it already exists.
# Ignoring reaction '3pg_pd' since it already exists.
# Ignoring reaction 'glyclt_pd' since it already exists.
# Ignoring reaction 'acon_DASH_C_pd' since it already exists.
# Ignoring reaction 'succ_pd' since it already exists.

# %%
#Shows all the added plasmodesmatal reactions
pd_rxn = [item for item in ios2164_2cell.reactions if "_pd" in item.id]

ios2164_2cell.reactions
#Stoichiometry is missing. Bakit kaya?
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-9273840cd174> in <module>
#       2 pd_rxn = [item for item in ios2164_2cell.reactions if "_pd" in item.id]
#       3
# ----> 4 ios2164_2cell.reactions()
#       5 #Stoichiometry is missing. Bakit kaya?
#
# TypeError: 'DictList' object is not callable
