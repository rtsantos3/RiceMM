# %%
import sys
sys.path.append("../src/") 
import os

import model_manipulation as mm
import cobra
import cplex 
import libsbml
import pandas as pd
import copy
from pathlib import Path
import memote
import csv
import pytest

# %%
#This jupyter notebook is to test out the basic properties of the two cell model, 
#based on Thiel & Fleming (2018?)
# https://opencobra.github.io/cobratoolbox/latest/tutorials/tutorialModelSanityChecks.html

model = cobra.io.read_sbml_model('../model/ios2164_1cell.xml')
model.solve = 'gurobi'

# %%
model2 =cobra.io.read_sbml_model('../Supplementary_PrevLit/Lakshmanan et al/ios2164.xml')
# Out:
# Model does not contain SBML fbc package information.
# SBML package 'layout' not supported by cobrapy, information is not parsed
# SBML package 'render' not supported by cobrapy, information is not parsed
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_ala_DASH_L_c "L-Alanine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ala_DASH_L_c "L-Alanine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_arg_DASH_L_c "L-Arginine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_arg_DASH_L_c "L-Arginine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_asp_DASH_L_c "L-Aspartate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_asp_DASH_L_c "L-Aspartate">
# ...

# %%
#Test nga natin yung model2 kung ganyan rin siya.


for item in model2.reactions:
    if "EX_" in item.id:
        item.lower_bound = 0


model2.reactions.get_by_id('EX_photonVis_LPAREN_e_RPAREN_').lower_bound = -1000
#     model2.reactions.get_by_id('EX_o2_LPAREN_e_RPAREN_').lower_bound = -10
#     model2.reactions.get_by_id('EX_co2_LPAREN_e_RPAREN_').lower_bound = -10
model2.reactions.get_by_id('EX_fe3_LPAREN_e_RPAREN_').lower_bound = -10
# model2.reactions.get_by_id('EX_mg2_LPAREN_e_RPAREN_').lower_bound = -10
model2.reactions.get_by_id('EX_no3_LPAREN_e_RPAREN_').lower_bound = -10
model2.reactions.get_by_id('EX_so4_LPAREN_e_RPAREN_').lower_bound = -10
model2.reactions.get_by_id('EX_h2o_LPAREN_e_RPAREN_').lower_bound = -10
model2.reactions.get_by_id('EX_pi_LPAREN_e_RPAREN_').lower_bound = -1000
model2.reactions.get_by_id('EX_h_LPAREN_e_RPAREN_').lower_bound = -10


with model2:
    
    cobra.flux_analysis.add_loopless(model2)
    summ = model2.optimize()
# Out:
# ---------------------------------------------------------------------------
# OptimizationError                         Traceback (most recent call last)
# <ipython-input-6-a6d30b4ab66e> in <module>
#      22
#      23     cobra.flux_analysis.add_loopless(model2)
# ---> 24     summ = model2.optimize()
#      25
#      26 summ
#
# ~/anaconda3/lib/python3.8/site-packages/cobra/core/model.py in optimize(self, objective_sense, raise_error)
#    1092         )
#    1093         self.slim_optimize()
# -> 1094         solution = get_solution(self, raise_error=raise_error)
#    1095         self.objective.direction = original_direction
#    1096         return solution
#
# ~/anaconda3/lib/python3.8/site-packages/cobra/core/solution.py in get_solution(model, reactions, metabolites, raise_error)
#     234     legacy solvers.
#     235     """
# --> 236     check_solver_status(model.solver.status, raise_error=raise_error)
#     237     if reactions is None:
# ...

# %%
summ.to_frame

summ
# Out:
# <Solution 1.329 at 0x7f674dff53d0>

# %%
#Notes:
#Main paths from pi_e include feeding towards erroneous ATP generation. 
#ATP and cellulose (derived from another ATP generating process) also feeds into biomass equation
#pFBA doesn't work to remove the loops
#Loopless FBA (add_loopless) doesn't work

# %%
#Notes for curated 1-cell model:
#Erroneous loops particularly in GAPDH1ys have abnormally high flux, which in turn generates more ATP and feeding to biomass

# %%
#The original modellers for ios2164 turned off a number of reactions to prevent co-factor  recycling:
#From Lakshmanan et al (2016):

#Considering the large size of iOS2164, a set of reactions belonging to folates metabolism, 
#glycolysis/gluconeogenesis, nitrogen metabolism, and sulfate metabolism was also constrained 
#at zero in leaf and coleoptile simulations to avoid free cofactor recycling. 
#The complete sets of reactions that are inactivated during both the simulations are listed in Supplemental Data Set S2.

# %%
#I'll try to export these reactions to a list first then implement it, then check if the solutions are still ok afterwards

# %%
#Load inactive reactions in model
file = csv.reader(open('../misc/leaf_inactivated.tsv'), delimiter='\t')
leaf_inactive_rxns = list()
for rows in file:
    row = str()
    for rxns in rows:
        row += str(rxns)
    leaf_inactive_rxns.append(row)

leaf_inactive_rxns
# Out:
# ['Reactions inactivated in leaf',
#  'Coleoptile_Biomass',
#  'PRISM_blue_LED',
#  'PRISM_red_LED',
#  'PRISM_green_LED',
#  'RBPCs/RBPC2s',
#  'GDHym',
#  'GDHm',
#  'AGATx',
#  'AGATs',
#  'ICDHc',
#  'GTHPs',
#  'GLCNGBc',
#  'GLCNGAc',
#  'MDHs',
#  'MDHc',
#  'ASPTAm',
#  'PDHam1m',
#  'PDHam2m',
#  'PDHe2m',
#  'PDHe3m',
#  'THR3DHx',
#  'FDHNc',
#  'SULOm',
#  'ASNS1c',
#  'GLYCORc',
#  'TYRTAs',
#  'ARGOAT1s',
#  'PGI2c',
#  'PGI2s',
#  'GAMPTc',
#  'FTHFLc',
#  'CALANc',
#  'FORAc',
#  'SHMTs',
#  'MLTHFRs',
#  'METSc',
#  'GAPDHys',
#  'GAPDH2s',
#  'MTHFDm',
#  'MTHFDc',
#  'FTHFCLc',
#  'MTHFDym',
#  'MTHFDys',
#  'GLYK2s',
#  'UREASEc',
#  'ATSc',
#  'SHSL1s',
#  'SPPAs',
#  'PFPc',
#  'PTOXs',
#  'PFKc',
#  'PFKs',
#  'AAs',
#  'HCO3Es',
#  'HCO3Em',
#  'CHLASEs',
#  'ALTNDAc',
#  'NADOR2u',
#  'AKGCITtm',
#  'AKGICITtm',
#  'MALICITtm',
#  'MALOAAtm',
#  'OAAAKGtm',
#  'OAACITtm',
#  'OAAICITtm',
#  '5FTHFtm',
#  'MLTHFtm',
#  'NA1Htm',
#  'PI:natm',
#  '5FTHFts',
# ...

# %%
#With phosphate import

with model: 
    for rxns in model.reactions:
        if rxns.id in leaf_inactive_rxns: #Turn off all reactions in list shown above
            rxns.bounds = (0,0)
            
    photo_medium = mm.read_medium_csv('../misc/photo_medium.csv', model)
    photo_medium['EX_co2(e)'] = 1
    photo_medium['EX_o2(e)'] = 1
    photo_medium['EX_pi(e)'] = 1
    photo_medium['EX_no3(e)'] = 1
    photo_medium['EX_photonVis(e)'] = 1000

    model.medium = photo_medium 
    
    summ_no_cofactor_cyc = model.summary()
    blocked_rxns_list = cobra.flux_analysis.find_blocked_reactions(model)
    cobra.io.write_sbml_model(model, '../model/for_testing/ios2164_1cell_turned_off_leaf_rxns.xml')
summ_no_cofactor_cyc
# Out:
# /home/rtsantos3/anaconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# Could not get flux for reaction AOXm, setting it to NaN. This is usually due to numerical instability.
# /home/rtsantos3/anaconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# Could not get flux for reaction FA183ACOASc, setting it to NaN. This is usually due to numerical instability.
# <h3>Objective</h3><p>1.0 Straw_Biomass = 0.01906174710800505</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>co2_e</td>
#       <td>EX_co2(e)</td>
#       <td>1</td>
# ...

# %%
#No phosphate import

with model: 
    for rxns in model.reactions:
        if rxns.id in leaf_inactive_rxns: #Turn off all reactions in list shown above
            rxns.bounds = (0,0)
            
    photo_medium = mm.read_medium_csv('../misc/photo_medium.csv', model)
    photo_medium['EX_co2(e)'] = 1
    photo_medium['EX_o2(e)'] = 1
    photo_medium['EX_pi(e)'] = 0
    photo_medium['EX_no3(e)'] = 1
    photo_medium['EX_photonVis(e)'] = 1000

    model.medium = photo_medium 
    
    summ_no_cofactor_cyc = model.summary()
summ_no_cofactor_cyc
# Out:
# <h3>Objective</h3><p>1.0 Straw_Biomass = 0.0</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>o2_e</td>
#       <td>EX_o2(e)</td>
#       <td>0.0201</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>photonVis_e</td>
#       <td>EX_photonVis(e)</td>
#       <td>0.9781</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>photonDrain_u</td>
#       <td>DM_photonDrain(u)</td>
#       <td>-0.5462</td>
# ...

# %%
#with phosphate import but no gases

with model: 
    for rxns in model.reactions:
        if rxns.id in leaf_inactive_rxns: #Turn off all reactions in list shown above
            rxns.bounds = (0,0)
            
    photo_medium = mm.read_medium_csv('../misc/photo_medium.csv', model)
    photo_medium['EX_co2(e)'] = 0
    photo_medium['EX_o2(e)'] = 0
    photo_medium['EX_pi(e)'] = 0
    photo_medium['EX_no3(e)'] = 1
    photo_medium['EX_photonVis(e)'] = 1000

    model.medium = photo_medium 
    
    summ_no_cofactor_cyc = model.summary()
summ_no_cofactor_cyc
# Out:
# <h3>Objective</h3><p>1.0 Straw_Biomass = 0.0</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>photonVis_e</td>
#       <td>EX_photonVis(e)</td>
#       <td>0.9792</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>photonDrain_u</td>
#       <td>DM_photonDrain(u)</td>
#       <td>-0.556</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>h2o_e</td>
#       <td>EX_h2o(e)</td>
#       <td>-0.1969</td>
# ...

# %%
#1st attempt:  passed  complete  list from Lakshmanan  et  al (2016) to deactivate all co-factor
#Cycling related  genes. Was blocked as it included  PRISM_White_LED, which was the only wavelength
#that I've activated. Result was that solver
#was infeasible.

#2nd attempt: Passed  the  same  list as  above except for PRISM_White_LED. Result was that 
#the there  was a optimal solutiion to the solver. Furthermore, testing it with no phosphate input
#Returns 0 flux to Biomass.

#3rd  attempt: Same  conditions, no gas input. No production of biomass.

# %%
for item in model.exchanges:
    print(item.id, item.bounds)
# Out:
# EX_co2(e) (-1000000, 0.0)
# EX_h2o(e) (-1000000, 1000000000.0)
# EX_h(e) (0, 1000000000.0)
# EX_no3(e) (-1000000, 0.0)
# EX_o2(e) (-1000000, 1000000000.0)
# EX_pi(e) (-1000000, 1000000000.0)
# EX_sucr(e) (0, 0.0)
# EX_fru-B(e) (0, 0.0)
# EX_glc-A(e) (0, 0.0)
# EX_so4(e) (-1000000, 1000000000.0)
# EX_hco3(e) (0, 0.0)
# EX_so3(e) (-1000000, 0.0)
# EX_h2s(e) (-1000000, 0.0)
# EX_nh4(e) (-1000000, 0.0)
# EX_asn-L(e) (0, 1000000000.0)
# EX_gln-L(e) (0, 1000000000.0)
# EX_etoh(e) (0, 1000000000.0)
# EX_ac(e) (0, 1000000000.0)
# EX_lac-L(e) (0, 1000000000.0)
# EX_tsul(e) (0, 0.0)
# EX_fe2(e) (-1000000, 1000000000.0)
# EX_fe3(e) (-1000000, 0.0)
# EX_mg2(e) (-1000000, 1000000000.0)
# EX_ala-L(e) (0, 1000000000.0)
# EX_arg-L(e) (0, 1000000000.0)
# EX_asp-L(e) (0, 1000000000.0)
# EX_cys-L(e) (0, 1000000000.0)
# EX_glu-L(e) (0, 1000000000.0)
# EX_gly(e) (0, 1000000000.0)
# EX_his-L(e) (0, 1000000000.0)
# EX_ile-L(e) (0, 1000000000.0)
# EX_leu-L(e) (0, 1000000000.0)
# ...

# %%
model2.summary()
# Out:
# <h3>Objective</h3><p>1.0 Straw_Biomass = 1.3290987708860376</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>h_e</td>
#       <td>EX_h_LPAREN_e_RPAREN_</td>
#       <td>10</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>no3_e</td>
#       <td>EX_no3_LPAREN_e_RPAREN_</td>
#       <td>10</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>photonVis_e</td>
#       <td>EX_photonVis_LPAREN_e_RPAREN_</td>
#       <td>1000</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>pi_e</td>
#       <td>EX_pi_LPAREN_e_RPAREN_</td>
#       <td>0.2743</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>so4_e</td>
# ...

# %%
#Weirdly enough this artifact is also observed in the original iOS2164 model.

# %%
#Define closed_model first
closed_model = model.copy()
for bounds in closed_model.boundary:
    bounds.lower_bounds = 0
# Out:
# Read LP format model from file /tmp/tmpxsdz1lkk.lp
# Reading time = 0.01 seconds
# : 1999 rows, 4910 columns, 21084 nonzeros

# %%
closed_model.reactions
# Out:
# [<Reaction Coleoptile_Biomass at 0x7f6752583d00>,
#  <Reaction Straw_Biomass at 0x7f6752583d30>,
#  <Reaction ACCOAC_OSAc at 0x7f6752583d90>,
#  <Reaction ACCOAC_OSAr at 0x7f6752583e80>,
#  <Reaction ACPC_OSs at 0x7f6752583f40>,
#  <Reaction ACPC_OSm at 0x7f6752583dc0>,
#  <Reaction FAC_Osc at 0x7f67525841f0>,
#  <Reaction FAC_Osr at 0x7f6752584340>,
#  <Reaction EX_co2(e) at 0x7f6752584400>,
#  <Reaction EX_h2o(e) at 0x7f6752584550>,
#  <Reaction EX_h(e) at 0x7f6752584670>,
#  <Reaction EX_no3(e) at 0x7f67525847c0>,
#  <Reaction EX_o2(e) at 0x7f6752584880>,
#  <Reaction EX_pi(e) at 0x7f67525849d0>,
#  <Reaction EX_sucr(e) at 0x7f6752584af0>,
#  <Reaction EX_fru-B(e) at 0x7f6752584c40>,
#  <Reaction EX_glc-A(e) at 0x7f6752584d00>,
#  <Reaction EX_so4(e) at 0x7f6752584e50>,
#  <Reaction EX_hco3(e) at 0x7f6752584f70>,
#  <Reaction EX_so3(e) at 0x7f67525840d0>,
#  <Reaction EX_h2s(e) at 0x7f67525851c0>,
#  <Reaction EX_nh4(e) at 0x7f67525852e0>,
# ...

# %%
#First check if model can create biomass from scratch  or from inorganic solutes

#Parametrize the model first using phototrophic  medium
photo_medium = mm.read_medium_csv('../misc/photo_medium.csv', model)
photo_medium['EX_co2(e)'] = 1
photo_medium['EX_o2(e)'] = 1
photo_medium['EX_pi(e)'] = 0
photo_medium['EX_no3(e)'] = 1
photo_medium['EX_photonVis(e)'] = 1000

model.medium = photo_medium

photo_medium
model.summary()
# Out:
# <h3>Objective</h3><p>1.0 Straw_Biomass = 0.0</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>o2_e</td>
#       <td>EX_o2(e)</td>
#       <td>0.02222</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>photonVis_e</td>
#       <td>EX_photonVis(e)</td>
#       <td>0.5675</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>photonDrain_u</td>
#       <td>DM_photonDrain(u)</td>
#       <td>-0.3385</td>
# ...

# %%
# cobra.io.write_sbml_model(model, '../model/for_testing/ios2164_1cell_no_pi.xml')
cobra.io.write_sbml_model(model2, '../model/for_testing/ios2164_original_with_pi.xml')

# %%
#Based on Fluxer, it seems that both the original ios2164 and modified models are producing biomass out of phosphate only
#By generating ATP out of thin air.

# %%
model.metabolites.pi_c.summary()
# Out:
# <h3>pi_c</h3><p>HPO4</p><h4>Producing Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10.26%</td>
#       <td>0.0076</td>
#       <td>PItx</td>
#       <td>h_c + pi_c &lt;=&gt; h_x + pi_x</td>
#     </tr>
#     <tr>
#       <td>32.08%</td>
#       <td>0.02376</td>
#       <td>PPAIcxc</td>
#       <td>h2o_c + ppi_c --&gt; h_x + 2.0 pi_c</td>
#     </tr>
#     <tr>
#       <td>57.66%</td>
#       <td>0.0427</td>
#       <td>ngam_atp_c</td>
#       <td>atp_c --&gt; adp_c + pi_c</td>
#     </tr>
#   </tbody>
# </table><h4>Consuming Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %%
consistent_model = cobra.flux_analysis.fastcc(model)
# Out:
# Read LP format model from file /tmp/tmp94d166lu.lp
# Reading time = 0.01 seconds
# : 1999 rows, 4910 columns, 21084 nonzeros
# /home/rtsantos3/anaconda3/lib/python3.8/site-packages/cobra/core/group.py:107: UserWarning: need to pass in a list
#   warn("need to pass in a list")

# %%
help(cobra.flux_analysis.fastcc)
# Out:
# Help on function fastcc in module cobra.flux_analysis.fastcc:
#
# fastcc(model: 'Model', flux_threshold: float = 1.0, zero_cutoff: Union[float, NoneType] = None) -> 'Model'
#     Check consistency of a metabolic network using FASTCC [1]_.
#
#     FASTCC (Fast Consistency Check) is an algorithm for rapid and
#     efficient consistency check in metabolic networks. FASTCC is
#     a pure LP implementation and is low on computation resource
#     demand. FASTCC also circumvents the problem associated with
#     reversible reactions for the purpose. Given a global model,
#     it will generate a consistent global model i.e., remove
#     blocked reactions. For more details on FASTCC, please
#     check [1]_.
#
#     Parameters
#     ----------
#     model: cobra.Model
#         The model to operate on.
#     flux_threshold: float, optional
#         The flux threshold to consider (default 1.0).
#     zero_cutoff: float, optional
# ...

# %%
blocked_lists =list()

for items in model.reactions:
    if items not in consistent_model.reactions:
        blocked_lists.append(items)
        
len(blocked_lists)
# Out:
# 916

# %%
for item in blocked_lists:
    print(item.id, item.name)
# Out:
# Coleoptile_Biomass Coleoptile Biomass reaction
# Straw_Biomass Straw Biomass reaction
# ACCOAC_OSAc Acyl-CoA (Aerobic composition)
# ACPC_OSs ACP(Aerobic composition)
# ACPC_OSm ACP(Aerobic composition)
# FAC_Osc Fatty acid (Aerobic composition)
# EX_pi(e) Phosphate exchange
# EX_sucr(e) Sucrose exchange
# EX_fru-B(e) Fructose exchange
# EX_glc-A(e) Glucose exchange
# EX_hco3(e) Bicarbonate exchange
# EX_tsul(e) Thiosulfate exchange
# EX_fe2(e) Fe2+ exchange
# EX_fe3(e) Fe3+ exchange
# PRISM_blue_LED spectral decomposition of blue LED (450  nm)
# PRISM_red_LED spectral decomposition of red LED (660  nm)
# PRISM_green_LED spectral decomposition of red LED (530  nm)
# PRISM_solar_litho spectral decomposition of solar light measured from Earth's surface
# RPSI_410(u) Photosystem I 410 specific reaction
# RPSII_410(u) Photosystem II 410 specific reaction
# Pitex PI transport in via diffusion (extracellular to cytosol)
# ...

# %%
consistent_model.summary()
# Out:
# Non-linear or non-reaction model objective. Falling back to minimal display.
# <h3>Objective</h3><p>nan Expression = nan</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>o2_e</td>
#       <td>EX_o2(e)</td>
#       <td>0.02222</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>photonVis_e</td>
#       <td>EX_photonVis(e)</td>
#       <td>0.5675</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %%
# !memote report snapshot '../Supplementary_PrevLit/Lakshmanan et al/ios2164.xml'
# Out:
# ...
# Set parameter Username
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-06-12
# Academic license - for non-commercial use only - expires 2022-06-12
# ...
# ...
# ...
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# ============================= test session starts ==============================
# platform linux -- Python 3.8.8, pytest-7.1.1, pluggy-0.13.1
# rootdir: /home/rtsantos3
# plugins: anyio-3.3.0, metadata-2.0.1
# collected 155 items / 1 skipped
#
# ../../../anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py F [  0%]
# FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF..         [ 41%]
# ../../../anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_basic.py . [ 42%]
# ...F.F........F.....FF                                                   [ 56%]
# ...
