# %%
import cobra
import libsbml
import escher
from cobra import Model, Reaction, Metabolite
import csv
import pandas as pd
import copy

# %%
ios2164_orig = cobra.io.read_sbml_model("../model/iOS2164_orig.xml")
# Out:
# Model does not contain SBML fbc package information.
# SBML package 'layout' not supported by cobrapy, information is not parsed
# SBML package 'render' not supported by cobrapy, information is not parsed
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_ala_DASH_L_c "L-Alanine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ala_DASH_L_c "L-Alanine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_arg_DASH_L_c "L-Arginine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_arg_DASH_L_c "L-Arginine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_asp_DASH_L_c "L-Aspartate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_asp_DASH_L_c "L-Aspartate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_cys_DASH_L_c "L-Cysteine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_cys_DASH_L_c "L-Cysteine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_glu_DASH_L_c "L-Glutamate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_glu_DASH_L_c "L-Glutamate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_gly_c "Glycine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_gly_c "Glycine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_his_DASH_L_c "L-Histidine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_his_DASH_L_c "L-Histidine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_ile_DASH_L_c "L-Isoleucine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ile_DASH_L_c "L-Isoleucine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_leu_DASH_L_c "L-Leucine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_leu_DASH_L_c "L-Leucine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_lys_DASH_L_c "L-Lysine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_lys_DASH_L_c "L-Lysine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_met_DASH_L_c "L-Methionine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_met_DASH_L_c "L-Methionine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_phe_DASH_L_c "L-Phenylalanine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_phe_DASH_L_c "L-Phenylalanine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_pro_DASH_L_c "L-Proline">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_pro_DASH_L_c "L-Proline">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_ser_DASH_L_c "L-Serine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ser_DASH_L_c "L-Serine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_thr_DASH_L_c "L-Threonine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_thr_DASH_L_c "L-Threonine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_trp_DASH_L_c "L-Tryptophan">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_trp_DASH_L_c "L-Tryptophan">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_tyr_DASH_L_c "L-Tyrosine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_tyr_DASH_L_c "L-Tyrosine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_val_DASH_L_c "L-Valine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_val_DASH_L_c "L-Valine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_glc_DASH_A_c "alpha-D-glucose">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_glc_DASH_A_c "alpha-D-glucose">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_sucr_c "Sucrose">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_sucr_c "Sucrose">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_fru_DASH_B_c "beta-D-fructose">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_fru_DASH_B_c "beta-D-fructose">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_starch_s "Starch (n=4, 4 glucose units)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_starch_s "Starch (n=4, 4 glucose units)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_cellulose_c "Cellulose">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_cellulose_c "Cellulose">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_udparab_c "UDP-L-arabinose">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_udparab_c "UDP-L-arabinose">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_udpxyl_c "UDP-D-xylose">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_udpxyl_c "UDP-D-xylose">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_udpgal_c "UDP-galactose">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_udpgal_c "UDP-galactose">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_udpg_c "UDP-glucose">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_udpg_c "UDP-glucose">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_udpglcur_c "UDP-D-glucuronate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_udpglcur_c "UDP-D-glucuronate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_datp_c "dATP">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_datp_c "dATP">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_dctp_c "dCTP">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_dctp_c "dCTP">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_dttp_c "dTTP">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_dttp_c "dTTP">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_dgtp_c "dGTP">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_dgtp_c "dGTP">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_utp_c "UTP">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_utp_c "UTP">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_ctp_c "CTP">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ctp_c "CTP">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_gtp_c "GTP">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_gtp_c "GTP">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_fa_os_r "fatty acid, lumped (oryza sativa specific)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_fa_os_r "fatty acid, lumped (oryza sativa specific)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_triglyc_os_r "Triacylglycerol (oryza sativa specific)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_triglyc_os_r "Triacylglycerol (oryza sativa specific)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_pa_os_r "Phosphatidate (oryza sativa specific)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_pa_os_r "Phosphatidate (oryza sativa specific)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_pc_os_r "Phosphatidylcholine (oryza sativa specific)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_pc_os_r "Phosphatidylcholine (oryza sativa specific)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_pe_os_r "Phosphatidylethanolamine (oryza sativa specific)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_pe_os_r "Phosphatidylethanolamine (oryza sativa specific)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_ptd1ino_os_r "1-Phosphatidyl-D-myo-inositol (oryza sativa specific)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ptd1ino_os_r "1-Phosphatidyl-D-myo-inositol (oryza sativa specific)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_atp_c "ATP">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_atp_c "ATP">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_adp_c "ADP">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_adp_c "ADP">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_pi_c "Phosphate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_pi_c "Phosphate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_udp_c "UDP">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_udp_c "UDP">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_h_c "H+">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_h_c "H+">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_coumoh_c "4-Coumaryl alcohol">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_coumoh_c "4-Coumaryl alcohol">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_conoh_c "Coniferyl alcohol">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_conoh_c "Coniferyl alcohol">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_sinoh_c "Sinapoyl alcohol">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_sinoh_c "Sinapoyl alcohol">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_pmtcoa_c "Palmitoyl-CoA (n-C16:0CoA)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_pmtcoa_c "Palmitoyl-CoA (n-C16:0CoA)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_hdcoa_c "Hexadecenoyl-CoA (n-C16:1CoA)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_hdcoa_c "Hexadecenoyl-CoA (n-C16:1CoA)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_odecoa_c "Octadecenoyl-CoA (n-C18:1CoA)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_odecoa_c "Octadecenoyl-CoA (n-C18:1CoA)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_ocdycacoa_c "Octadecadienoyl-CoA (n-C18:2CoA)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ocdycacoa_c "Octadecadienoyl-CoA (n-C18:2CoA)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_lnlncoa_c "Linolenoyl-CoA (n-C18:3CoA)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_lnlncoa_c "Linolenoyl-CoA (n-C18:3CoA)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_acylcoa_os_c "Acyl-CoA (oryza sativa specific)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_acylcoa_os_c "Acyl-CoA (oryza sativa specific)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_pmtcoa_r "Palmitoyl-CoA (n-C16:0CoA)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_pmtcoa_r "Palmitoyl-CoA (n-C16:0CoA)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_hdcoa_r "Hexadecenoyl-CoA (n-C16:1CoA)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_hdcoa_r "Hexadecenoyl-CoA (n-C16:1CoA)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_odecoa_r "Octadecenoyl-CoA (n-C18:1CoA)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_odecoa_r "Octadecenoyl-CoA (n-C18:1CoA)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_ocdycacoa_r "Octadecadienoyl-CoA (n-C18:2CoA)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ocdycacoa_r "Octadecadienoyl-CoA (n-C18:2CoA)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_lnlncoa_r "Linolenoyl-CoA (n-C18:3CoA)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_lnlncoa_r "Linolenoyl-CoA (n-C18:3CoA)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_acylcoa_os_r "Acyl-CoA (oryza sativa specific)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_acylcoa_os_r "Acyl-CoA (oryza sativa specific)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_palmACP_s "Palmitoyl-ACP (n-C16:0ACP)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_palmACP_s "Palmitoyl-ACP (n-C16:0ACP)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_hdeACP_s "cis-hexadec-9-enoyl-[acyl-carrier protein] ((9Z)-n-C16:1)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_hdeACP_s "cis-hexadec-9-enoyl-[acyl-carrier protein] ((9Z)-n-C16:1)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_octeACP_s "cis-octadec-11-enoyl-[acyl-carrier protein] ((11Z)-n-C18:1)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_octeACP_s "cis-octadec-11-enoyl-[acyl-carrier protein] ((11Z)-n-C18:1)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_ocdcyaACP_s "Octadecadienoyl-[acyl-carrier protein] (n-C18:2ACP)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ocdcyaACP_s "Octadecadienoyl-[acyl-carrier protein] (n-C18:2ACP)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_lnlnlACP_s "Linolenoyl-[acyl-carrier protein] (n-C18:3ACP)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_lnlnlACP_s "Linolenoyl-[acyl-carrier protein] (n-C18:3ACP)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_ACP_os_s "acyl carrier protein (oryza sativa specific)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ACP_os_s "acyl carrier protein (oryza sativa specific)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_palmACP_m "Palmitoyl-ACP (n-C16:0ACP)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_palmACP_m "Palmitoyl-ACP (n-C16:0ACP)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_hdeACP_m "cis-hexadec-9-enoyl-[acyl-carrier protein] ((9Z)-n-C16:1)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_hdeACP_m "cis-hexadec-9-enoyl-[acyl-carrier protein] ((9Z)-n-C16:1)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_octeACP_m "cis-octadec-11-enoyl-[acyl-carrier protein] ((11Z)-n-C18:1)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_octeACP_m "cis-octadec-11-enoyl-[acyl-carrier protein] ((11Z)-n-C18:1)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_ocdcyaACP_m "Octadecadienoyl-[acyl-carrier protein] (n-C18:2ACP)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ocdcyaACP_m "Octadecadienoyl-[acyl-carrier protein] (n-C18:2ACP)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_lnlnlACP_m "Linolenoyl-[acyl-carrier protein] (n-C18:3ACP)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_lnlnlACP_m "Linolenoyl-[acyl-carrier protein] (n-C18:3ACP)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_ACP_os_m "acyl carrier protein (oryza sativa specific)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ACP_os_m "acyl carrier protein (oryza sativa specific)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_fa_os_c "fatty acid, lumped (oryza sativa specific)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_fa_os_c "fatty acid, lumped (oryza sativa specific)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_hdca_c "Hexadecanoate (n-C16:0)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_hdca_c "Hexadecanoate (n-C16:0)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_hdcea_c "Hexadecenoate (16:1(9Z))">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_hdcea_c "Hexadecenoate (16:1(9Z))">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_ocdcea_c "octadecenoate (n-C18:1)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ocdcea_c "octadecenoate (n-C18:1)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_ocdcya_c "Octadecadienoate (n-C18:2)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ocdcya_c "Octadecadienoate (n-C18:2)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_lnlnl_c "Linolenate (n-C18:3)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_lnlnl_c "Linolenate (n-C18:3)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_hdca_r "Hexadecanoate (n-C16:0)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_hdca_r "Hexadecanoate (n-C16:0)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_hdcea_r "Hexadecenoate (16:1(9Z))">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_hdcea_r "Hexadecenoate (16:1(9Z))">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_ocdcea_r "octadecenoate (n-C18:1)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ocdcea_r "octadecenoate (n-C18:1)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_ocdcya_r "Octadecadienoate (n-C18:2)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ocdcya_r "Octadecadienoate (n-C18:2)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_lnlnl_r "Linolenate (n-C18:3)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_lnlnl_r "Linolenate (n-C18:3)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_co2_e "CO2">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_co2_e "CO2">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_h2o_e "H2O">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_h2o_e "H2O">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_h_e "H+">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_h_e "H+">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_no3_e "Nitrate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_no3_e "Nitrate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_o2_e "O2">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_o2_e "O2">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_pi_e "Phosphate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_pi_e "Phosphate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_sucr_e "Sucrose">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_sucr_e "Sucrose">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_fru_DASH_B_e "beta-D-fructose">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_fru_DASH_B_e "beta-D-fructose">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_glc_DASH_A_e "alpha-D-glucose">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_glc_DASH_A_e "alpha-D-glucose">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_so4_e "Sulfate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_so4_e "Sulfate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_hco3_e "Bicarbonate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_hco3_e "Bicarbonate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_hso3_e "Sulfite">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_hso3_e "Sulfite">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_h2s_e "Hydrogen sulfide">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_h2s_e "Hydrogen sulfide">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_nh4_e "Ammonium">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_nh4_e "Ammonium">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_asn_DASH_L_e "L-Asparagine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_asn_DASH_L_e "L-Asparagine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_gln_DASH_L_e "L-Glutamine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_gln_DASH_L_e "L-Glutamine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_etoh_e "Ethanol">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_etoh_e "Ethanol">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_ac_e "Acetate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ac_e "Acetate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_lac_DASH_L_e "L-Lactate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_lac_DASH_L_e "L-Lactate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_tsul_e "Thiosulfate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_tsul_e "Thiosulfate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_fe2_e "Fe2+">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_fe2_e "Fe2+">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_fe3_e "Fe3+">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_fe3_e "Fe3+">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_mg2_e "Magnesium">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_mg2_e "Magnesium">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_ala_DASH_L_e "L-Alanine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ala_DASH_L_e "L-Alanine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_arg_DASH_L_e "L-Arginine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_arg_DASH_L_e "L-Arginine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_asp_DASH_L_e "L-Aspartate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_asp_DASH_L_e "L-Aspartate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_cys_DASH_L_e "L-Cysteine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_cys_DASH_L_e "L-Cysteine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_glu_DASH_L_e "L-Glutamate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_glu_DASH_L_e "L-Glutamate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_gly_e "Glycine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_gly_e "Glycine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_his_DASH_L_e "L-Histidine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_his_DASH_L_e "L-Histidine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_ile_DASH_L_e "L-Isoleucine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ile_DASH_L_e "L-Isoleucine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_leu_DASH_L_e "L-Leucine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_leu_DASH_L_e "L-Leucine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_lys_DASH_L_e "L-Lysine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_lys_DASH_L_e "L-Lysine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_met_DASH_L_e "L-Methionine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_met_DASH_L_e "L-Methionine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_phe_DASH_L_e "L-Phenylalanine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_phe_DASH_L_e "L-Phenylalanine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_pro_DASH_L_e "L-Proline">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_pro_DASH_L_e "L-Proline">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_ser_DASH_L_e "L-Serine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ser_DASH_L_e "L-Serine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_thr_DASH_L_e "L-Threonine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_thr_DASH_L_e "L-Threonine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_trp_DASH_L_e "L-Tryptophan">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_trp_DASH_L_e "L-Tryptophan">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_tyr_DASH_L_e "L-Tyrosine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_tyr_DASH_L_e "L-Tyrosine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_val_DASH_L_e "L-Valine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_val_DASH_L_e "L-Valine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_photonVis_e "photon (380 to 750 nm, visible spectrum)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_photonVis_e "photon (380 to 750 nm, visible spectrum)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_photon410_u "photon (281 to 306 nm, UVB)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_photon410_u "photon (281 to 306 nm, UVB)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_photon430_u "photon (406 to 454 nm, indigo/blue)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_photon430_u "photon (406 to 454 nm, indigo/blue)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_photon450_u "photon (378 to 482 nm, violet/blue)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_photon450_u "photon (378 to 482 nm, violet/blue)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_photon470_u "photon (417 to 472 nm, indigo/blue)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_photon470_u "photon (417 to 472 nm, indigo/blue)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_photon490_u "photon (451 to 526 nm, blue/green)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_photon490_u "photon (451 to 526 nm, blue/green)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_photon610_u "photon (662 to 691 nm, red)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_photon610_u "photon (662 to 691 nm, red)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_photon630_u "photon (662 to 691 nm, red)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_photon630_u "photon (662 to 691 nm, red)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_photon650_u "photon (662 to 691 nm, red)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_photon650_u "photon (662 to 691 nm, red)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_photon670_u "photon (662 to 691 nm, red)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_photon670_u "photon (662 to 691 nm, red)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_photon690_u "photon (662 to 691 nm, red)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_photon690_u "photon (662 to 691 nm, red)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_photon510_u "photon (608 to 666 nm, orange/red)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_photon510_u "photon (608 to 666 nm, orange/red)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_photon530_u "photon (659 to 684 nm, red)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_photon530_u "photon (659 to 684 nm, red)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_photon550_u "photon (662 to 691 nm, red)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_photon550_u "photon (662 to 691 nm, red)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_photon570_u "photon (662 to 691 nm, red)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_photon570_u "photon (662 to 691 nm, red)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_photon590_u "photon (662 to 691 nm, red)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_photon590_u "photon (662 to 691 nm, red)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_photonPSI_u "photon (380 to 750 nm, visible spectrum)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_photonPSI_u "photon (380 to 750 nm, visible spectrum)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_photonDrain_u "photon Drain">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_photonDrain_u "photon Drain">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_photonPSII_u "photon (380 to 750 nm, visible spectrum)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_photonPSII_u "photon (380 to 750 nm, visible spectrum)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_co2_c "CO2">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_co2_c "CO2">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_h2o_c "H2O">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_h2o_c "H2O">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_no3_c "Nitrate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_no3_c "Nitrate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_o2_c "O2">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_o2_c "O2">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_so4_c "Sulfate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_so4_c "Sulfate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_hso3_c "HSO3-">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_hso3_c "HSO3-">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_hco3_c "Bicarbonate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_hco3_c "Bicarbonate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_h2s_c "Hydrogen sulfide">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_h2s_c "Hydrogen sulfide">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_nh4_c "Ammonium">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_nh4_c "Ammonium">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_asn_DASH_L_c "L-Asparagine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_asn_DASH_L_c "L-Asparagine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_gln_DASH_L_c "L-Glutamine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_gln_DASH_L_c "L-Glutamine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_etoh_c "Ethanol">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_etoh_c "Ethanol">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_ac_c "Acetate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ac_c "Acetate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_lac_DASH_L_c "L-Lactate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_lac_DASH_L_c "L-Lactate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_tsul_c "Thiosulfate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_tsul_c "Thiosulfate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_fe2_c "Fe2+">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_fe2_c "Fe2+">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_fe3_c "Fe3+">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_fe3_c "Fe3+">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_mg2_c "Magnesium">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_mg2_c "Magnesium">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_ppi_c "Diphosphate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ppi_c "Diphosphate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_h2o_s "H2O">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_h2o_s "H2O">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_ppi_s "Diphosphate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ppi_s "Diphosphate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_h_s "H+">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_h_s "H+">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_pi_s "Phosphate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_pi_s "Phosphate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_h2o_m "H2O">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_h2o_m "H2O">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_ppi_m "Diphosphate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ppi_m "Diphosphate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_h_m "H+">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_h_m "H+">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_pi_m "Phosphate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_pi_m "Phosphate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_h2o_x "H2O">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_h2o_x "H2O">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_ppi_x "Diphosphate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ppi_x "Diphosphate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_h_x "H+">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_h_x "H+">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_pi_x "Phosphate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_pi_x "Phosphate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_h2o_v "H2O">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_h2o_v "H2O">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_ppi_v "Diphosphate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ppi_v "Diphosphate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_h_v "H+">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_h_v "H+">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_pi_v "Phosphate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_pi_v "Phosphate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_pyr_s "Pyruvate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_pyr_s "Pyruvate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_2ahethmpp_s "2-(alpha-Hydroxyethyl)thiamine diphosphate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_2ahethmpp_s "2-(alpha-Hydroxyethyl)thiamine diphosphate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_alac_DASH_S_s "(S)-2-Acetolactate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_alac_DASH_S_s "(S)-2-Acetolactate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_thmpp_s "Thiamine diphosphate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_thmpp_s "Thiamine diphosphate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_pyr_m "Pyruvate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_pyr_m "Pyruvate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_2ahethmpp_m "2-(alpha-Hydroxyethyl)thiamine diphosphate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_2ahethmpp_m "2-(alpha-Hydroxyethyl)thiamine diphosphate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_alac_DASH_S_m "(S)-2-Acetolactate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_alac_DASH_S_m "(S)-2-Acetolactate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_thmpp_m "Thiamine diphosphate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_thmpp_m "Thiamine diphosphate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_h2o2_v "Hydrogen peroxide">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_h2o2_v "Hydrogen peroxide">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_o2_v "O2">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_o2_v "O2">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_h2o2_s "Hydrogen peroxide">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_h2o2_s "Hydrogen peroxide">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_o2_s "O2">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_o2_s "O2">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_h2o2_x "Hydrogen peroxide">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_h2o2_x "Hydrogen peroxide">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_o2_x "O2">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_o2_x "O2">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_h2o2_m "Hydrogen peroxide">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_h2o2_m "Hydrogen peroxide">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_o2_m "O2">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_o2_m "O2">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_gln_DASH_L_m "L-Glutamine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_gln_DASH_L_m "L-Glutamine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_akg_m "2-Oxoglutarate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_akg_m "2-Oxoglutarate">
# ...
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_HMPKs "Hydroxymethylpyrimidine kinase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_THMKs "Thiamine kinase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_PMPKs "Phosphomethylpyrimidine kinase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_THICs "thiamine biosynthesis protein (ThiC)">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_THZPSN3s "thiazole phosphate synthesis">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_TYRLs "tyrosine lyase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_ICYSDSs "ISC Cysteine desulfuration">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_THMPs "thiamin phosphatase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_TMDPKc "Thiamine pyrophosphokinase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_PRFGCLs "phosphoribosylformylglycinamidine cyclo-ligase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_PRAICs "Phosphoribosylaminoimidazole carboxylase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_PPNCL2c "Phosphopantothenate--cysteine ligase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_FPGFTs "Phosphoribosylglycinamide formyltransferase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_FGFTs "N2-Formyl-N1-(5-phospho-D-ribosyl)glycinamide formyltransferase, chloroplast">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_IMDHs "3-isopropylMalate dehydrogenase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_MOD_LPAREN_4mop_RPAREN_ "3-methyl-2-oxobutanoate dehydrogenase, 4-Methyl-2-oxopentanoate transforming">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_MOD_LPAREN_3mhtpp_RPAREN_ "3-methyl-2-oxobutanoate dehydrogenase, 3-Methyl-1-hydroxybutyl-ThPP transforming">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DHRT_LPAREN_ivcoa_RPAREN_ "dihydrolipoyllysine-residue (2-methylpropanoyl)transferase, Isovaleryl-CoA forming">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_IVCDHm "Isovaleryl-CoA dehydrogenase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_MCTCm "Methylcrotonyl-CoA carboxylase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_MGCm "Methylglutaconyl-CoA hydratase ">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_HMGLm "Hydroxymethylglutaryl-CoA lyase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_PPCOAOc "Propanoyl-CoA:(acceptor) 2,3-oxidoreductase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_FPGFTm "Phosphoribosylglycinamide formyltransferase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_FGFTm "N2-Formyl-N1-(5-phospho-D-ribosyl)glycinamide formyltransferase, mitochondria">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_PRFGSs "phosphoribosylformylglycinamidine synthetase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_IMGPSs "Imidazole glycerol phosphate synthase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_AIALs "Adenylosuccinate lyase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_FPAIFs "Phosphoribosylaminoimidazolecarboxamide formyltransferase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_PRAISs "Phosphoribosylaminoimidazole-succinocarboxamide synthetase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DNMPPAc "Dihydroneopterin monophosphate dephosphorylase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DNTPPAc "dihydroneopterin triphosphate diphosphatase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_PRICIs "N-(5-phospho-D-ribosylformimino)-5-amino-1-(5-phosphoribosyl)-4- imidazole carboxamide isomerase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_PFKc "6-phosphofructokinase, cytosolic">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_PFKs "6-phosphofructokinase, plastidic">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_KARA2is "Ketol-acid reductoisomerase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DHAD_DASH_ps "Dihydroxy-acid dehydratase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_GLDPs "4-alpha-glucanotransferase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_ADCLs "Aminodeoxychorismate lyase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_BPNTs "3-Phospho-5-adenylyl sulfate 3-phosphohydrolase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_BPNT2s "3(2),5-bisphosphate nucleotidase ">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_ADSKs "Adenylylsulfate kinase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_ADSKc "Adenylylsulfate kinase, cytosolic">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_PAPSRs "Phosphoadenylyl-sulfate reductase (thioredoxin)">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_ASRGs "Adenylyl-sulfate reductase (glutathione)">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_AAs "alpha-amylase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_PHETAs "L-phenylalanine transferase, plastidic">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_PHETAc "L-phenylalanine transferase, cytosolic">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_PPYRDCc "Phenylpyruvate decarboxylase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_ALCD25c "Phenylethylalcohol:NAD+ oxidoreductase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DAPATs "LL-2,6-diaminoheptanedioate aminotransferase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_PGMTc "Phosphoglucomutase, cytosolic">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_PGMTv "Phosphoglucomutase, cytosolic">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_PGMTs "Phosphoglucomutase, plastidic">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_ACHBSs "Acetolactate synthase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_MOD_LPAREN_3mop_RPAREN_ "3-methyl-2-oxobutanoate dehydrogenase, 3-Methyl-2-oxopentanoate transforming">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_MOD_LPAREN_2mbdhl_RPAREN_ "3-methyl-2-oxobutanoate dehydrogenase, 2-Methyl-1-hydroxybutyl-ThPP transforming">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DHRT_LPAREN_2mbcoa_RPAREN_ "dihydrolipoyllysine-residue (2-methylpropanoyl)transferase, 2-Methylbutanoyl-CoA forming">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_MCDH2m "2-methyl-branched-chain-enoyl-CoA reductase ">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_ECH2m "Tiglyl-CoA hydratase ">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_HMNOSm "3-hydroxy-2-methylbutyryl-CoA dehydrogenase ">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_ACCATm "2-methylacetoacetyl-CoA thiolase ">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_CYSTS_Gs "Cystathionine gamma-synthase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DHRDHm "Dihydroorotate dehydrogenase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_CBMKs "Carbamate kinase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_CBPSs "carbamoyl-phosphate synthase (ammonia)">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_HCO3Es "carbonic anhydrase, plastidic">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_HCO3Ec "carbonic anhydrase, cytosolic">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_HCO3Em "carbonic anhydrase, mitochondrial">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_ACCOACs "Acetyl-CoA carboxylase, plastidic">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_ACCOACc "Acetyl-CoA carboxylase, cytosolic">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_PHENH4Lc "Phenylalanine ammonia-lyase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_TYRNH4Lc "Tyrosine ammonia-lyase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_COUMCOARc "4-coumaryl-CoA reductase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_COUMCOALc "4-coumarate--CoA ligase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_CAFFCMTc "Caffeoyl-CoA O-methyltransferase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_CAFFQTc "Caffeoyl-CoA:quinate O-(3,4-dihydroxycinnamoyl)transferase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_FERCOARc "feruloyl-CoA reductase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_TCMO4c "Trans-cinnamate 4-monooxygenase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_TCMO2c "Trans-cinnamate 2-monooxygenase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_SKMHCTc "Shikimate O-hydroxycinnamoyltransferase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_CONOHDHc "coniferyl-alcohol dehydrogenase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_SINOHDHc "sinapyl-alcohol dehydrogenase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_COUMQMOc "coumaroylquinate 3-monooxygenase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_FERH2c "ferulate 5-hydroxylase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_CONCMTc "S-adenosyl-L-methionine:3,4-dihydroxy-trans-cinnamate 3-O-methyltransferase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_COUMSKMMOc "coumaroylshikimate 3-monooxygenase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_COUMCQHc "p-coumaroyl-CoA:quinate hydroxycinnamoyltransferase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_HCCSHCTc "Hydroxycinnamoyl-CoA:shikimate hydroxycinnamoyltransferase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_COUMOHDHc "4-coumaryl-alcohol dehydrogenase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_CINNCOARc "Cinnamoyl-CoA reductase ">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_CINNCOALc "cinnamate:CoA ligase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_CINNALDOc "cinnamaldehyde oxidase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_CINNOHDHc "cinnamyl-alcohol dehydrogenase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_TFCOASc "trans-feruloyl-CoA synthase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_COUMGUTFc "2-coumarate O-beta-glucosyltransferase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_COUMGUIc "2-coumarate beta-D-glucoside isomerase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_EBGLCSc "exo-beta-glucanse">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_COUMNSc "coumarin synthase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_COUMHYc "4-coumaroyl 2-hydroxylase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_UMBLFSc "umbelliferone biosynthesis ">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_PRENTc "prenyltransferase">
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
ios2164_m = copy.deepcopy(ios2164_orig)

for met in ios2164_m.metabolites:
    met.id = str(met.id) + '0'
    met.compartment = str(met.compartment) + '0'
for rxn in ios2164_m.reactions:
    rxn.id = str(rxn.id) + '_M'
    
ios2164_m
# Out:
# <Model iOS2164 at 0x7f4f9d608df0>

# %%
ios2164_bs = copy.deepcopy(ios2164_orig)

for met in ios2164_bs.metabolites:
    met.id = str(met.id) + '1'
    met.compartment = str(met.compartment) + '1'
    
for rxn in ios2164_bs.reactions:
    rxn.id = str(rxn.id)  + '_BS'

# %%
#Merging the BS and M Cells
ios2164_2cell = ios2164_m.merge(ios2164_bs, objective = "sum", inplace = 1)
# Out:
# Ignoring reaction 'Coleoptile_Biomass_BS' since it already exists.
# Ignoring reaction 'Straw_Biomass_BS' since it already exists.
# Ignoring reaction 'ACCOAC_OSAc_BS' since it already exists.
# Ignoring reaction 'ACCOAC_OSAr_BS' since it already exists.
# Ignoring reaction 'ACPC_OSs_BS' since it already exists.
# Ignoring reaction 'ACPC_OSm_BS' since it already exists.
# Ignoring reaction 'FAC_Osc_BS' since it already exists.
# Ignoring reaction 'FAC_Osr_BS' since it already exists.
# Ignoring reaction 'EX_co2_LPAREN_e_RPAREN__BS' since it already exists.
# Ignoring reaction 'EX_h2o_LPAREN_e_RPAREN__BS' since it already exists.
# Ignoring reaction 'EX_h_LPAREN_e_RPAREN__BS' since it already exists.
# Ignoring reaction 'EX_no3_LPAREN_e_RPAREN__BS' since it already exists.
# Ignoring reaction 'EX_o2_LPAREN_e_RPAREN__BS' since it already exists.
# Ignoring reaction 'EX_pi_LPAREN_e_RPAREN__BS' since it already exists.
# Ignoring reaction 'EX_sucr_LPAREN_e_RPAREN__BS' since it already exists.
# Ignoring reaction 'EX_fru_DASH_B_LPAREN_e_RPAREN__BS' since it already exists.
# Ignoring reaction 'EX_glc_DASH_A_LPAREN_e_RPAREN__BS' since it already exists.
# Ignoring reaction 'EX_so4_LPAREN_e_RPAREN__BS' since it already exists.
# Ignoring reaction 'EX_hco3_LPAREN_e_RPAREN__BS' since it already exists.
# Ignoring reaction 'EX_so3_LPAREN_e_RPAREN__BS' since it already exists.
# Ignoring reaction 'EX_h2s_LPAREN_e_RPAREN__BS' since it already exists.
# Ignoring reaction 'EX_nh4_LPAREN_e_RPAREN__BS' since it already exists.
# Ignoring reaction 'EX_asn_DASH_L_LPAREN_e_RPAREN__BS' since it already exists.
# Ignoring reaction 'EX_gln_DASH_L_LPAREN_e_RPAREN__BS' since it already exists.
# Ignoring reaction 'EX_etoh_LPAREN_e_RPAREN__BS' since it already exists.
# Ignoring reaction 'EX_ac_LPAREN_e_RPAREN__BS' since it already exists.
# Ignoring reaction 'EX_lac_DASH_L_LPAREN_e_RPAREN__BS' since it already exists.
# Ignoring reaction 'EX_tsul_LPAREN_e_RPAREN__BS' since it already exists.
# Ignoring reaction 'EX_fe2_LPAREN_e_RPAREN__BS' since it already exists.
# Ignoring reaction 'EX_fe3_LPAREN_e_RPAREN__BS' since it already exists.
# Ignoring reaction 'EX_mg2_LPAREN_e_RPAREN__BS' since it already exists.
# Ignoring reaction 'EX_ala_DASH_L_LPAREN_e_RPAREN__BS' since it already exists.
# Ignoring reaction 'EX_arg_DASH_L_LPAREN_e_RPAREN__BS' since it already exists.
# Ignoring reaction 'EX_asp_DASH_L_LPAREN_e_RPAREN__BS' since it already exists.
# Ignoring reaction 'EX_cys_DASH_L_LPAREN_e_RPAREN__BS' since it already exists.
# Ignoring reaction 'EX_glu_DASH_L_LPAREN_e_RPAREN__BS' since it already exists.
# Ignoring reaction 'EX_gly_LPAREN_e_RPAREN__BS' since it already exists.
# Ignoring reaction 'EX_his_DASH_L_LPAREN_e_RPAREN__BS' since it already exists.
# Ignoring reaction 'EX_ile_DASH_L_LPAREN_e_RPAREN__BS' since it already exists.
# Ignoring reaction 'EX_leu_DASH_L_LPAREN_e_RPAREN__BS' since it already exists.
# Ignoring reaction 'EX_lys_DASH_L_LPAREN_e_RPAREN__BS' since it already exists.
# Ignoring reaction 'EX_met_DASH_L_LPAREN_e_RPAREN__BS' since it already exists.
# Ignoring reaction 'EX_phe_DASH_L_LPAREN_e_RPAREN__BS' since it already exists.
# Ignoring reaction 'EX_pro_DASH_L_LPAREN_e_RPAREN__BS' since it already exists.
# Ignoring reaction 'EX_ser_DASH_L_LPAREN_e_RPAREN__BS' since it already exists.
# Ignoring reaction 'EX_thr_DASH_L_LPAREN_e_RPAREN__BS' since it already exists.
# Ignoring reaction 'EX_trp_DASH_L_LPAREN_e_RPAREN__BS' since it already exists.
# Ignoring reaction 'EX_tyr_DASH_L_LPAREN_e_RPAREN__BS' since it already exists.
# Ignoring reaction 'EX_val_DASH_L_LPAREN_e_RPAREN__BS' since it already exists.
# Ignoring reaction 'EX_photonVis_LPAREN_e_RPAREN__BS' since it already exists.
# Ignoring reaction 'PRISM_blue_LED_BS' since it already exists.
# Ignoring reaction 'PRISM_red_LED_BS' since it already exists.
# Ignoring reaction 'PRISM_white_LED_BS' since it already exists.
# Ignoring reaction 'PRISM_green_LED_BS' since it already exists.
# Ignoring reaction 'PRISM_solar_litho_BS' since it already exists.
# Ignoring reaction 'RPSI_410_LPAREN_u_RPAREN__BS' since it already exists.
# Ignoring reaction 'RPSI_430_LPAREN_u_RPAREN__BS' since it already exists.
# Ignoring reaction 'RPSI_450_LPAREN_u_RPAREN__BS' since it already exists.
# Ignoring reaction 'RPSI_470_LPAREN_u_RPAREN__BS' since it already exists.
# Ignoring reaction 'RPSI_490_LPAREN_u_RPAREN__BS' since it already exists.
# Ignoring reaction 'RPSI_510_LPAREN_u_RPAREN__BS' since it already exists.
# Ignoring reaction 'RPSI_530_LPAREN_u_RPAREN__BS' since it already exists.
# Ignoring reaction 'RPSI_550_LPAREN_u_RPAREN__BS' since it already exists.
# Ignoring reaction 'RPSI_570_LPAREN_u_RPAREN__BS' since it already exists.
# Ignoring reaction 'RPSI_590_LPAREN_u_RPAREN__BS' since it already exists.
# Ignoring reaction 'RPSI_610_LPAREN_u_RPAREN__BS' since it already exists.
# Ignoring reaction 'RPSI_630_LPAREN_u_RPAREN__BS' since it already exists.
# Ignoring reaction 'RPSI_650_LPAREN_u_RPAREN__BS' since it already exists.
# Ignoring reaction 'RPSI_670_LPAREN_u_RPAREN__BS' since it already exists.
# Ignoring reaction 'RPSI_690_LPAREN_u_RPAREN__BS' since it already exists.
# Ignoring reaction 'RPSII_410_LPAREN_u_RPAREN__BS' since it already exists.
# Ignoring reaction 'RPSII_430_LPAREN_u_RPAREN__BS' since it already exists.
# Ignoring reaction 'RPSII_450_LPAREN_u_RPAREN__BS' since it already exists.
# Ignoring reaction 'RPSII_470_LPAREN_u_RPAREN__BS' since it already exists.
# Ignoring reaction 'RPSII_490_LPAREN_u_RPAREN__BS' since it already exists.
# Ignoring reaction 'RPSII_510_LPAREN_u_RPAREN__BS' since it already exists.
# Ignoring reaction 'RPSII_530_LPAREN_u_RPAREN__BS' since it already exists.
# Ignoring reaction 'RPSII_550_LPAREN_u_RPAREN__BS' since it already exists.
# Ignoring reaction 'RPSII_570_LPAREN_u_RPAREN__BS' since it already exists.
# Ignoring reaction 'RPSII_590_LPAREN_u_RPAREN__BS' since it already exists.
# Ignoring reaction 'RPSII_610_LPAREN_u_RPAREN__BS' since it already exists.
# Ignoring reaction 'RPSII_630_LPAREN_u_RPAREN__BS' since it already exists.
# Ignoring reaction 'RPSII_650_LPAREN_u_RPAREN__BS' since it already exists.
# Ignoring reaction 'RPSII_670_LPAREN_u_RPAREN__BS' since it already exists.
# Ignoring reaction 'RPSII_690_LPAREN_u_RPAREN__BS' since it already exists.
# Ignoring reaction 'CO2tex_BS' since it already exists.
# Ignoring reaction 'H2Otex_BS' since it already exists.
# Ignoring reaction 'Htex_BS' since it already exists.
# Ignoring reaction 'NO3tex_BS' since it already exists.
# Ignoring reaction 'O2tex_BS' since it already exists.
# Ignoring reaction 'Pitex_BS' since it already exists.
# Ignoring reaction 'SUCRtex_BS' since it already exists.
# Ignoring reaction 'FRUtex_BS' since it already exists.
# Ignoring reaction 'GLCtex_BS' since it already exists.
# Ignoring reaction 'SO4tex_BS' since it already exists.
# Ignoring reaction 'SO3tex_BS' since it already exists.
# Ignoring reaction 'HCO3tex_BS' since it already exists.
# Ignoring reaction 'H2Stex_BS' since it already exists.
# Ignoring reaction 'NH4tex_BS' since it already exists.
# Ignoring reaction 'ASNtex_BS' since it already exists.
# Ignoring reaction 'GLNtex_BS' since it already exists.
# Ignoring reaction 'ETOHtex_BS' since it already exists.
# Ignoring reaction 'ACtex_BS' since it already exists.
# Ignoring reaction 'LACtex_BS' since it already exists.
# Ignoring reaction 'TSULtex_BS' since it already exists.
# Ignoring reaction 'FE2tex_BS' since it already exists.
# Ignoring reaction 'FE3tex_BS' since it already exists.
# Ignoring reaction 'MG2tex_BS' since it already exists.
# Ignoring reaction 'ALAtex_BS' since it already exists.
# Ignoring reaction 'ARGtex_BS' since it already exists.
# Ignoring reaction 'ASPtex_BS' since it already exists.
# Ignoring reaction 'CYStex_BS' since it already exists.
# Ignoring reaction 'GLUtex_BS' since it already exists.
# Ignoring reaction 'GLYtex_BS' since it already exists.
# Ignoring reaction 'HIStex_BS' since it already exists.
# Ignoring reaction 'ILEtex_BS' since it already exists.
# Ignoring reaction 'LEUtex_BS' since it already exists.
# Ignoring reaction 'LYStex_BS' since it already exists.
# Ignoring reaction 'METtex_BS' since it already exists.
# Ignoring reaction 'PHEtex_BS' since it already exists.
# Ignoring reaction 'PROtex_BS' since it already exists.
# Ignoring reaction 'SERtex_BS' since it already exists.
# Ignoring reaction 'THRtex_BS' since it already exists.
# Ignoring reaction 'TRPtex_BS' since it already exists.
# Ignoring reaction 'TYRtex_BS' since it already exists.
# Ignoring reaction 'VALtex_BS' since it already exists.
# Ignoring reaction 'PPASc_BS' since it already exists.
# Ignoring reaction 'PPASs_BS' since it already exists.
# Ignoring reaction 'PPASm_BS' since it already exists.
# Ignoring reaction 'PPASx_BS' since it already exists.
# Ignoring reaction 'PPASv_BS' since it already exists.
# Ignoring reaction 'PPAIcxc_BS' since it already exists.
# Ignoring reaction 'PPAIcvc_BS' since it already exists.
# Ignoring reaction 'APLs_BS' since it already exists.
# Ignoring reaction 'APLm_BS' since it already exists.
# Ignoring reaction 'CATv_BS' since it already exists.
# Ignoring reaction 'CATs_BS' since it already exists.
# Ignoring reaction 'CATx_BS' since it already exists.
# Ignoring reaction 'CATm_BS' since it already exists.
# Ignoring reaction 'GLUSfm_BS' since it already exists.
# Ignoring reaction 'GLUSfs_BS' since it already exists.
# Ignoring reaction 'RBPCs_BS' since it already exists.
# Ignoring reaction 'RBPC2s_BS' since it already exists.
# Ignoring reaction 'CYOO6m_BS' since it already exists.
# Ignoring reaction 'NO3Rm_BS' since it already exists.
# Ignoring reaction 'AOXm_BS' since it already exists.
# Ignoring reaction 'ATPPHc_BS' since it already exists.
# Ignoring reaction 'ATPPHm_BS' since it already exists.
# Ignoring reaction 'ATPPHs_BS' since it already exists.
# Ignoring reaction 'ATPSs_BS' since it already exists.
# Ignoring reaction 'ATPSm_BS' since it already exists.
# Ignoring reaction 'ATPSv_BS' since it already exists.
# Ignoring reaction 'GLUSs_BS' since it already exists.
# Ignoring reaction 'GLUSys_BS' since it already exists.
# Ignoring reaction 'GTHRc_BS' since it already exists.
# Ignoring reaction 'GTHRs_BS' since it already exists.
# Ignoring reaction 'GTHRm_BS' since it already exists.
# Ignoring reaction 'ADK1c_BS' since it already exists.
# Ignoring reaction 'ADK1m_BS' since it already exists.
# Ignoring reaction 'ADK1s_BS' since it already exists.
# Ignoring reaction 'ATPAPc_BS' since it already exists.
# Ignoring reaction 'ADPAc_BS' since it already exists.
# Ignoring reaction 'GAL1PUTc_BS' since it already exists.
# Ignoring reaction 'DPCOAKc_BS' since it already exists.
# Ignoring reaction 'URIKGc_BS' since it already exists.
# Ignoring reaction 'URIKGs_BS' since it already exists.
# Ignoring reaction 'DHDHc_BS' since it already exists.
# Ignoring reaction 'BUPNc_BS' since it already exists.
# Ignoring reaction 'DHPDc_BS' since it already exists.
# Ignoring reaction 'TMDSc_BS' since it already exists.
# Ignoring reaction 'CYTDc_BS' since it already exists.
# Ignoring reaction 'GTPCYTDPTc_BS' since it already exists.
# Ignoring reaction 'GTPCYTDPTs_BS' since it already exists.
# Ignoring reaction 'DCTPDAc_BS' since it already exists.
# Ignoring reaction 'CTPRc_BS' since it already exists.
# Ignoring reaction 'UTPRc_BS' since it already exists.
# Ignoring reaction 'ATPRc_BS' since it already exists.
# Ignoring reaction 'GTPRc_BS' since it already exists.
# Ignoring reaction 'DCAHc_BS' since it already exists.
# Ignoring reaction 'UPRTs_BS' since it already exists.
# Ignoring reaction 'UPRTc_BS' since it already exists.
# Ignoring reaction 'UPHc_BS' since it already exists.
# Ignoring reaction 'UPHs_BS' since it already exists.
# Ignoring reaction 'DURIKc_BS' since it already exists.
# Ignoring reaction 'TMDKc_BS' since it already exists.
# Ignoring reaction 'ATCYc_BS' since it already exists.
# Ignoring reaction 'ATCYs_BS' since it already exists.
# Ignoring reaction 'AUPTc_BS' since it already exists.
# Ignoring reaction 'AUPTs_BS' since it already exists.
# Ignoring reaction 'DGSNHc_BS' since it already exists.
# Ignoring reaction 'TPHc_BS' since it already exists.
# Ignoring reaction 'TPHs_BS' since it already exists.
# Ignoring reaction 'DUMPc_BS' since it already exists.
# Ignoring reaction 'DCMPc_BS' since it already exists.
# Ignoring reaction 'CMPc_BS' since it already exists.
# Ignoring reaction 'CMPs_BS' since it already exists.
# Ignoring reaction 'UMPc_BS' since it already exists.
# Ignoring reaction 'UMPs_BS' since it already exists.
# Ignoring reaction 'CTPSc_BS' since it already exists.
# Ignoring reaction 'DUTNHc_BS' since it already exists.
# Ignoring reaction 'DCDTc_BS' since it already exists.
# Ignoring reaction 'DUDTc_BS' since it already exists.
# Ignoring reaction 'TDSRs_BS' since it already exists.
# Ignoring reaction 'TDSRc_BS' since it already exists.
# Ignoring reaction 'TDSRm_BS' since it already exists.
# Ignoring reaction 'ATDTDc_BS' since it already exists.
# Ignoring reaction 'DTMPKc_BS' since it already exists.
# Ignoring reaction 'ATDUDc_BS' since it already exists.
# Ignoring reaction 'DUMPKc_BS' since it already exists.
# Ignoring reaction 'ATDCDc_BS' since it already exists.
# Ignoring reaction 'DCMPKc_BS' since it already exists.
# Ignoring reaction 'ATCDc_BS' since it already exists.
# Ignoring reaction 'ATCDs_BS' since it already exists.
# Ignoring reaction 'CMPKc_BS' since it already exists.
# Ignoring reaction 'CMPKs_BS' since it already exists.
# Ignoring reaction 'ATUDc_BS' since it already exists.
# Ignoring reaction 'ATUDs_BS' since it already exists.
# Ignoring reaction 'ATUDv_BS' since it already exists.
# Ignoring reaction 'UMPKc_BS' since it already exists.
# Ignoring reaction 'MATc_BS' since it already exists.
# Ignoring reaction 'AMPDc_BS' since it already exists.
# Ignoring reaction 'AMPPc_BS' since it already exists.
# Ignoring reaction 'ADNKc_BS' since it already exists.
# Ignoring reaction 'APPRTc_BS' since it already exists.
# Ignoring reaction 'APPRTs_BS' since it already exists.
# Ignoring reaction 'ADSHc_BS' since it already exists.
# Ignoring reaction 'PEPSs_BS' since it already exists.
# Ignoring reaction 'PYKc_BS' since it already exists.
# Ignoring reaction 'PYKs_BS' since it already exists.
# Ignoring reaction 'PPDKs_BS' since it already exists.
# Ignoring reaction 'PPDKc_BS' since it already exists.
# Ignoring reaction 'MDH2c_BS' since it already exists.
# Ignoring reaction 'MDH2s_BS' since it already exists.
# Ignoring reaction 'PDCm_BS' since it already exists.
# Ignoring reaction 'PDCs_BS' since it already exists.
# Ignoring reaction 'ACSc_BS' since it already exists.
# Ignoring reaction 'ACSx_BS' since it already exists.
# Ignoring reaction 'ACSs_BS' since it already exists.
# Ignoring reaction 'GLU5Kc_BS' since it already exists.
# Ignoring reaction 'GLU5Ks_BS' since it already exists.
# Ignoring reaction 'GDHym_BS' since it already exists.
# Ignoring reaction 'GDHm_BS' since it already exists.
# Ignoring reaction 'PYR5CDm_BS' since it already exists.
# Ignoring reaction 'PYR5CDs_BS' since it already exists.
# Ignoring reaction 'PYR5CDym_BS' since it already exists.
# Ignoring reaction 'PYR5CDys_BS' since it already exists.
# Ignoring reaction 'GALc_BS' since it already exists.
# Ignoring reaction 'GALm_BS' since it already exists.
# Ignoring reaction 'GALs_BS' since it already exists.
# Ignoring reaction 'AGATm_BS' since it already exists.
# Ignoring reaction 'AGATx_BS' since it already exists.
# Ignoring reaction 'AGATs_BS' since it already exists.
# Ignoring reaction 'ALAATc_BS' since it already exists.
# Ignoring reaction 'ALAATm_BS' since it already exists.
# Ignoring reaction 'ALAATs_BS' since it already exists.
# Ignoring reaction 'AAATc_BS' since it already exists.
# Ignoring reaction 'ARGDs_BS' since it already exists.
# Ignoring reaction 'ARGDc_BS' since it already exists.
# Ignoring reaction 'ARGDm_BS' since it already exists.
# Ignoring reaction 'ASPCLc_BS' since it already exists.
# Ignoring reaction 'ICDHc_BS' since it already exists.
# Ignoring reaction 'ICDHm_BS' since it already exists.
# Ignoring reaction 'GTHPs_BS' since it already exists.
# Ignoring reaction 'GTHPc_BS' since it already exists.
# Ignoring reaction 'GTHPm_BS' since it already exists.
# Ignoring reaction 'UPGCDc_BS' since it already exists.
# Ignoring reaction 'GALKc_BS' since it already exists.
# Ignoring reaction 'UGLTc_BS' since it already exists.
# Ignoring reaction 'THAc_BS' since it already exists.
# Ignoring reaction 'THPc_BS' since it already exists.
# Ignoring reaction 'TPSc_BS' since it already exists.
# Ignoring reaction 'GLCNSc_BS' since it already exists.
# Ignoring reaction 'GLCNGBc_BS' since it already exists.
# Ignoring reaction 'GLCNGBv_BS' since it already exists.
# Ignoring reaction 'GLCNGAc_BS' since it already exists.
# Ignoring reaction 'GLCNGAv_BS' since it already exists.
# Ignoring reaction 'GALUic_BS' since it already exists.
# Ignoring reaction 'GALUiv_BS' since it already exists.
# Ignoring reaction 'MTGHc_BS' since it already exists.
# Ignoring reaction 'MGHAc_BS' since it already exists.
# Ignoring reaction 'MGHBc_BS' since it already exists.
# Ignoring reaction 'SFHc_BS' since it already exists.
# Ignoring reaction 'RGHc_BS' since it already exists.
# Ignoring reaction 'SYGHc_BS' since it already exists.
# Ignoring reaction 'GRGTc_BS' since it already exists.
# Ignoring reaction 'RAFFINSc_BS' since it already exists.
# Ignoring reaction 'IAGTc_BS' since it already exists.
# Ignoring reaction 'UDPG4Ec_BS' since it already exists.
# Ignoring reaction 'ATGDc_BS' since it already exists.
# Ignoring reaction 'ATGDs_BS' since it already exists.
# Ignoring reaction 'GTPDPKs_BS' since it already exists.
# Ignoring reaction 'GBDPs_BS' since it already exists.
# Ignoring reaction 'GDTPs_BS' since it already exists.
# Ignoring reaction 'UMPKs_BS' since it already exists.
# Ignoring reaction 'ATDADc_BS' since it already exists.
# Ignoring reaction 'ATDGDc_BS' since it already exists.
# Ignoring reaction 'PPCKc_BS' since it already exists.
# Ignoring reaction 'MDHys_BS' since it already exists.
# Ignoring reaction 'MDHs_BS' since it already exists.
# Ignoring reaction 'MDHc_BS' since it already exists.
# Ignoring reaction 'MDHx_BS' since it already exists.
# Ignoring reaction 'MDHm_BS' since it already exists.
# Ignoring reaction 'MDHv_BS' since it already exists.
# Ignoring reaction 'PPCc_BS' since it already exists.
# Ignoring reaction 'ATPCSc_BS' since it already exists.
# Ignoring reaction 'CSx_BS' since it already exists.
# Ignoring reaction 'CSm_BS' since it already exists.
# Ignoring reaction 'OXAACc_BS' since it already exists.
# Ignoring reaction 'OXAODc_BS' since it already exists.
# Ignoring reaction 'ASPO1s_BS' since it already exists.
# Ignoring reaction 'NNDPRs_BS' since it already exists.
# Ignoring reaction 'NNATc_BS' since it already exists.
# Ignoring reaction 'NADS_LPAREN_nh4_RPAREN_c_BS' since it already exists.
# Ignoring reaction 'NADS_LPAREN_gln_DASH_L_RPAREN_c_BS' since it already exists.
# Ignoring reaction 'QULNSs_BS' since it already exists.
# Ignoring reaction 'NAMNPPc_BS' since it already exists.
# Ignoring reaction 'NNAMc_BS' since it already exists.
# Ignoring reaction 'NMNDAc_BS' since it already exists.
# Ignoring reaction 'NMNNc_BS' since it already exists.
# Ignoring reaction 'NMNATc_BS' since it already exists.
# Ignoring reaction 'N2PHs_BS' since it already exists.
# Ignoring reaction 'N2PHc_BS' since it already exists.
# Ignoring reaction 'NADKc_BS' since it already exists.
# Ignoring reaction 'NADKs_BS' since it already exists.
# Ignoring reaction 'NADKm_BS' since it already exists.
# Ignoring reaction 'NADHKc_BS' since it already exists.
# Ignoring reaction 'NADHKs_BS' since it already exists.
# Ignoring reaction 'NADHKm_BS' since it already exists.
# Ignoring reaction 'ASPTAc_BS' since it already exists.
# Ignoring reaction 'ASPTAm_BS' since it already exists.
# Ignoring reaction 'ASPTAs_BS' since it already exists.
# Ignoring reaction 'GLYTAx_BS' since it already exists.
# Ignoring reaction 'SUCL_LPAREN_GDP_RPAREN_m_BS' since it already exists.
# Ignoring reaction 'SUCL_LPAREN_ADP_RPAREN_m_BS' since it already exists.
# Ignoring reaction 'CTPCHc_BS' since it already exists.
# Ignoring reaction 'LYSDCs_BS' since it already exists.
# Ignoring reaction 'AASADc_BS' since it already exists.
# Ignoring reaction 'SACCDyc_BS' since it already exists.
# Ignoring reaction 'SACCDc_BS' since it already exists.
# Ignoring reaction 'AATAc_BS' since it already exists.
# Ignoring reaction 'PDHam1m_BS' since it already exists.
# Ignoring reaction 'PDHam2m_BS' since it already exists.
# Ignoring reaction 'PDHe2m_BS' since it already exists.
# Ignoring reaction 'PDHe3m_BS' since it already exists.
# Ignoring reaction 'PDHam1s_BS' since it already exists.
# Ignoring reaction 'PDHam2s_BS' since it already exists.
# Ignoring reaction 'PDHe2s_BS' since it already exists.
# Ignoring reaction 'PDHe3s_BS' since it already exists.
# Ignoring reaction 'AKGDHam1m_BS' since it already exists.
# Ignoring reaction 'AKGDHam2m_BS' since it already exists.
# Ignoring reaction 'AKGDHe2m_BS' since it already exists.
# Ignoring reaction 'OXADH1m_BS' since it already exists.
# Ignoring reaction 'OXADH2m_BS' since it already exists.
# Ignoring reaction 'DAPDCs_BS' since it already exists.
# Ignoring reaction 'MALSs_BS' since it already exists.
# Ignoring reaction 'MALSx_BS' since it already exists.
# Ignoring reaction 'GOXx_BS' since it already exists.
# Ignoring reaction 'ICLx_BS' since it already exists.
# Ignoring reaction 'AMOx_BS' since it already exists.
# Ignoring reaction 'AOBUTDx_BS' since it already exists.
# Ignoring reaction 'THR3DHx_BS' since it already exists.
# Ignoring reaction 'GLYATx_BS' since it already exists.
# Ignoring reaction 'ASPKs_BS' since it already exists.
# Ignoring reaction 'ASPALs_BS' since it already exists.
# Ignoring reaction 'ASPALc_BS' since it already exists.
# Ignoring reaction 'ASNNc_BS' since it already exists.
# Ignoring reaction 'FDHm_BS' since it already exists.
# Ignoring reaction 'FDHNc_BS' since it already exists.
# Ignoring reaction 'SULOx_BS' since it already exists.
# Ignoring reaction 'SULOm_BS' since it already exists.
# Ignoring reaction 'SUATc_BS' since it already exists.
# Ignoring reaction 'SUATs_BS' since it already exists.
# Ignoring reaction 'ARGNc_BS' since it already exists.
# Ignoring reaction 'PTORc_BS' since it already exists.
# Ignoring reaction 'PAOc_BS' since it already exists.
# Ignoring reaction 'AMPORc_BS' since it already exists.
# Ignoring reaction 'SPMDDHc_BS' since it already exists.
# Ignoring reaction 'ABORc_BS' since it already exists.
# Ignoring reaction 'ARG2MO_BS' since it already exists.
# Ignoring reaction 'GABUTAHc_BS' since it already exists.
# Ignoring reaction 'GABUTNAHc_BS' since it already exists.
# Ignoring reaction 'CMPAc_BS' since it already exists.
# Ignoring reaction 'AGDIc_BS' since it already exists.
# Ignoring reaction 'AGMTc_BS' since it already exists.
# Ignoring reaction 'ARDCc_BS' since it already exists.
# Ignoring reaction 'NOSc_BS' since it already exists.
# Ignoring reaction 'ARGDIc_BS' since it already exists.
# Ignoring reaction 'HCGALc_BS' since it already exists.
# Ignoring reaction 'ASNS1c_BS' since it already exists.
# Ignoring reaction 'ASNS1s_BS' since it already exists.
# Ignoring reaction 'PSPs_BS' since it already exists.
# Ignoring reaction 'CYSTGLs_BS' since it already exists.
# Ignoring reaction 'CYSTBSs_BS' since it already exists.
# Ignoring reaction 'SATc_BS' since it already exists.
# Ignoring reaction 'SATs_BS' since it already exists.
# Ignoring reaction 'SATm_BS' since it already exists.
# Ignoring reaction 'SGATs_BS' since it already exists.
# Ignoring reaction 'SGATx_BS' since it already exists.
# Ignoring reaction 'METSMTc_BS' since it already exists.
# Ignoring reaction 'HCYSMTc_BS' since it already exists.
# Ignoring reaction 'AMETAHYCSTc_BS' since it already exists.
# Ignoring reaction 'HCYSMT2c_BS' since it already exists.
# Ignoring reaction 'MSx_BS' since it already exists.
# Ignoring reaction 'MSv_BS' since it already exists.
# Ignoring reaction 'MSc_BS' since it already exists.
# Ignoring reaction 'ACDOc_BS' since it already exists.
# Ignoring reaction 'METLc_BS' since it already exists.
# Ignoring reaction 'ACHYSLc_BS' since it already exists.
# Ignoring reaction 'MOTAc_BS' since it already exists.
# Ignoring reaction 'M5TRKc_BS' since it already exists.
# Ignoring reaction 'MTANc_BS' since it already exists.
# Ignoring reaction 'SPRMSc_BS' since it already exists.
# Ignoring reaction 'ORDCc_BS' since it already exists.
# Ignoring reaction 'SPMSc_BS' since it already exists.
# Ignoring reaction 'AMCLc_BS' since it already exists.
# Ignoring reaction 'ACPCSc_BS' since it already exists.
# Ignoring reaction 'AMCPCOc_BS' since it already exists.
# Ignoring reaction 'M5TRPIc_BS' since it already exists.
# Ignoring reaction 'M5TRPHc_BS' since it already exists.
# Ignoring reaction 'ACRSPc_BS' since it already exists.
# Ignoring reaction 'ENOc_BS' since it already exists.
# Ignoring reaction 'ENOs_BS' since it already exists.
# Ignoring reaction 'ORNTAm_BS' since it already exists.
# Ignoring reaction 'ORNTAc_BS' since it already exists.
# Ignoring reaction 'TRPMOc_BS' since it already exists.
# Ignoring reaction 'IAOc_BS' since it already exists.
# Ignoring reaction 'TOORc_BS' since it already exists.
# Ignoring reaction 'TRPTAc_BS' since it already exists.
# Ignoring reaction 'ALAADc_BS' since it already exists.
# Ignoring reaction 'INDPYRDc_BS' since it already exists.
# Ignoring reaction 'IAOHLc_BS' since it already exists.
# Ignoring reaction 'TRYPTORc_BS' since it already exists.
# Ignoring reaction 'NTRLASEc_BS' since it already exists.
# Ignoring reaction 'TRP2MOc_BS' since it already exists.
# Ignoring reaction 'AMID3c_BS' since it already exists.
# Ignoring reaction 'IAAGTc_BS' since it already exists.
# Ignoring reaction 'IAAINOSTc_BS' since it already exists.
# Ignoring reaction 'IAAIGSc_BS' since it already exists.
# Ignoring reaction 'IAAIASc_BS' since it already exists.
# Ignoring reaction 'IAAALASc_BS' since it already exists.
# Ignoring reaction 'IAALEUSc_BS' since it already exists.
# Ignoring reaction 'IAAASPSc_BS' since it already exists.
# Ignoring reaction 'IAAGLUSc_BS' since it already exists.
# Ignoring reaction 'IAAGLNSc_BS' since it already exists.
# Ignoring reaction 'IAAALAHc_BS' since it already exists.
# Ignoring reaction 'IAALEUHc_BS' since it already exists.
# Ignoring reaction 'IAAAMYHc_BS' since it already exists.
# Ignoring reaction 'SERHs_BS' since it already exists.
# Ignoring reaction 'TRPS2s_BS' since it already exists.
# Ignoring reaction 'PPDHc_BS' since it already exists.
# Ignoring reaction 'PPDHs_BS' since it already exists.
# Ignoring reaction 'LDH_Lc_BS' since it already exists.
# Ignoring reaction 'MALCOADCc_BS' since it already exists.
# Ignoring reaction 'MALSADHm_BS' since it already exists.
# Ignoring reaction 'MALSADHym_BS' since it already exists.
# Ignoring reaction 'ICHDxm_BS' since it already exists.
# Ignoring reaction 'ACALDHc_BS' since it already exists.
# Ignoring reaction 'ACALDHs_BS' since it already exists.
# Ignoring reaction 'ACALDHm_BS' since it already exists.
# Ignoring reaction 'GLYCRORc_BS' since it already exists.
# Ignoring reaction 'GLYCORc_BS' since it already exists.
# Ignoring reaction 'SSNOm_BS' since it already exists.
# Ignoring reaction 'TYRDCc_BS' since it already exists.
# Ignoring reaction '34HPPORc_BS' since it already exists.
# Ignoring reaction '34HPPORs_BS' since it already exists.
# Ignoring reaction 'HGDOc_BS' since it already exists.
# Ignoring reaction 'PPORs_BS' since it already exists.
# Ignoring reaction 'TYRTAc_BS' since it already exists.
# Ignoring reaction 'TYRTAs_BS' since it already exists.
# Ignoring reaction 'FAAc_BS' since it already exists.
# Ignoring reaction 'MAAIc_BS' since it already exists.
# Ignoring reaction 'ARGDHTs_BS' since it already exists.
# Ignoring reaction 'ARGOAT1s_BS' since it already exists.
# Ignoring reaction 'ARGOAT2s_BS' since it already exists.
# Ignoring reaction 'ARGDHs_BS' since it already exists.
# Ignoring reaction 'ALCDx2c_BS' since it already exists.
# Ignoring reaction 'BETALDDHc_BS' since it already exists.
# Ignoring reaction 'BETHCYSs_BS' since it already exists.
# Ignoring reaction 'DMTGDHs_BS' since it already exists.
# Ignoring reaction 'SARCOs_BS' since it already exists.
# Ignoring reaction 'GLYDHDm_BS' since it already exists.
# Ignoring reaction 'DHLDHm_BS' since it already exists.
# Ignoring reaction 'MTAMnh4m_BS' since it already exists.
# Ignoring reaction 'THRAc_BS' since it already exists.
# Ignoring reaction 'ALCDx1c_BS' since it already exists.
# Ignoring reaction 'MAN6PIc_BS' since it already exists.
# Ignoring reaction 'PMANMc_BS' since it already exists.
# Ignoring reaction 'MANKINc_BS' since it already exists.
# Ignoring reaction 'MDHARc_BS' since it already exists.
# Ignoring reaction 'MDHARs_BS' since it already exists.
# Ignoring reaction 'MDHARm_BS' since it already exists.
# Ignoring reaction 'MDHARyc_BS' since it already exists.
# Ignoring reaction 'MDHARys_BS' since it already exists.
# Ignoring reaction 'MDHARym_BS' since it already exists.
# Ignoring reaction 'ASCOXc_BS' since it already exists.
# Ignoring reaction 'ASCPO1c_BS' since it already exists.
# Ignoring reaction 'ASCPO1s_BS' since it already exists.
# Ignoring reaction 'ASCPO2c_BS' since it already exists.
# Ignoring reaction 'ASCPO2s_BS' since it already exists.
# Ignoring reaction 'GGT1v_BS' since it already exists.
# Ignoring reaction 'GGT2c_BS' since it already exists.
# Ignoring reaction 'GGLUCTc_BS' since it already exists.
# Ignoring reaction 'OPAHirc_BS' since it already exists.
# Ignoring reaction 'CYSGLYv_BS' since it already exists.
# Ignoring reaction 'GLUCYSs_BS' since it already exists.
# Ignoring reaction 'GLUCYSm_BS' since it already exists.
# Ignoring reaction 'GTHSs_BS' since it already exists.
# Ignoring reaction 'GTHSm_BS' since it already exists.
# Ignoring reaction 'GTHDHc_BS' since it already exists.
# Ignoring reaction 'GTHDHs_BS' since it already exists.
# Ignoring reaction 'GALLDHm_BS' since it already exists.
# Ignoring reaction 'GALDHc_BS' since it already exists.
# Ignoring reaction 'GDPGPc_BS' since it already exists.
# Ignoring reaction 'GDPME1c_BS' since it already exists.
# Ignoring reaction 'GDPME3c_BS' since it already exists.
# Ignoring reaction 'GAMPGc_BS' since it already exists.
# Ignoring reaction 'GMANDc_BS' since it already exists.
# Ignoring reaction 'GOFUCRc_BS' since it already exists.
# Ignoring reaction 'FUCPGTc_BS' since it already exists.
# Ignoring reaction 'LACDHc_BS' since it already exists.
# Ignoring reaction 'FCPAc_BS' since it already exists.
# Ignoring reaction 'FCKc_BS' since it already exists.
# Ignoring reaction 'FCIc_BS' since it already exists.
# Ignoring reaction 'FUKc_BS' since it already exists.
# Ignoring reaction 'FBPc_BS' since it already exists.
# Ignoring reaction 'FBPs_BS' since it already exists.
# Ignoring reaction 'SPSc_BS' since it already exists.
# Ignoring reaction 'SPSv_BS' since it already exists.
# Ignoring reaction 'PGI1c_BS' since it already exists.
# Ignoring reaction 'PGI1s_BS' since it already exists.
# Ignoring reaction 'PGI2c_BS' since it already exists.
# Ignoring reaction 'PGI2s_BS' since it already exists.
# Ignoring reaction 'NO2Rs_BS' since it already exists.
# Ignoring reaction 'NODOx_BS' since it already exists.
# Ignoring reaction 'NODOy_BS' since it already exists.
# Ignoring reaction 'NITRc_BS' since it already exists.
# Ignoring reaction 'NITRv_BS' since it already exists.
# Ignoring reaction 'BFFSc_BS' since it already exists.
# Ignoring reaction 'BFFSv_BS' since it already exists.
# Ignoring reaction 'INVc_BS' since it already exists.
# Ignoring reaction 'INVv_BS' since it already exists.
# Ignoring reaction 'SPPc_BS' since it already exists.
# Ignoring reaction 'SPPv_BS' since it already exists.
# Ignoring reaction 'SUSc_BS' since it already exists.
# Ignoring reaction 'SUSv_BS' since it already exists.
# Ignoring reaction 'MI3PSc_BS' since it already exists.
# Ignoring reaction 'SULRs_BS' since it already exists.
# Ignoring reaction 'XYL2c_BS' since it already exists.
# Ignoring reaction 'XYL2v_BS' since it already exists.
# Ignoring reaction 'UDPACGEc_BS' since it already exists.
# Ignoring reaction 'UDPACGLPc_BS' since it already exists.
# Ignoring reaction 'ACGAMPMc_BS' since it already exists.
# Ignoring reaction 'ACGAM6PSic_BS' since it already exists.
# Ignoring reaction 'GAMPTc_BS' since it already exists.
# Ignoring reaction 'GAMACTc_BS' since it already exists.
# Ignoring reaction 'ACGAMKc_BS' since it already exists.
# Ignoring reaction 'CAGHc_BS' since it already exists.
# Ignoring reaction 'CHITNc_BS' since it already exists.
# Ignoring reaction 'ACGAM2Ec_BS' since it already exists.
# Ignoring reaction 'UAG2EMAic_BS' since it already exists.
# Ignoring reaction 'ACNMLc_BS' since it already exists.
# Ignoring reaction 'CMPSASc_BS' since it already exists.
# Ignoring reaction 'GF6PTAc_BS' since it already exists.
# Ignoring reaction 'FKc_BS' since it already exists.
# Ignoring reaction 'MCPSTm_BS' since it already exists.
# Ignoring reaction 'TSSTm_BS' since it already exists.
# Ignoring reaction 'MCPSTs_BS' since it already exists.
# Ignoring reaction 'TSSTs_BS' since it already exists.
# Ignoring reaction 'SOXs_BS' since it already exists.
# Ignoring reaction 'CYSATs_BS' since it already exists.
# Ignoring reaction 'CYSATm_BS' since it already exists.
# Ignoring reaction 'AATCs_BS' since it already exists.
# Ignoring reaction 'AATCm_BS' since it already exists.
# Ignoring reaction '3SPYRSPs_BS' since it already exists.
# Ignoring reaction '3SPYRSPm_BS' since it already exists.
# Ignoring reaction 'LCYSTSs_BS' since it already exists.
# Ignoring reaction 'LCYSTSm_BS' since it already exists.
# Ignoring reaction 'CYSSc_BS' since it already exists.
# Ignoring reaction 'CYSSm_BS' since it already exists.
# Ignoring reaction 'CYSSs_BS' since it already exists.
# Ignoring reaction 'ALABATc_BS' since it already exists.
# Ignoring reaction 'DHFRc_BS' since it already exists.
# Ignoring reaction 'DHFRm_BS' since it already exists.
# Ignoring reaction 'FPGSc_BS' since it already exists.
# Ignoring reaction 'FTHFLc_BS' since it already exists.
# Ignoring reaction 'FTHFLm_BS' since it already exists.
# Ignoring reaction 'FTHFLs_BS' since it already exists.
# Ignoring reaction 'CALANc_BS' since it already exists.
# Ignoring reaction 'CALASc_BS' since it already exists.
# Ignoring reaction 'MANITL_BS' since it already exists.
# Ignoring reaction 'BG1c_BS' since it already exists.
# Ignoring reaction 'BG2c_BS' since it already exists.
# Ignoring reaction 'FORAc_BS' since it already exists.
# Ignoring reaction 'FORMHLc_BS' since it already exists.
# Ignoring reaction 'FTHDFc_BS' since it already exists.
# Ignoring reaction 'FTHDFm_BS' since it already exists.
# Ignoring reaction 'FTHDFs_BS' since it already exists.
# Ignoring reaction 'SHMTs_BS' since it already exists.
# Ignoring reaction 'SHMTm_BS' since it already exists.
# Ignoring reaction 'MLTHFRc_BS' since it already exists.
# Ignoring reaction 'MLTHFRs_BS' since it already exists.
# Ignoring reaction 'METSc_BS' since it already exists.
# Ignoring reaction 'METSs_BS' since it already exists.
# Ignoring reaction 'MLTHFR_Fs_BS' since it already exists.
# Ignoring reaction 'MLTHFR_Fc_BS' since it already exists.
# Ignoring reaction 'GLPATs_BS' since it already exists.
# Ignoring reaction 'HCGALm_BS' since it already exists.
# Ignoring reaction 'ORPDCs_BS' since it already exists.
# Ignoring reaction 'ATNSs_BS' since it already exists.
# Ignoring reaction 'TALc_BS' since it already exists.
# Ignoring reaction 'TPIc_BS' since it already exists.
# Ignoring reaction 'TPIs_BS' since it already exists.
# Ignoring reaction 'RPDPKc_BS' since it already exists.
# Ignoring reaction 'RPDPKs_BS' since it already exists.
# Ignoring reaction 'PPMc_BS' since it already exists.
# Ignoring reaction 'PPMs_BS' since it already exists.
# Ignoring reaction 'RBKc_BS' since it already exists.
# Ignoring reaction 'RBKs_BS' since it already exists.
# Ignoring reaction 'AUNORs_BS' since it already exists.
# Ignoring reaction 'RIBFSs_BS' since it already exists.
# Ignoring reaction 'RIBFKc_BS' since it already exists.
# Ignoring reaction 'FMNATs_BS' since it already exists.
# Ignoring reaction 'FMNATc_BS' since it already exists.
# Ignoring reaction 'FMNATm_BS' since it already exists.
# Ignoring reaction 'GTPDHs_BS' since it already exists.
# Ignoring reaction 'DHPAHs_BS' since it already exists.
# Ignoring reaction 'R5PFLs_BS' since it already exists.
# Ignoring reaction 'DLDLBTs_BS' since it already exists.
# Ignoring reaction 'AUSs_BS' since it already exists.
# Ignoring reaction 'RPIc_BS' since it already exists.
# Ignoring reaction 'RPIs_BS' since it already exists.
# Ignoring reaction 'GAPDHys_BS' since it already exists.
# Ignoring reaction 'GAPDH1c_BS' since it already exists.
# Ignoring reaction 'GAPDH2s_BS' since it already exists.
# Ignoring reaction 'GAPDHc_BS' since it already exists.
# Ignoring reaction 'GAPDH1ys_BS' since it already exists.
# Ignoring reaction 'KHKc_BS' since it already exists.
# Ignoring reaction 'FBA2c_BS' since it already exists.
# Ignoring reaction 'FALDTKc_BS' since it already exists.
# Ignoring reaction 'FALDTKs_BS' since it already exists.
# Ignoring reaction 'GLYCNKc_BS' since it already exists.
# Ignoring reaction 'GLYCNKs_BS' since it already exists.
# Ignoring reaction 'FBAc_BS' since it already exists.
# Ignoring reaction 'FBAs_BS' since it already exists.
# Ignoring reaction 'HDCs_BS' since it already exists.
# Ignoring reaction 'ADPARTs_BS' since it already exists.
# Ignoring reaction 'PRDPARs_BS' since it already exists.
# Ignoring reaction 'ANTPPTs_BS' since it already exists.
# Ignoring reaction 'FUMm_BS' since it already exists.
# Ignoring reaction 'ADSALc_BS' since it already exists.
# Ignoring reaction 'ADSALs_BS' since it already exists.
# Ignoring reaction 'ARGSL1c_BS' since it already exists.
# Ignoring reaction 'LATs_BS' since it already exists.
# Ignoring reaction 'LATm_BS' since it already exists.
# Ignoring reaction 'GSNPc_BS' since it already exists.
# Ignoring reaction 'ADNPc_BS' since it already exists.
# Ignoring reaction 'INSPc_BS' since it already exists.
# Ignoring reaction 'ADNDAc_BS' since it already exists.
# Ignoring reaction 'IMPc_BS' since it already exists.
# Ignoring reaction 'GMPRc_BS' since it already exists.
# Ignoring reaction 'IMPCs_BS' since it already exists.
# Ignoring reaction 'GMPS2c_BS' since it already exists.
# Ignoring reaction 'GMPS1c_BS' since it already exists.
# Ignoring reaction 'GDKc_BS' since it already exists.
# Ignoring reaction 'ATDGMc_BS' since it already exists.
# Ignoring reaction 'ATDAMc_BS' since it already exists.
# Ignoring reaction 'DGDTc_BS' since it already exists.
# Ignoring reaction 'DADTc_BS' since it already exists.
# Ignoring reaction 'IMPDc_BS' since it already exists.
# Ignoring reaction 'INSKc_BS' since it already exists.
# Ignoring reaction 'HXPRTc_BS' since it already exists.
# Ignoring reaction 'ADSSc_BS' since it already exists.
# Ignoring reaction 'ADSSs_BS' since it already exists.
# Ignoring reaction 'MIOORc_BS' since it already exists.
# Ignoring reaction 'PI45PLCc_BS' since it already exists.
# Ignoring reaction 'PI5P4Kc_BS' since it already exists.
# Ignoring reaction 'PI4P5Kc_BS' since it already exists.
# Ignoring reaction 'PIK4c_BS' since it already exists.
# Ignoring reaction 'PIK3c_BS' since it already exists.
# Ignoring reaction 'PI3P5Kc_BS' since it already exists.
# Ignoring reaction 'MI34Pc_BS' since it already exists.
# Ignoring reaction 'MI346Pc_BS' since it already exists.
# Ignoring reaction 'MI3456Pc_BS' since it already exists.
# Ignoring reaction 'IBPHc_BS' since it already exists.
# Ignoring reaction 'MI14PPc_BS' since it already exists.
# Ignoring reaction 'MI134PPc_BS' since it already exists.
# Ignoring reaction 'MI145PPc_BS' since it already exists.
# Ignoring reaction 'MI1456PKc_BS' since it already exists.
# Ignoring reaction 'MI145PKc_BS' since it already exists.
# Ignoring reaction 'MI134PK1c_BS' since it already exists.
# Ignoring reaction 'MI134PK2c_BS' since it already exists.
# Ignoring reaction 'MI1346PK1c_BS' since it already exists.
# Ignoring reaction 'MI1346PK2c_BS' since it already exists.
# Ignoring reaction 'IPKK2c_BS' since it already exists.
# Ignoring reaction 'IPKK5c_BS' since it already exists.
# Ignoring reaction 'IPKK4c_BS' since it already exists.
# Ignoring reaction 'IPKK6c_BS' since it already exists.
# Ignoring reaction 'PHYTASEc_BS' since it already exists.
# Ignoring reaction 'MIHPPc_BS' since it already exists.
# Ignoring reaction 'MI1345PPc_BS' since it already exists.
# Ignoring reaction 'MI1345PP2c_BS' since it already exists.
# Ignoring reaction 'ITK1Kc_BS' since it already exists.
# Ignoring reaction 'MI4PPc_BS' since it already exists.
# Ignoring reaction 'MI3PPc_BS' since it already exists.
# Ignoring reaction 'DHAD_DASH_bs_BS' since it already exists.
# Ignoring reaction 'HMGCOASc_BS' since it already exists.
# Ignoring reaction 'HMGCOASm_BS' since it already exists.
# Ignoring reaction 'GCOADx_BS' since it already exists.
# Ignoring reaction 'GCOADCx_BS' since it already exists.
# Ignoring reaction 'ACACTx_BS' since it already exists.
# Ignoring reaction 'ACACTs_BS' since it already exists.
# Ignoring reaction 'ACACTc_BS' since it already exists.
# Ignoring reaction 'ACACTm_BS' since it already exists.
# Ignoring reaction 'IPMSs_BS' since it already exists.
# Ignoring reaction 'HMNOm_BS' since it already exists.
# Ignoring reaction 'MOD_BS' since it already exists.
# Ignoring reaction 'MOD_LPAREN_2mhop_RPAREN__BS' since it already exists.
# Ignoring reaction 'DHRT_LPAREN_ibcoa_RPAREN__BS' since it already exists.
# Ignoring reaction 'MMSDm_BS' since it already exists.
# Ignoring reaction 'MCDH1m_BS' since it already exists.
# Ignoring reaction 'HIBHm_BS' since it already exists.
# Ignoring reaction 'ECH1m_BS' since it already exists.
# Ignoring reaction 'DHADm_BS' since it already exists.
# Ignoring reaction 'VALATs_BS' since it already exists.
# Ignoring reaction 'VALATm_BS' since it already exists.
# Ignoring reaction 'MTHFDm_BS' since it already exists.
# Ignoring reaction 'MTHFDs_BS' since it already exists.
# Ignoring reaction 'MTHFDc_BS' since it already exists.
# Ignoring reaction 'FTHFCLc_BS' since it already exists.
# Ignoring reaction 'FTHFCLm_BS' since it already exists.
# Ignoring reaction 'FTHFCLs_BS' since it already exists.
# Ignoring reaction 'MTHFDym_BS' since it already exists.
# Ignoring reaction 'MTHFDys_BS' since it already exists.
# Ignoring reaction 'MTHFDyc_BS' since it already exists.
# Ignoring reaction 'MOHMTm_BS' since it already exists.
# Ignoring reaction 'GMPc_BS' since it already exists.
# Ignoring reaction 'GNSKc_BS' since it already exists.
# Ignoring reaction 'GUAPRTc_BS' since it already exists.
# Ignoring reaction 'DAD2DAc_BS' since it already exists.
# Ignoring reaction 'DGSNPP_BS' since it already exists.
# Ignoring reaction 'DINSPc_BS' since it already exists.
# Ignoring reaction 'DURIPP_BS' since it already exists.
# Ignoring reaction 'DAD2NPc_BS' since it already exists.
# Ignoring reaction 'DAMPHc_BS' since it already exists.
# Ignoring reaction 'ADEDAc_BS' since it already exists.
# Ignoring reaction 'ADNRHc_BS' since it already exists.
# Ignoring reaction 'GTPDPKc_BS' since it already exists.
# Ignoring reaction 'PPPGPPPc_BS' since it already exists.
# Ignoring reaction 'PRODHm_BS' since it already exists.
# Ignoring reaction 'P5CRc_BS' since it already exists.
# Ignoring reaction 'P5CRs_BS' since it already exists.
# Ignoring reaction 'P5CRyc_BS' since it already exists.
# Ignoring reaction 'P5CRys_BS' since it already exists.
# Ignoring reaction 'CYSTALs_BS' since it already exists.
# Ignoring reaction 'GCALDDc_BS' since it already exists.
# Ignoring reaction 'PGLYCPs_BS' since it already exists.
# Ignoring reaction 'GLCRPUic_BS' since it already exists.
# Ignoring reaction 'XYLXYLc_BS' since it already exists.
# Ignoring reaction 'XSc_BS' since it already exists.
# Ignoring reaction 'UGEc_BS' since it already exists.
# Ignoring reaction 'UG46DHc_BS' since it already exists.
# Ignoring reaction 'PECTNc_BS' since it already exists.
# Ignoring reaction 'UDDGEc_BS' since it already exists.
# Ignoring reaction 'URMNORc_BS' since it already exists.
# Ignoring reaction 'UGDCc_BS' since it already exists.
# Ignoring reaction 'HPRs_BS' since it already exists.
# Ignoring reaction 'HPRx_BS' since it already exists.
# Ignoring reaction 'HPRys_BS' since it already exists.
# Ignoring reaction 'HPRyx_BS' since it already exists.
# Ignoring reaction 'ASPCT1c_BS' since it already exists.
# Ignoring reaction 'THRSs_BS' since it already exists.
# Ignoring reaction 'AAPTc_BS' since it already exists.
# Ignoring reaction 'UTPUc_BS' since it already exists.
# Ignoring reaction 'UMPUc_BS' since it already exists.
# Ignoring reaction 'ARABFv_BS' since it already exists.
# Ignoring reaction 'ARABFc_BS' since it already exists.
# Ignoring reaction 'UA4Ec_BS' since it already exists.
# Ignoring reaction 'GLCURKc_BS' since it already exists.
# Ignoring reaction 'PGKc_BS' since it already exists.
# Ignoring reaction 'PGKs_BS' since it already exists.
# Ignoring reaction 'PGLYDHs_BS' since it already exists.
# Ignoring reaction 'GLYK1s_BS' since it already exists.
# Ignoring reaction 'GLYK2s_BS' since it already exists.
# Ignoring reaction 'PGMc_BS' since it already exists.
# Ignoring reaction 'PGMs_BS' since it already exists.
# Ignoring reaction 'G6PEc_BS' since it already exists.
# Ignoring reaction 'G6PEs_BS' since it already exists.
# Ignoring reaction 'PRUKs_BS' since it already exists.
# Ignoring reaction 'GLNKc_BS' since it already exists.
# Ignoring reaction 'GLNKs_BS' since it already exists.
# Ignoring reaction 'GNDc_BS' since it already exists.
# Ignoring reaction 'GNDs_BS' since it already exists.
# Ignoring reaction 'XYLIc_BS' since it already exists.
# Ignoring reaction 'XYLKc_BS' since it already exists.
# Ignoring reaction 'RPEc_BS' since it already exists.
# Ignoring reaction 'RPEs_BS' since it already exists.
# Ignoring reaction '3HPPDc_BS' since it already exists.
# Ignoring reaction 'TKT1s_BS' since it already exists.
# Ignoring reaction 'ABTA1m_BS' since it already exists.
# Ignoring reaction 'ABTA2m_BS' since it already exists.
# Ignoring reaction 'MOPCs_BS' since it already exists.
# Ignoring reaction 'MTHFCc_BS' since it already exists.
# Ignoring reaction 'MTHFCs_BS' since it already exists.
# Ignoring reaction 'MTHFCm_BS' since it already exists.
# Ignoring reaction 'GUADc_BS' since it already exists.
# Ignoring reaction 'GSNRHc_BS' since it already exists.
# Ignoring reaction 'CHRSs_BS' since it already exists.
# Ignoring reaction 'CHRMs_BS' since it already exists.
# Ignoring reaction 'ADCSs_BS' since it already exists.
# Ignoring reaction 'UREASEc_BS' since it already exists.
# Ignoring reaction 'ATAHc_BS' since it already exists.
# Ignoring reaction 'ATNAHc_BS' since it already exists.
# Ignoring reaction 'ATSc_BS' since it already exists.
# Ignoring reaction 'HIUHc_BS' since it already exists.
# Ignoring reaction 'UROc_BS' since it already exists.
# Ignoring reaction 'XANDHc_BS' since it already exists.
# Ignoring reaction 'HXANORc_BS' since it already exists.
# Ignoring reaction 'INSRHc_BS' since it already exists.
# Ignoring reaction 'HOMATs_BS' since it already exists.
# Ignoring reaction 'HOMSTs_BS' since it already exists.
# Ignoring reaction 'AHSLs_BS' since it already exists.
# Ignoring reaction 'SHSL4s_BS' since it already exists.
# Ignoring reaction 'SHSL1s_BS' since it already exists.
# Ignoring reaction 'HSKs_BS' since it already exists.
# Ignoring reaction 'HSDHs_BS' since it already exists.
# Ignoring reaction 'HSDHys_BS' since it already exists.
# Ignoring reaction 'GLUKAc_BS' since it already exists.
# Ignoring reaction 'GLUKAs_BS' since it already exists.
# Ignoring reaction 'ADE1c_BS' since it already exists.
# Ignoring reaction 'ADE1s_BS' since it already exists.
# Ignoring reaction 'GLUKBc_BS' since it already exists.
# Ignoring reaction 'GLUKBs_BS' since it already exists.
# Ignoring reaction 'BAMYLs_BS' since it already exists.
# Ignoring reaction 'GGSs_BS' since it already exists.
# Ignoring reaction 'MGHs_BS' since it already exists.
# Ignoring reaction 'SPPAs_BS' since it already exists.
# Ignoring reaction 'DPHSs_BS' since it already exists.
# Ignoring reaction 'TALAs_BS' since it already exists.
# Ignoring reaction 'FBA3s_BS' since it already exists.
# Ignoring reaction 'TKT2s_BS' since it already exists.
# Ignoring reaction 'SBPs_BS' since it already exists.
# Ignoring reaction 'ASPCTs_BS' since it already exists.
# Ignoring reaction 'ORPRTs_BS' since it already exists.
# Ignoring reaction 'ACONTc_BS' since it already exists.
# Ignoring reaction 'ACONc_BS' since it already exists.
# Ignoring reaction 'ACONTm_BS' since it already exists.
# ...
# Ignoring reaction 'METHFts_BS' since it already exists.
# Ignoring reaction 'NA1ATPases_BS' since it already exists.
# Ignoring reaction 'PYRts_BS' since it already exists.
# Ignoring reaction 'NA1Hts_BS' since it already exists.
# Ignoring reaction 'SO3t_BS' since it already exists.
# Ignoring reaction 'FA140s_BS' since it already exists.
# Ignoring reaction 'FA160s_BS' since it already exists.
# Ignoring reaction 'FA161s_BS' since it already exists.
# Ignoring reaction 'FA180s_BS' since it already exists.
# Ignoring reaction 'FA181s_BS' since it already exists.
# Ignoring reaction 'FA182s_BS' since it already exists.
# Ignoring reaction 'FA183s_BS' since it already exists.
# Ignoring reaction 'ARGSUCts_BS' since it already exists.
# Ignoring reaction 'ACGLUts_BS' since it already exists.
# Ignoring reaction 'GLYBETts_BS' since it already exists.
# Ignoring reaction 'AMETt2s_BS' since it already exists.
# Ignoring reaction 'AC5GSAtr_BS' since it already exists.
# Ignoring reaction 'ACORNts_BS' since it already exists.
# Ignoring reaction 'CHORts_BS' since it already exists.
# Ignoring reaction '26dap_DASH_Mts_BS' since it already exists.
# Ignoring reaction 'STEMts_BS' since it already exists.
# Ignoring reaction 'EIKAURts_BS' since it already exists.
# Ignoring reaction 'ECASDts_BS' since it already exists.
# Ignoring reaction 'ESANDts_BS' since it already exists.
# Ignoring reaction 'DHZts_BS' since it already exists.
# Ignoring reaction 'IPADNEts_BS' since it already exists.
# Ignoring reaction 'TZTNRts_BS' since it already exists.
# Ignoring reaction 'TZTNts_BS' since it already exists.
# Ignoring reaction 'IPADNts_BS' since it already exists.
# Ignoring reaction 'COA_LPAREN_h_RPAREN_ts_BS' since it already exists.
# Ignoring reaction 'OPDAts_BS' since it already exists.
# Ignoring reaction 'PYRtv_BS' since it already exists.
# Ignoring reaction 'SUCRtv_BS' since it already exists.
# Ignoring reaction 'FRUCtv_BS' since it already exists.
# Ignoring reaction 'GLCAtv_BS' since it already exists.
# Ignoring reaction 'GLCBtv_BS' since it already exists.
# Ignoring reaction 'GLYtv_BS' since it already exists.
# Ignoring reaction 'CYStv_BS' since it already exists.
# Ignoring reaction 'H2Otv_BS' since it already exists.
# Ignoring reaction 'GTHRDabcv_BS' since it already exists.
# Ignoring reaction 'THFtv_BS' since it already exists.
# Ignoring reaction 'HPGLUtv_BS' since it already exists.
# Ignoring reaction 'NO2tvr_BS' since it already exists.
# Ignoring reaction 'NO3tvr_BS' since it already exists.
# Ignoring reaction 'O2tv_BS' since it already exists.
# Ignoring reaction 'H2O2tv_BS' since it already exists.
# Ignoring reaction 'PYRt2v_BS' since it already exists.
# Ignoring reaction 'FA140COAabcx_BS' since it already exists.
# Ignoring reaction 'FA160COAabcx_BS' since it already exists.
# Ignoring reaction 'FA161COAabcx_BS' since it already exists.
# Ignoring reaction 'FA180COAabcx_BS' since it already exists.
# Ignoring reaction 'FA181COAabcx_BS' since it already exists.
# Ignoring reaction 'FA182COAabcx_BS' since it already exists.
# Ignoring reaction 'FA183COAabcx_BS' since it already exists.
# Ignoring reaction 'ATP2tx_BS' since it already exists.
# Ignoring reaction 'ATPtx_BS' since it already exists.
# Ignoring reaction 'GLYtx_BS' since it already exists.
# Ignoring reaction 'SERtx_BS' since it already exists.
# Ignoring reaction 'GLYCLTtx_BS' since it already exists.
# Ignoring reaction 'MALOAAtx_BS' since it already exists.
# Ignoring reaction 'H2Otx_BS' since it already exists.
# Ignoring reaction 'CITx_BS' since it already exists.
# Ignoring reaction 'CO2tx_BS' since it already exists.
# Ignoring reaction 'O2tx_BS' since it already exists.
# Ignoring reaction 'PItx_BS' since it already exists.
# Ignoring reaction 'CITtcx_BS' since it already exists.
# Ignoring reaction 'ACtx_BS' since it already exists.
# Ignoring reaction 'ALAtx_BS' since it already exists.
# Ignoring reaction 'PYRt2x_BS' since it already exists.
# Ignoring reaction 'SUCCtx_BS' since it already exists.
# Ignoring reaction 'NH4tx_BS' since it already exists.
# Ignoring reaction 'THRtx_BS' since it already exists.
# Ignoring reaction 'ACCOAtx_BS' since it already exists.
# Ignoring reaction 'COA_LPAREN_h_RPAREN_tx_BS' since it already exists.
# Ignoring reaction 'GLXtx_BS' since it already exists.
# Ignoring reaction 'GLUtx_BS' since it already exists.
# Ignoring reaction 'AKGtx_BS' since it already exists.
# Ignoring reaction 'GCOAtx_BS' since it already exists.
# Ignoring reaction 'GLYCRtx_BS' since it already exists.
# Ignoring reaction 'FADH2tx_BS' since it already exists.
# Ignoring reaction 'FADtx_BS' since it already exists.
# Ignoring reaction 'NADPH2tx_BS' since it already exists.
# Ignoring reaction 'NADPtx_BS' since it already exists.
# Ignoring reaction 'MTHGXLtx_BS' since it already exists.
# Ignoring reaction 'B2COAtx_BS' since it already exists.
# Ignoring reaction 'FA40COAtx_BS' since it already exists.
# Ignoring reaction 'JAStx_BS' since it already exists.
# Ignoring reaction 'OPDAtx_BS' since it already exists.
# Ignoring reaction 'SO4tx_BS' since it already exists.
# Ignoring reaction 'FA140CoAr_BS' since it already exists.
# Ignoring reaction 'FA160CoAr_BS' since it already exists.
# Ignoring reaction 'FA161CoAr_BS' since it already exists.
# Ignoring reaction 'FA180CoAr_BS' since it already exists.
# Ignoring reaction 'FA181CoAr_BS' since it already exists.
# Ignoring reaction 'FA182CoAr_BS' since it already exists.
# Ignoring reaction 'FA183CoAr_BS' since it already exists.
# Ignoring reaction 'FA140r_BS' since it already exists.
# Ignoring reaction 'FA160r_BS' since it already exists.
# Ignoring reaction 'FA161r_BS' since it already exists.
# Ignoring reaction 'FA180r_BS' since it already exists.
# Ignoring reaction 'FA181r_BS' since it already exists.
# Ignoring reaction 'FA182r_BS' since it already exists.
# Ignoring reaction 'FA183r_BS' since it already exists.
# Ignoring reaction 'NADPH2tr_BS' since it already exists.
# Ignoring reaction 'NADPtr_BS' since it already exists.
# Ignoring reaction 'UDPGr_BS' since it already exists.
# Ignoring reaction 'GLUSIDEr_BS' since it already exists.
# Ignoring reaction 'HYDRO16tr_BS' since it already exists.
# Ignoring reaction 'HYDRO18tr_BS' since it already exists.
# Ignoring reaction 'DHYDRO1016tr_BS' since it already exists.
# Ignoring reaction 'DHYDRO1018tr_BS' since it already exists.
# Ignoring reaction 'THYDRO91018tr_BS' since it already exists.
# Ignoring reaction 'AMETt2r_BS' since it already exists.
# Ignoring reaction 'ATPtr_BS' since it already exists.
# Ignoring reaction 'ATP2tr_BS' since it already exists.
# Ignoring reaction 'H2Otr_BS' since it already exists.
# Ignoring reaction 'CO2tr_BS' since it already exists.
# Ignoring reaction 'O2tr_BS' since it already exists.
# Ignoring reaction 'MALCOAtr_BS' since it already exists.
# Ignoring reaction 'Pitr_BS' since it already exists.
# Ignoring reaction 'SERtr_BS' since it already exists.
# Ignoring reaction 'COA_LPAREN_h_RPAREN_tr_BS' since it already exists.
# Ignoring reaction 'GLYC3Ptr_BS' since it already exists.
# Ignoring reaction 'TRIGLYCtr_BS' since it already exists.
# Ignoring reaction 'CTPtr_BS' since it already exists.
# Ignoring reaction 'CMPtr_BS' since it already exists.
# Ignoring reaction 'CDPDAGtr_BS' since it already exists.
# Ignoring reaction 'PTD1INOtr_BS' since it already exists.
# Ignoring reaction 'PEtr_BS' since it already exists.
# Ignoring reaction 'PStr_BS' since it already exists.
# Ignoring reaction 'PGPtr_BS' since it already exists.
# Ignoring reaction 'PCtr_BS' since it already exists.
# Ignoring reaction 'CHOLtr_BS' since it already exists.
# Ignoring reaction 'INOSTtr_BS' since it already exists.
# Ignoring reaction 'FADH2tr_BS' since it already exists.
# Ignoring reaction 'FADtr_BS' since it already exists.
# Ignoring reaction 'O2tu_BS' since it already exists.
# Ignoring reaction 'H2Otu_BS' since it already exists.
# Ignoring reaction 'DM_12O9DD_LPAREN_s_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_3_DASH_NON_LPAREN_s_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_3_DASH_NOND_LPAREN_s_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_9_DASH_NONAN_LPAREN_s_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_ACRTNL_LPAREN_s_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_ACT_LPAREN_s_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_ADE_LPAREN_s_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_AFZL_LPAREN_c_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_AMOB_LPAREN_c_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_AMYGD_LPAREN_c_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_APGNNP_LPAREN_c_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_AVITE1_LPAREN_s_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_BGPTN_LPAREN_c_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_BILIVERD_LPAREN_s_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_BRSNL_LPAREN_c_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_BTN_LPAREN_c_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_BUTIN_LPAREN_c_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_CADAVERINE_LPAREN_s_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_CAMP_LPAREN_c_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_CAMPSTFER_LPAREN_c_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_CATCN_LPAREN_c_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_CERDT_LPAREN_r_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_CEROOL_LPAREN_r_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_CHSTEROL_LPAREN_c_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_CHUMU_LPAREN_c_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_CNDM35DG_LPAREN_c_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_COA_LPAREN_c_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_COUMN_LPAREN_c_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_COUMOH_LPAREN_c_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_CPP1_LPAREN_s_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_CRPE_LPAREN_c_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_CYARTFER_LPAREN_c_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_CYTC_LPAREN_m_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_CYTC_LPAREN_s_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_C_DASH_ZTN7G_LPAREN_c_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_C_DASH_ZTN9G_LPAREN_c_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_ZTNG_LPAREN_c_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_DHBZCAROT_LPAREN_s_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_DHZ7G_LPAREN_c_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_DHZ9G_LPAREN_c_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_DHZG_LPAREN_c_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_DVCHLDA_LPAREN_s_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_EIHKAUR_LPAREN_c_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_ELM_LPAREN_c_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_ENTB_LPAREN_s_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_EPCTCN_LPAREN_c_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_EPLZN_LPAREN_c_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_ERGTOL_LPAREN_c_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_ETHYLENE_LPAREN_c_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_GA13_LPAREN_c_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_GA17_LPAREN_c_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_GA29CAT_LPAREN_c_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_GA34_LPAREN_c_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_GA51CAT_LPAREN_c_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_GA8CAT_LPAREN_c_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_GA98_LPAREN_c_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_GENTDP_LPAREN_c_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_HUML_LPAREN_c_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_HUMU_LPAREN_c_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_IORNTN2GCOUM_LPAREN_c_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_IPADNE7G_LPAREN_c_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_IPADNE9G_LPAREN_c_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_ISCPRN2GCOUM_LPAREN_c_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_ISCPRN2GFER_LPAREN_c_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_IVTXN2GFER_LPAREN_c_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_JASILE_LPAREN_c_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_JASLEU_LPAREN_c_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_JASVAL_LPAREN_c_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_JASKMPFL3G_LPAREN_c_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_LACXAN_LPAREN_s_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_LGNCOL_LPAREN_r_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_LGNDT_LPAREN_r_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_LIM_LPAREN_s_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_LTNNP_LPAREN_c_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_LUTEIN_LPAREN_c_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_MNQNNE_LPAREN_s_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_MOMA_LPAREN_s_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_ORNTN_LPAREN_c_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_OZLN_DASH_C_LPAREN_c_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_OZLN_DASH_E_LPAREN_c_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_OZLN_DASH_F_LPAREN_c_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_OZLN_DASH_S_LPAREN_c_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_PHAS_LPAREN_s_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_PHOM_LPAREN_c_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_photonDrain_LPAREN_u_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_PHTC_DASH_A_LPAREN_c_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_PHTC_DASH_B_LPAREN_c_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_PHTC_DASH_D_LPAREN_c_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_PHTC_DASH_E_LPAREN_c_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_PINBAN_LPAREN_c_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_PLAST_LPAREN_s_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_PLGNG_LPAREN_c_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_PQNNE_LPAREN_s_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_PRIMARDN_LPAREN_s_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_QRCTN3G_LPAREN_c_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_SCLGN_LPAREN_c_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_SQ12DGR_OS_LPAREN_s_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_SRNTN_LPAREN_c_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_STCSD_LPAREN_c_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_TRICING_LPAREN_c_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_TRPN_LPAREN_c_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_T_DASH_ZTN7G_LPAREN_c_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_T_DASH_ZTN9G_LPAREN_c_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_T_DASH_ZTNG_LPAREN_c_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_T_DASH_ZTNR_LPAREN_c_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_VTXN_LPAREN_c_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_YVITE_LPAREN_s_RPAREN__BS' since it already exists.
# Ignoring reaction 'DM_PSI_BS' since it already exists.
# Ignoring reaction 'DM_PSII_BS' since it already exists.

# %%
ios2164_2cell.compartments = {
 'c0': 'M Cell Cytoplasm',
 's0': 'M Cell Plastid',
 'r0': 'M Cell Endoplasmic_reticulum',
 'm0': 'M Cell Mitochondrion',
 'e0': 'M Cell Extracellular',
 'u0': 'M Cell Thylakoid',
 'x0': 'M Cell Peroxisome',
 'v0': 'M Cell Vacuole',
 'c1': 'BS Cell Cytoplasm',
 's1': 'BS Cell Plastid',
 'r1': 'BS Cell Endoplasmic_reticulum',
 'm1': 'BS Cell Mitochondrion',
 'e1': 'BS Cell Extracellular',
 'u1': 'BS Cell Thylakoid',
 'x1': 'BS Cell Peroxisome',
 'v1': 'BS Cell Vacuole'}
#Apparently compartments don't update after  merging so I've updated it na lang after that
#Also need to rebuild the model medium

# %%
ios2164_2cell.metabolites.glc_DASH_A_c1.summary()
#It works
# Out:
# <h3>glc_DASH_A_c1</h3><p>C6H12O6</p><h4>Producing Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>48.66%</td>
#       <td>70.12</td>
#       <td>INVc_BS</td>
#       <td>h2o_c1 + sucr_c1 --&gt; fru_DASH_B_c1 + glc_DASH_A_c1</td>
#     </tr>
#     <tr>
#       <td>51.34%</td>
#       <td>73.98</td>
#       <td>XYL2c_BS</td>
#       <td>glc_DASH_A_c1 &lt;=&gt; fru_DASH_B_c1</td>
#     </tr>
#   </tbody>
# </table><h4>Consuming Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>96.66%</td>
#       <td>-139.3</td>
#       <td>GLUKAc_BS</td>
#       <td>atp_c1 + glc_DASH_A_c1 --&gt; adp_c1 + g6p_DASH_A_c1 + h_c1</td>
#     </tr>
#     <tr>
#       <td>3.34%</td>
#       <td>-4.819</td>
#       <td>Straw_Biomass_BS</td>
#       <td>0.0321 ala_DASH_L_c1 + 0.0123 arg_DASH_L_c1 + 0.0417 asp_DASH_L_c1 + 33.259 atp_c1 + 2.0789 cellulose_c1 + 0.1721 conoh_c1 + 0.2065 coumoh_c1 + 0.0071 ctp_c1 + 0.0033 cys_DASH_L_c1 + 0.0009 datp_c1 + 0.0007 dctp_c1 + 0.0007 dgtp_c1 + 0.0009 dttp_c1 + 0.00285 fa_os_r1 + 0.0643 fru_DASH_B_c1 + 0.0546 glc_DASH_A_c1 + 0.0385 glu_DASH_L_c1 + 0.0282 gly_c1 + 0.0071 gtp_c1 + 0.057 his_DASH_L_c1 + 0.014 ile_DASH_L_c1 + 0.0234 leu_DASH_L_c1 + 0.0153 lys_DASH_L_c1 + 0.0076 met_DASH_L_c1 + 0.000191 pa_os_r1 + 0.0034 pc_os_r1 + 0.00178 pe_os_r1 + 0.0133 phe_DASH_L_c1 + 0.0225 pro_DASH_L_c1 + 0.00041 ptd1ino_os_r1 + 0.0219 ser_DASH_L_c1 + 0.1475 sinoh_c1 + 0.3249 starch_s1 + 0.1049 sucr_c1 + 0.0192 thr_DASH_L_c1 + 0.0298 triglyc_os_r1 + 0.0016 trp_DASH_L_c1 + 0.0077 tyr_DASH_L_c1 + 0.1256 udparab_c1 + 0.4018 udpg_c1 + 0.0229 udpgal_c1 + 0.5033 udpglcur_c1 + 0.572 udpxyl_c1 + 0.009 utp_c1 + 0.0225 val_DASH_L_c1 --&gt; 33.259 adp_c1 + 1.626 h_c1 + 33.259 pi_c1 + 1.626 udp_c1</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# From Blatke & Brautigam (2019):
#
# "The mesophyll and bundle sheath networks are connected by a range of cytosolic transport metabolites including amino acids, sugars (glucose, fructose, sucrose, trehalose, ribose), single phosphorylated sugar (glucose-6-phosphate, glucose-1-phosphate, fructose-6-phosphate, sucrose-6-phosphate), mono-/di-/tri-carboxylic acids (phosphoenolpyruvate, pyruvate, citrate, cis-aconitate, isocitrate, α-ketoglutarate, succinate, fumarate, malate), glyceric acids (2-Phosphoglycerate, 3-Phosphoglycerate), glycolate, glycerate, glyceraldehyde-3-phosphate, di-hydroxyacetone-phosphate and CO2.
#
# Nucleotides, NAD/NADH, NADP/NADPH, pyrophosphate, inorganic phosphate are not considered as transport metabolites.
#
# Oxaloacetate has been excluded as transport metabolite since concentrations of oxaloacetate are very low in vivo and it is reasonably unstable in aqueous solutions.
#
# Other small molecules that can be imported by the bundle sheath from the environment, as well as protons and HCO3-, are not exchanged between the two cell types.
#
# #So bale yung mga organic na soluble lang with reasonably long cellular half-lives.

# %%
#Open the initial curated list to get the metabolite ids
transport_rxns = pd.read_csv('../model/initial_list_transport_rxns.csv')
#Ok it gets the reactions now


for item in ios2164_orig.metabolites:
    if item.compartment == "c":
        if item.id in transport_rxns.id.values:
            pd_rxn = Reaction()
            #Generate reaction name
            pd_rxn.id = str(item.id[:-2] + '_pd') #Replaces suffix with '_pd'
            pd_rxn.name = str('Plasmodesmatal transport of ' + item.name)
            pd_rxn.subsystem = str('PD Transport Reaction')
            #Reaction is reversible
            pd_rxn.lower_bound = -1000
            pd_rxn.upper_bound = 1000
            
            
            #Generate metabolite names
            
            
            met_mcell = str(item.id) + '0'
            met_bcell = str(item.id) + '1'
            
            met_mcell = ios2164_2cell.metabolites.get_by_id(met_mcell)
            met_bcell = ios2164_2cell.metabolites.get_by_id(met_bcell)
            pd_rxn.add_metabolites({met_mcell:-1.0, met_bcell:1.0})
            ios2164_2cell.add_reaction(pd_rxn)
# Out:
# Ignoring reaction 'ala_DASH_L_pd' since it already exists.
# Ignoring reaction 'arg_DASH_L_pd' since it already exists.
# Ignoring reaction 'asp_DASH_L_pd' since it already exists.
# Ignoring reaction 'cys_DASH_L_pd' since it already exists.
# Ignoring reaction 'glu_DASH_L_pd' since it already exists.
# Ignoring reaction 'gly_pd' since it already exists.
# Ignoring reaction 'his_DASH_L_pd' since it already exists.
# Ignoring reaction 'ile_DASH_L_pd' since it already exists.
# Ignoring reaction 'leu_DASH_L_pd' since it already exists.
# Ignoring reaction 'lys_DASH_L_pd' since it already exists.
# Ignoring reaction 'met_DASH_L_pd' since it already exists.
# Ignoring reaction 'phe_DASH_L_pd' since it already exists.
# Ignoring reaction 'pro_DASH_L_pd' since it already exists.
# Ignoring reaction 'ser_DASH_L_pd' since it already exists.
# Ignoring reaction 'thr_DASH_L_pd' since it already exists.
# Ignoring reaction 'trp_DASH_L_pd' since it already exists.
# Ignoring reaction 'tyr_DASH_L_pd' since it already exists.
# Ignoring reaction 'val_DASH_L_pd' since it already exists.
# Ignoring reaction 'glc_DASH_A_pd' since it already exists.
# Ignoring reaction 'sucr_pd' since it already exists.
# Ignoring reaction 'fru_DASH_B_pd' since it already exists.
# Ignoring reaction 'udparab_pd' since it already exists.
# Ignoring reaction 'udpxyl_pd' since it already exists.
# Ignoring reaction 'udpgal_pd' since it already exists.
# Ignoring reaction 'udpg_pd' since it already exists.
# Ignoring reaction 'udpglcur_pd' since it already exists.
# Ignoring reaction 'co2_pd' since it already exists.
# Ignoring reaction 'h2o_pd' since it already exists.
# Ignoring reaction 'o2_pd' since it already exists.
# Ignoring reaction 'pep_pd' since it already exists.
# Ignoring reaction 'pyr_pd' since it already exists.
# Ignoring reaction 'mal_DASH_L_pd' since it already exists.
# Ignoring reaction 'accoa_pd' since it already exists.
# Ignoring reaction 'glu5p_pd' since it already exists.
# Ignoring reaction 'akg_pd' since it already exists.
# Ignoring reaction 'icit_pd' since it already exists.
# Ignoring reaction 'gal_pd' since it already exists.
# Ignoring reaction 'g1p_pd' since it already exists.
# Ignoring reaction 'tre_pd' since it already exists.
# Ignoring reaction 'glc_DASH_B_pd' since it already exists.
# Ignoring reaction 'tre6p_pd' since it already exists.
# Ignoring reaction 'g6p_DASH_A_pd' since it already exists.
# Ignoring reaction 'b_DASH_glucan_pd' since it already exists.
# Ignoring reaction 'mnt_pd' since it already exists.
# Ignoring reaction 'melib_pd' since it already exists.
# Ignoring reaction 'stc_pd' since it already exists.
# Ignoring reaction 'raffin_pd' since it already exists.
# Ignoring reaction '1Dgali_pd' since it already exists.
# Ignoring reaction 'inost_pd' since it already exists.
# Ignoring reaction 'cit_pd' since it already exists.
# Ignoring reaction 'oxa_pd' since it already exists.
# Ignoring reaction '2pg_pd' since it already exists.
# Ignoring reaction 'dhap_pd' since it already exists.
# Ignoring reaction 'g3p_pd' since it already exists.
# Ignoring reaction '3pg_pd' since it already exists.
# Ignoring reaction 'glyclt_pd' since it already exists.
# Ignoring reaction 'acon_DASH_C_pd' since it already exists.
# Ignoring reaction 'succ_pd' since it already exists.

# %%
#Shows all the added plasmodesmatal reactions
pd_rxn = [item for item in ios2164_2cell.reactions if "_pd" in item.id]

for item in pd_rxn:
    print(item.id)
#Oks na :)
# Out:
# ala_DASH_L_pd
# arg_DASH_L_pd
# asp_DASH_L_pd
# cys_DASH_L_pd
# glu_DASH_L_pd
# gly_pd
# his_DASH_L_pd
# ile_DASH_L_pd
# leu_DASH_L_pd
# lys_DASH_L_pd
# met_DASH_L_pd
# phe_DASH_L_pd
# pro_DASH_L_pd
# ser_DASH_L_pd
# thr_DASH_L_pd
# trp_DASH_L_pd
# tyr_DASH_L_pd
# val_DASH_L_pd
# glc_DASH_A_pd
# sucr_pd
# fru_DASH_B_pd
# udparab_pd
# udpxyl_pd
# udpgal_pd
# udpg_pd
# udpglcur_pd
# co2_pd
# h2o_pd
# o2_pd
# pep_pd
# pyr_pd
# mal_DASH_L_pd
# accoa_pd
# glu5p_pd
# akg_pd
# icit_pd
# gal_pd
# g1p_pd
# tre_pd
# glc_DASH_B_pd
# tre6p_pd
# g6p_DASH_A_pd
# b_DASH_glucan_pd
# mnt_pd
# melib_pd
# stc_pd
# raffin_pd
# 1Dgali_pd
# inost_pd
# cit_pd
# oxa_pd
# 2pg_pd
# dhap_pd
# g3p_pd
# 3pg_pd
# glyclt_pd
# acon_DASH_C_pd
# succ_pd

# %%
#Add reactions specific to each compartments and their bounds
ios2164_2cell.reactions.get_by_id('mal_DASH_L_pd')
# Out:
# <Reaction mal_DASH_L_pd at 0x7f4f99dfbb50>

# %%
ios2164_2cell.metabolites.ala_DASH_L_c0.summary()
#omg nagkaka-flux na siya thru the plasmodesmata :)
# Out:
# <h3>ala_DASH_L_c0</h3><p>C3H7NO2</p><h4>Producing Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>84.62%</td>
#       <td>1000</td>
#       <td>ALAt2m_M</td>
#       <td>ala_DASH_L_m0 + h_m0 &lt;=&gt; ala_DASH_L_c0 + h_c0</td>
#     </tr>
#     <tr>
#       <td>15.38%</td>
#       <td>181.7</td>
#       <td>ala_DASH_L_pd</td>
#       <td>ala_DASH_L_c0 &lt;=&gt; ala_DASH_L_c1</td>
#     </tr>
#   </tbody>
# </table><h4>Consuming Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>15.37%</td>
#       <td>-181.7</td>
#       <td>ALAATc_M</td>
#       <td>akg_c0 + ala_DASH_L_c0 &lt;=&gt; glu_DASH_L_c0 + pyr_c0</td>
#     </tr>
#     <tr>
#       <td>84.62%</td>
#       <td>-1000</td>
#       <td>ALAtex_M</td>
#       <td>ala_DASH_L_e0 &lt;=&gt; ala_DASH_L_c0</td>
#     </tr>
#     <tr>
#       <td>0.00%</td>
#       <td>-0.03889</td>
#       <td>Straw_Biomass_M</td>
#       <td>0.0321 ala_DASH_L_c0 + 0.0123 arg_DASH_L_c0 + 0.0417 asp_DASH_L_c0 + 33.259 atp_c0 + 2.0789 cellulose_c0 + 0.1721 conoh_c0 + 0.2065 coumoh_c0 + 0.0071 ctp_c0 + 0.0033 cys_DASH_L_c0 + 0.0009 datp_c0 + 0.0007 dctp_c0 + 0.0007 dgtp_c0 + 0.0009 dttp_c0 + 0.00285 fa_os_r0 + 0.0643 fru_DASH_B_c0 + 0.0546 glc_DASH_A_c0 + 0.0385 glu_DASH_L_c0 + 0.0282 gly_c0 + 0.0071 gtp_c0 + 0.057 his_DASH_L_c0 + 0.014 ile_DASH_L_c0 + 0.0234 leu_DASH_L_c0 + 0.0153 lys_DASH_L_c0 + 0.0076 met_DASH_L_c0 + 0.000191 pa_os_r0 + 0.0034 pc_os_r0 + 0.00178 pe_os_r0 + 0.0133 phe_DASH_L_c0 + 0.0225 pro_DASH_L_c0 + 0.00041 ptd1ino_os_r0 + 0.0219 ser_DASH_L_c0 + 0.1475 sinoh_c0 + 0.3249 starch_s0 + 0.1049 sucr_c0 + 0.0192 thr_DASH_L_c0 + 0.0298 triglyc_os_r0 + 0.0016 trp_DASH_L_c0 + 0.0077 tyr_DASH_L_c0 + 0.1256 udparab_c0 + 0.4018 udpg_c0 + 0.0229 udpgal_c0 + 0.5033 udpglcur_c0 + 0.572 udpxyl_c0 + 0.009 utp_c0 + 0.0225 val_DASH_L_c0 --&gt; 33.259 adp_c0 + 1.626 h_c0 + 33.259 pi_c0 + 1.626 udp_c0</td>
#     </tr>
#   </tbody>
# </table>

# %%
ios2164_2cell.metabolites.ala_DASH_L_c1.summary()
#ang  cool haha the model's predicting some backflow ng alanine pabalik sa M cell :)
# Out:
# <h3>ala_DASH_L_c1</h3><p>C3H7NO2</p><h4>Producing Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>52.25%</td>
#       <td>1000</td>
#       <td>ALAATc_BS</td>
#       <td>akg_c1 + ala_DASH_L_c1 &lt;=&gt; glu_DASH_L_c1 + pyr_c1</td>
#     </tr>
#     <tr>
#       <td>47.75%</td>
#       <td>914</td>
#       <td>ALAtx_BS</td>
#       <td>ala_DASH_L_c1 + h_c1 &lt;=&gt; ala_DASH_L_x1 + h_x1</td>
#     </tr>
#   </tbody>
# </table><h4>Consuming Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>37.99%</td>
#       <td>-727.2</td>
#       <td>ALAt2m_BS</td>
#       <td>ala_DASH_L_m1 + h_m1 &lt;=&gt; ala_DASH_L_c1 + h_c1</td>
#     </tr>
#     <tr>
#       <td>52.25%</td>
#       <td>-1000</td>
#       <td>ALAtex_BS</td>
#       <td>ala_DASH_L_e1 &lt;=&gt; ala_DASH_L_c1</td>
#     </tr>
#     <tr>
#       <td>0.27%</td>
#       <td>-5.112</td>
#       <td>Straw_Biomass_BS</td>
#       <td>0.0321 ala_DASH_L_c1 + 0.0123 arg_DASH_L_c1 + 0.0417 asp_DASH_L_c1 + 33.259 atp_c1 + 2.0789 cellulose_c1 + 0.1721 conoh_c1 + 0.2065 coumoh_c1 + 0.0071 ctp_c1 + 0.0033 cys_DASH_L_c1 + 0.0009 datp_c1 + 0.0007 dctp_c1 + 0.0007 dgtp_c1 + 0.0009 dttp_c1 + 0.00285 fa_os_r1 + 0.0643 fru_DASH_B_c1 + 0.0546 glc_DASH_A_c1 + 0.0385 glu_DASH_L_c1 + 0.0282 gly_c1 + 0.0071 gtp_c1 + 0.057 his_DASH_L_c1 + 0.014 ile_DASH_L_c1 + 0.0234 leu_DASH_L_c1 + 0.0153 lys_DASH_L_c1 + 0.0076 met_DASH_L_c1 + 0.000191 pa_os_r1 + 0.0034 pc_os_r1 + 0.00178 pe_os_r1 + 0.0133 phe_DASH_L_c1 + 0.0225 pro_DASH_L_c1 + 0.00041 ptd1ino_os_r1 + 0.0219 ser_DASH_L_c1 + 0.1475 sinoh_c1 + 0.3249 starch_s1 + 0.1049 sucr_c1 + 0.0192 thr_DASH_L_c1 + 0.0298 triglyc_os_r1 + 0.0016 trp_DASH_L_c1 + 0.0077 tyr_DASH_L_c1 + 0.1256 udparab_c1 + 0.4018 udpg_c1 + 0.0229 udpgal_c1 + 0.5033 udpglcur_c1 + 0.572 udpxyl_c1 + 0.009 utp_c1 + 0.0225 val_DASH_L_c1 --&gt; 33.259 adp_c1 + 1.626 h_c1 + 33.259 pi_c1 + 1.626 udp_c1</td>
#     </tr>
#     <tr>
#       <td>9.49%</td>
#       <td>-181.7</td>
#       <td>ala_DASH_L_pd</td>
#       <td>ala_DASH_L_c0 &lt;=&gt; ala_DASH_L_c1</td>
#     </tr>
#   </tbody>
# </table>

# %%
ios2164_2cell.metabolites.mal_DASH_L_c0.summary()
# Out:
# <h3>mal_DASH_L_c0</h3><p>C4H4O5</p><h4>Producing Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.00%</td>
#       <td>0.02108</td>
#       <td>DICtm_M</td>
#       <td>mal_DASH_L_m0 + succ_c0 --&gt; mal_DASH_L_c0 + succ_m0</td>
#     </tr>
#     <tr>
#       <td>100.00%</td>
#       <td>526.8</td>
#       <td>mal_DASH_L_pd</td>
#       <td>mal_DASH_L_c0 &lt;=&gt; mal_DASH_L_c1</td>
#     </tr>
#   </tbody>
# </table><h4>Consuming Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>6.82%</td>
#       <td>-35.94</td>
#       <td>MALAKGtm_M</td>
#       <td>akg_m0 + mal_DASH_L_c0 --&gt; akg_c0 + mal_DASH_L_m0</td>
#     </tr>
#     <tr>
#       <td>0.00%</td>
#       <td>-0.02108</td>
#       <td>MALFUMts_M</td>
#       <td>fum_c0 + mal_DASH_L_s0 &lt;=&gt; fum_s0 + mal_DASH_L_c0</td>
#     </tr>
#     <tr>
#       <td>76.51%</td>
#       <td>-403.1</td>
#       <td>MALOAAtm_M</td>
#       <td>mal_DASH_L_m0 + oaa_c0 &lt;-- mal_DASH_L_c0 + oaa_m0</td>
#     </tr>
#     <tr>
#       <td>16.67%</td>
#       <td>-87.82</td>
#       <td>MDH2c_M</td>
#       <td>mal_DASH_L_c0 + nadp_c0 --&gt; co2_c0 + nadph_c0 + pyr_c0</td>
#     </tr>
#   </tbody>
# </table>

# %%
cobra.io.write_sbml_model(ios2164_2cell, filename= "../model/ios2164_2cell.xml")
