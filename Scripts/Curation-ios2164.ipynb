# %%
import cobra
import libsbml
import escher
from cobra import Model, Reaction, Metabolite
import csv
import pandas as pd
import copy

# %%
ios2164_orig = cobra.io.read_sbml_model("../model/iOS2164_orig.xml")
# Out:
# Model does not contain SBML fbc package information.
# SBML package 'layout' not supported by cobrapy, information is not parsed
# SBML package 'render' not supported by cobrapy, information is not parsed
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_ala_DASH_L_c "L-Alanine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ala_DASH_L_c "L-Alanine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_arg_DASH_L_c "L-Arginine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_arg_DASH_L_c "L-Arginine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_asp_DASH_L_c "L-Aspartate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_asp_DASH_L_c "L-Aspartate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_cys_DASH_L_c "L-Cysteine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_cys_DASH_L_c "L-Cysteine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_glu_DASH_L_c "L-Glutamate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_glu_DASH_L_c "L-Glutamate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_gly_c "Glycine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_gly_c "Glycine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_his_DASH_L_c "L-Histidine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_his_DASH_L_c "L-Histidine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_ile_DASH_L_c "L-Isoleucine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ile_DASH_L_c "L-Isoleucine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_leu_DASH_L_c "L-Leucine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_leu_DASH_L_c "L-Leucine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_lys_DASH_L_c "L-Lysine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_lys_DASH_L_c "L-Lysine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_met_DASH_L_c "L-Methionine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_met_DASH_L_c "L-Methionine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_phe_DASH_L_c "L-Phenylalanine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_phe_DASH_L_c "L-Phenylalanine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_pro_DASH_L_c "L-Proline">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_pro_DASH_L_c "L-Proline">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_ser_DASH_L_c "L-Serine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ser_DASH_L_c "L-Serine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_thr_DASH_L_c "L-Threonine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_thr_DASH_L_c "L-Threonine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_trp_DASH_L_c "L-Tryptophan">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_trp_DASH_L_c "L-Tryptophan">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_tyr_DASH_L_c "L-Tyrosine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_tyr_DASH_L_c "L-Tyrosine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_val_DASH_L_c "L-Valine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_val_DASH_L_c "L-Valine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_glc_DASH_A_c "alpha-D-glucose">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_glc_DASH_A_c "alpha-D-glucose">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_sucr_c "Sucrose">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_sucr_c "Sucrose">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_fru_DASH_B_c "beta-D-fructose">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_fru_DASH_B_c "beta-D-fructose">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_starch_s "Starch (n=4, 4 glucose units)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_starch_s "Starch (n=4, 4 glucose units)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_cellulose_c "Cellulose">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_cellulose_c "Cellulose">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_udparab_c "UDP-L-arabinose">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_udparab_c "UDP-L-arabinose">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_udpxyl_c "UDP-D-xylose">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_udpxyl_c "UDP-D-xylose">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_udpgal_c "UDP-galactose">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_udpgal_c "UDP-galactose">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_udpg_c "UDP-glucose">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_udpg_c "UDP-glucose">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_udpglcur_c "UDP-D-glucuronate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_udpglcur_c "UDP-D-glucuronate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_datp_c "dATP">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_datp_c "dATP">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_dctp_c "dCTP">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_dctp_c "dCTP">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_dttp_c "dTTP">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_dttp_c "dTTP">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_dgtp_c "dGTP">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_dgtp_c "dGTP">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_utp_c "UTP">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_utp_c "UTP">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_ctp_c "CTP">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ctp_c "CTP">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_gtp_c "GTP">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_gtp_c "GTP">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_fa_os_r "fatty acid, lumped (oryza sativa specific)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_fa_os_r "fatty acid, lumped (oryza sativa specific)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_triglyc_os_r "Triacylglycerol (oryza sativa specific)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_triglyc_os_r "Triacylglycerol (oryza sativa specific)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_pa_os_r "Phosphatidate (oryza sativa specific)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_pa_os_r "Phosphatidate (oryza sativa specific)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_pc_os_r "Phosphatidylcholine (oryza sativa specific)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_pc_os_r "Phosphatidylcholine (oryza sativa specific)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_pe_os_r "Phosphatidylethanolamine (oryza sativa specific)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_pe_os_r "Phosphatidylethanolamine (oryza sativa specific)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_ptd1ino_os_r "1-Phosphatidyl-D-myo-inositol (oryza sativa specific)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ptd1ino_os_r "1-Phosphatidyl-D-myo-inositol (oryza sativa specific)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_atp_c "ATP">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_atp_c "ATP">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_adp_c "ADP">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_adp_c "ADP">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_pi_c "Phosphate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_pi_c "Phosphate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_udp_c "UDP">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_udp_c "UDP">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_h_c "H+">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_h_c "H+">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_coumoh_c "4-Coumaryl alcohol">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_coumoh_c "4-Coumaryl alcohol">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_conoh_c "Coniferyl alcohol">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_conoh_c "Coniferyl alcohol">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_sinoh_c "Sinapoyl alcohol">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_sinoh_c "Sinapoyl alcohol">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_pmtcoa_c "Palmitoyl-CoA (n-C16:0CoA)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_pmtcoa_c "Palmitoyl-CoA (n-C16:0CoA)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_hdcoa_c "Hexadecenoyl-CoA (n-C16:1CoA)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_hdcoa_c "Hexadecenoyl-CoA (n-C16:1CoA)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_odecoa_c "Octadecenoyl-CoA (n-C18:1CoA)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_odecoa_c "Octadecenoyl-CoA (n-C18:1CoA)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_ocdycacoa_c "Octadecadienoyl-CoA (n-C18:2CoA)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ocdycacoa_c "Octadecadienoyl-CoA (n-C18:2CoA)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_lnlncoa_c "Linolenoyl-CoA (n-C18:3CoA)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_lnlncoa_c "Linolenoyl-CoA (n-C18:3CoA)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_acylcoa_os_c "Acyl-CoA (oryza sativa specific)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_acylcoa_os_c "Acyl-CoA (oryza sativa specific)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_pmtcoa_r "Palmitoyl-CoA (n-C16:0CoA)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_pmtcoa_r "Palmitoyl-CoA (n-C16:0CoA)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_hdcoa_r "Hexadecenoyl-CoA (n-C16:1CoA)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_hdcoa_r "Hexadecenoyl-CoA (n-C16:1CoA)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_odecoa_r "Octadecenoyl-CoA (n-C18:1CoA)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_odecoa_r "Octadecenoyl-CoA (n-C18:1CoA)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_ocdycacoa_r "Octadecadienoyl-CoA (n-C18:2CoA)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ocdycacoa_r "Octadecadienoyl-CoA (n-C18:2CoA)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_lnlncoa_r "Linolenoyl-CoA (n-C18:3CoA)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_lnlncoa_r "Linolenoyl-CoA (n-C18:3CoA)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_acylcoa_os_r "Acyl-CoA (oryza sativa specific)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_acylcoa_os_r "Acyl-CoA (oryza sativa specific)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_palmACP_s "Palmitoyl-ACP (n-C16:0ACP)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_palmACP_s "Palmitoyl-ACP (n-C16:0ACP)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_hdeACP_s "cis-hexadec-9-enoyl-[acyl-carrier protein] ((9Z)-n-C16:1)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_hdeACP_s "cis-hexadec-9-enoyl-[acyl-carrier protein] ((9Z)-n-C16:1)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_octeACP_s "cis-octadec-11-enoyl-[acyl-carrier protein] ((11Z)-n-C18:1)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_octeACP_s "cis-octadec-11-enoyl-[acyl-carrier protein] ((11Z)-n-C18:1)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_ocdcyaACP_s "Octadecadienoyl-[acyl-carrier protein] (n-C18:2ACP)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ocdcyaACP_s "Octadecadienoyl-[acyl-carrier protein] (n-C18:2ACP)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_lnlnlACP_s "Linolenoyl-[acyl-carrier protein] (n-C18:3ACP)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_lnlnlACP_s "Linolenoyl-[acyl-carrier protein] (n-C18:3ACP)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_ACP_os_s "acyl carrier protein (oryza sativa specific)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ACP_os_s "acyl carrier protein (oryza sativa specific)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_palmACP_m "Palmitoyl-ACP (n-C16:0ACP)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_palmACP_m "Palmitoyl-ACP (n-C16:0ACP)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_hdeACP_m "cis-hexadec-9-enoyl-[acyl-carrier protein] ((9Z)-n-C16:1)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_hdeACP_m "cis-hexadec-9-enoyl-[acyl-carrier protein] ((9Z)-n-C16:1)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_octeACP_m "cis-octadec-11-enoyl-[acyl-carrier protein] ((11Z)-n-C18:1)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_octeACP_m "cis-octadec-11-enoyl-[acyl-carrier protein] ((11Z)-n-C18:1)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_ocdcyaACP_m "Octadecadienoyl-[acyl-carrier protein] (n-C18:2ACP)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ocdcyaACP_m "Octadecadienoyl-[acyl-carrier protein] (n-C18:2ACP)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_lnlnlACP_m "Linolenoyl-[acyl-carrier protein] (n-C18:3ACP)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_lnlnlACP_m "Linolenoyl-[acyl-carrier protein] (n-C18:3ACP)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_ACP_os_m "acyl carrier protein (oryza sativa specific)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ACP_os_m "acyl carrier protein (oryza sativa specific)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_fa_os_c "fatty acid, lumped (oryza sativa specific)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_fa_os_c "fatty acid, lumped (oryza sativa specific)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_hdca_c "Hexadecanoate (n-C16:0)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_hdca_c "Hexadecanoate (n-C16:0)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_hdcea_c "Hexadecenoate (16:1(9Z))">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_hdcea_c "Hexadecenoate (16:1(9Z))">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_ocdcea_c "octadecenoate (n-C18:1)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ocdcea_c "octadecenoate (n-C18:1)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_ocdcya_c "Octadecadienoate (n-C18:2)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ocdcya_c "Octadecadienoate (n-C18:2)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_lnlnl_c "Linolenate (n-C18:3)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_lnlnl_c "Linolenate (n-C18:3)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_hdca_r "Hexadecanoate (n-C16:0)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_hdca_r "Hexadecanoate (n-C16:0)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_hdcea_r "Hexadecenoate (16:1(9Z))">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_hdcea_r "Hexadecenoate (16:1(9Z))">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_ocdcea_r "octadecenoate (n-C18:1)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ocdcea_r "octadecenoate (n-C18:1)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_ocdcya_r "Octadecadienoate (n-C18:2)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ocdcya_r "Octadecadienoate (n-C18:2)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_lnlnl_r "Linolenate (n-C18:3)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_lnlnl_r "Linolenate (n-C18:3)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_co2_e "CO2">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_co2_e "CO2">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_h2o_e "H2O">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_h2o_e "H2O">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_h_e "H+">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_h_e "H+">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_no3_e "Nitrate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_no3_e "Nitrate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_o2_e "O2">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_o2_e "O2">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_pi_e "Phosphate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_pi_e "Phosphate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_sucr_e "Sucrose">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_sucr_e "Sucrose">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_fru_DASH_B_e "beta-D-fructose">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_fru_DASH_B_e "beta-D-fructose">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_glc_DASH_A_e "alpha-D-glucose">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_glc_DASH_A_e "alpha-D-glucose">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_so4_e "Sulfate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_so4_e "Sulfate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_hco3_e "Bicarbonate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_hco3_e "Bicarbonate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_hso3_e "Sulfite">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_hso3_e "Sulfite">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_h2s_e "Hydrogen sulfide">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_h2s_e "Hydrogen sulfide">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_nh4_e "Ammonium">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_nh4_e "Ammonium">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_asn_DASH_L_e "L-Asparagine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_asn_DASH_L_e "L-Asparagine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_gln_DASH_L_e "L-Glutamine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_gln_DASH_L_e "L-Glutamine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_etoh_e "Ethanol">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_etoh_e "Ethanol">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_ac_e "Acetate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ac_e "Acetate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_lac_DASH_L_e "L-Lactate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_lac_DASH_L_e "L-Lactate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_tsul_e "Thiosulfate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_tsul_e "Thiosulfate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_fe2_e "Fe2+">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_fe2_e "Fe2+">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_fe3_e "Fe3+">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_fe3_e "Fe3+">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_mg2_e "Magnesium">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_mg2_e "Magnesium">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_ala_DASH_L_e "L-Alanine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ala_DASH_L_e "L-Alanine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_arg_DASH_L_e "L-Arginine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_arg_DASH_L_e "L-Arginine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_asp_DASH_L_e "L-Aspartate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_asp_DASH_L_e "L-Aspartate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_cys_DASH_L_e "L-Cysteine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_cys_DASH_L_e "L-Cysteine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_glu_DASH_L_e "L-Glutamate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_glu_DASH_L_e "L-Glutamate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_gly_e "Glycine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_gly_e "Glycine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_his_DASH_L_e "L-Histidine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_his_DASH_L_e "L-Histidine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_ile_DASH_L_e "L-Isoleucine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ile_DASH_L_e "L-Isoleucine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_leu_DASH_L_e "L-Leucine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_leu_DASH_L_e "L-Leucine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_lys_DASH_L_e "L-Lysine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_lys_DASH_L_e "L-Lysine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_met_DASH_L_e "L-Methionine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_met_DASH_L_e "L-Methionine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_phe_DASH_L_e "L-Phenylalanine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_phe_DASH_L_e "L-Phenylalanine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_pro_DASH_L_e "L-Proline">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_pro_DASH_L_e "L-Proline">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_ser_DASH_L_e "L-Serine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ser_DASH_L_e "L-Serine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_thr_DASH_L_e "L-Threonine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_thr_DASH_L_e "L-Threonine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_trp_DASH_L_e "L-Tryptophan">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_trp_DASH_L_e "L-Tryptophan">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_tyr_DASH_L_e "L-Tyrosine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_tyr_DASH_L_e "L-Tyrosine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_val_DASH_L_e "L-Valine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_val_DASH_L_e "L-Valine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_photonVis_e "photon (380 to 750 nm, visible spectrum)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_photonVis_e "photon (380 to 750 nm, visible spectrum)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_photon410_u "photon (281 to 306 nm, UVB)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_photon410_u "photon (281 to 306 nm, UVB)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_photon430_u "photon (406 to 454 nm, indigo/blue)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_photon430_u "photon (406 to 454 nm, indigo/blue)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_photon450_u "photon (378 to 482 nm, violet/blue)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_photon450_u "photon (378 to 482 nm, violet/blue)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_photon470_u "photon (417 to 472 nm, indigo/blue)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_photon470_u "photon (417 to 472 nm, indigo/blue)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_photon490_u "photon (451 to 526 nm, blue/green)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_photon490_u "photon (451 to 526 nm, blue/green)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_photon610_u "photon (662 to 691 nm, red)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_photon610_u "photon (662 to 691 nm, red)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_photon630_u "photon (662 to 691 nm, red)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_photon630_u "photon (662 to 691 nm, red)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_photon650_u "photon (662 to 691 nm, red)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_photon650_u "photon (662 to 691 nm, red)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_photon670_u "photon (662 to 691 nm, red)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_photon670_u "photon (662 to 691 nm, red)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_photon690_u "photon (662 to 691 nm, red)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_photon690_u "photon (662 to 691 nm, red)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_photon510_u "photon (608 to 666 nm, orange/red)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_photon510_u "photon (608 to 666 nm, orange/red)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_photon530_u "photon (659 to 684 nm, red)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_photon530_u "photon (659 to 684 nm, red)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_photon550_u "photon (662 to 691 nm, red)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_photon550_u "photon (662 to 691 nm, red)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_photon570_u "photon (662 to 691 nm, red)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_photon570_u "photon (662 to 691 nm, red)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_photon590_u "photon (662 to 691 nm, red)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_photon590_u "photon (662 to 691 nm, red)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_photonPSI_u "photon (380 to 750 nm, visible spectrum)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_photonPSI_u "photon (380 to 750 nm, visible spectrum)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_photonDrain_u "photon Drain">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_photonDrain_u "photon Drain">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_photonPSII_u "photon (380 to 750 nm, visible spectrum)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_photonPSII_u "photon (380 to 750 nm, visible spectrum)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_co2_c "CO2">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_co2_c "CO2">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_h2o_c "H2O">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_h2o_c "H2O">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_no3_c "Nitrate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_no3_c "Nitrate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_o2_c "O2">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_o2_c "O2">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_so4_c "Sulfate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_so4_c "Sulfate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_hso3_c "HSO3-">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_hso3_c "HSO3-">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_hco3_c "Bicarbonate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_hco3_c "Bicarbonate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_h2s_c "Hydrogen sulfide">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_h2s_c "Hydrogen sulfide">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_nh4_c "Ammonium">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_nh4_c "Ammonium">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_asn_DASH_L_c "L-Asparagine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_asn_DASH_L_c "L-Asparagine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_gln_DASH_L_c "L-Glutamine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_gln_DASH_L_c "L-Glutamine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_etoh_c "Ethanol">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_etoh_c "Ethanol">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_ac_c "Acetate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ac_c "Acetate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_lac_DASH_L_c "L-Lactate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_lac_DASH_L_c "L-Lactate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_tsul_c "Thiosulfate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_tsul_c "Thiosulfate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_fe2_c "Fe2+">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_fe2_c "Fe2+">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_fe3_c "Fe3+">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_fe3_c "Fe3+">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_mg2_c "Magnesium">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_mg2_c "Magnesium">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_ppi_c "Diphosphate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ppi_c "Diphosphate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_h2o_s "H2O">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_h2o_s "H2O">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_ppi_s "Diphosphate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ppi_s "Diphosphate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_h_s "H+">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_h_s "H+">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_pi_s "Phosphate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_pi_s "Phosphate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_h2o_m "H2O">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_h2o_m "H2O">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_ppi_m "Diphosphate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ppi_m "Diphosphate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_h_m "H+">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_h_m "H+">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_pi_m "Phosphate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_pi_m "Phosphate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_h2o_x "H2O">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_h2o_x "H2O">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_ppi_x "Diphosphate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ppi_x "Diphosphate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_h_x "H+">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_h_x "H+">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_pi_x "Phosphate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_pi_x "Phosphate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_h2o_v "H2O">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_h2o_v "H2O">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_ppi_v "Diphosphate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ppi_v "Diphosphate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_h_v "H+">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_h_v "H+">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_pi_v "Phosphate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_pi_v "Phosphate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_pyr_s "Pyruvate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_pyr_s "Pyruvate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_2ahethmpp_s "2-(alpha-Hydroxyethyl)thiamine diphosphate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_2ahethmpp_s "2-(alpha-Hydroxyethyl)thiamine diphosphate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_alac_DASH_S_s "(S)-2-Acetolactate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_alac_DASH_S_s "(S)-2-Acetolactate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_thmpp_s "Thiamine diphosphate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_thmpp_s "Thiamine diphosphate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_pyr_m "Pyruvate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_pyr_m "Pyruvate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_2ahethmpp_m "2-(alpha-Hydroxyethyl)thiamine diphosphate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_2ahethmpp_m "2-(alpha-Hydroxyethyl)thiamine diphosphate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_alac_DASH_S_m "(S)-2-Acetolactate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_alac_DASH_S_m "(S)-2-Acetolactate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_thmpp_m "Thiamine diphosphate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_thmpp_m "Thiamine diphosphate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_h2o2_v "Hydrogen peroxide">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_h2o2_v "Hydrogen peroxide">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_o2_v "O2">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_o2_v "O2">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_h2o2_s "Hydrogen peroxide">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_h2o2_s "Hydrogen peroxide">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_o2_s "O2">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_o2_s "O2">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_h2o2_x "Hydrogen peroxide">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_h2o2_x "Hydrogen peroxide">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_o2_x "O2">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_o2_x "O2">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_h2o2_m "Hydrogen peroxide">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_h2o2_m "Hydrogen peroxide">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_o2_m "O2">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_o2_m "O2">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_gln_DASH_L_m "L-Glutamine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_gln_DASH_L_m "L-Glutamine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_akg_m "2-Oxoglutarate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_akg_m "2-Oxoglutarate">
# ...
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_3OAR40m "3-oxoacyl-[acyl-carrier-protein] reductase (n-C4:0)">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_3HAD40m "3-hydroxyacyl-[acyl-carrier-protein] dehydratase (n-C4:0)">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_EAR40ym "enoyl-[acyl-carrier-protein] reductase (NADPH) (n-C4:0)">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_3OAS60m "3-oxoacyl-[acyl-carrier-protein] synthase (n-C6:0)">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_3OAR60m "3-oxoacyl-[acyl-carrier-protein] reductase (n-C6:0)">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_3HAD60m "3-hydroxyacyl-[acyl-carrier-protein] dehydratase (n-C6:0)">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_EAR60ym "enoyl-[acyl-carrier-protein] reductase (NADPH) (n-C6:0)">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_3OAS80m "3-oxoacyl-[acyl-carrier-protein] synthase (n-C8:0)">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_3OAR80m "3-oxoacyl-[acyl-carrier-protein] reductase (n-C8:0)">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_3HAD80m "3-hydroxyacyl-[acyl-carrier-protein] dehydratase (n-C8:0)">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_EAR80ym "enoyl-[acyl-carrier-protein] reductase (NADPH) (n-C8:0)">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_3OAS100m "3-oxoacyl-[acyl-carrier-protein] synthase (n-C10:0)">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_3OAR100m "3-oxoacyl-[acyl-carrier-protein] reductase (n-C10:0)">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_3HAD100m "3-hydroxyacyl-[acyl-carrier-protein] dehydratase (n-C10:0)">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_EAR100ym "enoyl-[acyl-carrier-protein] reductase (NADPH) (n-C10:0)">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_3OAS120m "3-oxoacyl-[acyl-carrier-protein] synthase (n-C12:0)">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_3OAR120m "3-oxoacyl-[acyl-carrier-protein] reductase (n-C12:0)">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_3HAD120m "3-hydroxyacyl-[acyl-carrier-protein] dehydratase (n-C12:0)">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_EAR120ym "enoyl-[acyl-carrier-protein] reductase (NADPH) (n-C12:0)">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_3OAS140m "3-oxoacyl-[acyl-carrier-protein] synthase (n-C14:0)">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_3OAR140m "3-oxoacyl-[acyl-carrier-protein] reductase (n-C14:0)">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_3HAD140m "3-hydroxyacyl-[acyl-carrier-protein] dehydratase (n-C14:0)">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_EAR140ym "enoyl-[acyl-carrier-protein] reductase (NADPH) (n-C14:0)">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_3OAS160m "3-oxoacyl-[acyl-carrier-protein] synthase (n-C16:0)">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_3OAR160m "3-oxoacyl-[acyl-carrier-protein] reductase (n-C16:0)">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_3HAD160m "3-hydroxyacyl-[acyl-carrier-protein] dehydratase (n-C16:0)">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_EAR160ym "enoyl-[acyl-carrier-protein] reductase (NADPH) (n-C16:0)">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_3OAS180m "3-oxoacyl-[acyl-carrier-protein] synthase (n-C18:0)">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_3OAR180m "3-oxoacyl-[acyl-carrier-protein] reductase (n-C18:0)">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_3HAD180m "3-hydroxyacyl-[acyl-carrier-protein] dehydratase (n-C18:0)">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_EAR180ym "enoyl-[acyl-carrier-protein] reductase (NADPH) (n-C18:0)">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_FAS161ACP_Lm "fatty acyl-ACP synthase (n-C16:1ACP)">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_FAS181ACP_Lm "fatty acyl-ACP synthase (n-C18:1ACP)">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_FAS182ACP_Lm "fatty acyl-ACP synthase (n-C18:2ACP)">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_FAS183ACP_Lm "fatty acyl-ACP synthase (n-C18:3ACP)">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_G3PDc "glycerol-3-phosphate dehydrogenase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_GLYCKr "Glycerol kinase, cytosolic">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_GLYCKs "Glycerol kinase, plastidic">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_GLYCKm "Glycerol kinase, mitochondrial">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_G3PDNc "glycerol-3-phosphate dehydrogenase (NAD+)">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_G3PATr "Glycerol-3-phosphate O-acyltransferase, endoplasmic reticular">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_G3PATs "Glycerol-3-phosphate O-acyltransferase, plastidic">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_G3PATm "Glycerol-3-phosphate O-acyltransferase, mitochondrial">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_AGPATr "1-acylglycerol-3-phosphate O-acyltransferase, endoplasmic reticular">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_AGPATs "1-acylglycerol-3-phosphate O-acyltransferase, plastidic">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_AGPATm "1-acylglycerol-3-phosphate O-acyltransferase, mitochondrial">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_PAPAr "Phosphatidate phosphatase, endoplasmic reticular">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_PAPAs "Phosphatidate phosphatase, plastidic">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_PAPAm "Phosphatidate phosphatase, mitochondrial">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DAGKm "diacylglycerol kinase (ATP dependent), mitochondrial">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DAGACTr "diacylglycerol O-acyltransferase, endoplasmic reticular">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_TAGLc "triacylglycerol lipase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DAGLc "diacylglycerol lipase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_MAGLc "monoacylglycerol lipase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_CDPDAGSr "phosphatidate cytidylyltransferase, endoplasmic reticular">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_CDPDAGSm "phosphatidate cytidylyltransferase, mitochondrial">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_CDIPTr "phosphatidylinositol synthase, endoplasmic reticular">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_PGPSr "CDP-diacylglycerol--glycerol-3-phosphate 3-phosphatidyltransferase, endoplasmic reticular">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_PGPSm "CDP-diacylglycerol--glycerol-3-phosphate 3-phosphatidyltransferase, mitochondrial">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_PGPPm "Phosphatidylglycerophosphatase, mitochondrial">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_CLPNSm "cardiolipin synthase, mitochondrial">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_PSSr "phosphatidylserine synthase, endoplasmic reticular">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_PSSm "phosphatidylserine synthase, mitochondrial">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_PEDCr "phosphatidylserine decarboxylase, endoplasmic reticular">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_PEDCm "phosphatidylserine decarboxylase, mitochondrial">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_ETHAPTr "Ethanolaminephosphotransferase, endoplasmic reticular">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_PETHACTr "phosphoethanolamine cytidyltransferase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_ETHAKr "Ethanolamine kinase, endoplasmic reticular">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_ETHAKs "Ethanolamine kinase, plastidic">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_SERDCr "serine decarboxylase, endoplasmic reticular">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_SERDCs "serine decarboxylase, plastidic">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_PETHAMTr "phosphoethanolamine N-methyltransferase , endoplasmic reticular">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_PETHAMTs "phosphoethanolamine N-methyltransferase, plastidic">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_CHOLKr "choline kinase, endoplasmic reticular">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_CHOLKs "choline kinase, plastidic">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_PCHOLPPr "phocholine phosphatase, endoplasmic reticular">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_PCHOLPPs "phocholine phosphatase, plastidic">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_CHOLPCTr "choline phosphate cytididyltransferase, endoplasmic reticular">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_CHOLPCTs "choline phosphate cytididyltransferase, plastidic">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DAGCPr "diacylglycerol cholinephosphotransferase, endoplasmic reticular">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DAGCPs "diacylglycerol cholinephosphotransferase, plastidic">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_PLCr "Phospholipase C ">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_PLAr "Phospholipase A">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_LPPr "Lysophospholipase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_GPEPEr "Glycerophosphodiester phosphodiesterase (Glycerophosphocholine)">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_MGDGSs "monogalactosyldiacylglycerol synthase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DGDGSs "digalactosyldiacylglycerol synthase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_SQTs "sulfoquinovosyltransferase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_UDPSQSs "UDP-sulfoquinovose synthase ">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_LNL9LOs "linolenate 9-lipoxygenase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_OCDCYA9LOs "linoleate 9-lipoxygenase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_LNL13LOs "linolenate 13-lipoxygenase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_OCDCYA13LOs "linoleate 13-lipoxygenase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_LNL9HPLs "linolenate 9-hydroperoxide lyase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_OCDCYA9HPLs "linoleate 9-hydroperoxide lyase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_LNL13HPLs "linolenate 13-hydroperoxide lyase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_OCDCYA13HPLs "linoleate 13-hydroperoxide lyase">
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
ios2164_m = copy.deepcopy(ios2164_orig)

for met in ios2164_m.metabolites:
    met.id = str(met.id) + '0'
    met.compartment = str(met.compartment) + '0'
for rxn in ios2164_m.reactions:
    rxn.id = str(rxn.id) + '_M'
    if "EX_" in rxn.id: #Rename media reactions
        rxn.name = "M " + str(rxn.name)

# %%
ios2164_bs = copy.deepcopy(ios2164_orig)

for met in ios2164_bs.metabolites:
    met.id = str(met.id) + '1'
    met.compartment = str(met.compartment) + '1'
    
for rxn in ios2164_bs.reactions:
    rxn.id = str(rxn.id)  + '_BS'
    if "EX_" in rxn.id: #Rename media reactions
        rxn.name = "BS " + str(rxn.name)

# %%
#Merging the BS and M Cells
ios2164_2cell = ios2164_m.merge(ios2164_bs, objective = "sum", inplace = 1)

# %%
ios2164_2cell.compartments = {
 'c0': 'M Cell Cytoplasm',
 's0': 'M Cell Plastid',
 'r0': 'M Cell Endoplasmic_reticulum',
 'm0': 'M Cell Mitochondrion',
 'e0': 'M Cell Extracellular',
 'u0': 'M Cell Thylakoid',
 'x0': 'M Cell Peroxisome',
 'v0': 'M Cell Vacuole',
 'c1': 'BS Cell Cytoplasm',
 's1': 'BS Cell Plastid',
 'r1': 'BS Cell Endoplasmic_reticulum',
 'm1': 'BS Cell Mitochondrion',
 'e1': 'BS Cell Extracellular',
 'u1': 'BS Cell Thylakoid',
 'x1': 'BS Cell Peroxisome',
 'v1': 'BS Cell Vacuole'}
#Apparently compartments don't update after  merging so I've updated it na lang after that
#Also need to rebuild the model medium

# %%
ios2164_2cell.metabolites.glc_DASH_A_c1.summary()
#It works
# Out:
# <h3>glc_DASH_A_c1</h3><p>C6H12O6</p><h4>Producing Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>48.66%</td>
#       <td>70.12</td>
#       <td>INVc_BS</td>
#       <td>h2o_c1 + sucr_c1 --&gt; fru_DASH_B_c1 + glc_DASH_A_c1</td>
#     </tr>
#     <tr>
#       <td>51.34%</td>
#       <td>73.98</td>
#       <td>XYL2c_BS</td>
#       <td>glc_DASH_A_c1 &lt;=&gt; fru_DASH_B_c1</td>
#     </tr>
#   </tbody>
# </table><h4>Consuming Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>96.66%</td>
#       <td>-139.3</td>
#       <td>GLUKAc_BS</td>
#       <td>atp_c1 + glc_DASH_A_c1 --&gt; adp_c1 + g6p_DASH_A_c1 + h_c1</td>
#     </tr>
#     <tr>
#       <td>3.34%</td>
#       <td>-4.819</td>
#       <td>Straw_Biomass_BS</td>
#       <td>0.0321 ala_DASH_L_c1 + 0.0123 arg_DASH_L_c1 + 0.0417 asp_DASH_L_c1 + 33.259 atp_c1 + 2.0789 cellulose_c1 + 0.1721 conoh_c1 + 0.2065 coumoh_c1 + 0.0071 ctp_c1 + 0.0033 cys_DASH_L_c1 + 0.0009 datp_c1 + 0.0007 dctp_c1 + 0.0007 dgtp_c1 + 0.0009 dttp_c1 + 0.00285 fa_os_r1 + 0.0643 fru_DASH_B_c1 + 0.0546 glc_DASH_A_c1 + 0.0385 glu_DASH_L_c1 + 0.0282 gly_c1 + 0.0071 gtp_c1 + 0.057 his_DASH_L_c1 + 0.014 ile_DASH_L_c1 + 0.0234 leu_DASH_L_c1 + 0.0153 lys_DASH_L_c1 + 0.0076 met_DASH_L_c1 + 0.000191 pa_os_r1 + 0.0034 pc_os_r1 + 0.00178 pe_os_r1 + 0.0133 phe_DASH_L_c1 + 0.0225 pro_DASH_L_c1 + 0.00041 ptd1ino_os_r1 + 0.0219 ser_DASH_L_c1 + 0.1475 sinoh_c1 + 0.3249 starch_s1 + 0.1049 sucr_c1 + 0.0192 thr_DASH_L_c1 + 0.0298 triglyc_os_r1 + 0.0016 trp_DASH_L_c1 + 0.0077 tyr_DASH_L_c1 + 0.1256 udparab_c1 + 0.4018 udpg_c1 + 0.0229 udpgal_c1 + 0.5033 udpglcur_c1 + 0.572 udpxyl_c1 + 0.009 utp_c1 + 0.0225 val_DASH_L_c1 --&gt; 33.259 adp_c1 + 1.626 h_c1 + 33.259 pi_c1 + 1.626 udp_c1</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# From Blatke & Brautigam (2019):
#
# "The mesophyll and bundle sheath networks are connected by a range of cytosolic transport metabolites including amino acids, sugars (glucose, fructose, sucrose, trehalose, ribose), single phosphorylated sugar (glucose-6-phosphate, glucose-1-phosphate, fructose-6-phosphate, sucrose-6-phosphate), mono-/di-/tri-carboxylic acids (phosphoenolpyruvate, pyruvate, citrate, cis-aconitate, isocitrate, α-ketoglutarate, succinate, fumarate, malate), glyceric acids (2-Phosphoglycerate, 3-Phosphoglycerate), glycolate, glycerate, glyceraldehyde-3-phosphate, di-hydroxyacetone-phosphate and CO2.
#
# Nucleotides, NAD/NADH, NADP/NADPH, pyrophosphate, inorganic phosphate are not considered as transport metabolites.
#
# Oxaloacetate has been excluded as transport metabolite since concentrations of oxaloacetate are very low in vivo and it is reasonably unstable in aqueous solutions.
#
# Other small molecules that can be imported by the bundle sheath from the environment, as well as protons and HCO3-, are not exchanged between the two cell types.
#
# #So bale yung mga organic na soluble lang with reasonably long cellular half-lives.

# %%
#Open the initial curated list to get the metabolite ids
transport_rxns = pd.read_csv('../model/initial_list_transport_rxns.csv')
#Ok it gets the reactions now


for item in ios2164_orig.metabolites:
    if item.compartment == "c":
        if item.id in transport_rxns.id.values:
            pd_rxn = Reaction()
            #Generate reaction name
            pd_rxn.id = str(item.id[:-2] + '_pd') #Replaces suffix with '_pd'
            pd_rxn.name = str('Plasmodesmatal transport of ' + item.name)
            pd_rxn.subsystem = str('PD Transport Reaction')
            #Reaction is reversible
            pd_rxn.lower_bound = -1000
            pd_rxn.upper_bound = 1000
            
            
            #Generate metabolite names
            
            
            met_mcell = str(item.id) + '0'
            met_bcell = str(item.id) + '1'
            
            met_mcell = ios2164_2cell.metabolites.get_by_id(met_mcell)
            met_bcell = ios2164_2cell.metabolites.get_by_id(met_bcell)
            pd_rxn.add_metabolites({met_mcell:-1.0, met_bcell:1.0})
            ios2164_2cell.add_reaction(pd_rxn)

# %%
#Shows all the media boundary reactions.
media_rxn = [item for item in ios2164_2cell.reactions if "EX_" in item.id]

#Initialize muna to outflow yung mga reactions so I can alter it at will.
for item in media_rxn:
    print(item.name, item.bounds)


# ios2164_2cell.media = media_rxn

#Oks na :)
# Out:
# M CO2 exchange (-1000.0, 0.0)
# M H2O exchange (-1000.0, 1000.0)
# M H+ exchange (-1000.0, 1000.0)
# M nitrate exchange (-1000.0, 0.0)
# M O2 exchange (-1000.0, 1000.0)
# M Phosphate exchange (-1000.0, 1000.0)
# M Sucrose exchange (-1000.0, 0.0)
# M Fructose exchange (-1000.0, 0.0)
# M Glucose exchange (-1000.0, 0.0)
# M Sulfate exchange (-1000.0, 1000.0)
# M Bicarbonate exchange (-1000.0, 0.0)
# M Sulfite exchange (-1000.0, 0.0)
# M Hydrogen sulfide exchange (-1000.0, 0.0)
# M Ammonia exchange (-1000.0, 0.0)
# M L-Asparagine exchange (-1000.0, 1000.0)
# M L-Glutamine exchange (-1000.0, 1000.0)
# M Ethanol exchange (-1000.0, 1000.0)
# M Acetate exchange (-1000.0, 1000.0)
# M L-Lactate exchange (-1000.0, 1000.0)
# M Thiosulfate exchange (-1000.0, 0.0)
# M Fe2+ exchange (-1000.0, 1000.0)
# M Fe3+ exchange (-1000.0, 0.0)
# M Magnesium exchange (-1000.0, 1000.0)
# M L-Alanine exchange (-1000.0, 1000.0)
# M L-Arginine exchange (-1000.0, 1000.0)
# M L-Aspartate exchange (-1000.0, 1000.0)
# M L-Cysteine exchange (-1000.0, 1000.0)
# M L-Glutamate exchange (-1000.0, 1000.0)
# M Glycine exchange (-1000.0, 1000.0)
# M L-Histidine exchange (-1000.0, 1000.0)
# M L-Isoleucine exchange (-1000.0, 1000.0)
# M L-Leucine exchange (-1000.0, 1000.0)
# M L-Lysine exchange (-1000.0, 1000.0)
# M L-Methionine exchange (-1000.0, 1000.0)
# M L-Phenylalanine exchange (-1000.0, 1000.0)
# M L-Proline exchange (-1000.0, 1000.0)
# M L-Serine exchange (-1000.0, 1000.0)
# M L-Threonine exchange (-1000.0, 1000.0)
# M L-Tryptophan exchange (-1000.0, 1000.0)
# M L-Tyrosine exchange (-1000.0, 1000.0)
# M L-Valine exchange (-1000.0, 1000.0)
# M photon emission (-1000.0, 0.0)
# BS CO2 exchange (-1000.0, 0.0)
# BS H2O exchange (-1000.0, 1000.0)
# BS H+ exchange (-1000.0, 1000.0)
# BS nitrate exchange (-1000.0, 0.0)
# BS O2 exchange (-1000.0, 1000.0)
# BS Phosphate exchange (-1000.0, 1000.0)
# BS Sucrose exchange (-1000.0, 0.0)
# BS Fructose exchange (-1000.0, 0.0)
# BS Glucose exchange (-1000.0, 0.0)
# BS Sulfate exchange (-1000.0, 1000.0)
# BS Bicarbonate exchange (-1000.0, 0.0)
# BS Sulfite exchange (-1000.0, 0.0)
# BS Hydrogen sulfide exchange (-1000.0, 0.0)
# BS Ammonia exchange (-1000.0, 0.0)
# BS L-Asparagine exchange (-1000.0, 1000.0)
# BS L-Glutamine exchange (-1000.0, 1000.0)
# BS Ethanol exchange (-1000.0, 1000.0)
# BS Acetate exchange (-1000.0, 1000.0)
# BS L-Lactate exchange (-1000.0, 1000.0)
# BS Thiosulfate exchange (-1000.0, 0.0)
# BS Fe2+ exchange (-1000.0, 1000.0)
# BS Fe3+ exchange (-1000.0, 0.0)
# BS Magnesium exchange (-1000.0, 1000.0)
# BS L-Alanine exchange (-1000.0, 1000.0)
# BS L-Arginine exchange (-1000.0, 1000.0)
# BS L-Aspartate exchange (-1000.0, 1000.0)
# BS L-Cysteine exchange (-1000.0, 1000.0)
# BS L-Glutamate exchange (-1000.0, 1000.0)
# BS Glycine exchange (-1000.0, 1000.0)
# BS L-Histidine exchange (-1000.0, 1000.0)
# BS L-Isoleucine exchange (-1000.0, 1000.0)
# BS L-Leucine exchange (-1000.0, 1000.0)
# BS L-Lysine exchange (-1000.0, 1000.0)
# BS L-Methionine exchange (-1000.0, 1000.0)
# BS L-Phenylalanine exchange (-1000.0, 1000.0)
# BS L-Proline exchange (-1000.0, 1000.0)
# BS L-Serine exchange (-1000.0, 1000.0)
# BS L-Threonine exchange (-1000.0, 1000.0)
# BS L-Tryptophan exchange (-1000.0, 1000.0)
# BS L-Tyrosine exchange (-1000.0, 1000.0)
# BS L-Valine exchange (-1000.0, 1000.0)
# BS photon emission (-1000.0, 0.0)

# %%
#Add reactions specific to each compartments and their bounds
ios2164_2cell.reactions.get_by_id('mal_DASH_L_pd')
# Out:
# <Reaction mal_DASH_L_pd at 0x7f34909e9eb0>

# %%
ios2164_2cell.metabolites.ala_DASH_L_c0.summary()
#omg nagkaka-flux na siya thru the plasmodesmata :)
# Out:
# <h3>ala_DASH_L_c0</h3><p>C3H7NO2</p><h4>Producing Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>69.39%</td>
#       <td>1000</td>
#       <td>ALAATc_M</td>
#       <td>akg_c0 + ala_DASH_L_c0 &lt;=&gt; glu_DASH_L_c0 + pyr_c0</td>
#     </tr>
#     <tr>
#       <td>30.61%</td>
#       <td>441</td>
#       <td>ALAtx_M</td>
#       <td>ala_DASH_L_c0 + h_c0 &lt;=&gt; ala_DASH_L_x0 + h_x0</td>
#     </tr>
#   </tbody>
# </table><h4>Consuming Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>30.41%</td>
#       <td>-438.2</td>
#       <td>ALAt2m_M</td>
#       <td>ala_DASH_L_m0 + h_m0 &lt;=&gt; ala_DASH_L_c0 + h_c0</td>
#     </tr>
#     <tr>
#       <td>69.39%</td>
#       <td>-1000</td>
#       <td>ALAtex_M</td>
#       <td>ala_DASH_L_e0 &lt;=&gt; ala_DASH_L_c0</td>
#     </tr>
#     <tr>
#       <td>0.20%</td>
#       <td>-2.833</td>
#       <td>Straw_Biomass_M</td>
#       <td>0.0321 ala_DASH_L_c0 + 0.0123 arg_DASH_L_c0 + 0.0417 asp_DASH_L_c0 + 33.259 atp_c0 + 2.0789 cellulose_c0 + 0.1721 conoh_c0 + 0.2065 coumoh_c0 + 0.0071 ctp_c0 + 0.0033 cys_DASH_L_c0 + 0.0009 datp_c0 + 0.0007 dctp_c0 + 0.0007 dgtp_c0 + 0.0009 dttp_c0 + 0.00285 fa_os_r0 + 0.0643 fru_DASH_B_c0 + 0.0546 glc_DASH_A_c0 + 0.0385 glu_DASH_L_c0 + 0.0282 gly_c0 + 0.0071 gtp_c0 + 0.057 his_DASH_L_c0 + 0.014 ile_DASH_L_c0 + 0.0234 leu_DASH_L_c0 + 0.0153 lys_DASH_L_c0 + 0.0076 met_DASH_L_c0 + 0.000191 pa_os_r0 + 0.0034 pc_os_r0 + 0.00178 pe_os_r0 + 0.0133 phe_DASH_L_c0 + 0.0225 pro_DASH_L_c0 + 0.00041 ptd1ino_os_r0 + 0.0219 ser_DASH_L_c0 + 0.1475 sinoh_c0 + 0.3249 starch_s0 + 0.1049 sucr_c0 + 0.0192 thr_DASH_L_c0 + 0.0298 triglyc_os_r0 + 0.0016 trp_DASH_L_c0 + 0.0077 tyr_DASH_L_c0 + 0.1256 udparab_c0 + 0.4018 udpg_c0 + 0.0229 udpgal_c0 + 0.5033 udpglcur_c0 + 0.572 udpxyl_c0 + 0.009 utp_c0 + 0.0225 val_DASH_L_c0 --&gt; 33.259 adp_c0 + 1.626 h_c0 + 33.259 pi_c0 + 1.626 udp_c0</td>
#     </tr>
#   </tbody>
# </table>

# %%
ios2164_2cell.metabolites.ala_DASH_L_c1.summary()
#ang  cool haha the model's predicting some backflow ng alanine pabalik sa M cell :)
# Out:
# <h3>ala_DASH_L_c1</h3><p>C3H7NO2</p><h4>Producing Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>69.39%</td>
#       <td>1000</td>
#       <td>ALAATc_BS</td>
#       <td>akg_c1 + ala_DASH_L_c1 &lt;=&gt; glu_DASH_L_c1 + pyr_c1</td>
#     </tr>
#     <tr>
#       <td>30.61%</td>
#       <td>441</td>
#       <td>ALAtx_BS</td>
#       <td>ala_DASH_L_c1 + h_c1 &lt;=&gt; ala_DASH_L_x1 + h_x1</td>
#     </tr>
#   </tbody>
# </table><h4>Consuming Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>30.41%</td>
#       <td>-438.2</td>
#       <td>ALAt2m_BS</td>
#       <td>ala_DASH_L_m1 + h_m1 &lt;=&gt; ala_DASH_L_c1 + h_c1</td>
#     </tr>
#     <tr>
#       <td>69.39%</td>
#       <td>-1000</td>
#       <td>ALAtex_BS</td>
#       <td>ala_DASH_L_e1 &lt;=&gt; ala_DASH_L_c1</td>
#     </tr>
#     <tr>
#       <td>0.20%</td>
#       <td>-2.833</td>
#       <td>Straw_Biomass_BS</td>
#       <td>0.0321 ala_DASH_L_c1 + 0.0123 arg_DASH_L_c1 + 0.0417 asp_DASH_L_c1 + 33.259 atp_c1 + 2.0789 cellulose_c1 + 0.1721 conoh_c1 + 0.2065 coumoh_c1 + 0.0071 ctp_c1 + 0.0033 cys_DASH_L_c1 + 0.0009 datp_c1 + 0.0007 dctp_c1 + 0.0007 dgtp_c1 + 0.0009 dttp_c1 + 0.00285 fa_os_r1 + 0.0643 fru_DASH_B_c1 + 0.0546 glc_DASH_A_c1 + 0.0385 glu_DASH_L_c1 + 0.0282 gly_c1 + 0.0071 gtp_c1 + 0.057 his_DASH_L_c1 + 0.014 ile_DASH_L_c1 + 0.0234 leu_DASH_L_c1 + 0.0153 lys_DASH_L_c1 + 0.0076 met_DASH_L_c1 + 0.000191 pa_os_r1 + 0.0034 pc_os_r1 + 0.00178 pe_os_r1 + 0.0133 phe_DASH_L_c1 + 0.0225 pro_DASH_L_c1 + 0.00041 ptd1ino_os_r1 + 0.0219 ser_DASH_L_c1 + 0.1475 sinoh_c1 + 0.3249 starch_s1 + 0.1049 sucr_c1 + 0.0192 thr_DASH_L_c1 + 0.0298 triglyc_os_r1 + 0.0016 trp_DASH_L_c1 + 0.0077 tyr_DASH_L_c1 + 0.1256 udparab_c1 + 0.4018 udpg_c1 + 0.0229 udpgal_c1 + 0.5033 udpglcur_c1 + 0.572 udpxyl_c1 + 0.009 utp_c1 + 0.0225 val_DASH_L_c1 --&gt; 33.259 adp_c1 + 1.626 h_c1 + 33.259 pi_c1 + 1.626 udp_c1</td>
#     </tr>
#   </tbody>
# </table>

# %%
ios2164_2cell.metabolites.mal_DASH_L_c0.summary()
# Out:
# <h3>mal_DASH_L_c0</h3><p>C4H4O5</p><h4>Producing Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100.00%</td>
#       <td>167.1</td>
#       <td>DICtm_M</td>
#       <td>mal_DASH_L_m0 + succ_c0 --&gt; mal_DASH_L_c0 + succ_m0</td>
#     </tr>
#   </tbody>
# </table><h4>Consuming Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.92%</td>
#       <td>-1.536</td>
#       <td>MALFUMts_M</td>
#       <td>fum_c0 + mal_DASH_L_s0 &lt;=&gt; fum_s0 + mal_DASH_L_c0</td>
#     </tr>
#     <tr>
#       <td>99.08%</td>
#       <td>-165.5</td>
#       <td>MALOAAtm_M</td>
#       <td>mal_DASH_L_m0 + oaa_c0 &lt;-- mal_DASH_L_c0 + oaa_m0</td>
#     </tr>
#   </tbody>
# </table>

# %%
#Ok, let's add the reactions specific to the C4 pathway now from Ermakova et al., (2021
#Will be using the alias _transg_ as annotation 
#I'll just use a parser instead

#             pd_rxn = Reaction()
#             #Generate reaction name
#             pd_rxn.id = str(item.id[:-2] + '_pd') #Replaces suffix with '_pd'
#             pd_rxn.name = str('Plasmodesmatal transport of ' + item.name)
#             pd_rxn.subsystem = str('PD Transport Reaction')
#             #Reaction is reversible
#             pd_rxn.lower_bound = -1000
#             pd_rxn.upper_bound = 1000

# %%
for item in ios2164_2cell.reactions:
    print(item.name,)
# Out:
# Coleoptile Biomass reaction
# Straw Biomass reaction
# Acyl-CoA (Aerobic composition)
# Acyl-CoA (Aerobic composition)
# ACP(Aerobic composition)
# ACP(Aerobic composition)
# Fatty acid (Aerobic composition)
# Fatty acid (Aerobic composition)
# M CO2 exchange
# M H2O exchange
# M H+ exchange
# M nitrate exchange
# M O2 exchange
# M Phosphate exchange
# M Sucrose exchange
# M Fructose exchange
# M Glucose exchange
# M Sulfate exchange
# M Bicarbonate exchange
# M Sulfite exchange
# M Hydrogen sulfide exchange
# M Ammonia exchange
# M L-Asparagine exchange
# M L-Glutamine exchange
# M Ethanol exchange
# M Acetate exchange
# M L-Lactate exchange
# M Thiosulfate exchange
# M Fe2+ exchange
# M Fe3+ exchange
# M Magnesium exchange
# M L-Alanine exchange
# M L-Arginine exchange
# M L-Aspartate exchange
# M L-Cysteine exchange
# M L-Glutamate exchange
# M Glycine exchange
# M L-Histidine exchange
# M L-Isoleucine exchange
# M L-Leucine exchange
# M L-Lysine exchange
# M L-Methionine exchange
# M L-Phenylalanine exchange
# M L-Proline exchange
# M L-Serine exchange
# M L-Threonine exchange
# M L-Tryptophan exchange
# M L-Tyrosine exchange
# M L-Valine exchange
# M photon emission
# spectral decomposition of blue LED (450  nm)
# spectral decomposition of red LED (660  nm)
# spectral decomposition of red LED (Mix of R, G & B)
# spectral decomposition of red LED (530  nm)
# spectral decomposition of solar light measured from Earth's surface
# Photosystem I 410 specific reaction
# Photosystem I 430 specific reaction
# Photosystem I 450 specific reaction
# Photosystem I 470 specific reaction
# Photosystem I 490 specific reaction
# Photosystem I 510 specific reaction
# Photosystem I 530 specific reaction
# Photosystem I 550 specific reaction
# Photosystem I 570 specific reaction
# Photosystem I 590 specific reaction
# Photosystem I 610 specific reaction
# Photosystem I 630 specific reaction
# Photosystem I 630 specific reaction
# Photosystem I 670 specific reaction
# Photosystem I 690 specific reaction
# Photosystem II 410 specific reaction
# Photosystem II 430 specific reaction
# Photosystem II 450 specific reaction
# Photosystem II 470 specific reaction
# Photosystem II 490 specific reaction
# Photosystem II 510 specific reaction
# Photosystem II 530 specific reaction
# Photosystem II 550 specific reaction
# Photosystem II 570 specific reaction
# Photosystem II 590 specific reaction
# Photosystem II 610 specific reaction
# Photosystem II 630 specific reaction
# Photosystem II 630 specific reaction
# Photosystem II 670 specific reaction
# Photosystem II 690 specific reaction
# CO2 transport (extracellular to cytosol)
# H2O transport (extracellular to cytosol)
# proton transport via diffusion (extracellular to cytosol)
# nitrate transport (extracellular to cytosol)
# O2 transport in via diffusion (extracellular to cytosol)
# PI transport in via diffusion (extracellular to cytosol)
# sucrose transport transport via diffusion (extracellular to cytosol)
# D-fructose transport via diffusion (extracellular to cytosol)
# glucose transport via diffusion (extracellular to cytosol)
# sulfate transport via diffusion (extracellular to cytosol)
# sulfite transport via diffusion (extracellular to cytosol)
# bicarbonate transport via diffusion (extracellular to cytosol)
# hydrogen sulfide transport via diffusion (extracellular to cytosol)
# ammonia transport via diffusion (extracellular to cytosol)
# L-asparagine transport via diffusion (extracellular to cytosol)
# L-glutamine transport via diffusion (extracellular to cytosol)
# ethanol transport via diffusion (extracellular to cytosol)
# Acetate transport via diffusion (extracellular to cytosol)
# L-lactate transport via diffusion (extracellular to cytosol)
# Thiosulfate transport via diffusion (extracellular to cytosol)
# Fe2+ transport via diffusion (extracellular to cytosol)
# Fe3+ transport via diffusion (extracellular to cytosol)
# Mg2 transport via diffusion (extracellular to cytosol)
# L-alanine transport via diffusion (extracellular to cytosol)
# L-arginine transport via diffusion (extracellular to cytosol)
# L-aspartate transport via diffusion (extracellular to cytosol)
# L-cysteine transport via diffusion (extracellular to cytosol)
# L-glutamate transport via diffusion (extracellular to cytosol)
# Glycine transport via diffusion (extracellular to cytosol)
# L-histidine transport via diffusion (extracellular to cytosol)
# L-isoleucine transport via diffusion (extracellular to cytosol)
# L-leucine transport via diffusion (extracellular to cytosol)
# L-lysine transport via diffusion (extracellular to cytosol)
# L-methionine transport via diffusion (extracellular to cytosol)
# L-phenylalanine transport via diffusion (extracellular to cytosol)
# L-proline transport via diffusion (extracellular to cytosol)
# L-serine transport via diffusion (extracellular to cytosol)
# L-threonine transport via diffusion (extracellular to cytosol)
# L-tryptophan transport via diffusion (extracellular to cytosol)
# L-tyrosine transport via diffusion (extracellular to cytosol)
# L-valine transport via diffusion (extracellular to cytosol)
# Soluble inorganic pyrophosphatase, cytosol
# Soluble inorganic pyrophosphatase, plastidic
# Soluble inorganic pyrophosphatase, mitochondrial
# Soluble inorganic pyrophosphatase, peroxisomal
# Soluble inorganic pyrophosphatase, vacuolar
# Membrane -bound H+-inorganic pyrophosphatase, peroxisomal
# Membrane -bound H+-inorganic pyrophosphatase, vacuolar
# Acetolactate synthase, plastidic
# Acetolactate synthase, mitochondrial
# Catalase, vacuolar
# Catalase, plastidic
# Catalase, peroxisomal
# Catalase, mitochondrial
# Glutamate synthase (ferredoxin), mitochondrial
# Glutamate synthase (ferredoxin), plastidic
# Ribulose-bisphosphate carboxylase
# Ribulose-bisphosphate carboxylase (photorespiration, Vc/Vo=3/1)
# Cytochrome c oxidase (complex IV)
# Nitrate reductase (Ubiquinol-8), mitochondrial
# Alternative oxidase
# ATP phosphohydrolase, cytosolic
# ATP phosphohydrolase, mitochondrial
# ATP phosphohydrolase, plastidic
# ATP synthase (complex V), plastidic
# ATP synthase (complex V), mitochondrial
# ATP synthase (complex V-type), vacuolar
# Glutamate synthase (NADH)
# Glutamate synthase (NADPH)
# Glutathione reductase (NADPH), cytosolic
# Glutathione reductase (NADPH), plastidic
# Glutathione reductase (NADPH), mitochondrial
# Adenylate kinase, cytosolic
# Adenylate kinase, mitochondrial
# Adenylate kinase, plastidic
# Apyrase
# ADP-Apyrase
# galactose-1-phosphate uridylyltransferase
# Dephospho-CoA kinase
# uridine kinase (GTP), cytosolic
# uridine kinase (GTP), plastidic
# Dihydropyrimidine dehydrogenase (NADP+)
# beta-ureidopropionase
# Dihydropyrimidinase
# Thymidylate synthase
# Cytidine deaminase
# GTP:cytidine 5-phosphotransferase, cytosolic
# GTP:cytidine 5-phosphotransferase, plastidic
# deoxycytidine triphosphate deaminase
# ribonucleoside-triphosphate reductase (CTP)
# ribonucleoside-triphosphate reductase (UTP)
# ribonucleoside-triphosphate reductase (ATP)
# ribonucleoside-triphosphate reductase (GTP)
# Deoxycytidine aminohydrolase
# Uracil phosphoribosyltransferase, plastidic
# Uracil phosphoribosyltransferase, cytosolic
# Uridine phosphorylase, cytosolic
# Uridine phosphorylase, plastidic
# ATP:deoxyuridine 5-phosphotransferase
# Thymidine kinase
# ATP:cytidine 5-phosphotransferase, cytosolic
# ATP:cytidine 5-phosphotransferase, plastidic
# Uridine kinase, cytosolic
# Uridine kinase, plastidic
# Deoxyguanosine 5-phosphohydrolase, cytosolic
# Thymidylate 5-phosphohydrolase, cytosolic
# Thymidylate 5-phosphohydrolase, plastidic
# 2-Deoxyuridine 5-monophosphate phosphohydrolase
# 2-Deoxycytidine 5-monophosphate phosphohydrolase
# Cytidine-5-monophosphate phosphohydrolase
# Cytidine-5-monophosphate phosphohydrolase
# Uridine 5-monophosphate phosphohydrolase, cytosolic
# Uridine 5-monophosphate phosphohydrolase, plastidic
# CTP synthetase
# dUTP pyrophosphatase
# 2-Deoxycytidine diphosphate:oxidized-thioredoxin 2-oxidoreductase
# 2-Deoxyuridine 5-diphosphate:oxidized-thioredoxin 2-oxidoreductase
# Thioredoxin reductase (NADPH), plastidic
# Thioredoxin reductase (NADPH), cytosolic
# Thioredoxin reductase (NADPH), mitochondrial
# ATP:dTDP phosphotransferase
# dTMP kinase
# ATP:dUDP phosphotransferase
# dUMP kinase
# ATP:dCDP phosphotransferase
# dCMP kinase
# ATP:CDP phosphotransferase, cytosolic
# ATP:CDP phosphotransferase, plastidic
# CMP kinase, cytosolic
# CMP kinase, plastidic
# ATP:UDP phosphotransferase, cystosolic
# ATP:UDP phosphotransferase, plastidic
# ATP:UDP phosphotransferase, vacuolar
# ATP:UMP phosphotransferase
# Methionine adenosyltransferase
# AMP deaminase
# Adenosine 5-monophosphate phosphohydrolase
# Adenosine kinase
# Adenine phosphoribosyltransferase, cytosolic
# Adenine phosphoribosyltransferase, plastidic
# Adenosylhomocysteinase
# PEP synthetase
# Pyruvate kinase, cytosolic
# Pyruvate kinase, plastidic
# Pyruvate phosphate dikinase, plastidic
# Pyruvate phosphate dikinase, cytosolic
# Malate dehydrogenase (oxaloacetate decarboxylating) (NADP+), cytosolic
# Malate dehydrogenase (oxaloacetate decarboxylating) (NADP+), plastidic
# pyruvate decarboxylase, mitochondrial
# pyruvate decarboxylase, plastidic
# acetate--CoA ligase, cytosolic
# acetate--CoA ligase, peroxisomal
# acetate--CoA ligase, plastidic
# Glutamate 5-kinase, cytosolic
# Glutamate 5-kinase, plastidic
# Glutamate dehydrogenase (NADP+)
# Glutamate dehydrogenase (NAD+)
# 1-pyrroline-5-carboxylate dehydrogenase (NAD), mitochondrial
# 1-pyrroline-5-carboxylate dehydrogenase (NAD), plastidic
# 1-pyrroline-5-carboxylate dehydrogenase (NADP), mitochondrial
# 1-pyrroline-5-carboxylate dehydrogenase (NADP), plastidic
# Glutamate--ammonia ligase, cytosolic
# Glutamate--ammonia ligase, mitochondrial
# Glutamate--ammonia ligase, plastidic
# Alanine--glyoxylate aminotransferase, mitochondrial
# Alanine--glyoxylate aminotransferase, peroxisomal
# Alanine--glyoxylate aminotransferase, plastidic
# Alanine aminotransferase, cytosolic
# Alanine aminotransferase, mitochondrial
# Alanine aminotransferase, plastidic
# Amino-acid N-acetyltransferase
# Glutamate decarboxylase, plastidic
# Glutamate decarboxylase, cytosolic
# Glutamate decarboxylase, mitochondrial
# L-aspartate 1-carboxy-lyase (beta-alanine-forming)
# Isocitrate dehydrogenase (NADP+), cytosolic
# Isocitrate dehydrogenase (NADP+), mitochondrial
# glutathione peroxidase, plastidic
# glutathione peroxidase, cytosolic
# glutathione peroxidase, mitochondrial
# UDP-glucose 6-dehydrogenase
# Galactokinase
# UDP-glucose--hexose-1-phosphate uridylyltransferase
# alpha,alpha-trehalase
# Trehalose-phosphatase
# alpha,alpha-trehalose-phosphate synthase (UDP-forming)
# 1,3-beta-glucan synthase
# Glucan endo-1,3-beta-D-glucosidase
# Glucan endo-1,3-beta-D-glucosidase
# Glucan 1,3-beta-glucosidase
# Glucan 1,3-beta-glucosidase
# UTP--glucose-1-phosphate uridylyltransferase
# UTP--glucose-1-phosphate uridylyltransferase
# manninotriose galactohydrolase
# melibiose galactohydrolase (glc-A)
# melibiose galactohydrolase (glc-B)
# stachyose fructohydrolase
# Raffinose galactohydrolase
# stachyose galactohydrolase
# galactinol---raffinose galactosyltransferase
# raffinose synthase
# inositol 3-alpha-galactosyltransferase
# UDP-glucose 4-epimerase
# ATP:GDP phosphotransferase, cytosolic
# ATP:GDP phosphotransferase, plastidic
# GTP diphosphokinase
# Guanosine-3,5-bis(diphosphate) 3-pyrophosphohydrolase
# Guanosine-5-triphosphate,3-diphosphate pyrophosphatase
# ATP:UMP phosphotransferase
# ATP:dADP phosphotransferase
# ATP:dGDP phosphotransferase
# Phosphoenolpyruvate carboxykinase (ATP)
# malate dehydrogenase (NADP+), plastidic
# Malate dehydrogenase, plastidic
# Malate dehydrogenase, cytosolic
# Malate dehydrogenase, peroxisomal
# Malate dehydrogenase, mitochondrial
# Malate dehydrogenase, vacuolar
# Phosphoenolpyruvate carboxylase
# ATP-citrate (pro-S-)-lyase
# Citrate synthase, peroxisomal
# Citrate synthase, mitochondrial
# oxaloacetase
# Oxaloacetate oxidase
# L-aspartate oxidase
# Nicotinate-nucleotide pyrophosphorylase (carboxylating)
# Nicotinate-nucleotide adenylyltransferase
# NAD(+) synthetase
# NAD(+) synthetase (glutamine-hydrolysing)
# quinolinate synthase
# Nicotinate phosphoribosyltransferase
# nicotinamidase
# Nicotinamide-nucleotide amidase
# NMN nucleosidase
# Nicotinamide-nucleotide adenylyltransferase
# NADP phosphatase, plastidic
# NADP phosphatase, cytosolic
# NAD(+) kinase, cytosolic
# NAD(+) kinase, plastidic
# NAD(+) kinase, mitochondrial
# NADH kinase, cytosolic
# NADH kinase, plastidic
# NADH kinase, mitochondrial
# Aspartate aminotransferase, cytosolic
# Aspartate aminotransferase, mitochondrial
# Aspartate aminotransferase, plastidic
# Glycine aminotransferase
# Succinate--CoA ligase (GDP-forming)
# Succinate--CoA ligase (ADP-forming)
# GTP cyclohydrolase I
# Lysine decarboxylase
# alpha-aminoadipate reductase
# Saccharopine dehydrogenase (NADP+, L-lysine forming)
# Saccharopine dehydrogenase (NAD+, L-glutamate forming)
# 2-aminoadipate aminotransferase
# Pyruvate dehydrogenase (lipoamide) (reaction 1), mitochondrial
# Pyruvate dehydrogenase (lipoamide) (reaction 2), mitochondrial
# Dihydrolipoamide S-acetyltransferase, mitochondrial
# dihydrolipoyl dehydrogenase, mitochondrial
# Pyruvate dehydrogenase (lipoamide) (reaction 1), plastidic
# Pyruvate dehydrogenase (lipoamide) (reaction 2), plastidic
# Dihydrolipoamide S-acetyltransferase, plastidic
# dihydrolipoyl dehydrogenase, plastidic
# 2-oxoglutarate dehydrogenase (lipoamide) (reaction 1), mitochondrial
# 2-oxoglutarate dehydrogenase (lipoamide) (reaction 2), mitochondrial
# 2-oxoglutarate dehydrogenase E2 component
# 2-oxoadipate dehydrogenase E1 component
# 2-oxoadipate dehydrogenase E2 component
# Diaminopimelate decarboxylase
# Malate synthase, plastidic
# Malate synthase, peroxisomal
# glycolate oxidase
# Isocitrate lyase
# aminoacetone:oxygen oxidoreductase(deaminating)
# (No enzyme)
# L-threonine 3-dehydrogenase
# Glycine C-acetyltransferase
# Aspartate kinase
# Aspartate--ammonia ligase
# Aspartate--ammonia ligase
# Asparaginase
# Formate dehydrogenase, mitochondrial
# Formate dehydrogenase-N
# sulfite oxidase, peroxisomal
# sulfite oxidase, mitochondrial
# Sulfate adenylyltransferase, cytosolic
# Sulfate adenylyltransferase, plastidic
# Arginase
# putrescine oxidase
# primary-amine oxidase
# 3-aminopropanal:NAD+ oxidoreductase
# Spermidine dehydrogenase
# 4-aminobutanal:NAD+ 1-oxidoreductase
# arginine 2-monooxygenase
# 4-Guanidinobutanamide amidohydrolase
# 4-Guanidinobutanoate amidinohydrolase
# N-carbamoylputrescine amidase
# Agmatine deiminase
# Agmatinase
# Arginine decarboxylase
# Nitric-oxide synthase
# Arginine deiminase
# carbamoyl-phosphate synthetase (glutamine-hydrolysing)
# asparagine synthetase (glutamine-hydrolysing), cytosolic
# asparagine synthetase (glutamine-hydrolysing), plstidic
# Phosphoserine phosphatase
# Cystathionine gamma-lyase
# Cystathionine beta-synthase
# Serine O-acetyltransferase, cytosolic
# Serine O-acetyltransferase, plastidic
# Serine O-acetyltransferase, mitochondrial
# Serine--glyoxylate aminotransferase, plastidic
# Serine--glyoxylate aminotransferase, peroxisomal
# Methionine S-methyltransferase
# Homocysteine S-methyltransferase (acetylhomocysteine forming)
# S-adenosyl-L-methionine:L-histidine N-methyltransferase
# Homocysteine S-methyltransferase (methionine forming)
# 5-methyltetrahydropteroyltriglutamate-homocysteine S-methyltransferase, peroxisomal
# 5-methyltetrahydropteroyltriglutamate-homocysteine S-methyltransferase, vacuolor
# 5-methyltetrahydropteroyltriglutamate-homocysteine S-methyltransferase, cytosolic
# acireductone dioxygenase [iron(II)-requiring]
# Methionine gamma-lyase
# O-Acetyl-L-homoserine acetate-lyase (adding methanethiol)
# methionine--phenylpyruvate transaminase
# 5-methylthioribose kinase
# Methylthioadenosine nucleosidase
# Spermine synthase
# Ornithine decarboxylase
# Spermidine synthase
# Adenosylmethionine decarboxylase
# 1-aminocyclopropane-1-carboxylate synthase
# aminocyclopropanecarboxylate oxidase
# 5-methylthioribose-1-phosphate isomerase
# methylthioribulose 1-phosphate dehydratase
# acireductone synthase, phosphate forming
# enolase, cytosolic
# enolase, plastidic
# Ornithine--oxo-acid aminotransferase, mitochondrial
# Ornithine--oxo-acid aminotransferase, cytosolic
# tryptophan N-monooxygenase
# Indole-3-acetaldehyde oxidase
# Tryptamine:oxygen oxidoreductase(deaminating)
# Tryptophan aminotransferase
# Aromatic-L-amino-acid decarboxylase
# Indolepyruvate decarboxylase
# 3-Indoleacetaldoxime hydro-lyase
# Tryptamine 5-hydroxylase
# nitrilase
# Tryptophan 2-monooxygenase
# indole acetamide hydrolase
# indole-3-acetate beta-glucosyltransferase
# IAA-myo-inositol synthase
# indol-3-ylacetyl-myo-inositol galactoside synthase
# indol-3-ylacetyl-myo-inositol arabinoside synthase
# indole-3-acetic acid amido synthetase (ala-L)
# indole-3-acetic acid amido synthetase (leu-L)
# indole-3-acetic acid amido synthetase (asp-L)
# indole-3-acetic acid amido synthetase (glu-L)
# indole-3-acetic acid amido synthetase (gln-L)
# IAA-amino acid conjugate hydrolase (iaa-ala)
# IAA-amino acid conjugate hydrolase (iaa-leu)
# indole-3-acetyl-myo-inositol hydrolase
# Tryptophan synthase (indoleglycerol phosphate)
# Tryptophan synthase (indole)
# Prephenate dehydratase, cytosolic
# Prephenate dehydratase, plastidic
# L-lactate dehydrogenase
# Malonyl-CoA decarboxylase
# malonate-semialdehyde dehydrogenase (acetylating)
# malonate-semialdehyde dehydrogenase (acetylating)
# Isocitrate dehydrogenase (NAD+)
# acetaldehyde dehydrogenase, cytosolic
# acetaldehyde dehydrogenase, plastidic
# acetaldehyde dehydrogenase, mitochondrial
# Glycerol:NAD+ oxidoreductase
# Glycerol:NADP+ oxidoreductase
# Succinate-semialdehyde dehydrogenase, mitochondrial
# Tyrosine decarboxylase
# 3,4-hydroxyphenylpyruvate dioxygenase, cytosolic
# 3,4-hydroxyphenylpyruvate dioxygenase, plastidic
# Homogentisate 1,2-dioxygenase
# Prephenate dehydrogenase (NADP+)
# Tyrosine aminotransferase, cytosolic
# Tyrosine aminotransferase, plastidic
# Fumarylacetoacetase
# Maleylacetoacetate isomerase
# arogenate dehydratase
# L-arogenate:oxaloacetate aminotransferase
# L-arogenate:2-oxoglutarate aminotransferase
# arogenate dehydrogenase
# alcohol dehydrogenase (NAD)
# Betaine-aldehyde dehydrogenase
# Betaine--homocysteine S-methyltransferase
# dimethylglycine dehydrogenase
# Sarcosine oxidase
# Glycine dehydrogenase (decarboxylating)
# dihydrolipoylprotein:NAD+ oxidoreductase
# Aminomethyltransferase
# L-threonine aldolase
# alcohol dehydrogenase
# Mannose-6-phosphate isomerase
# Phosphomannomutase
# Hexokinase (D-mannose)
# Monodehydroascorbate reductase (NADH), cytosolic
# Monodehydroascorbate reductase (NADH), plastidic
# Monodehydroascorbate reductase (NADH), mitochondrial
# Monodehydroascorbate reductase (NADPH), cytosolic
# Monodehydroascorbate reductase (NADPH), plastidic
# Monodehydroascorbate reductase (NADPH), mitochondrial
# L-ascorbate oxidase
# L-ascorbate peroxidase (reaction 1), cytosolic
# L-ascorbate peroxidase (reaction 1), plastidic
# L-ascorbate peroxidase (reaction 2), cytosolic
# L-ascorbate peroxidase (reaction 2), plastidic
# gamma-glutamyltransferase (reaction 1)
# gamma-glutamyltransferase (reaction 2)
# gamma-glutamylcyclotransferase
#  5-Oxoproline amidohydrolase (ATP-hydrolysing) (ir)
# cysteinylglycinase
# Glutamate--cysteine ligase, plastidic
# Glutamate--cysteine ligase, mitochondrial
# glutathione synthetase, plastidic
# glutathione synthetase, mitochondrial
# Glutathione dehydrogenase (ascorbate), cytosolic
# Glutathione dehydrogenase (ascorbate), plastidic
# Galactonolactone dehydrogenase, mitochondrial
# L-galactose 1-dehydrogenase
# GDP-L-galactose phosphorylase
# GDP-mannose 3,5-epimerase
# GDP-D-galactose:GDP-L-gulose epimerase
# Mannose-1-phosphate guanylyltransferase
# GDP-D-mannose dehydratase
# GDP-4-oxo-L-fucose reductase
# fucose-1-phosphate guanylyltransferase
# Lactaldehyde dehydrogenase
# L-fuculose-phosphate aldolase
# L-fuculokinase
# L-fucose isomerase
# fucokinase
# Fructose-bisphosphatase, cytosolic
# Fructose-bisphosphatase, plastidic
# Sucrose-phosphate synthase, cytosol
# Sucrose-phosphate synthase, vacuolar
# Glucose-6-phosphate isomerase (g6p-A), cytoslic
# Glucose-6-phosphate isomerase (g6p-A), plastidic
# Glucose-6-phosphate isomerase (g6p-B), cytoslic
# Glucose-6-phosphate isomerase (g6p-B), plastidic
# Ferredoxin--nitrite reductase
# nitric oxide, NADH2:oxygen oxidoreductase
# nitric oxide, NADPH2:oxygen oxidoreductase
# nitrate reductase (NADH), cytosolic
# nitrate reductase (NADH), vacuolar
# Beta-fructofuranosidase, cytoslic
# Beta-fructofuranosidase, vacuolar
# Invertase, cytosolic
# Invertase, vacuolar
# Sucrose-phosphatase, cytosolic
# Sucrose-phosphatase, vacuolar
# Sucrose synthase, cytosolic
# Sucrose synthase, vacuolar
# myo-inositol-1-phosphate synthase
# Sulfite reductase (ferredoxin)
# Xylose isomerase, cytosolic
# Xylose isomerase, vacuolar
# UDP-N-acetylglucosamine 4-epimerase
# UDP-N-acetylglucosamine pyrophosphorylase
# Phosphoacetylglucosamine mutase
# Glucosamine-phosphate N-acetyltransferase
# ATP:D-glucosamine 6-phosphotransferase
# glucosamine acetyltransferase
# N-acetylglucosamine kinase
# chitobiose N-acetylglucosaminohydrolase
# chitinase
# N-acetylglucosamine 2-epimerase
# UDP-N-acetyl-D-glucosamine 2-epimerase (Hydrolysis)
# N-Acetylneuraminate lyase
# CMP sialic acid synthase
# Glucosamine--fructose-6-phosphate aminotransferase (isomerizing)
# Fructokinase
# 3-mercaptopyruvate sulfurtransferase
# Thiosulfate sulfurtransferase
# 3-mercaptopyruvate sulfurtransferase
# Thiosulfate sulfurtransferase
# sulfite oxidase
# aspartate aminotransferase, cysteine forming, plastidic
# aspartate aminotransferase, cysteine forming, mitochondrial
# aspartate aminotransferase, cysteate forming, plastidic
# aspartate aminotransferase, cysteate forming, mitochondrial
# 3-sulfinopyruvate hydrolase (spontaneous), plastidic
# 3-sulfinopyruvate hydrolase (spontaneous), mitochondrial
# cysteine dioxygenase, plastid
# cysteine dioxygenase, mitochondrial
# Cysteine synthase, cytosolic
# Cysteine synthase, mitochondrial
# Cysteine synthase, plastidic
# b-alanine-pyruvate aminotransferase
# Dihydrofolate reductase, cytosolic
# Dihydrofolate reductase, mitochondrial
# folylpolyglutamate synthetase
# Formate--tetrahydrofolate ligase, cytosolic
# Formate--tetrahydrofolate ligase, mitochondrial
# Formate--tetrahydrofolate ligase, plastidic
# beta-cyanoalanine nitrilase
# beta-cyanoalanine synthetase
# (R)-mandelonitrile lyase
# beta-glucosidase (prunasin forming)
# beta-glucosidase (amyloglucoside forming)
# Formamidase
# formamide hydro-lyase (cyanide-forming)
# Formyltetrahydrofolate deformylase, cytosolic
# Formyltetrahydrofolate deformylase, mitochondrial
# Formyltetrahydrofolate deformylase, plastidic
# Serine hydroxymethyltransferase, plastidic
# Serine hydroxymethyltransferase, mitochondrial
# methylenetetrahydrofolate reductase, cytosolic
# methylenetetrahydrofolate reductase, plastidic
# 5-methyltetrahydrofolate--homocysteine S-methyltransferase, cytosolic
# 5-methyltetrahydrofolate--homocysteine S-methyltransferase, plastidic
# methylenetetrahydrofolate reductase (ferredoxin), cytosolic
# methylenetetrahydrofolate reductase (ferredoxin), plastidic
# Glucose-1-phosphate adenylyltransferase
# carbamoyl-phosphate synthetase (glutamine-hydrolysing)
# Orotidine-5-phosphate decarboxylase
# Anthranilate synthase
# Threonine dehydratase
# Triosephosphate isomerase, cytosolic
# Triosephosphate isomerase, plastidic
# ribose-phosphate diphosphokinase, cytosolic
# ribose-phosphate diphosphokinase, plastidic
# Phosphopentosemutase, cytosolic
# Phosphopentosemutase, plastidic
# Ribokinase, cytosolic
# Ribokinase, plastidic
# 5-amino-6-(5-phosphoribosylamino)uracil reductase
# Riboflavin synthase
# Riboflavin kinase
# FMN adenylyltransferase, plastidic
# FMN adenylyltransferase, cytosolic
# FMN adenylyltransferase, mitochondrial
# GTP cyclohydrolase II
# diaminohydroxyphosphoribosylaminopyrimidine deaminase
# 3,4-dihydroxy-2-butanone-4-phosphate synthase
# 6,7-dimethyl-8-ribityllumazine synthase
# 5-amino-6-(5-phosphoribitylamino)uracil phosphatase
# ribose-5-phosphate isomerase, cytosolic
# ribose-5-phosphate isomerase, plastidic
# Glyceraldehyde-3-phosphate dehydrogenase (NADP+), plastidic
# Glyceraldehyde-3-phosphate dehydrogenase (NAD+), cytsolic
# Glyceraldehyde-3-phosphate dehydrogenase (NAD+), plastidic
# Glyceraldehyde 3-phosphate dehydrogenase (phosphorylating), cytosolic
# Glyceraldehyde 3-phosphate dehydrogenase (phosphorylating), plastidic
# ketohexokinase
# Fructose-bisphosphate aldolase
# Formaldehyde transketolase, cytosolic
# Formaldehyde transketolase, plastidic
# Glycerone kinase, cytsosolic
# Glycerone kinase, plastidic
# Fructose-bisphosphate aldolase, cytosolic
# Fructose-bisphosphate aldolase, plastidic
# Histidine decarboxylase
# ATP phosphoribosyltransferase
# Amidophosphoribosyltransferase
# Anthranilate phosphoribosyltransferase
# Fumarate hydratase, mitochondrial
# Adenylosuccinate lyase, cytosolic
# Adenylosuccinate lyase, plastidic
# Argininosuccinate lyase
# L-leucine aminotransferase, plastidic
# L-leucine aminotransferase, cytosolic
# guanosine phosphorylase
# adenosine phosphorylase
# inosine phosphorylase
# adenosine deaminase (polypeptide)
# Inosine 5-monophosphate phosphohydrolase
# GMP reductase
# IMP cyclohydrolase
# GMP synthetase (glutamine-hydrolysing)
# GMP synthetase
# Guanylate kinase
# ATP:dGMP phosphotransferase
# ATP:dAMP phosphotransferase
# 2-Deoxyadenosine 5-diphosphate (GDP):oxidized-thioredoxin 2-oxidoreductase
# 2-Deoxyadenosine 5-diphosphate (ADP):oxidized-thioredoxin 2-oxidoreductase
# IMP dehydrogenase
# Inosine kinase
# Hypoxanthine phosphoribosyltransferase
# adenylosuccinate synthetase, cytosolic
# adenylosuccinate synthetase, plastidic
# Myo-inositol oxygenase
# 1-phosphatidylinositol-4,5-bisphosphate phosphodiesterase
# 1-phosphatidylinositol-5-phosphate 4-kinase
# 1-phosphatidylinositol-4-phosphate kinase
# 1-phosphatidylinositol 4-kinase
# 1-phosphatidylinositol 3-kinase
# 1-phosphatidylinositol-3-phosphate 5-kinase
# Inositol-3-phosphate 4-kinase
# Inositol-3,4-diphosphate 6-kinase
# Inositol-3,4,6-triphosphate 5-kinase
# Inositol-3,4-bisphosphate 4-phosphatase
# D-myo-Inositol-1,4-bisphosphate 1-phosphohydrolase
# D-myo-Inositol 1,3,4-trisphosphate 1-phosphohydrolase
# Inositol-1,4,5-trisphosphate 5-phosphatase
# inositol-polyphosphate multikinase
# 1D-myo-inositol-trisphosphate 3-kinase
# Inositol-1,3,4-trisphosphate 5/6-kinase 1
# Inositol-1,3,4-trisphosphate 5/6-kinase 2
# inositol-tetrakisphosphate 5-kinase
# inositol-tetrakisphosphate 5-kinase
# Inositol-pentakisphosphate 2-kinase
# Inositol-pentakisphosphate 5-kinase
# Inositol-pentakisphosphate 4-kinase
# Inositol-pentakisphosphate 6-kinase
# 6-phytase
# myo-inositol-hexakisphosphate 4-phosphohydrolase
# inositol (1,3,4,5)-tetrakisphosphate 3-phosphatase
# D-myo-inositol(1,4,5)/(1,3,4,5)-polyphosphate 5-phosphatase
# 1D-myo-inositol-tetrakisphosphate 1-kinase
# Myo-inositol-1(or 4)-monophosphatase
# Myo-inositol-1(or 4)-monophosphatase
# Dihydroxy-acid dehydratase
# Hydroxymethylglutaryl-CoA synthase, cytosolic
# Hydroxymethylglutaryl-CoA synthase, mitochondrial
# glutaryl-CoA degradation
# Glutaconyl-CoA decarboxylase
# Acetyl-CoA C-acetyltransferase, peroxisomal
# Acetyl-CoA C-acetyltransferase, plastidic
# Acetyl-CoA C-acetyltransferase, cytosol
# Acetyl-CoA C-acetyltransferase, mitochondrial
# 2-isopropylMalate synthase
# 3-hydroxyisobutyrate dehydrogenase
# 3-methyl-2-oxobutanoate dehydrogenase
# 3-methyl-2-oxobutanoate dehydrogenase, 2-Methyl-1-hydroxypropyl-ThPP transforming
# dihydrolipoyllysine-residue (2-methylpropanoyl)transferase, 2-Methylbutanoyl-CoA forming
# Methylmalonate-semialdehyde dehydrogenase (acylating)
# 2-methylacyl-CoA dehydrogenase
# 3-hydroxyisobutyryl-CoA hydrolase
# Enoyl-CoA hydratase
# Dihydroxy-acid dehydratase
# L-valine aminotransferase, plastidic
# L-valine aminotransferase, mitochondrial
# Methylenetetrahydrofolate dehydrogenase (NAD+)
# Methylenetetrahydrofolate dehydrogenase (NAD+)
# Methylenetetrahydrofolate dehydrogenase (NAD+)
# 5-formyltetrahydrofolate cyclo-ligase, cytosolic
# 5-formyltetrahydrofolate cyclo-ligase, mitochondrial
# 5-formyltetrahydrofolate cyclo-ligase, plastidic
# Methylenetetrahydrofolate dehydrogenase (NADP+)
# Methylenetetrahydrofolate dehydrogenase (NADP+)
# Methylenetetrahydrofolate dehydrogenase (NADP+)
# 5,10-Methylenetetrahydrofolate:3-methyl-2-oxobutanoate hydroxymethyltransferase
# Guanosine 5-monophosphate phosphohydrolase
# Guanosine 5-phosphotransferase
# guanine phosphoribosyltransferase
# Deoxyadenosine aminohydrolase
# Deoxyguanosine phosphorylase
# Deoxyinosine:orthophosphate ribosyltransferase
# deoxyuridine phosphorylase
# Deoxyadenosine:orthophosphate ribosyltransferase
# 2-Deoxyadenosine 5-monophosphate phosphohydrolase
# adenine deaminase
# Adenosine ribohydrolase
# GTP diphosphokinase
# guanosine-5-triphosphate, 3-diphosphate pyrophosphatase
# Proline dehydrogenase
# Pyrroline-5-carboxylate reductase (NADH), cytosolic
# Pyrroline-5-carboxylate reductase (NADH), plastidic
# Pyrroline-5-carboxylate reductase (NADPH), cytosolic
# Pyrroline-5-carboxylate reductase (NADPH), plastidic
# Cystathionine beta-lyase
# Glycolaldehyde dehydrogenase
# Phosphoglycolate phosphatase
# Glucuronate-1-phosphate uridylyltransferase
# xylan 1,4-beta-xylosidase
# 1,4-beta-D-xylan synthase
# UDP-glucuronate 4-epimerase
# UDP-glucose 4,6-dehydratase
# Pectinesterase
# UDP-4-dehydro-6-deoxy-glucose 3,5-epimerase
# UDP-L-rhamnose:NADP+ 4-oxidoreductase
# UDP-glucuronate decarboxylase
# Hydroxypyruvate reductase (NAD), plastidic
# Hydroxypyruvate reductase (NAD), peroxisomal
# Hydroxypyruvate reductase (NADP), plastidic
# Hydroxypyruvate reductase (NADP), peroxisomal
# Aspartate carbamoyltransferase (asp-L)
# Threonine synthase
# L-arabinokinase
# UTP-monosaccharide-1-phosphate uridylyltransferase
# beta-L-arabinose-1-phosphate uridylyltransferase
# alpha-L-arabinofuranosidase, vacuolar
# alpha-L-arabinofuranosidase, cytosolic
# UDP-arabinose 4-epimerase
# Glucuronokinase
# Phosphoglycerate kinase
# Phosphoglycerate kinase
# Phosphoglycerate dehydrogenase
# Glycerate kinase (3-PG)
# Glycerate kinase (2-PG)
# Phosphoglycerate mutase, cytosolic
# Phosphoglycerate mutase, plastidic
# glucose-6-phosphate 1-epimerase, cytosolic
# glucose-6-phosphate 1-epimerase, plastidic
# Phosphoribulokinase
# Gluconokinase, cytosolic
# Gluconokinase, plastidic
# Phosphogluconate dehydrogenase (decarboxylating), cytosolic
# Phosphogluconate dehydrogenase (decarboxylating), plastidic
# Xylose isomerase
# Xylulokinase
# ribulose phosphate 3-epimerase, cytosolic
# ribulose phosphate 3-epimerase, plastidic
# 3-hydroxypropionate dehydrogenase
# Transketolase
# 4-aminobutyrate aminotransferase (GABA-TK)
# 4-aminobutyrate aminotransferase (GABA-TP)
# leucine biosynthesis; spontaneous reaction
# Methenyltetrahydrofolate cyclohydrolase, cytosolic
# Methenyltetrahydrofolate cyclohydrolase, plastidic
# Methenyltetrahydrofolate cyclohydrolase, mitochondrial
# Guanine deaminase
# Guanosine ribohydrolase
# Chorismate synthase
# Chorismate mutase
# Aminodeoxychorismate synthase
# Urease
# Allantoicase
# Allantoinase
# allantoin synthetase
# Hydroxyisourate hydrolase
# Urate oxidase
# Xanthine dehydrogenase
# hypoxanthine oxidoreductase
# Inosine ribohydrolase
# Homoserine O-acetyltransferase
# Homoserine O-succinyltransferase
# O-Acetyl-L-homoserine succinate-lyase (adding cysteine)
# O-Succinyl-L-homoserine succinate-lyase
# O-succinylhomoserine (thiol)-lyase
# Homoserine kinase
# Homoserine dehydrogenase (NADH)
# Homoserine dehydrogenase (NADPH)
# Glucokinase (glc-A), cytosolic
# Glucokinase (glc-A), plastidic
# Aldose 1-epimerase, cytosolic
# Aldose 1-epimerase, plastidic
# Hexokinase (glc-B), cytosolic
# Hexokinase (glc-B), plastidic
# beta-amylase
# Glucan 1,4-alpha-glucosidase
# maltose glucohydrolase
# starch phosphorylase
# 2-dehydro-3-deoxyphosphoheptonate aldolase
# Transaldolase
# Sedoheptulose 1,7-bisphosphate D-glyceraldehyde-3-phosphate-lyase
# Transketolase
# Sedoheptulose-bisphosphatase
# Aspartate carbamoyltransferase
# Orotate phosphoribosyltransferase
# Aconitate hydratase, cytosolic
# Aconitase, cytosolic
# Aconitate hydratase, mitochondrial
# Aconitase, mitochondrial
# argininosuccinate synthetase, plastidic
# argininosuccinate synthetase, cytosolic
# Dihydroorotase
# 6-phosphogluconolactonase, cytosolic
# 6-phosphogluconolactonase, plastidic
# Diphosphate--fructose-6-phosphate 1-phosphotransferase
# Amylo-1,6-glucosidase
# Xanthosine phosphorylase
# Xanthosine ribohydrolase
# Guanosine deaminase
# Q-cytochrome c oxidoreductase (complex III)
# NADH-coenzyme Q oxidoreductase (complex I)
# Plastid terminal oxidase
# NAD(P)H-dehydrogenase (complex I-like)
# Succinate-Q oxidoreductase (complex II)
# Branched-chain amino acid (ile-L) aminotransferase, plastidic
# Branched-chain amino acid (ile-L) aminotransferase, mitochondrial
# dihydrofolate synthetase
# Glutamate N-acetyltransferase
# Acetylornithine aminotransferase
# Acetylornithine deacetylase
# Ornithine carbamoyltransferase, plastidic
# Ornithine carbamoyltransferase, cytosolic
# Aspartate-semialdehyde dehydrogenase
# dihydrodipicolinate synthase
# Indole-3-glycerol-phosphate lyase
# shikimate-kinase
# Shikimate 5-dehydrogenase
# Starch (bacterial glycogen) synthase
# 2-dehydropantoate 2-reductase
# pantothenate synthetase
# Acetylglutamate kinase
# 3-hydroxyacyl-CoA dehydrogenase
# Xanthosine 5-phosphate phosphohydrolase
# Diaminopimelate epimerase
# Glucose-6-phosphate 1-dehydrogenase, cytosolic
# Glucose-6-phosphate 1-dehydrogenase, plastidic
# cellobiose beta-glucosidase
# cellulase
# Cellulose synthase (UDP-forming)
# Histidinol dehydrogenase
# Histidinal dehydrogenase
# Histidinol-phosphatase
# Pantothenate kinase
# Pantetheine-phosphate adenylyltransferase
# Ketol-acid reductoisomerase, mitochondrial
# Ketol-acid reductoisomerase, plastidic
# Dihydropteroate synthase
# 3-dehydroquinate synthase
# 3-dehydroquinate dehydratase
# 3-hydroxyisobutyryl-CoA hydrolase
# Histidinol-phosphate aminotransferase
# Phosphopantothenoylcysteine decarboxylase
# Glutamate-5-semialdehyde dehydrogenase, cytosolic
# Glutamate-5-semialdehyde dehydrogenase, plastidic
# Proline biosynthesis; spontaneous reaction, cytosolic
# Proline biosynthesis; spontaneous reaction, mitochondrial
# Proline biosynthesis; spontaneous reaction, plastidic
# N-acetyl-gamma-glutamyl-phosphate reductase
# Imidazoleglycerol-phosphate dehydratase
# 3-phosphoshikimate 1-carboxyvinyltransferase
# 2-amino-4-hydroxy-6-hydroxymethyldihydropteridine pyrophosphokinase
# Pyridoxamine-phosphate oxidase
# Pyridoxine 5-phosphate:oxygen oxidoreductase
# Pyridoxine:oxygen oxidoreductase (deaminating)
# Pyridoxamine:oxygen oxidoreductase (deaminating)
# pyridoxine 5-phosphotransferase
# pyridoxal 5-phosphotransferase
# Pyridoxal kinase
# Pyridoxamine--pyruvate aminotransferase
# Pyridoxine synthase
# Dihydroneopterin aldolase
# indole-3-glycerol-phosphate synthase
# Phosphoribosylanthranilate isomerase
# 3-isopropylMalate dehydratase
# Phosphoribosyl-ATP pyrophosphatase
# Phosphoribosyl-AMP cyclohydrolase
# Phosphoribosylamine--glycine ligase
# Phosphoserine aminotransferase
# Dihydrodipicolinate reductase
# Dihydrodipicolinate reductase
# thiamin-monophosphate kinase
# 1-deoxy-D-xylulose-5-phosphate synthase
# Thiamine-phosphate pyrophosphorylase
# Hydroxymethylpyrimidine kinase
# Thiamine kinase
# Phosphomethylpyrimidine kinase
# thiamine biosynthesis protein (ThiC)
# thiazole phosphate synthesis
# tyrosine lyase
# ISC Cysteine desulfuration
# thiamin phosphatase
# Thiamine pyrophosphokinase
# phosphoribosylformylglycinamidine cyclo-ligase
# Phosphoribosylaminoimidazole carboxylase
# Phosphopantothenate--cysteine ligase
# Phosphoribosylglycinamide formyltransferase
# N2-Formyl-N1-(5-phospho-D-ribosyl)glycinamide formyltransferase, chloroplast
# 3-isopropylMalate dehydrogenase
# 3-methyl-2-oxobutanoate dehydrogenase, 4-Methyl-2-oxopentanoate transforming
# 3-methyl-2-oxobutanoate dehydrogenase, 3-Methyl-1-hydroxybutyl-ThPP transforming
# dihydrolipoyllysine-residue (2-methylpropanoyl)transferase, Isovaleryl-CoA forming
# Isovaleryl-CoA dehydrogenase
# Methylcrotonyl-CoA carboxylase
# Methylglutaconyl-CoA hydratase
# Hydroxymethylglutaryl-CoA lyase
# Propanoyl-CoA:(acceptor) 2,3-oxidoreductase
# Phosphoribosylglycinamide formyltransferase
# N2-Formyl-N1-(5-phospho-D-ribosyl)glycinamide formyltransferase, mitochondria
# phosphoribosylformylglycinamidine synthetase
# Imidazole glycerol phosphate synthase
# Adenylosuccinate lyase
# Phosphoribosylaminoimidazolecarboxamide formyltransferase
# Phosphoribosylaminoimidazole-succinocarboxamide synthetase
# Dihydroneopterin monophosphate dephosphorylase
# dihydroneopterin triphosphate diphosphatase
# N-(5-phospho-D-ribosylformimino)-5-amino-1-(5-phosphoribosyl)-4- imidazole carboxamide isomerase
# 6-phosphofructokinase, cytosolic
# 6-phosphofructokinase, plastidic
# Ketol-acid reductoisomerase
# Dihydroxy-acid dehydratase
# 4-alpha-glucanotransferase
# Aminodeoxychorismate lyase
# 3-Phospho-5-adenylyl sulfate 3-phosphohydrolase
# 3(2),5-bisphosphate nucleotidase
# Adenylylsulfate kinase
# Adenylylsulfate kinase, cytosolic
# Phosphoadenylyl-sulfate reductase (thioredoxin)
# Adenylyl-sulfate reductase (glutathione)
# alpha-amylase
# L-phenylalanine transferase, plastidic
# L-phenylalanine transferase, cytosolic
# Phenylpyruvate decarboxylase
# Phenylethylalcohol:NAD+ oxidoreductase
# LL-2,6-diaminoheptanedioate aminotransferase
# Phosphoglucomutase, cytosolic
# Phosphoglucomutase, cytosolic
# Phosphoglucomutase, plastidic
# Acetolactate synthase
# 3-methyl-2-oxobutanoate dehydrogenase, 3-Methyl-2-oxopentanoate transforming
# 3-methyl-2-oxobutanoate dehydrogenase, 2-Methyl-1-hydroxybutyl-ThPP transforming
# dihydrolipoyllysine-residue (2-methylpropanoyl)transferase, 2-Methylbutanoyl-CoA forming
# 2-methyl-branched-chain-enoyl-CoA reductase
# Tiglyl-CoA hydratase
# 3-hydroxy-2-methylbutyryl-CoA dehydrogenase
# 2-methylacetoacetyl-CoA thiolase
# Cystathionine gamma-synthase
# Dihydroorotate dehydrogenase
# Carbamate kinase
# carbamoyl-phosphate synthase (ammonia)
# carbonic anhydrase, plastidic
# carbonic anhydrase, cytosolic
# carbonic anhydrase, mitochondrial
# Acetyl-CoA carboxylase, plastidic
# Acetyl-CoA carboxylase, cytosolic
# Phenylalanine ammonia-lyase
# Tyrosine ammonia-lyase
# 4-coumaryl-CoA reductase
# 4-coumarate--CoA ligase
# Caffeoyl-CoA O-methyltransferase
# Caffeoyl-CoA:quinate O-(3,4-dihydroxycinnamoyl)transferase
# feruloyl-CoA reductase
# Trans-cinnamate 4-monooxygenase
# Trans-cinnamate 2-monooxygenase
# Shikimate O-hydroxycinnamoyltransferase
# coniferyl-alcohol dehydrogenase
# sinapyl-alcohol dehydrogenase
# coumaroylquinate 3-monooxygenase
# ferulate 5-hydroxylase
# S-adenosyl-L-methionine:3,4-dihydroxy-trans-cinnamate 3-O-methyltransferase
# coumaroylshikimate 3-monooxygenase
# p-coumaroyl-CoA:quinate hydroxycinnamoyltransferase
# Hydroxycinnamoyl-CoA:shikimate hydroxycinnamoyltransferase
# 4-coumaryl-alcohol dehydrogenase
# Cinnamoyl-CoA reductase
# cinnamate:CoA ligase
# cinnamaldehyde oxidase
# cinnamyl-alcohol dehydrogenase
# trans-feruloyl-CoA synthase
# 2-coumarate O-beta-glucosyltransferase
# 2-coumarate beta-D-glucoside isomerase
# exo-beta-glucanse
# coumarin synthase
# 4-coumaroyl 2-hydroxylase
# umbelliferone biosynthesis
# prenyltransferase
# marmesin synthase
# psoralen synthase
# psoralen 5-monooxygenase
# bergaptol O-methyltransferase
# Pinocembrin,2-oxoglutarate:oxygen oxidoreductase (3-hydroxylating)
# malonyl-CoA:cinnamoyl-CoA malonyltransferase (cyclizing)
# Pinocembrin chalcone lyase (decyclizing)
# Naringenin 3-dioxygenase
# 6-deoxychalcone synthase
# Naringenin-chalcone synthase
# Chalcone isomerase
# naringenin 2-oxoglutarate oxygen oxidoreductase
# naingenin, NADPH:oxygen osidoreductase
# apigenin 3-hydroxylase
# eriodictyol 2-hydroxylase
# 2-hydroxyeriodictyol dibenzoylmethane tautomer synthase
# 2-hydroxyeriodictyol dibenzoylmethane tautomer 6C-glucosyltransferase
# 2-hydroxyeriodictyol-C-glucoside dehydratase
# 2-hydroxyeriodictyol dibenzoylmethane tautomer 8C-glucosyltransferase
# orientin synthase (spontaneous)
# naringenin 2-hydroxylase
# 2-hydroxynaringenin dibenzoylmethane tautomer synthase
# 2-hydroxynaringenin dibenzoylmethane tautomer 6C-glucosyltransferase
# 2-hydroxynaringenin-C-glucoside dehydratase
# 2-hydroxynaringenin dibenzoylmethane tautomer 8C-glucosyltransferase
# vitexin synthase (spontaneous)
# isovitexin beta-glucosyltransferase
# isoorientin 3-methyltransferase
# Isoscoparin beta-glucosyltransferase
# Isoorientin beta-glucosyltransferase
# Tricin beta-glucosyltransferase
# luteolin 3-hydroxylase
# tricin synthase 1
# tricin synthase 2
# Isoliquiritigenin lyase (decyclizing)
# Liquiritigenin 6-hydroxylase
# Naringenin 3-monooxygenase
# Dihydrokaempferol,2-oxoglutarate:oxygen oxidoreductase
# Dihydroquercetin,2-oxoglutarate:oxygen oxidoreductase
# Dihydrokaempferol 3-monooxygenase
# Kaempferol 3-monooxygenase
# Quercetin 3-O-glucosyltransferase
# Kaempferol 3-O-glucosyltransferase
# dihydrokaempferol 4-reductase
# leucocyanidin:NADP+ 4-oxidoreductase
# Eriodictyol 2-oxoglutarate:oxygen oxidoreductase (3-hydroxylating)
# leucopelargonidin reductase
# leucoanthocyanidin reductase
# leucopelargonidin dioxygenase
# Pelargonidin 3-O-glucosyltransferase
# Pelargonidin reductase
# Cyanidin reductase
# Cyanidin 3-O-glucosyltransferase
# Cyanidin 5-O-glucosyltransferase
# Cyanidin 5-O-glucoside: 3-O-glucosyltransferase
# Cyanidin 3-O-glucoside: 5-O-glucosyltransferase
# Leucoanthocyanidin dioxygenase
# glutamyl-tRNA reductase
# Hydroxymethylbilane synthase
# Porphobilinogen synthase
# uroporphyrinogen-III synthase
# Glutamate-1-semialdehyde 2,1-aminomutase
# Glutamate--tRNA ligase
# uroporphyrinogen-III methyltransferase
# precorrin 2 dehydrogenase
# sirohydrochlorin ferrochelatase
# magnesium-protoporphyrin IX monomethyl ester (oxidative) cyclase
# magnesium-protoporphyrin IX monomethyl ester (oxidative) cyclase
# magnesium-protoporphyrin IX monomethyl ester (oxidative) cyclase
# chlorophyllide-a:NADP+ oxidoreductase (photon410)
# chlorophyllide-a:NADP+ oxidoreductase (photon430)
# chlorophyllide-a:NADP+ oxidoreductase (photon450)
# chlorophyllide-a:NADP+ oxidoreductase (photon470)
# chlorophyllide-a:NADP+ oxidoreductase (photon490)
# chlorophyllide-a:NADP+ oxidoreductase (photon510)
# chlorophyllide-a:NADP+ oxidoreductase (photon530)
# chlorophyllide-a:NADP+ oxidoreductase (photon550)
# chlorophyllide-a:NADP+ oxidoreductase (photon570)
# chlorophyllide-a:NADP+ oxidoreductase (photon590)
# chlorophyllide-a:NADP+ oxidoreductase (photon610)
# chlorophyllide-a:NADP+ oxidoreductase (photon630)
# chlorophyllide-a:NADP+ oxidoreductase (photon650)
# chlorophyllide-a:NADP+ oxidoreductase (photon670)
# chlorophyllide-a:NADP+ oxidoreductase (photon690)
# divinyl chlorophyllide-a:NADP+ oxidoreductase (photon410)
# divinyl chlorophyllide-a:NADP+ oxidoreductase (photon430)
# divinyl chlorophyllide-a:NADP+ oxidoreductase (photon450)
# divinyl chlorophyllide-a:NADP+ oxidoreductase (photon470)
# divinyl chlorophyllide-a:NADP+ oxidoreductase (photon490)
# divinyl chlorophyllide-a:NADP+ oxidoreductase (photon510)
# divinyl chlorophyllide-a:NADP+ oxidoreductase (photon530)
# divinyl chlorophyllide-a:NADP+ oxidoreductase (photon550)
# divinyl chlorophyllide-a:NADP+ oxidoreductase (photon570)
# divinyl chlorophyllide-a:NADP+ oxidoreductase (photon590)
# divinyl chlorophyllide-a:NADP+ oxidoreductase (photon610)
# divinyl chlorophyllide-a:NADP+ oxidoreductase (photon630)
# divinyl chlorophyllide-a:NADP+ oxidoreductase (photon650)
# divinyl chlorophyllide-a:NADP+ oxidoreductase (photon670)
# divinyl chlorophyllide-a:NADP+ oxidoreductase (photon690)
# Coproporphyrinogen oxidase
# Protoporphyrinogen oxidase
# Magnesium-protoporphyrin O-methyltransferase
# uroporphyrinogen I reductase
# uroporphyrinogen I synthase, spontaneous
# Uroporphyrinogen decarboxylase
# uroporphyrinogen decarboxylase (uroporphyrinogen I)
# coproporphyrinogen I oxidase
# uroporphyrinogen III oxidase
# Ferrochelatase
# Magnesium chelatase
# divinyl chlorophyllide a 8-vinyl-reductase
# divinylprotochlorophyllide vinyl-reductase
# Ferric-chelate reductase
# heme o biosynthesis
# heme c ligase (chloroplast)
# heme c ligase (mitochondria)
# heme a synthase (mitochondria)
# Heme oxygenase (decyclizing)
# Chlorophyllase
# chlorophyll synthase
# chlorophyllide-a oxygenase (CHLDA)
# chlorophyllide-a oxygenase (CHLA)
# Chlorophyllase
# chlorophyll synthase
# ferroxidase
# (2E,6E)-farnesyl-diphosphate:isopentenyl-diphosphate farnesyltranstransferase
# chorismate lyase
# 4-hydroxybenzoate octaprenyltransferase
# Hydroxylation of 3-Decaprenyl-4-hydroxybenzoate (NADPH)
# Hydroxylation of 3-Decaprenyl-4-hydroxybenzoate (NADPH)
# dihydroxydecaprenylbenzoate methyltransferase
# 3-Decaprenyl-4-hydroxy-5-methoxybenzoate  decarboxylation
# Ubiquinone biosynthesis monooxgenase COQ6
# Ubiquinone biosynthesis methyltransferase COQ5
# Ubiquinone biosynthesis COQ7
# methyltransferase COQ3
# 1,4-dihydroxy-2-naphthoyl-CoA synthase
# 1,4-dihydroxy-2-naphthoyl-CoA hydrolase
# Isochorismate mutase
# o-succinylbenzoate-CoA ligase
# o-succinylbenzoate synthase
# 1,4-dihydroxy-2-naphthoate polyprenyltransferase
# demethylphylloquinone phytyltransferase
# 1,4-dihydroxy-2-naphthoate octaprenyltransferase
# demethylphylloquinone methyltransferase
# 2-succinyl-5-enolpyruvyl-6-hydroxy-3-cyclohexene-1-carboxylic-acid synthase
# 2-succinyl-6-hydroxy-2,4-cyclohexadiene-1-carboxylate synthase
# 2-methyl-6-phytylquinol methyltransferase
# delta-tocopherol methyltransferase
# Tocopherol O-methyltransferase
# phytyl-diphosphate:homogentisate phytyltransferase (decarboxylating)
# (2E,6E)-farnesyl-diphosphate:isopentenyl-diphosphate farnesyltranstransferase
# (E)-octaprenyl-diphosphate:isopentenyl-diphosphate octaprenyltranstransferase
# homogentisate solanesyltransferase
# MPBQ/MSBQ methyltransferase
# tocopherol cyclase
# tocopherol cyclase
# Hydroxymethylglutaryl-CoA reductase (NADPH)
# Hydroxymethylglutaryl-CoA reductase (NADH)
# Mevalonate kinase
# Phosphomevalonate kinase
# Diphosphomevalonate decarboxylase
# Isopentenyl-diphosphate delta-isomerase, cytosolic
# Isopentenyl-diphosphate delta-isomerase, mitochondrial
# Isopentenyl-diphosphate delta-isomerase, plastidic
# 1-deoxy-D-xylulose-5-phosphate reductoisomerase
# 1-hydroxy-2-methyl-2-(E)-butenyl 4-diphosphate reductase (ipdp, nadph)
# 1-hydroxy-2-methyl-2-(E)-butenyl 4-diphosphate reductase (ipdp, nadh)
# 1-hydroxy-2-methyl-2-(E)-butenyl 4-diphosphate reductase (dmpp, nadph)
# 1-hydroxy-2-methyl-2-(E)-butenyl 4-diphosphate reductase (dmpp, nadh)
# (E)-4-hydroxy-3-methylbut-2-enyl-diphosphate synthase
# 4-(cytidine 5-diphospho)-2-C-methyl-D-erythritol kinase
# 2-C-methyl-D-erythritol 4-phosphate cytidylyltransferase
# 2-C-methyl-D-erythritol 2,4-cyclodiphosphate synthase
# Dimethylallyltransferase, plastidic
# Dimethylallyltransferase, mitochondrial
# geranyltranstransferase, plastidic
# geranyltranstransferase, mitochondrial
# Farnesyltranstransferase
# Dimethylallyltransferase, cytosolic
# geranyltranstransferase, cytosolic
# geranylgeranyl diphosphate reductase
# (4S)-limonene synthase
# Farnesyl-diphosphate farnesyltransferase
# squalene synthase
# squalene monooxygenase
# 9-beta-pimara-7,15-diene oxidase
# syn-copalyl-diphosphate synthase
# syn-pimara-7,15-diene synthase
# momilactone-A synthase
# momilactone-A synthase
# stemar-13-ene synthase
# stemar-13-ene oxidase
# cytochrome P450 monooxygenase
# ent-sandaracopimaradiene synthase
# ent-cassa-12,15-diene oxidase
# cytochrome P450 monooxygenase
# cytochrome P450 monooxygenase
# cytochrome P450 monooxygenase
# Oryzalexin D oxidase
# Oryzalexin D oxidase
# Oryzalexin A oxidase
# Oryzalexin B oxidase
# ent-pimara-8(14),15-diene synthase
# ent-isokaurene synthase
# ent-isokaurene C2-hydroxylase
# ent-cassa-12,15-diene synthase
# ent-cassa-12,15-diene oxidase
# ent-cassa-12,15-diene oxidase
# ent-cassa-12,15-diene oxidase
# ent-cassa-12,15-diene-3alpha-ol-11-keto oxidase
# ent-cassa-12,15-diene-3alpha-ol-11-keto oxidase
# cytochrome P450 monooxygenase
# ent-cassa-12,15-diene-3alpha-ol-11-keto oxidase
# ent-cassa-12,15-diene-2,3alpha-ol-11-keto oxidase
# ent-cassa-12,15-diene-2,3alpha-ol-11-keto oxidase
# cytochrome P450 monooxygenase
# Ent-kaurene synthase
# ent-copalyl diphosphate synthase
# Ent-kaurene oxidase
# Ent-kaurene oxidase
# Ent-kaurene oxidase
# Ent-kaurenoic acid oxidase
# Ent-kaurenoic acid oxidase
# Ent-kaurenoic acid oxidase
# (gibberellin-12),2-oxoglutarate:oxygen oxidoreductase
# (gibberellin-12),2-oxoglutarate:oxygen oxidoreductase
# (gibberellin-15),2-oxoglutarate:oxygen oxidoreductase
# (gibberellin-24),2-oxoglutarate:oxygen oxidoreductase
# gibberellin 3beta-dioxygenase
# (gibberellin-4),2-oxoglutarate:oxygen oxidoreductase
# (gibberellin-9),2-oxoglutarate:oxygen oxidoreductase
# (gibberellin-51),2-oxoglutarate:oxygen oxidoreductase
# (gibberellin-24),2-oxoglutarate:oxygen oxidoreductase
# gibberellin 3beta-dioxygenase
# gibberellin 3beta-dioxygenase
# gibberellin 3beta-dioxygenase
# gibberellin 3beta-dioxygenase
# (gibberellin-37),2-oxoglutarate:oxygen oxidoreductase
# (gibberellin-36),2-oxoglutarate:oxygen oxidoreductase
# gibberellin 3beta-dioxygenase
# (gibberellin-19),2-oxoglutarate:oxygen oxidoreductase
# (gibberellin-19),2-oxoglutarate:oxygen oxidoreductase
# (gibberellin-20),2-oxoglutarate:oxygen oxidoreductase
# (gibberellin-29),2-oxoglutarate:oxygen oxidoreductase
# gibberellin-44 dioxygenase
# gibberellin 3 beta-dioxygenase
# gibberellin 2 beta-dioxygenase
# gibberellin 2 beta-dioxygenase
# violaxanthin de-epoxidase
# antheraxanthin de-epoxidase
# zeaxanthin epoxidase (nadph)
# zeaxanthin epoxidase (nadh)
# antheraxanthin epoxidase (nadph)
# antheraxanthin epoxidase (nadh)
# alpha-carotene,NADH:oxygen 3-oxidoreductase
# carotene epsilon-monooxygenase
# alpha-cryptoxanthin,NADH:oxygen 3-oxidoreductase
# zeinoxanthin epsilon-monooxygenase
# 15-cis-phytoene desaturase
# all-trans phytofluene desaturase
# beta-carotene 3-hydroxylase
# ...
# Amino acid transporter (ile-L), plastidic
# Amino acid transporter (leu-L), plastidic
# Amino acid transporter (lys-L), plastidic
# Amino acid transporter (met-L), plastidic
# phenylalanine transport, plastidic
# Amino acid transporter (pro-L), plastidic
# Amino acid transporter (ser-L), plastidic
# Amino acid transporter (thr-L), plastidic
# Tryptophan permease, plastidic
# Tyrosine permease, plastidic
# Amino acid transporter (val-L), plastidic
# Amino acid transporter (arg-L), plastidic
# Tetrahydrofolate transport, diffusion, plastidic
# formate out via proton symport, plastidic
# Glucose 1-phosphate:pi antiporter, plastidic
# Glyceraldehyde 3-phosphate transport via triose-phosphate translocator (from plastid)
# alpha-glucose 6-phosphate:pi antiporter, plastidic
# beta-glucose 6-phosphate:pi antiporter, plastidic
# Dihydroxyacetone phosphate transport via triose-phosphate translocator (from plastidic)
# 3-Phospho-D-glycerate transport via triose phosphate translocator (from plastidic)
# Phosphoenolpyruvate:Pi antiporter, plastidic
# AMP transporter, plastidic
# FMN transport, plastidic
# 4-Aminobenzoate plastidic transport via diffusion
# Nicotinate D-ribonucleotide plastidic transport via diffusion
# Thiamine diphosphate transport, plastidic
# Thiamine diphosphate transport, plastidic
# H2O transport, plastidic
# CO2 plastidic transport
# H2S plastidic transport
# Glutamate/Glutamine transporter
# ammonia transport, plastidic
# O2 transport (diffusion), plastidic
# phosphate transporter, plastidic
# Sulfate transport, plastidic
# nitrite transport, plastidic
# homocysteine transport, chloropalst
# ADP/ATP transporter, plastidic
# Glycolate/Glycerate transport, plastidic
# Malate/Fumarate transport, plastidic
# Oxaloacetate/Malate transport, plastidic
# alpha-Ketoglutarate/Malate transport, plastidic
# Glutamate/Malate transport, plastidic
# succinate-fumarate antiport, plastid
# UDP-galactose:UMP antiporter, plastid
# UDP-glucose antiporter, plastid
# riboflavin transport, plastidic
# Isopentenyl diphosphate transport, plastidic
# ent-kaurene transport, plastidic
# UMP transporter
# prephenate transport, plastidic
# Choline transport, plastidic
# Phosphatidylcholine transport, plastidic
# Gamma-aminobutyric acid permease, plastidic
# Glutamate:gamma-aminobutyrate antiporter, plastidic, irreversible
# glycerol 3-phosphate transport (plastid)
# Glycerol:H+ symporter, plastidic
# CDP/CTP transporter, plastidic
# UDP/UTP transporter, plastidic
# ferrous iron transport, plastidic
# ferric iron transport (ABC-type), plastidic
# hco3 transport, plastid
# homogentisate transport
# protoheme transport (plastid)
# Pi:Na+ symporter, plastid
# Divalent cation (Mg2+) transport system, plastid
# 5,10-Methenyltetrahydrofolate uptake carrier, plastid
# Na+-translocating F-type ATPase, plastid
# pyruvate transport by free diffusion, plastid
# Na+/H+ antiporter, plastid
# sulfite tranport, plastid
# fatty acid transport (14:0), plastidic
# fatty acid transport (16:0), plastidic
# fatty acid transport (16:1), plastidic
# fatty acid transport (18:0), plastidic
# fatty acid transport (18:1), plastidic
# fatty acid transport (18:2), plastidic
# fatty acid transport (18:3), plastidic
# Argininosuccinate transport, plastid
# Acetylglutamate transport, plastid
# Glycine betaine transport, plastid
# S-Adenosyl-L-methionine reversible transport, plastidic
# N-Acetyl-L-glutamate 5-semialdehyde transport
# N2-Acetyl-L-ornithine transport
# Chorismate transport
# meso-2,6-Diaminoheptanedioate transport
# Stemar-13-ene transport
# ent-isokaurene transport
# ent-Cassa-12,15-diene transport
# ent-Sandaracopimara-8(14),15-diene transport
# Dihydrozeatin transport
# N6-Dimethylallyladenine transport
# trans-zeatin riboside transport
# trans-zeatin transport
# Isopentenyl adenosine transport
# CoA transport, plastid
# OPDA transport, plastidic
# pyruvate vacuolar transport
# sucrsoe vacuolar transport via proton symport
# hexose vacuolar transport via proton symport
# hexose vacuolar transport via proton symport
# hexose vacuolar transport via proton symport
# Amino acid transporter (gly), vacuolar
# cysteine transport, vacuolar
# H2O transport, vacuolar
# Reduced glutathione via ABC system (vacuolar)
# Tetrahydrofolate transport, diffusion, vacuolar
# Tetrahydropteroyltri-L-glutamate transport, diffusion, vacuolar
# O2 transport (diffusion)
# NO3 transport (diffusion)
# O2 transport (diffusion)
# hydrogen peroxide transport via diffusion, vacuole
# pyruvate vacuolar transport via proton symport
# fatty acyl-CoA transport via ABC system (14:0), peroxisomal
# fatty acyl-CoA transport via ABC system (16:0), peroxisomal
# fatty acyl-CoA transport via ABC system (16:1), peroxisomal
# fatty acyl-CoA transport via ABC system (18:0), peroxisomal
# fatty acyl-CoA transport via ABC system (18:1), peroxisomal
# fatty acyl-CoA transport via ABC system (18:2), peroxisomal
# fatty acyl-CoA transport via ABC system (18:3), peroxisomal
# AMP/ATP transporter, peroxisomal
# ADP/ATP transporter, peroxisomal
# Amino acid transporter (gly), peroxisomal
# Amino acid transporter (ser-L), peroxisomal
# glycolate transport, peroxisomal
# malate/oxaloacetate shuttle
# H2O transport, peroxisomal
# citrate transport, peroxisomal
# CO2 transport, peroxisomal
# O2 transport, peroxisomal
# phosphate peroxisomal transport via proton symport
# citrate/isocitrate antiport into peroxisome
# acetate transport, peroxisomal
# Amino acid transporter (ala-L), peroxisomal
# pyruvate peroxisomal transport via proton symport
# succinate transporter, peroxisome
# Ammonium transporter, peroxisomal
# Amino acid transporter (thr-L), peroxisomal
# Acetyl-CoA:CoA antiporter, peroxisomal
# CoA transport, peroxisome
# glyoxylate transport, peroxisomal
# L-glutamate transport, peroxisome
# alpha-Ketoglutarate transport, peroxisome
# Glutaryl-CoA transport, peroxisome
# Glycerate transport, peroxisome
# FADH2 transport, peroxisome
# FAD transport by free diffusion, peroxisome
# NADPH transport, peroxisome
# NADP transport by free diffusion, peroxisome
# Methyl glyoxal transport via diffucision
# Crotonoyl-CoA transport
# butanoyl-CoA transport (peroxisome)
# Jasmonate transport, peroxisomal
# OPDA transport, peroxisomal
# Sulfate transport, peroxisomal
# fatty acyl CoA transport (14:0), ER
# fatty acyl CoA transport (16:0), ER
# fatty acyl CoA transport (16:1), ER
# fatty acyl CoA transport (18:0), ER
# fatty acyl CoA transport (18:1), ER
# fatty acyl CoA transport (18:2), ER
# fatty acyl CoA transport (18:3), ER
# fatty acid transport (14:0), ER
# fatty acid transport (16:0), ER
# fatty acid transport (16:1), ER
# fatty acid transport (18:0), ER
# fatty acid transport (18:1), ER
# fatty acid transport (18:2), ER
# fatty acid transport (18:3), ER
# NADPH transport, ER
# NADP transport by free diffusion, ER
# UDP-glucose transport, ER
# Glucosylceramide transport, ER
# 16-Hydroxypalmitate transport, ER
# 18-Hydroxypalmitate transport, ER
# 10,16-dihydroxypalmitate transport, ER
# 9,10-epoxy-18-hydroxystearate transport, ER
# 9,10,18-trihydroxystearate transport, ER
# S-Adenosyl-L-methionine reversible transport, ER
# ADP/ATP transporter, ER
# AMP/ATP transporter, ER
# H2O transport, ER
# CO2 transport, ER
# O2 transport, ER
# Malonyl-CoA transport, ER
# phosphate ER transport via proton symport
# Amino acid transporter (ser-L), ER
# CoA transport, ER
# glycerol 3-phosphate transport (ER)
# Triacylglycerol transport, ER
# CTP transport, ER
# CMP transport, ER
# CDP-diacylglycerol transport, ER
# 1-Phosphatidyl-D-myo-inositol transport, ER
# Phosphatidylethanolamine transport, ER
# Phosphatidylserine transport, ER
# Phosphatidylglycerophosphate transport, ER
# Phosphatidylcholine transport, ER
# Choline transport, ER
# Inositol transport, ER
# FADH2 transport, ER
# FAD transport by free diffusion, ER
# O2 thylakoid trnasport
# H2O transport by passive diffusion, Thylakoid Lumen
# Sink needed to allow 12-oxo-c-9-dodecenoate to leave system
# Sink needed to allow (3Z)-nonenal to leave system
# Sink needed to allow (3Z,6Z)-nonadienal to leave system
# Sink needed to allow 9-oxo-nonanoate to leave system
# Sink needed to allow C25-Allenic-apo-aldehyde to leave system
# Sink needed to allow acetone to leave system
# Sink needed to allow Adenine to leave system
# Sink needed to allow Afzelechin to leave system
# Sink needed to allow S-Adenosyl-4-methylthio-2-oxobutanoate to leave system
# Sink needed to allow (R)-Amygdalin to leave system
# Sink needed to allow Apigenin 7-O-neohesperidoside to leave system
# Sink needed to allow alpha-Tocopherol to leave system
# Sink needed to allow bergapten to leave system
# Sink needed to allow Biliverdin to leave system
# Sink needed to allow Brassinolide to leave system
# Sink needed to allow Biotin to leave system
# Sink needed to allow Butin to leave system
# Sink needed to allow Cadaverine to leave system
# Sink needed to allow cyclic-AMP to leave system
# Sink needed to allow campesteryl ferulate to leave system
# Sink needed to allow D-Catechin to leave system
# Sink needed to allow cerotdioate (n-C26:0) to leave system
# Sink needed to allow Cerotyl alcohol to leave system
# Sink needed to allow Cholesterol to leave system
# Sink needed to allow Cohumulone to leave system
# Sink needed to allow cyanidin-3,5-diglucoside to leave system
# demand removing excess coa
# Sink needed to allow coumarin to leave system
# Sink needed to allow 4-Coumaryl alcohol to leave system
# Sink needed to allow Coproporphyrin I to leave system
# Sink needed to allow beta-Caryophyllene to leave system
# Sink needed to allow Cycloartenyl ferulate to leave system
# Sink needed to allow Cytochrome c to leave system
# Sink needed to allow Cytochrome c to leave system
# Sink needed to allow cis-zeatin-7-N-glucoside to leave system
# Sink needed to allow cis-zeatin-9-N-glucoside to leave system
# Sink needed to allow cis-Zeatin-O-glucoside to leave system
# Sink needed to allow 7,8-Dihydro-beta-carotene to leave system
# Sink needed to allow dihydrozeatin-7-N-glucoside to leave system
# Sink needed to allow dihydrozeatin-9-N-glucoside to leave system
# Sink needed to allow Dihydrozeatin-O-glucoside to leave system
# Sink needed to allow Divinyl chlorophyllide a to leave system
# Sink needed to allow ent-2alpha-Hydroxyisokaurene to leave system
# Sink needed to allow beta-elemene to leave system
# Sink needed to allow enterobactin to leave system
# Sink needed to allow Epicatechin to leave system
# Sink needed to allow Epiafzelechin to leave system
# Sink needed to allow Ergosterol to leave system
# Sink needed to allow Ethylene to leave system
# Sink needed to allow Gibberellin A13 to leave system
# Sink needed to allow gibberellin A17 to leave system
# Sink needed to allow gibberellin A29-catabolite to leave system
# Sink needed to allow Gibberellin A34 to leave system
# Sink needed to allow Gibberellin A51-catabolite to leave system
# Sink needed to allow Gibberellin A8-catabolite to leave system
# Sink needed to allow Gibberallin A 98 to leave system
# Sink needed to allow Gentiodelphin to leave system
# Sink needed to allow alpha-Humulene to leave system
# Sink needed to allow Humulone to leave system
# Sink needed to allow Isoorientin-2-(6-coumaroyl)-O-glucoside to leave system
# Sink needed to allow isopentenyladenine-7-N-glucoside to leave system
# Sink needed to allow isopentenyladenine-9-N-glucoside to leave system
# Sink needed to allow Isoscoparin-2-O-(6-coumaroyl)-glucoside to leave system
# Sink needed to allow Isoscoparin-2-O-(6-feruloyl)-glucoside to leave system
# Sink needed to allow Isovitexin-2-O-(6-feruloyl)-glucoside to leave system
# Sink needed to allow jasmonoyl-isoleucine to leave system
# Sink needed to allow jasmonoyl-leucine to leave system
# Sink needed to allow jasmonoyl-valine to leave system
# Sink needed to allow Kaempferol 3-O-glucoside to leave system
# Sink needed to allow Lactucaxanthin to leave system
# Sink needed to allow lignoceryl alcohol to leave system
# Sink needed to allow lignocerdioate (n-C24:0) to leave system
# Sink needed to allow (S)-Limonene to leave system
# Sink needed to allow Luteolin 7-O-neohesperidoside to leave system
# Sink needed to allow Lutein to leave system
# Sink needed to allow Menaquinone 8 to leave system
# Sink needed to allow Momilactone A to leave system
# Sink needed to allow Orientin to leave system
# Sink needed to allow oryzalexin C to leave system
# Sink needed to allow oryzalexin E to leave system
# Sink needed to allow oryzalexin F to leave system
# Sink needed to allow oryzalexin S to leave system
# Sink needed to allow O-Phospho-L-homoserine to leave system
# Sink needed to allow Menaquinone 8 to leave system
# demand removing excess photon from system
# Sink needed to allow phytocassane A to leave system
# Sink needed to allow phytocassane B to leave system
# Sink needed to allow phytocassane D to leave system
# Sink needed to allow phytocassane E to leave system
# Sink needed to allow Pinobanksin to leave system
# Sink needed to allow Plastoquinone A to leave system
# Sink needed to allow Pelargonidin 3-O-glucoside to leave system
# Sink needed to allow Phylloquinone to leave system
# Sink needed to allow ent-Pimara-8(14),15-diene to leave system
# Sink needed to allow Quercetin 3-O-glucoside to leave system
# Sink needed to allow Secologanin to leave system
# Sink needed to allow Sulfoquinovosyldiacylglycerol to leave system
# Sink needed to allow Serotonin to leave system
# Sink needed to allow Strictosidine to leave system
# Sink needed to allow Tricin-O-glucoside to leave system
# Sink needed to allow Tropinone to leave system
# Sink needed to allow trans-zeatin-7-N-glucoside to leave system
# Sink needed to allow trans-zeatin-9-N-glucoside to leave system
# Sink needed to allow trans-zeatin-O-glucoside to leave system
# Sink needed to allow trans-Zeatin riboside to leave system
# Sink needed to allow Vitexin to leave system
# Sink needed to allow gamma-Tocopherol to leave system
# demand removing excess photon from system
# demand removing excess photon from system
# Plasmodesmatal transport of L-Alanine
# Plasmodesmatal transport of L-Arginine
# Plasmodesmatal transport of L-Aspartate
# Plasmodesmatal transport of L-Cysteine
# Plasmodesmatal transport of L-Glutamate
# Plasmodesmatal transport of Glycine
# Plasmodesmatal transport of L-Histidine
# Plasmodesmatal transport of L-Isoleucine
# Plasmodesmatal transport of L-Leucine
# Plasmodesmatal transport of L-Lysine
# Plasmodesmatal transport of L-Methionine
# Plasmodesmatal transport of L-Phenylalanine
# Plasmodesmatal transport of L-Proline
# Plasmodesmatal transport of L-Serine
# Plasmodesmatal transport of L-Threonine
# Plasmodesmatal transport of L-Tryptophan
# Plasmodesmatal transport of L-Tyrosine
# Plasmodesmatal transport of L-Valine
# Plasmodesmatal transport of alpha-D-glucose
# Plasmodesmatal transport of Sucrose
# Plasmodesmatal transport of beta-D-fructose
# Plasmodesmatal transport of UDP-L-arabinose
# Plasmodesmatal transport of UDP-D-xylose
# Plasmodesmatal transport of UDP-galactose
# Plasmodesmatal transport of UDP-glucose
# Plasmodesmatal transport of UDP-D-glucuronate
# Plasmodesmatal transport of CO2
# Plasmodesmatal transport of H2O
# Plasmodesmatal transport of O2
# Plasmodesmatal transport of Phosphoenolpyruvate
# Plasmodesmatal transport of Pyruvate
# Plasmodesmatal transport of L-Malate
# Plasmodesmatal transport of Acetyl-CoA
# Plasmodesmatal transport of L-Glutamate 5-phosphate
# Plasmodesmatal transport of 2-Oxoglutarate
# Plasmodesmatal transport of Isocitrate
# Plasmodesmatal transport of D-Galactose
# Plasmodesmatal transport of D-Glucose 1-phosphate
# Plasmodesmatal transport of Trehalose
# Plasmodesmatal transport of beta-D-glucose
# Plasmodesmatal transport of alpha,alpha'-Trehalose 6-phosphate
# Plasmodesmatal transport of alpha-D-glucose 6 phosphate
# Plasmodesmatal transport of 1,3-beta-D-Glucan
# Plasmodesmatal transport of Manninotriose
# Plasmodesmatal transport of Melibiose
# Plasmodesmatal transport of Stachyose
# Plasmodesmatal transport of Raffinose
# Plasmodesmatal transport of 1-alpha-D-Galactosyl-myo-inositol
# Plasmodesmatal transport of myo-Inositol
# Plasmodesmatal transport of Citrate
# Plasmodesmatal transport of Oxalate
# Plasmodesmatal transport of D-Glycerate 2-phosphate
# Plasmodesmatal transport of Dihydroxyacetone phosphate
# Plasmodesmatal transport of D-glyceraldehyde 3-phosphate
# Plasmodesmatal transport of 3-Phospho-D-glycerate
# Plasmodesmatal transport of Glycolate
# Plasmodesmatal transport of cis-aconitate
# Plasmodesmatal transport of Succinate

# %%
cobra.io.write_sbml_model(ios2164_2cegramenell, filename= "../model/ios2164_2cell.xml")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-4b14545014a7> in <module>
# ----> 1 cobra.io.write_sbml_model(ios2164_2cegramenell, filename= "../model/ios2164_2cell.xml")
#
# NameError: name 'ios2164_2cegramenell' is not defined
