# %%
import cobra
import libsbml
import riptide
from cobra import Model, Reaction, Metabolite
import csv
import pandas as pd
import copy

# %%
ios2164_orig = cobra.io.read_sbml_model("../model/iOS2164_orig.xml")
rnaseq = pd.read_csv('../data/KitaakeLCM_rawcounts.csv')
#According to the  tool's author, the best way to merge is simply to generate
# Out:
# Model does not contain SBML fbc package information.
# SBML package 'layout' not supported by cobrapy, information is not parsed
# SBML package 'render' not supported by cobrapy, information is not parsed
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_ala_DASH_L_c "L-Alanine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ala_DASH_L_c "L-Alanine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_arg_DASH_L_c "L-Arginine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_arg_DASH_L_c "L-Arginine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_asp_DASH_L_c "L-Aspartate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_asp_DASH_L_c "L-Aspartate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_cys_DASH_L_c "L-Cysteine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_cys_DASH_L_c "L-Cysteine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_glu_DASH_L_c "L-Glutamate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_glu_DASH_L_c "L-Glutamate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_gly_c "Glycine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_gly_c "Glycine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_his_DASH_L_c "L-Histidine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_his_DASH_L_c "L-Histidine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_ile_DASH_L_c "L-Isoleucine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ile_DASH_L_c "L-Isoleucine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_leu_DASH_L_c "L-Leucine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_leu_DASH_L_c "L-Leucine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_lys_DASH_L_c "L-Lysine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_lys_DASH_L_c "L-Lysine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_met_DASH_L_c "L-Methionine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_met_DASH_L_c "L-Methionine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_phe_DASH_L_c "L-Phenylalanine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_phe_DASH_L_c "L-Phenylalanine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_pro_DASH_L_c "L-Proline">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_pro_DASH_L_c "L-Proline">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_ser_DASH_L_c "L-Serine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ser_DASH_L_c "L-Serine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_thr_DASH_L_c "L-Threonine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_thr_DASH_L_c "L-Threonine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_trp_DASH_L_c "L-Tryptophan">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_trp_DASH_L_c "L-Tryptophan">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_tyr_DASH_L_c "L-Tyrosine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_tyr_DASH_L_c "L-Tyrosine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_val_DASH_L_c "L-Valine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_val_DASH_L_c "L-Valine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_glc_DASH_A_c "alpha-D-glucose">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_glc_DASH_A_c "alpha-D-glucose">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_sucr_c "Sucrose">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_sucr_c "Sucrose">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_fru_DASH_B_c "beta-D-fructose">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_fru_DASH_B_c "beta-D-fructose">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_starch_s "Starch (n=4, 4 glucose units)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_starch_s "Starch (n=4, 4 glucose units)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_cellulose_c "Cellulose">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_cellulose_c "Cellulose">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_udparab_c "UDP-L-arabinose">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_udparab_c "UDP-L-arabinose">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_udpxyl_c "UDP-D-xylose">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_udpxyl_c "UDP-D-xylose">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_udpgal_c "UDP-galactose">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_udpgal_c "UDP-galactose">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_udpg_c "UDP-glucose">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_udpg_c "UDP-glucose">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_udpglcur_c "UDP-D-glucuronate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_udpglcur_c "UDP-D-glucuronate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_datp_c "dATP">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_datp_c "dATP">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_dctp_c "dCTP">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_dctp_c "dCTP">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_dttp_c "dTTP">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_dttp_c "dTTP">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_dgtp_c "dGTP">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_dgtp_c "dGTP">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_utp_c "UTP">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_utp_c "UTP">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_ctp_c "CTP">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ctp_c "CTP">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_gtp_c "GTP">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_gtp_c "GTP">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_fa_os_r "fatty acid, lumped (oryza sativa specific)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_fa_os_r "fatty acid, lumped (oryza sativa specific)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_triglyc_os_r "Triacylglycerol (oryza sativa specific)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_triglyc_os_r "Triacylglycerol (oryza sativa specific)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_pa_os_r "Phosphatidate (oryza sativa specific)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_pa_os_r "Phosphatidate (oryza sativa specific)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_pc_os_r "Phosphatidylcholine (oryza sativa specific)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_pc_os_r "Phosphatidylcholine (oryza sativa specific)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_pe_os_r "Phosphatidylethanolamine (oryza sativa specific)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_pe_os_r "Phosphatidylethanolamine (oryza sativa specific)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_ptd1ino_os_r "1-Phosphatidyl-D-myo-inositol (oryza sativa specific)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ptd1ino_os_r "1-Phosphatidyl-D-myo-inositol (oryza sativa specific)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_atp_c "ATP">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_atp_c "ATP">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_adp_c "ADP">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_adp_c "ADP">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_pi_c "Phosphate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_pi_c "Phosphate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_udp_c "UDP">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_udp_c "UDP">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_h_c "H+">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_h_c "H+">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_coumoh_c "4-Coumaryl alcohol">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_coumoh_c "4-Coumaryl alcohol">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_conoh_c "Coniferyl alcohol">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_conoh_c "Coniferyl alcohol">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_sinoh_c "Sinapoyl alcohol">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_sinoh_c "Sinapoyl alcohol">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_pmtcoa_c "Palmitoyl-CoA (n-C16:0CoA)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_pmtcoa_c "Palmitoyl-CoA (n-C16:0CoA)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_hdcoa_c "Hexadecenoyl-CoA (n-C16:1CoA)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_hdcoa_c "Hexadecenoyl-CoA (n-C16:1CoA)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_odecoa_c "Octadecenoyl-CoA (n-C18:1CoA)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_odecoa_c "Octadecenoyl-CoA (n-C18:1CoA)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_ocdycacoa_c "Octadecadienoyl-CoA (n-C18:2CoA)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ocdycacoa_c "Octadecadienoyl-CoA (n-C18:2CoA)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_lnlncoa_c "Linolenoyl-CoA (n-C18:3CoA)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_lnlncoa_c "Linolenoyl-CoA (n-C18:3CoA)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_acylcoa_os_c "Acyl-CoA (oryza sativa specific)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_acylcoa_os_c "Acyl-CoA (oryza sativa specific)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_pmtcoa_r "Palmitoyl-CoA (n-C16:0CoA)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_pmtcoa_r "Palmitoyl-CoA (n-C16:0CoA)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_hdcoa_r "Hexadecenoyl-CoA (n-C16:1CoA)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_hdcoa_r "Hexadecenoyl-CoA (n-C16:1CoA)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_odecoa_r "Octadecenoyl-CoA (n-C18:1CoA)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_odecoa_r "Octadecenoyl-CoA (n-C18:1CoA)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_ocdycacoa_r "Octadecadienoyl-CoA (n-C18:2CoA)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ocdycacoa_r "Octadecadienoyl-CoA (n-C18:2CoA)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_lnlncoa_r "Linolenoyl-CoA (n-C18:3CoA)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_lnlncoa_r "Linolenoyl-CoA (n-C18:3CoA)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_acylcoa_os_r "Acyl-CoA (oryza sativa specific)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_acylcoa_os_r "Acyl-CoA (oryza sativa specific)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_palmACP_s "Palmitoyl-ACP (n-C16:0ACP)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_palmACP_s "Palmitoyl-ACP (n-C16:0ACP)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_hdeACP_s "cis-hexadec-9-enoyl-[acyl-carrier protein] ((9Z)-n-C16:1)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_hdeACP_s "cis-hexadec-9-enoyl-[acyl-carrier protein] ((9Z)-n-C16:1)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_octeACP_s "cis-octadec-11-enoyl-[acyl-carrier protein] ((11Z)-n-C18:1)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_octeACP_s "cis-octadec-11-enoyl-[acyl-carrier protein] ((11Z)-n-C18:1)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_ocdcyaACP_s "Octadecadienoyl-[acyl-carrier protein] (n-C18:2ACP)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ocdcyaACP_s "Octadecadienoyl-[acyl-carrier protein] (n-C18:2ACP)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_lnlnlACP_s "Linolenoyl-[acyl-carrier protein] (n-C18:3ACP)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_lnlnlACP_s "Linolenoyl-[acyl-carrier protein] (n-C18:3ACP)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_ACP_os_s "acyl carrier protein (oryza sativa specific)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ACP_os_s "acyl carrier protein (oryza sativa specific)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_palmACP_m "Palmitoyl-ACP (n-C16:0ACP)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_palmACP_m "Palmitoyl-ACP (n-C16:0ACP)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_hdeACP_m "cis-hexadec-9-enoyl-[acyl-carrier protein] ((9Z)-n-C16:1)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_hdeACP_m "cis-hexadec-9-enoyl-[acyl-carrier protein] ((9Z)-n-C16:1)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_octeACP_m "cis-octadec-11-enoyl-[acyl-carrier protein] ((11Z)-n-C18:1)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_octeACP_m "cis-octadec-11-enoyl-[acyl-carrier protein] ((11Z)-n-C18:1)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_ocdcyaACP_m "Octadecadienoyl-[acyl-carrier protein] (n-C18:2ACP)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ocdcyaACP_m "Octadecadienoyl-[acyl-carrier protein] (n-C18:2ACP)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_lnlnlACP_m "Linolenoyl-[acyl-carrier protein] (n-C18:3ACP)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_lnlnlACP_m "Linolenoyl-[acyl-carrier protein] (n-C18:3ACP)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_ACP_os_m "acyl carrier protein (oryza sativa specific)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ACP_os_m "acyl carrier protein (oryza sativa specific)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_fa_os_c "fatty acid, lumped (oryza sativa specific)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_fa_os_c "fatty acid, lumped (oryza sativa specific)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_hdca_c "Hexadecanoate (n-C16:0)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_hdca_c "Hexadecanoate (n-C16:0)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_hdcea_c "Hexadecenoate (16:1(9Z))">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_hdcea_c "Hexadecenoate (16:1(9Z))">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_ocdcea_c "octadecenoate (n-C18:1)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ocdcea_c "octadecenoate (n-C18:1)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_ocdcya_c "Octadecadienoate (n-C18:2)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ocdcya_c "Octadecadienoate (n-C18:2)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_lnlnl_c "Linolenate (n-C18:3)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_lnlnl_c "Linolenate (n-C18:3)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_hdca_r "Hexadecanoate (n-C16:0)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_hdca_r "Hexadecanoate (n-C16:0)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_hdcea_r "Hexadecenoate (16:1(9Z))">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_hdcea_r "Hexadecenoate (16:1(9Z))">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_ocdcea_r "octadecenoate (n-C18:1)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ocdcea_r "octadecenoate (n-C18:1)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_ocdcya_r "Octadecadienoate (n-C18:2)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ocdcya_r "Octadecadienoate (n-C18:2)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_lnlnl_r "Linolenate (n-C18:3)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_lnlnl_r "Linolenate (n-C18:3)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_co2_e "CO2">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_co2_e "CO2">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_h2o_e "H2O">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_h2o_e "H2O">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_h_e "H+">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_h_e "H+">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_no3_e "Nitrate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_no3_e "Nitrate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_o2_e "O2">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_o2_e "O2">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_pi_e "Phosphate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_pi_e "Phosphate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_sucr_e "Sucrose">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_sucr_e "Sucrose">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_fru_DASH_B_e "beta-D-fructose">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_fru_DASH_B_e "beta-D-fructose">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_glc_DASH_A_e "alpha-D-glucose">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_glc_DASH_A_e "alpha-D-glucose">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_so4_e "Sulfate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_so4_e "Sulfate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_hco3_e "Bicarbonate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_hco3_e "Bicarbonate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_hso3_e "Sulfite">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_hso3_e "Sulfite">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_h2s_e "Hydrogen sulfide">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_h2s_e "Hydrogen sulfide">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_nh4_e "Ammonium">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_nh4_e "Ammonium">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_asn_DASH_L_e "L-Asparagine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_asn_DASH_L_e "L-Asparagine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_gln_DASH_L_e "L-Glutamine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_gln_DASH_L_e "L-Glutamine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_etoh_e "Ethanol">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_etoh_e "Ethanol">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_ac_e "Acetate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ac_e "Acetate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_lac_DASH_L_e "L-Lactate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_lac_DASH_L_e "L-Lactate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_tsul_e "Thiosulfate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_tsul_e "Thiosulfate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_fe2_e "Fe2+">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_fe2_e "Fe2+">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_fe3_e "Fe3+">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_fe3_e "Fe3+">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_mg2_e "Magnesium">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_mg2_e "Magnesium">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_ala_DASH_L_e "L-Alanine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ala_DASH_L_e "L-Alanine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_arg_DASH_L_e "L-Arginine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_arg_DASH_L_e "L-Arginine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_asp_DASH_L_e "L-Aspartate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_asp_DASH_L_e "L-Aspartate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_cys_DASH_L_e "L-Cysteine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_cys_DASH_L_e "L-Cysteine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_glu_DASH_L_e "L-Glutamate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_glu_DASH_L_e "L-Glutamate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_gly_e "Glycine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_gly_e "Glycine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_his_DASH_L_e "L-Histidine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_his_DASH_L_e "L-Histidine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_ile_DASH_L_e "L-Isoleucine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ile_DASH_L_e "L-Isoleucine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_leu_DASH_L_e "L-Leucine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_leu_DASH_L_e "L-Leucine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_lys_DASH_L_e "L-Lysine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_lys_DASH_L_e "L-Lysine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_met_DASH_L_e "L-Methionine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_met_DASH_L_e "L-Methionine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_phe_DASH_L_e "L-Phenylalanine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_phe_DASH_L_e "L-Phenylalanine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_pro_DASH_L_e "L-Proline">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_pro_DASH_L_e "L-Proline">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_ser_DASH_L_e "L-Serine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ser_DASH_L_e "L-Serine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_thr_DASH_L_e "L-Threonine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_thr_DASH_L_e "L-Threonine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_trp_DASH_L_e "L-Tryptophan">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_trp_DASH_L_e "L-Tryptophan">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_tyr_DASH_L_e "L-Tyrosine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_tyr_DASH_L_e "L-Tyrosine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_val_DASH_L_e "L-Valine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_val_DASH_L_e "L-Valine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_photonVis_e "photon (380 to 750 nm, visible spectrum)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_photonVis_e "photon (380 to 750 nm, visible spectrum)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_photon410_u "photon (281 to 306 nm, UVB)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_photon410_u "photon (281 to 306 nm, UVB)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_photon430_u "photon (406 to 454 nm, indigo/blue)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_photon430_u "photon (406 to 454 nm, indigo/blue)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_photon450_u "photon (378 to 482 nm, violet/blue)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_photon450_u "photon (378 to 482 nm, violet/blue)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_photon470_u "photon (417 to 472 nm, indigo/blue)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_photon470_u "photon (417 to 472 nm, indigo/blue)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_photon490_u "photon (451 to 526 nm, blue/green)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_photon490_u "photon (451 to 526 nm, blue/green)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_photon610_u "photon (662 to 691 nm, red)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_photon610_u "photon (662 to 691 nm, red)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_photon630_u "photon (662 to 691 nm, red)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_photon630_u "photon (662 to 691 nm, red)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_photon650_u "photon (662 to 691 nm, red)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_photon650_u "photon (662 to 691 nm, red)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_photon670_u "photon (662 to 691 nm, red)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_photon670_u "photon (662 to 691 nm, red)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_photon690_u "photon (662 to 691 nm, red)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_photon690_u "photon (662 to 691 nm, red)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_photon510_u "photon (608 to 666 nm, orange/red)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_photon510_u "photon (608 to 666 nm, orange/red)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_photon530_u "photon (659 to 684 nm, red)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_photon530_u "photon (659 to 684 nm, red)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_photon550_u "photon (662 to 691 nm, red)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_photon550_u "photon (662 to 691 nm, red)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_photon570_u "photon (662 to 691 nm, red)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_photon570_u "photon (662 to 691 nm, red)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_photon590_u "photon (662 to 691 nm, red)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_photon590_u "photon (662 to 691 nm, red)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_photonPSI_u "photon (380 to 750 nm, visible spectrum)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_photonPSI_u "photon (380 to 750 nm, visible spectrum)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_photonDrain_u "photon Drain">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_photonDrain_u "photon Drain">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_photonPSII_u "photon (380 to 750 nm, visible spectrum)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_photonPSII_u "photon (380 to 750 nm, visible spectrum)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_co2_c "CO2">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_co2_c "CO2">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_h2o_c "H2O">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_h2o_c "H2O">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_no3_c "Nitrate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_no3_c "Nitrate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_o2_c "O2">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_o2_c "O2">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_so4_c "Sulfate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_so4_c "Sulfate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_hso3_c "HSO3-">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_hso3_c "HSO3-">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_hco3_c "Bicarbonate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_hco3_c "Bicarbonate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_h2s_c "Hydrogen sulfide">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_h2s_c "Hydrogen sulfide">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_nh4_c "Ammonium">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_nh4_c "Ammonium">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_asn_DASH_L_c "L-Asparagine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_asn_DASH_L_c "L-Asparagine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_gln_DASH_L_c "L-Glutamine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_gln_DASH_L_c "L-Glutamine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_etoh_c "Ethanol">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_etoh_c "Ethanol">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_ac_c "Acetate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ac_c "Acetate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_lac_DASH_L_c "L-Lactate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_lac_DASH_L_c "L-Lactate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_tsul_c "Thiosulfate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_tsul_c "Thiosulfate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_fe2_c "Fe2+">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_fe2_c "Fe2+">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_fe3_c "Fe3+">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_fe3_c "Fe3+">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_mg2_c "Magnesium">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_mg2_c "Magnesium">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_ppi_c "Diphosphate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ppi_c "Diphosphate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_h2o_s "H2O">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_h2o_s "H2O">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_ppi_s "Diphosphate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ppi_s "Diphosphate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_h_s "H+">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_h_s "H+">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_pi_s "Phosphate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_pi_s "Phosphate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_h2o_m "H2O">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_h2o_m "H2O">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_ppi_m "Diphosphate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ppi_m "Diphosphate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_h_m "H+">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_h_m "H+">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_pi_m "Phosphate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_pi_m "Phosphate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_h2o_x "H2O">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_h2o_x "H2O">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_ppi_x "Diphosphate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ppi_x "Diphosphate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_h_x "H+">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_h_x "H+">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_pi_x "Phosphate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_pi_x "Phosphate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_h2o_v "H2O">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_h2o_v "H2O">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_ppi_v "Diphosphate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ppi_v "Diphosphate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_h_v "H+">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_h_v "H+">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_pi_v "Phosphate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_pi_v "Phosphate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_pyr_s "Pyruvate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_pyr_s "Pyruvate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_2ahethmpp_s "2-(alpha-Hydroxyethyl)thiamine diphosphate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_2ahethmpp_s "2-(alpha-Hydroxyethyl)thiamine diphosphate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_alac_DASH_S_s "(S)-2-Acetolactate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_alac_DASH_S_s "(S)-2-Acetolactate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_thmpp_s "Thiamine diphosphate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_thmpp_s "Thiamine diphosphate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_pyr_m "Pyruvate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_pyr_m "Pyruvate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_2ahethmpp_m "2-(alpha-Hydroxyethyl)thiamine diphosphate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_2ahethmpp_m "2-(alpha-Hydroxyethyl)thiamine diphosphate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_alac_DASH_S_m "(S)-2-Acetolactate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_alac_DASH_S_m "(S)-2-Acetolactate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_thmpp_m "Thiamine diphosphate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_thmpp_m "Thiamine diphosphate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_h2o2_v "Hydrogen peroxide">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_h2o2_v "Hydrogen peroxide">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_o2_v "O2">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_o2_v "O2">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_h2o2_s "Hydrogen peroxide">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_h2o2_s "Hydrogen peroxide">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_o2_s "O2">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_o2_s "O2">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_h2o2_x "Hydrogen peroxide">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_h2o2_x "Hydrogen peroxide">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_o2_x "O2">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_o2_x "O2">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_h2o2_m "Hydrogen peroxide">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_h2o2_m "Hydrogen peroxide">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_o2_m "O2">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_o2_m "O2">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_gln_DASH_L_m "L-Glutamine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_gln_DASH_L_m "L-Glutamine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_akg_m "2-Oxoglutarate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_akg_m "2-Oxoglutarate">
# ...
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_CNDM35DG_LPAREN_c_RPAREN_ "Sink needed to allow cyanidin-3,5-diglucoside to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_COA_LPAREN_c_RPAREN_ "demand removing excess coa">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_COUMN_LPAREN_c_RPAREN_ "Sink needed to allow coumarin to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_COUMOH_LPAREN_c_RPAREN_ "Sink needed to allow 4-Coumaryl alcohol to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_CPP1_LPAREN_s_RPAREN_ "Sink needed to allow Coproporphyrin I to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_CRPE_LPAREN_c_RPAREN_ "Sink needed to allow beta-Caryophyllene to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_CYARTFER_LPAREN_c_RPAREN_ "Sink needed to allow Cycloartenyl ferulate to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_CYTC_LPAREN_m_RPAREN_ "Sink needed to allow Cytochrome c to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_CYTC_LPAREN_s_RPAREN_ "Sink needed to allow Cytochrome c to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_C_DASH_ZTN7G_LPAREN_c_RPAREN_ "Sink needed to allow cis-zeatin-7-N-glucoside to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_C_DASH_ZTN9G_LPAREN_c_RPAREN_ "Sink needed to allow cis-zeatin-9-N-glucoside to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_ZTNG_LPAREN_c_RPAREN_ "Sink needed to allow cis-Zeatin-O-glucoside to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_DHBZCAROT_LPAREN_s_RPAREN_ "Sink needed to allow 7,8-Dihydro-beta-carotene to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_DHZ7G_LPAREN_c_RPAREN_ "Sink needed to allow dihydrozeatin-7-N-glucoside to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_DHZ9G_LPAREN_c_RPAREN_ "Sink needed to allow dihydrozeatin-9-N-glucoside to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_DHZG_LPAREN_c_RPAREN_ "Sink needed to allow Dihydrozeatin-O-glucoside to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_DVCHLDA_LPAREN_s_RPAREN_ "Sink needed to allow Divinyl chlorophyllide a to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_EIHKAUR_LPAREN_c_RPAREN_ "Sink needed to allow ent-2alpha-Hydroxyisokaurene to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_ELM_LPAREN_c_RPAREN_ "Sink needed to allow beta-elemene to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_ENTB_LPAREN_s_RPAREN_ "Sink needed to allow enterobactin to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_EPCTCN_LPAREN_c_RPAREN_ "Sink needed to allow Epicatechin to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_EPLZN_LPAREN_c_RPAREN_ "Sink needed to allow Epiafzelechin to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_ERGTOL_LPAREN_c_RPAREN_ "Sink needed to allow Ergosterol to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_ETHYLENE_LPAREN_c_RPAREN_ "Sink needed to allow Ethylene to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_GA13_LPAREN_c_RPAREN_ "Sink needed to allow Gibberellin A13 to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_GA17_LPAREN_c_RPAREN_ "Sink needed to allow gibberellin A17 to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_GA29CAT_LPAREN_c_RPAREN_ "Sink needed to allow gibberellin A29-catabolite to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_GA34_LPAREN_c_RPAREN_ "Sink needed to allow Gibberellin A34 to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_GA51CAT_LPAREN_c_RPAREN_ "Sink needed to allow Gibberellin A51-catabolite to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_GA8CAT_LPAREN_c_RPAREN_ "Sink needed to allow Gibberellin A8-catabolite to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_GA98_LPAREN_c_RPAREN_ "Sink needed to allow Gibberallin A 98 to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_GENTDP_LPAREN_c_RPAREN_ "Sink needed to allow Gentiodelphin to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_HUML_LPAREN_c_RPAREN_ "Sink needed to allow alpha-Humulene to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_HUMU_LPAREN_c_RPAREN_ "Sink needed to allow Humulone to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_IORNTN2GCOUM_LPAREN_c_RPAREN_ "Sink needed to allow Isoorientin-2-(6-coumaroyl)-O-glucoside to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_IPADNE7G_LPAREN_c_RPAREN_ "Sink needed to allow isopentenyladenine-7-N-glucoside to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_IPADNE9G_LPAREN_c_RPAREN_ "Sink needed to allow isopentenyladenine-9-N-glucoside to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_ISCPRN2GCOUM_LPAREN_c_RPAREN_ "Sink needed to allow Isoscoparin-2-O-(6-coumaroyl)-glucoside to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_ISCPRN2GFER_LPAREN_c_RPAREN_ "Sink needed to allow Isoscoparin-2-O-(6-feruloyl)-glucoside to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_IVTXN2GFER_LPAREN_c_RPAREN_ "Sink needed to allow Isovitexin-2-O-(6-feruloyl)-glucoside to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_JASILE_LPAREN_c_RPAREN_ "Sink needed to allow jasmonoyl-isoleucine to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_JASLEU_LPAREN_c_RPAREN_ "Sink needed to allow jasmonoyl-leucine to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_JASVAL_LPAREN_c_RPAREN_ "Sink needed to allow jasmonoyl-valine to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_JASKMPFL3G_LPAREN_c_RPAREN_ "Sink needed to allow Kaempferol 3-O-glucoside to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_LACXAN_LPAREN_s_RPAREN_ "Sink needed to allow Lactucaxanthin to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_LGNCOL_LPAREN_r_RPAREN_ "Sink needed to allow lignoceryl alcohol to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_LGNDT_LPAREN_r_RPAREN_ "Sink needed to allow lignocerdioate (n-C24:0) to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_LIM_LPAREN_s_RPAREN_ "Sink needed to allow (S)-Limonene to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_LTNNP_LPAREN_c_RPAREN_ "Sink needed to allow Luteolin 7-O-neohesperidoside to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_LUTEIN_LPAREN_c_RPAREN_ "Sink needed to allow Lutein to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_MNQNNE_LPAREN_s_RPAREN_ "Sink needed to allow Menaquinone 8 to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_MOMA_LPAREN_s_RPAREN_ "Sink needed to allow Momilactone A to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_ORNTN_LPAREN_c_RPAREN_ "Sink needed to allow Orientin to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_OZLN_DASH_C_LPAREN_c_RPAREN_ "Sink needed to allow oryzalexin C to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_OZLN_DASH_E_LPAREN_c_RPAREN_ "Sink needed to allow oryzalexin E to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_OZLN_DASH_F_LPAREN_c_RPAREN_ "Sink needed to allow oryzalexin F to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_OZLN_DASH_S_LPAREN_c_RPAREN_ "Sink needed to allow oryzalexin S to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_PHAS_LPAREN_s_RPAREN_ "Sink needed to allow O-Phospho-L-homoserine to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_PHOM_LPAREN_c_RPAREN_ "Sink needed to allow Menaquinone 8 to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_photonDrain_LPAREN_u_RPAREN_ "demand removing excess photon from system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_PHTC_DASH_A_LPAREN_c_RPAREN_ "Sink needed to allow phytocassane A to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_PHTC_DASH_B_LPAREN_c_RPAREN_ "Sink needed to allow phytocassane B to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_PHTC_DASH_D_LPAREN_c_RPAREN_ "Sink needed to allow phytocassane D to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_PHTC_DASH_E_LPAREN_c_RPAREN_ "Sink needed to allow phytocassane E to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_PINBAN_LPAREN_c_RPAREN_ "Sink needed to allow Pinobanksin to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_PLAST_LPAREN_s_RPAREN_ "Sink needed to allow Plastoquinone A to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_PLGNG_LPAREN_c_RPAREN_ "Sink needed to allow Pelargonidin 3-O-glucoside to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_PQNNE_LPAREN_s_RPAREN_ "Sink needed to allow Phylloquinone to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_PRIMARDN_LPAREN_s_RPAREN_ "Sink needed to allow ent-Pimara-8(14),15-diene to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_QRCTN3G_LPAREN_c_RPAREN_ "Sink needed to allow Quercetin 3-O-glucoside to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_SCLGN_LPAREN_c_RPAREN_ "Sink needed to allow Secologanin to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_SQ12DGR_OS_LPAREN_s_RPAREN_ "Sink needed to allow Sulfoquinovosyldiacylglycerol to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_SRNTN_LPAREN_c_RPAREN_ "Sink needed to allow Serotonin to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_STCSD_LPAREN_c_RPAREN_ "Sink needed to allow Strictosidine to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_TRICING_LPAREN_c_RPAREN_ "Sink needed to allow Tricin-O-glucoside to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_TRPN_LPAREN_c_RPAREN_ "Sink needed to allow Tropinone to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_T_DASH_ZTN7G_LPAREN_c_RPAREN_ "Sink needed to allow trans-zeatin-7-N-glucoside to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_T_DASH_ZTN9G_LPAREN_c_RPAREN_ "Sink needed to allow trans-zeatin-9-N-glucoside to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_T_DASH_ZTNG_LPAREN_c_RPAREN_ "Sink needed to allow trans-zeatin-O-glucoside to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_T_DASH_ZTNR_LPAREN_c_RPAREN_ "Sink needed to allow trans-Zeatin riboside to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_VTXN_LPAREN_c_RPAREN_ "Sink needed to allow Vitexin to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_YVITE_LPAREN_s_RPAREN_ "Sink needed to allow gamma-Tocopherol to leave system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_PSI "demand removing excess photon from system">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DM_PSII "demand removing excess photon from system">

# %%
mcell_exp = riptide.read_transcription_file("../data/m_abundance.csv", sep = ",", header = True)
bscell_exp = riptide.read_transcription_file("../data/bs_abundance.csv", sep = ",", header = True)
vcell_exp = riptide.read_transcription_file("../data/v_abundance.csv", sep = ",", header = True)

# %%
ios2164_m = copy.deepcopy(ios2164_orig)
for met in ios2164_m.metabolites:
    if met.compartment != "e": #Extracellular, defines boundary reactions
        met.id = str(met.id) + '0'
        met.compartment = str(met.compartment) + '0'

for rxn in ios2164_m.reactions:
    rxn.id = str(rxn.id)  + '_M'
    if "EX_" in rxn.id: #Rename media reactions
        rxn.name = "M " + str(rxn.name)


ios2164_m.repair()

# %%
ios2164_bs = copy.deepcopy(ios2164_orig)

for met in ios2164_bs.metabolites:
    if met.compartment != "e": #Extracellular, defines boundary reactions
        met.id = str(met.id) + '1'
        met.compartment = str(met.compartment) + '1'
    
for rxn in ios2164_bs.reactions:
    rxn.id = str(rxn.id)  + '_BS'
    if "EX_" in rxn.id: #Rename media reactions
        rxn.name = "BS " + str(rxn.name)


ios2164_bs.repair()

# %%
ios2164_v = copy.deepcopy(ios2164_orig)

for met in ios2164_v.metabolites:
    if met.compartment != "e": #Extracellular, defines boundary reactions
        met.id = str(met.id) + '2'
        met.compartment = str(met.compartment) + '2'
    
for rxn in ios2164_v.reactions:
    rxn.id = str(rxn.id)  + '_V'
    if "EX_" in rxn.id: #Rename media reactions
        rxn.name = "V " + str(rxn.name)

ios2164_v.repair()

# %%
mcell_rip = riptide.contextualize(ios2164_m, transcriptome = mcell_exp)
# Out:
# Initializing model and integrating transcriptomic data...
# Pruning zero flux subnetworks...
# Analyzing context-specific flux distributions...
#
# Reactions pruned to 432 from 2444 (82.32% change)
# Metabolites pruned to 435 from 1999 (78.24% change)
# Flux through the objective DECREASED to ~77.99 from ~88.27 (11.65% change)
# Context-specific metabolism correlates with transcriptome (r=0.123, p=0.011 *)
#
# RIPTiDe completed in 20 seconds

# %%
bscell_rip = riptide.contextualize(ios2164_bs, transcriptome = bscell_exp)
# Out:
# /home/rtsantos3/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Initializing model and integrating transcriptomic data...
# Pruning zero flux subnetworks...
# Analyzing context-specific flux distributions...
#
# Reactions pruned to 423 from 2444 (82.69% change)
# Metabolites pruned to 425 from 1999 (78.74% change)
# Flux through the objective DECREASED to ~77.69 from ~88.27 (11.99% change)
# Context-specific metabolism does not correlate with transcriptome (r=0.085, n.s.)
#
# RIPTiDe completed in 22 seconds

# %%
vcell_rip = riptide.contextualize(ios2164_v, transcriptome = vcell_exp)
# Out:
# /home/rtsantos3/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Initializing model and integrating transcriptomic data...
# Pruning zero flux subnetworks...
# Analyzing context-specific flux distributions...
#
# Reactions pruned to 411 from 2444 (83.18% change)
# Metabolites pruned to 418 from 1999 (79.09% change)
# Flux through the objective DECREASED to ~67.14 from ~88.27 (23.94% change)
# Context-specific metabolism correlates with transcriptome (r=0.17, p=0.001 *)
#
# RIPTiDe completed in 18 seconds

# %%
#Merging the BS and M Cells
twocell_rip = Model()
twocell_rip = mcell_rip.model.merge(bscell_rip.model, objective = "sum", inplace = False)
twocell_rip
# Out:
# <Model iOS2164_riptide_iOS2164_riptide at 0x7fbc0acc49a0>

# %%
threecell_rip = Model()
threecell_rip = twocell_rip.merge(vcell_rip.model, objective = "sum", inplace = False)

# %%
twocell_rip
# Out:
# <Model iOS2164_riptide_iOS2164_riptide at 0x7fbc0acc49a0>

# %%
threecell_rip
# Out:
# <Model iOS2164_riptide_iOS2164_riptide_iOS2164_riptide at 0x7fbc0a325b80>

# %%
threecell_rip.compartments = {
 'c0': 'M Cell Cytoplasm',
 's0': 'M Cell Plastid',
 'r0': 'M Cell Endoplasmic_reticulum',
 'm0': 'M Cell Mitochondrion',
 'e': 'Extracellular',
 'u0': 'M Cell Thylakoid',
 'x0': 'M Cell Peroxisome',
 'v0': 'M Cell Vacuole',
 'c1': 'BS Cell Cytoplasm',
 's1': 'BS Cell Plastid',
 'r1': 'BS Cell Endoplasmic_reticulum',
 'm1': 'BS Cell Mitochondrion',
 'u1': 'BS Cell Thylakoid',
 'x1': 'BS Cell Peroxisome',
 'v1': 'BS Cell Vacuole',
 'v2': 'V Cell Vacuole',
 'c2': 'V Cell Cytoplasm',
 's2': 'V Cell Plastid',
 'r2': 'V Cell Endoplasmic_reticulum',
 'm2': 'V Cell Mitochondrion',
 'u2': 'V Cell Thylakoid',
 'x2': 'V Cell Peroxisome',
 'v2': 'V Cell Vacuole'}

threecell_rip.repair()
#Apparently compartments don't update after  merging so I've updated it na lang after that
#Also need to rebuild the model medium

# %%
# Out:
# /home/rtsantos3/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# From Blatke & Brautigam (2019):
#
# "The mesophyll and bundle sheath networks are connected by a range of cytosolic transport metabolites including amino acids, sugars (glucose, fructose, sucrose, trehalose, ribose), single phosphorylated sugar (glucose-6-phosphate, glucose-1-phosphate, fructose-6-phosphate, sucrose-6-phosphate), mono-/di-/tri-carboxylic acids (phosphoenolpyruvate, pyruvate, citrate, cis-aconitate, isocitrate, α-ketoglutarate, succinate, fumarate, malate), glyceric acids (2-Phosphoglycerate, 3-Phosphoglycerate), glycolate, glycerate, glyceraldehyde-3-phosphate, di-hydroxyacetone-phosphate and CO2.
#
# Nucleotides, NAD/NADH, NADP/NADPH, pyrophosphate, inorganic phosphate are not considered as transport metabolites.
#
# Oxaloacetate has been excluded as transport metabolite since concentrations of oxaloacetate are very low in vivo and it is reasonably unstable in aqueous solutions.
#
# Other small molecules that can be imported by the bundle sheath from the environment, as well as protons and HCO3-, are not exchanged between the two cell types.
#
# #So bale yung mga organic na soluble lang with reasonably long cellular half-lives.

# %%
#Open the initial curated list to get the metabolite ids
transport_rxns = pd.read_csv('../model/initial_list_transport_rxns.csv')
#Ok it gets the reactions now

for item in ios2164_orig.metabolites:
    if item.compartment == "c":
        count = 0
        if item.id in transport_rxns.id.values:
            pd_rxn = Reaction()
            #Generate reaction name
            pd_rxn.id = str(item.id[:-2] + '_pd') #Replaces suffix with '_pd'
            pd_rxn.name = str('Plasmodesmatal transport of ' + item.name)
            pd_rxn.subsystem = str('PD Transport Reaction')
            #Reaction is reversible
            pd_rxn.lower_bound = -1000
            pd_rxn.upper_bound = 1000
            
            
            #Generate metabolite names
            
            
            met_mcell = str(item.id) + '0'
            met_bcell = str(item.id) + '1'
            

            if met_mcell in twocell_rip.metabolites:
                if met_bcell in twocell_rip.metabolites:
                    count += 1
                    met_mcell = twocell_rip.metabolites.get_by_id(met_mcell)
                    met_bcell = twocell_rip.metabolites.get_by_id(met_bcell)
                    pd_rxn.add_metabolites({met_mcell:-1.0, met_bcell:1.0})
                    twocell_rip.add_reaction(pd_rxn)
            
twocell_rip.repair()

printout = 'added ' + str(count) + ' PD reactions to model'
print(printout)
# Out:
# Ignoring reaction 'ala_DASH_L_pd' since it already exists.
# Ignoring reaction 'arg_DASH_L_pd' since it already exists.
# Ignoring reaction 'asp_DASH_L_pd' since it already exists.
# Ignoring reaction 'cys_DASH_L_pd' since it already exists.
# Ignoring reaction 'glu_DASH_L_pd' since it already exists.
# Ignoring reaction 'gly_pd' since it already exists.
# Ignoring reaction 'his_DASH_L_pd' since it already exists.
# Ignoring reaction 'ile_DASH_L_pd' since it already exists.
# Ignoring reaction 'leu_DASH_L_pd' since it already exists.
# Ignoring reaction 'lys_DASH_L_pd' since it already exists.
# Ignoring reaction 'met_DASH_L_pd' since it already exists.
# Ignoring reaction 'phe_DASH_L_pd' since it already exists.
# Ignoring reaction 'pro_DASH_L_pd' since it already exists.
# Ignoring reaction 'ser_DASH_L_pd' since it already exists.
# Ignoring reaction 'thr_DASH_L_pd' since it already exists.
# Ignoring reaction 'trp_DASH_L_pd' since it already exists.
# Ignoring reaction 'tyr_DASH_L_pd' since it already exists.
# Ignoring reaction 'val_DASH_L_pd' since it already exists.
# Ignoring reaction 'glc_DASH_A_pd' since it already exists.
# Ignoring reaction 'sucr_pd' since it already exists.
# Ignoring reaction 'fru_DASH_B_pd' since it already exists.
# Ignoring reaction 'udparab_pd' since it already exists.
# Ignoring reaction 'udpxyl_pd' since it already exists.
# Ignoring reaction 'udpgal_pd' since it already exists.
# Ignoring reaction 'udpg_pd' since it already exists.
# Ignoring reaction 'udpglcur_pd' since it already exists.
# Ignoring reaction 'co2_pd' since it already exists.
# Ignoring reaction 'h2o_pd' since it already exists.
# Ignoring reaction 'o2_pd' since it already exists.
# Ignoring reaction 'pep_pd' since it already exists.
# Ignoring reaction 'pyr_pd' since it already exists.
# Ignoring reaction 'mal_DASH_L_pd' since it already exists.
# Ignoring reaction 'accoa_pd' since it already exists.
# Ignoring reaction 'akg_pd' since it already exists.
# Ignoring reaction 'icit_pd' since it already exists.
# Ignoring reaction 'g1p_pd' since it already exists.
# Ignoring reaction 'g6p_DASH_A_pd' since it already exists.
# Ignoring reaction 'inost_pd' since it already exists.
# Ignoring reaction 'cit_pd' since it already exists.
# Ignoring reaction '2pg_pd' since it already exists.
# Ignoring reaction 'dhap_pd' since it already exists.
# Ignoring reaction 'g3p_pd' since it already exists.
# Ignoring reaction '3pg_pd' since it already exists.
# Ignoring reaction 'succ_pd' since it already exists.
# added 0 PD reactions to model

# %%
reup_twocell = riptide.contextualize(twocell_rip)
# Out:
# /home/rtsantos3/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# WARNING: No transcriptome provided. Analyzing most parsimonious state
#
# Initializing model and integrating transcriptomic data...
# Pruning zero flux subnetworks...
# Analyzing context-specific flux distributions...
#
# Reactions pruned to 745 from 899 (17.13% change)
# Metabolites pruned to 775 from 830 (6.63% change)
# Flux through the objective DECREASED to ~132.31 from ~155.68 (15.01% change)
# Context-specific metabolism does not correlate with transcriptome (r=-0.037, n.s.)
#
# RIPTiDe completed in 13 seconds

# %%
reup_twocell.model.medium
#Ang galing nakakagenerate siya ng parang upper bounds nung reaction na rin via pFBA haha
#I think I need to modify it in such a way as to remove all the glucose solutions
#Perhaps a modification of the objective function will yield a different result?
# Out:
# /home/rtsantos3/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# {'EX_o2_LPAREN_e_RPAREN__M': 1000.0,
#  'EX_pi_LPAREN_e_RPAREN__M': 14.774537869088563,
#  'EX_sucr_LPAREN_e_RPAREN__M': 579.7649614246227,
#  'EX_gln_DASH_L_LPAREN_e_RPAREN__M': 0.5584402018726617,
#  'EX_arg_DASH_L_LPAREN_e_RPAREN__M': 0.8806172414145035,
#  'EX_cys_DASH_L_LPAREN_e_RPAREN__M': 701.7808511887064,
#  'EX_glu_DASH_L_LPAREN_e_RPAREN__M': 779.0680914548269,
#  'EX_his_DASH_L_LPAREN_e_RPAREN__M': 4.08090916753034,
#  'EX_ile_DASH_L_LPAREN_e_RPAREN__M': 1.002328567463567,
#  'EX_leu_DASH_L_LPAREN_e_RPAREN__M': 1.6753206056177508,
#  'EX_lys_DASH_L_LPAREN_e_RPAREN__M': 1.0954019344424755,
#  'EX_met_DASH_L_LPAREN_e_RPAREN__M': 0.5441212223388461,
#  'EX_phe_DASH_L_LPAREN_e_RPAREN__M': 0.9522121390903424,
#  'EX_pro_DASH_L_LPAREN_e_RPAREN__M': 1.8969653074638362,
#  'EX_ser_DASH_L_LPAREN_e_RPAREN__M': 682.6709259106386,
#  'EX_thr_DASH_L_LPAREN_e_RPAREN__M': 1000.0000000000001,
#  'EX_trp_DASH_L_LPAREN_e_RPAREN__M': 0.11455183628152504,
#  'EX_tyr_DASH_L_LPAREN_e_RPAREN__M': 38.217356379434705,
#  'EX_val_DASH_L_LPAREN_e_RPAREN__M': 1.610885197709571,
#  'EX_photonVis_LPAREN_e_RPAREN__M': 1000.0,
#  'EX_o2_LPAREN_e_RPAREN__BS': 1000.0,
#  'EX_pi_LPAREN_e_RPAREN__BS': 14.737034433674149,
#  'EX_sucr_LPAREN_e_RPAREN__BS': 554.7770826506483,
#  'EX_gln_DASH_L_LPAREN_e_RPAREN__BS': 0.5570226667705942,
#  'EX_arg_DASH_L_LPAREN_e_RPAREN__BS': 0.8783818975997665,
#  'EX_cys_DASH_L_LPAREN_e_RPAREN__BS': 662.1956036077593,
#  'EX_his_DASH_L_LPAREN_e_RPAREN__BS': 4.0705502571696615,
#  'EX_ile_DASH_L_LPAREN_e_RPAREN__BS': 0.9997842736906897,
#  'EX_leu_DASH_L_LPAREN_e_RPAREN__BS': 1.6710680003117735,
#  'EX_lys_DASH_L_LPAREN_e_RPAREN__BS': 1.0926213848193296,
#  'EX_met_DASH_L_LPAREN_e_RPAREN__BS': 0.542740034306886,
#  'EX_phe_DASH_L_LPAREN_e_RPAREN__BS': 0.9497950600062114,
#  'EX_pro_DASH_L_LPAREN_e_RPAREN__BS': 1.8924582727803694,
#  'EX_thr_DASH_L_LPAREN_e_RPAREN__BS': 1000.0000000000001,
#  'EX_trp_DASH_L_LPAREN_e_RPAREN__BS': 0.11426105985038042,
#  'EX_tyr_DASH_L_LPAREN_e_RPAREN__BS': 38.120346092583794,
#  'EX_val_DASH_L_LPAREN_e_RPAREN__BS': 1.6067961541461018,
#  'EX_photonVis_LPAREN_e_RPAREN__BS': 999.9999999999999}

# %%
flux_samples = reup_twocell.flux_samples

for item in flux_samples:
    print(item, flux_samples[item])


#I'm running the experiment naively here so ayun
# Out:
# /home/rtsantos3/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Straw_Biomass_M 0      65.500671
# 1      66.652948
# 2      66.652948
# 3      66.652948
# 4      66.652948
#          ...
# 495    63.795305
# 496    63.488888
# 497    63.488888
# 498    67.121785
# 499    65.521771
# Name: Straw_Biomass_M, Length: 500, dtype: float64
# ACCOAC_OSAr_M 0      6.613079
# 1      6.729415
# 2      6.729415
# 3      6.729415
# 4      6.729415
#          ...
# 495    6.440902
# 496    6.409965
# 497    6.409965
# 498    6.776750
# 499    6.615209
# Name: ACCOAC_OSAr_M, Length: 500, dtype: float64
# FAC_Osr_M 0     -0.186677
# 1     -0.189961
# 2     -0.189961
# 3     -0.189961
# 4     -0.189961
#          ...
# 495   -0.181817
# 496   -0.180943
# 497   -0.180943
# 498   -0.191297
# 499   -0.186737
# Name: FAC_Osr_M, Length: 500, dtype: float64
# EX_h2o_LPAREN_e_RPAREN__M 0      1000.000000
# 1       784.699434
# 2       817.997615
# 3       817.997615
# 4       832.808493
#           ...
# 495     866.284005
# 496     920.740183
# 497     920.740183
# 498     982.541894
# 499     841.586134
# Name: EX_h2o_LPAREN_e_RPAREN__M, Length: 500, dtype: float64
# EX_o2_LPAREN_e_RPAREN__M 0     -945.286805
# 1     -945.286805
# 2     -945.286805
# 3     -945.286805
# 4     -945.286805
#           ...
# 495   -409.938065
# 496   -499.521446
# 497   -499.521446
# 498   -496.579295
# 499   -564.644583
# Name: EX_o2_LPAREN_e_RPAREN__M, Length: 500, dtype: float64
# EX_pi_LPAREN_e_RPAREN__M 0     -13.800968
# 1     -14.017850
# 2     -13.970498
# 3     -13.970498
# 4     -13.759611
#          ...
# 495   -13.101757
# 496   -13.101757
# 497   -13.101757
# 498   -13.101757
# 499   -13.101757
# Name: EX_pi_LPAREN_e_RPAREN__M, Length: 500, dtype: float64
# EX_sucr_LPAREN_e_RPAREN__M 0     -579.764961
# 1     -579.764961
# 2     -477.009213
# 3     -579.764961
# 4     -579.764961
#           ...
# 495   -397.684096
# 496   -411.474241
# 497   -411.474241
# 498   -424.582038
# 499   -408.078163
# Name: EX_sucr_LPAREN_e_RPAREN__M, Length: 500, dtype: float64
# EX_so4_LPAREN_e_RPAREN__M 0      701.571338
# 1      701.571338
# 2      701.571338
# 3      363.913387
# 4      701.571338
#           ...
# 495     64.599308
# 496    701.571338
# 497    112.243283
# 498    105.293196
# 499    151.234331
# Name: EX_so4_LPAREN_e_RPAREN__M, Length: 500, dtype: float64
# EX_gln_DASH_L_LPAREN_e_RPAREN__M 0     -0.521642
# 1     -0.529839
# 2     -0.528050
# 3     -0.528050
# 4     -0.520079
#          ...
# 495   -0.495213
# 496   -0.495213
# 497   -0.495213
# 498   -0.495213
# 499   -0.495213
# Name: EX_gln_DASH_L_LPAREN_e_RPAREN__M, Length: 500, dtype: float64
# EX_etoh_LPAREN_e_RPAREN__M 0      1000.000000
# 1      1000.000000
# 2      1000.000000
# 3      1000.000000
# 4       812.280431
#           ...
# 495     740.033732
# 496     679.763972
# 497     679.763972
# 498     768.362971
# 499     786.961025
# Name: EX_etoh_LPAREN_e_RPAREN__M, Length: 500, dtype: float64
# EX_ac_LPAREN_e_RPAREN__M 0      591.033480
# 1      598.209827
# 2      598.249909
# 3      598.249909
# 4      590.085565
#           ...
# 495    632.700807
# 496    553.216757
# 497    553.216757
# 498    576.884714
# 499    582.090206
# Name: EX_ac_LPAREN_e_RPAREN__M, Length: 500, dtype: float64
# EX_lac_DASH_L_LPAREN_e_RPAREN__M 0       956.768230
# 1       973.599542
# 2       973.599542
# 3       973.599542
# 4       973.599542
#           ...
# 495     931.857952
# 496    1000.000000
# 497    1000.000000
# 498    1000.000000
# 499     957.076440
# Name: EX_lac_DASH_L_LPAREN_e_RPAREN__M, Length: 500, dtype: float64
# EX_ala_DASH_L_LPAREN_e_RPAREN__M 0      891.668006
# 1      876.894976
# 2      827.101696
# 3      827.101696
# 4      790.971199
#           ...
# 495    790.629724
# 496    740.269251
# 497    740.269251
# 498    731.492181
# 499    778.237963
# Name: EX_ala_DASH_L_LPAREN_e_RPAREN__M, Length: 500, dtype: float64
# EX_arg_DASH_L_LPAREN_e_RPAREN__M 0     -0.822589
# 1     -0.835516
# 2     -0.832693
# 3     -0.832693
# 4     -0.820124
#          ...
# 495   -0.780913
# 496   -0.780913
# 497   -0.780913
# 498   -0.780913
# 499   -0.780913
# Name: EX_arg_DASH_L_LPAREN_e_RPAREN__M, Length: 500, dtype: float64
# EX_asp_DASH_L_LPAREN_e_RPAREN__M 0       996.084604
# 1       996.084604
# 2       996.084604
# 3       996.084604
# 4       996.084604
#           ...
# 495    1000.000000
# 496    1000.000000
# 497    1000.000000
# 498    1000.000000
# 499    1000.000000
# Name: EX_asp_DASH_L_LPAREN_e_RPAREN__M, Length: 500, dtype: float64
# EX_cys_DASH_L_LPAREN_e_RPAREN__M 0     -701.780851
# 1     -701.780851
# 2     -701.780851
# 3     -701.780851
# 4     -701.780851
#           ...
# 495   -701.780851
# 496   -112.452796
# 497   -701.780851
# 498   -105.514698
# 499   -151.450553
# Name: EX_cys_DASH_L_LPAREN_e_RPAREN__M, Length: 500, dtype: float64
# EX_glu_DASH_L_LPAREN_e_RPAREN__M 0     -717.992224
# 1     -726.729004
# 2     -726.644468
# 3     -726.644468
# 4     -717.925123
#           ...
# 495   -756.831325
# 496   -676.607503
# 497   -676.607503
# 498   -705.368646
# 499   -708.330978
# Name: EX_glu_DASH_L_LPAREN_e_RPAREN__M, Length: 500, dtype: float64
# EX_gly_LPAREN_e_RPAREN__M 0      1000.000000
# 1      1000.000000
# 2      1000.000000
# 3      1000.000000
# 4      1000.000000
#           ...
# 495     899.396310
# 496     838.055596
# 497     838.055596
# 498     931.674895
# 499     948.061890
# Name: EX_gly_LPAREN_e_RPAREN__M, Length: 500, dtype: float64
# EX_his_DASH_L_LPAREN_e_RPAREN__M 0     -3.811997
# 1     -3.871903
# 2     -3.858824
# 3     -3.858824
# 4     -3.800574
#          ...
# 495   -3.618867
# 496   -3.618867
# 497   -3.618867
# 498   -3.618867
# 499   -3.618867
# Name: EX_his_DASH_L_LPAREN_e_RPAREN__M, Length: 500, dtype: float64
# EX_ile_DASH_L_LPAREN_e_RPAREN__M 0     -0.936280
# 1     -0.950994
# 2     -0.947781
# 3     -0.947781
# 4     -0.933474
#          ...
# 495   -0.888844
# 496   -0.888844
# 497   -0.888844
# 498   -0.888844
# 499   -0.888844
# Name: EX_ile_DASH_L_LPAREN_e_RPAREN__M, Length: 500, dtype: float64
# EX_leu_DASH_L_LPAREN_e_RPAREN__M 0     -1.564925
# 1     -1.589518
# 2     -1.584149
# 3     -1.584149
# 4     -1.560236
#          ...
# 495   -1.485640
# 496   -1.485640
# 497   -1.485640
# 498   -1.485640
# 499   -1.485640
# Name: EX_leu_DASH_L_LPAREN_e_RPAREN__M, Length: 500, dtype: float64
# EX_lys_DASH_L_LPAREN_e_RPAREN__M 0     -1.023220
# 1     -1.039300
# 2     -1.035789
# 3     -1.035789
# 4     -1.020154
#          ...
# 495   -0.971380
# 496   -0.971380
# 497   -0.971380
# 498   -0.971380
# 499   -0.971380
# Name: EX_lys_DASH_L_LPAREN_e_RPAREN__M, Length: 500, dtype: float64
# EX_met_DASH_L_LPAREN_e_RPAREN__M 0     -0.508266
# 1     -0.516254
# 2     -0.514510
# 3     -0.514510
# 4     -0.506743
#          ...
# 495   -0.482516
# 496   -0.482516
# 497   -0.482516
# 498   -0.482516
# 499   -0.482516
# Name: EX_met_DASH_L_LPAREN_e_RPAREN__M, Length: 500, dtype: float64
# EX_phe_DASH_L_LPAREN_e_RPAREN__M 0     -0.889466
# 1     -0.903444
# 2     -0.900392
# 3     -0.900392
# 4     -0.886801
#          ...
# 495   -0.844402
# 496   -0.844402
# 497   -0.844402
# 498   -0.844402
# 499   -0.844402
# Name: EX_phe_DASH_L_LPAREN_e_RPAREN__M, Length: 500, dtype: float64
# EX_pro_DASH_L_LPAREN_e_RPAREN__M 0     -1.775719
# 1     -1.802729
# 2     -1.796832
# 3     -1.796832
# 4     -1.770568
#          ...
# 495   -1.574524
# 496   -1.574524
# 497   -1.574524
# 498   -1.574524
# 499   -1.574524
# Name: EX_pro_DASH_L_LPAREN_e_RPAREN__M, Length: 500, dtype: float64
# EX_ser_DASH_L_LPAREN_e_RPAREN__M 0     -620.461857
# 1     -628.220900
# 2     -628.273018
# 3     -628.273018
# 4     -620.162275
#           ...
# 495   -661.316899
# 496   -581.709267
# 497   -581.709267
# 498   -607.197596
# 499   -611.601353
# Name: EX_ser_DASH_L_LPAREN_e_RPAREN__M, Length: 500, dtype: float64
# EX_thr_DASH_L_LPAREN_e_RPAREN__M 0     -1000.000000
# 1     -1000.000000
# 2     -1000.000000
# 3     -1000.000000
# 4     -1000.000000
#           ...
# 495    -766.058779
# 496    -705.550524
# 497    -705.550524
# 498    -794.219274
# 499    -812.786608
# Name: EX_thr_DASH_L_LPAREN_e_RPAREN__M, Length: 500, dtype: float64
# EX_trp_DASH_L_LPAREN_e_RPAREN__M 0     -0.107003
# 1     -0.108685
# 2     -0.108318
# 3     -0.108318
# 4     -0.106683
#          ...
# 495   -0.101582
# 496   -0.101582
# 497   -0.101582
# 498   -0.101582
# 499   -0.101582
# Name: EX_trp_DASH_L_LPAREN_e_RPAREN__M, Length: 500, dtype: float64
# EX_tyr_DASH_L_LPAREN_e_RPAREN__M 0     -35.699020
# 1     -36.260030
# 2     -36.137544
# 3     -36.137544
# 4     -35.592040
#          ...
# 495   -34.358813
# 496   -33.890368
# 497   -33.890368
# 498   -35.829609
# 499   -34.975521
# Name: EX_tyr_DASH_L_LPAREN_e_RPAREN__M, Length: 500, dtype: float64
# EX_val_DASH_L_LPAREN_e_RPAREN__M 0     -1.504736
# 1     -1.528383
# 2     -1.523220
# 3     -1.523220
# 4     -1.500226
#          ...
# 495   -1.428500
# 496   -1.428500
# 497   -1.428500
# 498   -1.428500
# 499   -1.428500
# Name: EX_val_DASH_L_LPAREN_e_RPAREN__M, Length: 500, dtype: float64
# EX_photonVis_LPAREN_e_RPAREN__M 0     -1000.000000
# 1     -1000.000000
# 2     -1000.000000
# 3     -1000.000000
# 4     -1000.000000
#           ...
# 495    -110.855065
# 496      -0.371421
# 497      -0.371421
# 498    -113.322799
# 499    -124.620951
# Name: EX_photonVis_LPAREN_e_RPAREN__M, Length: 500, dtype: float64
# PRISM_blue_LED_M 0      675.811156
# 1      687.699917
# 2      687.699917
# 3      687.699917
# 4      687.699917
#           ...
# 495    658.215835
# 496    551.779330
# 497    551.779330
# 498    664.730707
# 499    676.028860
# Name: PRISM_blue_LED_M, Length: 500, dtype: float64
# RPSI_410_LPAREN_u_RPAREN__M 0      0.627855
# 1      0.638900
# 2      0.638900
# 3      0.638900
# 4      0.638900
#          ...
# 495    0.611508
# 496    0.512624
# 497    0.512624
# 498    0.617561
# 499    0.628057
# Name: RPSI_410_LPAREN_u_RPAREN__M, Length: 500, dtype: float64
# RPSI_430_LPAREN_u_RPAREN__M 0      250.399641
# 1      254.804631
# 2      254.804631
# 3      254.804631
# 4      254.804631
#           ...
# 495    243.880273
# 496    204.443719
# 497    204.443719
# 498    246.294144
# 499    250.480304
# Name: RPSI_430_LPAREN_u_RPAREN__M, Length: 500, dtype: float64
# RPSI_450_LPAREN_u_RPAREN__M 0      151.712435
# 1      154.381336
# 2      154.381336
# 3      154.381336
# 4      154.381336
#           ...
# 495    147.762472
# 496    130.384121
# 497    130.384121
# 498    150.979275
# 499    151.761307
# Name: RPSI_450_LPAREN_u_RPAREN__M, Length: 500, dtype: float64
# RPSII_450_LPAREN_u_RPAREN__M 0      199.980642
# 1      203.498670
# 2      203.498670
# 3      203.498670
# 4      203.498670
#           ...
# 495    194.773975
# 496    156.762619
# 497    156.762619
# 498    194.947521
# 499    200.045063
# Name: RPSII_450_LPAREN_u_RPAREN__M, Length: 500, dtype: float64
# RPSII_470_LPAREN_u_RPAREN__M 0      63.770601
# 1      64.892443
# 2      64.892443
# 3      64.892443
# 4      64.892443
#          ...
# 495    62.110279
# 496    52.066763
# 497    52.066763
# 498    62.725032
# 499    63.791144
# Name: RPSII_470_LPAREN_u_RPAREN__M, Length: 500, dtype: float64
# RPSII_490_LPAREN_u_RPAREN__M 0      3.094523
# 1      3.148961
# 2      3.148961
# 3      3.148961
# 4      3.148961
#          ...
# 495    3.013954
# 496    2.526584
# 497    2.526584
# 498    3.043786
# 499    3.095520
# Name: RPSII_490_LPAREN_u_RPAREN__M, Length: 500, dtype: float64
# H2Otex_M 0     -1000.000000
# 1     -1000.000000
# 2     -1000.000000
# 3     -1000.000000
# 4     -1000.000000
#           ...
# 495    -866.284005
# 496   -1000.000000
# 497   -1000.000000
# 498   -1000.000000
# 499   -1000.000000
# Name: H2Otex_M, Length: 500, dtype: float64
# O2tex_M 0      739.572492
# 1      757.435853
# 2      757.435853
# 3      757.435853
# 4      757.435853
#           ...
# 495    662.001307
# 496    704.941418
# 497    704.941418
# 498    763.777035
# 499    739.899601
# Name: O2tex_M, Length: 500, dtype: float64
# Pitex_M 0      13.516915
# 1      13.754702
# 2      13.754702
# 3      13.754702
# 4      13.754702
#          ...
# 495    13.164990
# 496    13.101757
# 497    13.101757
# 498    13.851453
# 499    13.521269
# Name: Pitex_M, Length: 500, dtype: float64
# SUCRtex_M 0      475.523952
# 1      483.889292
# 2      483.889292
# 3      483.889292
# 4      483.889292
#           ...
# 495    463.143279
# 496    479.073213
# 497    479.073213
# 498    492.181011
# 499    475.677135
# Name: SUCRtex_M, Length: 500, dtype: float64
# SO4tex_M 0     -379.376292
# 1     -388.476679
# 2     -388.476679
# 3     -388.476679
# 4     -388.476679
#           ...
# 495   -340.341015
# 496   -357.227590
# 497   -357.227590
# 498   -390.493904
# 499   -379.542936
# Name: SO4tex_M, Length: 500, dtype: float64
# GLNtex_M 0      0.510905
# 1      0.519893
# 2      0.519893
# 3      0.519893
# 4      0.519893
#          ...
# 495    0.497603
# 496    0.495213
# 497    0.495213
# 498    0.523550
# 499    0.511070
# Name: GLNtex_M, Length: 500, dtype: float64
# ETOHtex_M 0      915.881085
# 1      939.272499
# 2      939.272499
# 3      939.272499
# 4      939.272499
#           ...
# 495    902.738542
# 496    838.106611
# 497    838.106611
# 498    938.845342
# 499    916.309422
# Name: ETOHtex_M, Length: 500, dtype: float64
# ACtex_M 0      289.557666
# 1      297.077978
# 2      297.077978
# 3      297.077978
# 4      297.077978
#           ...
# 495    351.037771
# 496    270.167646
# 497    270.167646
# 498    298.452304
# 499    289.695376
# Name: ACtex_M, Length: 500, dtype: float64
# LACtex_M 0       956.768230
# 1       973.599542
# 2       973.599542
# 3       973.599542
# 4       973.599542
#           ...
# 495     931.857952
# 496    1000.000000
# 497    1000.000000
# 498    1000.000000
# 499     957.076440
# Name: LACtex_M, Length: 500, dtype: float64
# ALAtex_M 0     -346.436005
# 1     -354.956912
# 2     -354.956912
# 3     -354.956912
# 4     -354.956912
#           ...
# 495   -406.435234
# 496   -325.299028
# 497   -325.299028
# 498   -356.738358
# 499   -346.592037
# Name: ALAtex_M, Length: 500, dtype: float64
# ARGtex_M 0      0.805658
# 1      0.819831
# 2      0.819831
# 3      0.819831
# 4      0.819831
#          ...
# 495    0.784682
# 496    0.780913
# 497    0.780913
# 498    0.825598
# 499    0.805918
# Name: ARGtex_M, Length: 500, dtype: float64
# ASPtex_M 0     -665.279020
# 1     -681.835423
# 2     -681.835423
# 3     -681.835423
# 4     -681.835423
#           ...
# 495   -687.819008
# 496   -623.852556
# 497   -623.852556
# 498   -685.200812
# 499   -665.582196
# Name: ASPtex_M, Length: 500, dtype: float64
# CYStex_M 0      379.592444
# 1      388.696634
# 2      388.696634
# 3      388.696634
# 4      388.696634
#           ...
# 495    340.551539
# 496    357.437103
# 497    357.437103
# 498    390.715406
# 499    379.759158
# Name: CYStex_M, Length: 500, dtype: float64
# GLUtex_M 0      350.549447
# 1      359.142717
# 2      359.142717
# 3      359.142717
# 4      359.142717
#           ...
# 495    410.441579
# 496    329.286130
# 497    329.286130
# 498    360.953606
# 499    350.706804
# Name: GLUtex_M, Length: 500, dtype: float64
# GLYtex_M 0      -975.558746
# 1     -1000.000000
# 2     -1000.000000
# 3     -1000.000000
# 4     -1000.000000
#           ...
# 495    -960.862444
# 496    -895.951337
# 497    -895.951337
# 498   -1000.000000
# 499    -976.006307
# Name: GLYtex_M, Length: 500, dtype: float64
# HIStex_M 0      3.733538
# 1      3.799218
# 2      3.799218
# 3      3.799218
# 4      3.799218
#          ...
# 495    3.636332
# 496    3.618867
# 497    3.618867
# 498    3.825942
# 499    3.734741
# Name: HIStex_M, Length: 500, dtype: float64
# ILEtex_M 0      0.917009
# 1      0.933141
# 2      0.933141
# 3      0.933141
# 4      0.933141
#          ...
# 495    0.893134
# 496    0.888844
# 497    0.888844
# 498    0.939705
# 499    0.917305
# Name: ILEtex_M, Length: 500, dtype: float64
# LEUtex_M 0      1.532716
# 1      1.559679
# 2      1.559679
# 3      1.559679
# 4      1.559679
#          ...
# 495    1.492810
# 496    1.485640
# 497    1.485640
# 498    1.570650
# 499    1.533209
# Name: LEUtex_M, Length: 500, dtype: float64
# LYStex_M 0      1.002160
# 1      1.019790
# 2      1.019790
# 3      1.019790
# 4      1.019790
#          ...
# 495    0.976068
# 496    0.971380
# 497    0.971380
# 498    1.026963
# 499    1.002483
# Name: LYStex_M, Length: 500, dtype: float64
# METtex_M 0      0.497805
# 1      0.506562
# 2      0.506562
# 3      0.506562
# 4      0.506562
#          ...
# 495    0.484844
# 496    0.482516
# 497    0.482516
# 498    0.510126
# 499    0.497965
# Name: METtex_M, Length: 500, dtype: float64
# PHEtex_M 0      0.871159
# 1      0.886484
# 2      0.886484
# 3      0.886484
# 4      0.886484
#          ...
# 495    0.848478
# 496    0.844402
# 497    0.844402
# 498    0.892720
# 499    0.871440
# Name: PHEtex_M, Length: 500, dtype: float64
# PROtex_M 0      1.683367
# 1      1.712981
# 2      1.712981
# 3      1.712981
# 4      1.712981
#          ...
# 495    1.639539
# 496    1.631664
# 497    1.631664
# 498    1.725030
# 499    1.683910
# Name: PROtex_M, Length: 500, dtype: float64
# SERtex_M 0      322.378742
# 1      330.476437
# 2      330.476437
# 3      330.476437
# 4      330.476437
#           ...
# 495    383.004322
# 496    301.980658
# 497    301.980658
# 498    332.085688
# 499    322.527024
# Name: SERtex_M, Length: 500, dtype: float64
# THRtex_M 0      917.138698
# 1      940.552236
# 2      940.552236
# 3      940.552236
# 4      940.552236
#           ...
# 495    903.963412
# 496    839.325598
# 497    839.325598
# 498    940.134080
# 499    917.567440
# Name: THRtex_M, Length: 500, dtype: float64
# TRPtex_M 0      0.104801
# 1      0.106645
# 2      0.106645
# 3      0.106645
# 4      0.106645
#          ...
# 495    0.102072
# 496    0.101582
# 497    0.101582
# 498    0.107395
# 499    0.104835
# Name: TRPtex_M, Length: 500, dtype: float64
# TYRtex_M 0      34.964258
# 1      35.579344
# 2      35.579344
# 3      35.579344
# 4      35.579344
#          ...
# 495    34.053934
# 496    33.890368
# 497    33.890368
# 498    35.829609
# 499    34.975521
# Name: TYRtex_M, Length: 500, dtype: float64
# VALtex_M 0      1.473765
# 1      1.499691
# 2      1.499691
# 3      1.499691
# 4      1.499691
#          ...
# 495    1.435394
# 496    1.428500
# 497    1.428500
# 498    1.510240
# 499    1.474240
# Name: VALtex_M, Length: 500, dtype: float64
# PPASs_M 0      85.124671
# 1      86.622171
# 2      86.622171
# 3      86.622171
# 4      86.622171
#          ...
# 495    82.908378
# 496    82.510158
# 497    82.510158
# 498    87.231472
# 499    85.152093
# Name: PPASs_M, Length: 500, dtype: float64
# CATv_M 0      189.688146
# 1      194.238340
# 2      194.238340
# 3      194.238340
# 4      194.238340
#           ...
# 495    170.170507
# 496     35.763896
# 497     35.763896
# 498     87.262108
# 499     70.594071
# Name: CATv_M, Length: 500, dtype: float64
# CATm_M 0        0.000000
# 1        0.000000
# 2        0.000000
# 3        0.000000
# 4        0.000000
#           ...
# 495      0.000000
# 496    142.849899
# 497    142.849899
# 498    107.984844
# 499    119.177397
# Name: CATm_M, Length: 500, dtype: float64
# CYOO6m_M 0      183.151834
# 1      187.587042
# 2      187.587042
# 3      187.587042
# 4      187.587042
#           ...
# 495    163.804374
# 496    172.278239
# 497    172.278239
# 498    188.548869
# 499    183.233050
# Name: CYOO6m_M, Length: 500, dtype: float64
# ATPSs_M 0      195.753061
# 1      199.196718
# 2      199.196718
# 3      199.196718
# 4      199.196718
#           ...
# 495    190.656463
# 496    162.509011
# 497    162.509011
# 498    193.265811
# 499    195.816121
# Name: ATPSs_M, Length: 500, dtype: float64
# ATPSm_M 0      804.070617
# 1      823.675234
# 2      823.675234
# 3      823.675234
# 4      823.675234
#           ...
# 495    742.074916
# 496    755.757177
# 497    755.757177
# 498    827.859495
# 499    804.429612
# Name: ATPSm_M, Length: 500, dtype: float64
# ADK1c_M 0      117.093447
# 1      129.465793
# 2      129.465793
# 3      129.465793
# 4      129.465793
#           ...
# 495    211.021756
# 496    114.272817
# 497    114.272817
# 498    139.556431
# 499    117.320006
# Name: ADK1c_M, Length: 500, dtype: float64
# ATPAPc_M 0       75.962176
# 1       87.610948
# 2       87.610948
# 3       87.610948
# 4       87.610948
#           ...
# 495    170.961373
# 496     74.404849
# 497     74.404849
# 498     97.407178
# 499     76.175485
# Name: ATPAPc_M, Length: 500, dtype: float64
# TMDSc_M 0      0.058951
# 1      0.059988
# 2      0.059988
# 3      0.059988
# 4      0.059988
#          ...
# 495    0.057416
# 496    0.057140
# 497    0.057140
# 498    0.060410
# 499    0.058970
# Name: TMDSc_M, Length: 500, dtype: float64
# CTPRc_M 0      0.045850
# 1      0.046657
# 2      0.046657
# 3      0.046657
# 4      0.046657
#          ...
# 495    0.044657
# 496    0.044442
# 497    0.044442
# 498    0.046985
# 499    0.045865
# Name: CTPRc_M, Length: 500, dtype: float64
# UTPRc_M 0      0.058951
# 1      0.059988
# 2      0.059988
# 3      0.059988
# 4      0.059988
#          ...
# 495    0.057416
# 496    0.057140
# 497    0.057140
# 498    0.060410
# 499    0.058970
# Name: UTPRc_M, Length: 500, dtype: float64
# ATPRc_M 0      0.058951
# 1      0.059988
# 2      0.059988
# 3      0.059988
# 4      0.059988
#          ...
# 495    0.057416
# 496    0.057140
# 497    0.057140
# 498    0.060410
# 499    0.058970
# Name: ATPRc_M, Length: 500, dtype: float64
# GTPRc_M 0      0.045850
# 1      0.046657
# 2      0.046657
# 3      0.046657
# 4      0.046657
#          ...
# 495    0.044657
# 496    0.044442
# 497    0.044442
# 498    0.046985
# 499    0.045865
# Name: GTPRc_M, Length: 500, dtype: float64
# UPRTs_M 0      1.703017
# 1      1.732977
# 2      1.732977
# 3      1.732977
# 4      1.732977
#          ...
# 495    1.658678
# 496    1.650711
# 497    1.650711
# 498    1.745166
# 499    1.703566
# Name: UPRTs_M, Length: 500, dtype: float64
# UPHs_M 0     -1.703017
# 1     -1.732977
# 2     -1.732977
# 3     -1.732977
# 4     -1.732977
#          ...
# 495   -1.658678
# 496   -1.650711
# 497   -1.650711
# 498   -1.745166
# 499   -1.703566
# Name: UPHs_M, Length: 500, dtype: float64
# AUPTs_M 0      1.703017
# 1      1.732977
# 2      1.732977
# 3      1.732977
# 4      1.732977
#          ...
# 495    1.658678
# 496    1.650711
# 497    1.650711
# 498    1.745166
# 499    1.703566
# Name: AUPTs_M, Length: 500, dtype: float64
# CTPSc_M 0      0.510905
# 1      0.519893
# 2      0.519893
# 3      0.519893
# 4      0.519893
#          ...
# 495    0.497603
# 496    0.495213
# 497    0.495213
# 498    0.523550
# 499    0.511070
# Name: CTPSc_M, Length: 500, dtype: float64
# DUTNHc_M 0      0.058951
# 1      0.059988
# 2      0.059988
# 3      0.059988
# 4      0.059988
#          ...
# 495    0.057416
# 496    0.057140
# 497    0.057140
# 498    0.060410
# 499    0.058970
# Name: DUTNHc_M, Length: 500, dtype: float64
# ATDTDc_M 0      0.058951
# 1      0.059988
# 2      0.059988
# 3      0.059988
# 4      0.059988
#          ...
# 495    0.057416
# 496    0.057140
# 497    0.057140
# 498    0.060410
# 499    0.058970
# Name: ATDTDc_M, Length: 500, dtype: float64
# DTMPKc_M 0      0.058951
# 1      0.059988
# 2      0.059988
# 3      0.059988
# 4      0.059988
#          ...
# 495    0.057416
# 496    0.057140
# 497    0.057140
# 498    0.060410
# 499    0.058970
# Name: DTMPKc_M, Length: 500, dtype: float64
# ATCDs_M 0      8.369152
# 1      8.516380
# 2      8.516380
# 3      8.516380
# 4      8.516380
#          ...
# 495    8.151254
# 496    8.112102
# 497    8.112102
# 498    8.576285
# 499    8.371848
# Name: ATCDs_M, Length: 500, dtype: float64
# CMPKc_M 0      8.369152
# 1      8.516380
# 2      8.516380
# 3      8.516380
# 4      8.516380
#          ...
# 495    8.151254
# 496    8.112102
# 497    8.112102
# 498    8.576285
# 499    8.371848
# Name: CMPKc_M, Length: 500, dtype: float64
# ATUDs_M 0      1.159362
# 1      1.179757
# 2      1.179757
# 3      1.179757
# 4      1.179757
#          ...
# 495    1.129177
# 496    1.123753
# 497    1.123753
# 498    1.188056
# 499    1.159735
# Name: ATUDs_M, Length: 500, dtype: float64
# UMPKc_M 0      1.133162
# 1      1.153096
# 2      1.153096
# 3      1.153096
# 4      1.153096
#          ...
# 495    1.103659
# 496    1.098358
# 497    1.098358
# 498    1.161207
# 499    1.133527
# Name: UMPKc_M, Length: 500, dtype: float64
# AMPDc_M 0      0.510905
# 1      0.519893
# 2      0.519893
# 3      0.519893
# 4      0.519893
#          ...
# 495    0.497603
# 496    0.495213
# 497    0.495213
# 498    0.523550
# 499    0.511070
# Name: AMPDc_M, Length: 500, dtype: float64
# PYKc_M 0       925.930514
# 1       942.219335
# 2       942.219335
# 3       942.219335
# 4       942.219335
#           ...
# 495    1000.000000
# 496     970.109432
# 497     970.109432
# 498     968.399064
# 499     926.228790
# Name: PYKc_M, Length: 500, dtype: float64
# GDHym_M 0     -1.139712
# 1     -1.159761
# 2     -1.159761
# 3     -1.159761
# 4     -1.159761
#          ...
# 495   -1.110038
# 496   -1.104707
# 497   -1.104707
# 498   -1.167919
# 499   -1.140079
# Name: GDHym_M, Length: 500, dtype: float64
# PYR5CDm_M 0      0.209602
# 1      0.213289
# 2      0.213289
# 3      0.213289
# 4      0.213289
#          ...
# 495    0.204145
# 496    0.203164
# 497    0.203164
# 498    0.214790
# 499    0.209670
# Name: PYR5CDm_M, Length: 500, dtype: float64
# GALs_M 0      1.139712
# 1      1.159761
# 2      1.159761
# 3      1.159761
# 4      1.159761
#          ...
# 495    1.110038
# 496    1.104707
# 497    1.104707
# 498    1.167919
# 499    1.140079
# Name: GALs_M, Length: 500, dtype: float64
# ALAATc_M 0     -348.538576
# 1     -357.096471
# 2     -357.096471
# 3     -357.096471
# 4     -357.096471
#           ...
# 495   -408.483063
# 496   -327.337021
# 497   -327.337021
# 498   -358.892967
# 499   -348.695286
# Name: ALAATc_M, Length: 500, dtype: float64
# ICDHc_M 0     -349.887890
# 1     -358.469522
# 2     -358.469522
# 3     -358.469522
# 4     -358.469522
#           ...
# 495   -409.797246
# 496   -328.644893
# 497   -328.644893
# 498   -360.275676
# 499   -350.045034
# Name: ICDHc_M, Length: 500, dtype: float64
# ICDHm_M 0      1.139712
# 1      1.159761
# 2      1.159761
# 3      1.159761
# 4      1.159761
#          ...
# 495    1.110038
# 496    1.104707
# 497    1.104707
# 498    1.167919
# 499    1.140079
# Name: ICDHm_M, Length: 500, dtype: float64
# UPGCDc_M 0      78.659755
# 1      80.043525
# 2      80.043525
# 3      80.043525
# 4      80.043525
#          ...
# 495    76.611781
# 496    76.243805
# 497    76.243805
# 498    80.606552
# 499    78.685095
# Name: UPGCDc_M, Length: 500, dtype: float64
# UDPG4Ec_M 0      1.499965
# 1      1.526353
# 2      1.526353
# 3      1.526353
# 4      1.526353
#          ...
# 495    1.460912
# 496    1.453896
# 497    1.453896
# 498    1.537089
# 499    1.500449
# Name: UDPG4Ec_M, Length: 500, dtype: float64
# ATGDc_M 0      0.510905
# 1      0.519893
# 2      0.519893
# 3      0.519893
# 4      0.519893
#          ...
# 495    0.497603
# 496    0.495213
# 497    0.495213
# 498    0.523550
# 499    0.511070
# Name: ATGDc_M, Length: 500, dtype: float64
# ATGDs_M 0      0.569856
# 1      0.579881
# 2      0.579881
# 3      0.579881
# 4      0.579881
#          ...
# 495    0.555019
# 496    0.552353
# 497    0.552353
# 498    0.583960
# 499    0.570039
# Name: ATGDs_M, Length: 500, dtype: float64
# MDHys_M 0      2.279423
# 1      2.319523
# 2      2.319523
# 3      2.319523
# 4      2.319523
#          ...
# 495    2.220077
# 496    2.209413
# 497    2.209413
# 498    2.335838
# 499    2.280158
# Name: MDHys_M, Length: 500, dtype: float64
# MDHs_M 0     -1.139712
# 1     -1.159761
# 2     -1.159761
# 3     -1.159761
# 4     -1.159761
#          ...
# 495   -1.110038
# 496   -1.104707
# 497   -1.104707
# 498   -1.167919
# 499   -1.140079
# Name: MDHs_M, Length: 500, dtype: float64
# MDHm_M 0      30.837716
# 1      31.380208
# 2      31.380208
# 3      31.380208
# 4      31.380208
#          ...
# 495    30.034829
# 496    29.890568
# 497    29.890568
# 498    31.600936
# 499    30.847650
# Name: MDHm_M, Length: 500, dtype: float64
# PPCc_M 0     -3.908741e-13
# 1     -3.908741e-13
# 2     -3.908741e-13
# 3     -3.908741e-13
# 4     -3.908741e-13
#            ...
# 495   -9.817688e+01
# 496   -3.908741e-13
# 497   -3.908741e-13
# 498   -3.908741e-13
# 499   -3.908741e-13
# Name: PPCc_M, Length: 500, dtype: float64
# CSm_M 0     -348.748178
# 1     -357.309761
# 2     -357.309761
# 3     -357.309761
# 4     -357.309761
#           ...
# 495   -408.687208
# 496   -327.540186
# 497   -327.540186
# 498   -359.107757
# 499   -348.904956
# Name: CSm_M, Length: 500, dtype: float64
# ASPTAm_M 0     -379.585894
# 1     -388.689969
# 2     -388.689969
# 3     -388.689969
# 4     -388.689969
#           ...
# 495   -340.545160
# 496   -357.430754
# 497   -357.430754
# 498   -390.708693
# 499   -379.752605
# Name: ASPTAm_M, Length: 500, dtype: float64
# ASPTAs_M 0     -1.139712
# 1     -1.159761
# 2     -1.159761
# 3     -1.159761
# 4     -1.159761
#          ...
# 495   -1.110038
# 496   -1.104707
# 497   -1.104707
# 498   -1.167919
# 499   -1.140079
# Name: ASPTAs_M, Length: 500, dtype: float64
# FDHNc_M 0      334.332791
# 1      342.640780
# 2      342.640780
# 3      342.640780
# 4      342.640780
#           ...
# 495    296.470260
# 496    313.567551
# 497    313.567551
# 498    344.335595
# 499    334.484924
# Name: FDHNc_M, Length: 500, dtype: float64
# SULOm_M 0      379.376292
# 1      388.476679
# 2      388.476679
# 3      388.476679
# 4      388.476679
#           ...
# 495    340.341015
# 496    357.227590
# 497    357.227590
# 498    390.493904
# 499    379.542936
# Name: SULOm_M, Length: 500, dtype: float64
# SATc_M 0      289.557666
# 1      297.077978
# 2      297.077978
# 3      297.077978
# 4      297.077978
#           ...
# 495    351.037771
# 496    270.167646
# 497    270.167646
# 498    298.452304
# 499    289.695376
# Name: SATc_M, Length: 500, dtype: float64
# METSMTc_M 0      187.117245
# 1      251.677111
# 2      251.677111
# 3      251.677111
# 4      251.677111
#           ...
# 495    648.675484
# 496    224.957842
# 497    224.957842
# 498    318.482160
# 499    188.299448
# Name: METSMTc_M, Length: 500, dtype: float64
# HCYSMTc_M 0      437.971873
# 1      389.261396
# 2      389.261396
# 3      389.261396
# 4      389.261396
#           ...
# 495      0.000000
# 496    359.939203
# 497    359.939203
# 498    325.534067
# 499    437.079900
# Name: HCYSMTc_M, Length: 500, dtype: float64
# AMETAHYCSTc_M 0     -656.352589
# 1     -672.751959
# 2     -672.751959
# 3     -672.751959
# 4     -672.751959
#           ...
# 495   -679.124983
# 496   -615.200291
# 497   -615.200291
# 498   -676.053455
# 499   -656.652890
# Name: AMETAHYCSTc_M, Length: 500, dtype: float64
# HCYSMT2c_M 0      187.117245
# 1      251.677111
# 2      251.677111
# 3      251.677111
# 4      251.677111
#           ...
# 495    648.675484
# 496    224.957842
# 497    224.957842
# 498    318.482160
# 499    188.299448
# Name: HCYSMT2c_M, Length: 500, dtype: float64
# ENOc_M 0      925.930514
# 1      942.219335
# 2      942.219335
# 3      942.219335
# 4      942.219335
#           ...
# 495    901.823122
# 496    970.109432
# 497    970.109432
# 498    968.399064
# 499    926.228790
# Name: ENOc_M, Length: 500, dtype: float64
# LDH_Lc_M 0       956.768230
# 1       973.599542
# 2       973.599542
# 3       973.599542
# 4       973.599542
#           ...
# 495     931.857952
# 496    1000.000000
# 497    1000.000000
# 498    1000.000000
# 499     957.076440
# Name: LDH_Lc_M, Length: 500, dtype: float64
# GLYCORc_M 0      338.951784
# 1      334.602112
# 2      334.602112
# 3      334.602112
# 4      334.602112
#           ...
# 495    233.149948
# 496    345.919944
# 497    345.919944
# 498    332.663770
# 499    338.872134
# Name: GLYCORc_M, Length: 500, dtype: float64
# GLYDHDm_M 0     -31.047318
# 1     -31.593497
# 2     -31.593497
# 3     -31.593497
# 4     -31.593497
#          ...
# 495   -30.238974
# 496   -30.093733
# 497   -30.093733
# 498   -31.815726
# 499   -31.057319
# Name: GLYDHDm_M, Length: 500, dtype: float64
# DHLDHm_M 0     -31.047318
# 1     -31.593497
# 2     -31.593497
# 3     -31.593497
# 4     -31.593497
#          ...
# 495   -30.238974
# 496   -30.093733
# 497   -30.093733
# 498   -31.815726
# 499   -31.057319
# Name: DHLDHm_M, Length: 500, dtype: float64
# MTAMnh4m_M 0     -31.047318
# 1     -31.593497
# 2     -31.593497
# 3     -31.593497
# 4     -31.593497
#          ...
# 495   -30.238974
# 496   -30.093733
# 497   -30.093733
# 498   -31.815726
# 499   -31.057319
# Name: MTAMnh4m_M, Length: 500, dtype: float64
# THRAc_M 0      915.881085
# 1      939.272499
# 2      939.272499
# 3      939.272499
# 4      939.272499
#           ...
# 495    902.738542
# 496    838.106611
# 497    838.106611
# 498    938.845342
# 499    916.309422
# Name: THRAc_M, Length: 500, dtype: float64
# ALCDx1c_M 0      915.881085
# 1      939.272499
# 2      939.272499
# 3      939.272499
# 4      939.272499
#           ...
# 495    902.738542
# 496    838.106611
# 497    838.106611
# 498    938.845342
# 499    916.309422
# Name: ALCDx1c_M, Length: 500, dtype: float64
# PGI1s_M 0       1.135345
# 1       1.155318
# 2       1.155318
# 3       1.155318
# 4       1.155318
#          ...
# 495     1.105785
# 496    19.254944
# 497    19.254944
# 498     6.051482
# 499     1.135711
# Name: PGI1s_M, Length: 500, dtype: float64
# PGI2c_M 0     -0.026855
# 1     -0.027328
# 2     -0.027328
# 3     -0.027328
# 4     -0.027328
#          ...
# 495   -0.026156
# 496   -0.026030
# 497   -0.026030
# 498   -0.027520
# 499   -0.026864
# Name: PGI2c_M, Length: 500, dtype: float64
# INVc_M 0       89.836353
# 1       91.416740
# 2       91.416740
# 3       91.416740
# 4       91.416740
#           ...
# 495     87.497387
# 496    105.231596
# 497    105.231596
# 498     96.947804
# 499     89.865293
# Name: INVc_M, Length: 500, dtype: float64
# SUSc_M 0     -378.816578
# 1     -385.480659
# 2     -385.480659
# 3     -385.480659
# 4     -385.480659
#           ...
# 495   -368.953765
# 496   -367.181633
# 497   -367.181633
# 498   -388.192132
# 499   -378.938609
# Name: SUSc_M, Length: 500, dtype: float64
# MI3PSc_M 0      0.026855
# 1      0.027328
# 2      0.027328
# 3      0.027328
# 4      0.027328
#          ...
# 495    0.026156
# 496    0.026030
# 497    0.026030
# 498    0.027520
# 499    0.026864
# Name: MI3PSc_M, Length: 500, dtype: float64
# FKc_M 0      125.489454
# 1      138.009501
# 2      138.009501
# 3      138.009501
# 4      138.009501
#           ...
# 495    219.199166
# 496    122.410950
# 497    122.410950
# 498    148.160235
# 499    125.718717
# Name: FKc_M, Length: 500, dtype: float64
# AATCs_M 0      1.139712
# 1      1.159761
# 2      1.159761
# 3      1.159761
# 4      1.159761
#          ...
# 495    1.110038
# 496    1.104707
# 497    1.104707
# 498    1.167919
# 499    1.140079
# Name: AATCs_M, Length: 500, dtype: float64
# AATCm_M 0      378.236580
# 1      387.316918
# 2      387.316918
# 3      387.316918
# 4      387.316918
#           ...
# 495    339.230976
# 496    356.122883
# 497    356.122883
# 498    389.325985
# 499    378.402857
# Name: AATCm_M, Length: 500, dtype: float64
# 3SPYRSPs_M 0      1.139712
# 1      1.159761
# 2      1.159761
# 3      1.159761
# 4      1.159761
#          ...
# 495    1.110038
# 496    1.104707
# 497    1.104707
# 498    1.167919
# 499    1.140079
# Name: 3SPYRSPs_M, Length: 500, dtype: float64
# 3SPYRSPm_M 0      378.236580
# 1      387.316918
# 2      387.316918
# 3      387.316918
# 4      387.316918
#           ...
# 495    339.230976
# 496    356.122883
# 497    356.122883
# 498    389.325985
# 499    378.402857
# Name: 3SPYRSPm_M, Length: 500, dtype: float64
# LCYSTSs_M 0      1.139712
# 1      1.159761
# 2      1.159761
# 3      1.159761
# 4      1.159761
#          ...
# 495    1.110038
# 496    1.104707
# 497    1.104707
# 498    1.167919
# 499    1.140079
# Name: LCYSTSs_M, Length: 500, dtype: float64
# LCYSTSm_M 0      378.236580
# 1      387.316918
# 2      387.316918
# 3      387.316918
# 4      387.316918
#           ...
# 495    339.230976
# 496    356.122883
# 497    356.122883
# 498    389.325985
# 499    378.402857
# Name: LCYSTSm_M, Length: 500, dtype: float64
# CYSSc_M 0      289.557666
# 1      297.077978
# 2      297.077978
# 3      297.077978
# 4      297.077978
#           ...
# 495    351.037771
# 496    270.167646
# 497    270.167646
# 498    298.452304
# 499    289.695376
# Name: CYSSc_M, Length: 500, dtype: float64
# DHFRc_M 0      0.058951
# 1      0.059988
# 2      0.059988
# 3      0.059988
# 4      0.059988
#          ...
# 495    0.057416
# 496    0.057140
# 497    0.057140
# 498    0.060410
# 499    0.058970
# Name: DHFRc_M, Length: 500, dtype: float64
# FTHFLc_M 0     -623.890456
# 1     -639.718758
# 2     -639.718758
# 3     -639.718758
# 4     -639.718758
#           ...
# 495   -647.508031
# 496   -583.735198
# 497   -583.735198
# 498   -642.787898
# 499   -624.180300
# Name: FTHFLc_M, Length: 500, dtype: float64
# CALANc_M 0     -289.557666
# 1     -297.077978
# 2     -297.077978
# 3     -297.077978
# 4     -297.077978
#           ...
# 495   -351.037771
# 496   -270.167646
# 497   -270.167646
# 498   -298.452304
# 499   -289.695376
# Name: CALANc_M, Length: 500, dtype: float64
# CALASc_M 0      289.557666
# 1      297.077978
# 2      297.077978
# 3      297.077978
# 4      297.077978
#           ...
# 495    351.037771
# 496    270.167646
# 497    270.167646
# 498    298.452304
# 499    289.695376
# Name: CALASc_M, Length: 500, dtype: float64
# FORAc_M 0     -289.557666
# 1     -297.077978
# 2     -297.077978
# 3     -297.077978
# 4     -297.077978
#           ...
# 495   -351.037771
# 496   -270.167646
# 497   -270.167646
# 498   -298.452304
# 499   -289.695376
# Name: FORAc_M, Length: 500, dtype: float64
# FORMHLc_M 0      289.557666
# 1      297.077978
# 2      297.077978
# 3      297.077978
# 4      297.077978
#           ...
# 495    351.037771
# 496    270.167646
# 497    270.167646
# 498    298.452304
# 499    289.695376
# Name: FORMHLc_M, Length: 500, dtype: float64
# SHMTm_M 0     -31.047318
# 1     -31.593497
# 2     -31.593497
# 3     -31.593497
# 4     -31.593497
#          ...
# 495   -30.238974
# 496   -30.093733
# 497   -30.093733
# 498   -31.815726
# 499   -31.057319
# Name: SHMTm_M, Length: 500, dtype: float64
# MLTHFRc_M 0     -623.949407
# 1     -639.778746
# 2     -639.778746
# 3     -639.778746
# 4     -639.778746
#           ...
# 495   -647.565446
# 496   -583.792338
# 497   -583.792338
# 498   -642.848308
# 499   -624.239270
# Name: MLTHFRc_M, Length: 500, dtype: float64
# MLTHFRs_M 0     -1.139712
# 1     -1.159761
# 2     -1.159761
# 3     -1.159761
# 4     -1.159761
#          ...
# 495   -1.110038
# 496   -1.104707
# 497   -1.104707
# 498   -1.167919
# 499   -1.140079
# Name: MLTHFRs_M, Length: 500, dtype: float64
# METSc_M 0     -623.949407
# 1     -639.778746
# 2     -639.778746
# 3     -639.778746
# 4     -639.778746
#           ...
# 495   -647.565446
# 496   -583.792338
# 497   -583.792338
# 498   -642.848308
# 499   -624.239270
# Name: METSc_M, Length: 500, dtype: float64
# METSs_M 0     -1.139712
# 1     -1.159761
# 2     -1.159761
# 3     -1.159761
# 4     -1.159761
#          ...
# 495   -1.110038
# 496   -1.104707
# 497   -1.104707
# 498   -1.167919
# 499   -1.140079
# Name: METSs_M, Length: 500, dtype: float64
# GLPATs_M 0      85.124671
# 1      86.622171
# 2      86.622171
# 3      86.622171
# 4      86.622171
#          ...
# 495    82.908378
# 496    82.510158
# 497    82.510158
# 498    87.231472
# 499    85.152093
# Name: GLPATs_M, Length: 500, dtype: float64
# ORPDCs_M 0      1.133162
# 1      1.153096
# 2      1.153096
# 3      1.153096
# 4      1.153096
#          ...
# 495    1.103659
# 496    1.098358
# 497    1.098358
# 498    1.161207
# 499    1.133527
# Name: ORPDCs_M, Length: 500, dtype: float64
# TPIc_M 0      801.035588
# 1      804.814820
# 2      804.814820
# 3      804.814820
# 4      804.814820
#           ...
# 495    683.203005
# 496    830.120279
# 497    830.120279
# 498    815.960032
# 499    801.104792
# Name: TPIc_M, Length: 500, dtype: float64
# PPMs_M 0      1.703017
# 1      1.732977
# 2      1.732977
# 3      1.732977
# 4      1.732977
#          ...
# 495    1.658678
# 496    1.650711
# 497    1.650711
# 498    1.745166
# 499    1.703566
# Name: PPMs_M, Length: 500, dtype: float64
# RPIs_M 0     -1.135345
# 1     -1.155318
# 2     -1.155318
# 3     -1.155318
# 4     -1.155318
#          ...
# 495   -1.105785
# 496   -1.100474
# 497   -1.100474
# 498   -1.163444
# 499   -1.135711
# Name: RPIs_M, Length: 500, dtype: float64
# GAPDHc_M 0      926.498186
# 1      942.796993
# 2      942.796993
# 3      942.796993
# 4      942.796993
#           ...
# 495    902.376015
# 496    952.505198
# 497    952.505198
# 498    964.092748
# 499    926.796646
# Name: GAPDHc_M, Length: 500, dtype: float64
# GAPDH1ys_M 0      -0.567672
# 1      -0.577659
# 2      -0.577659
# 3      -0.577659
# 4      -0.577659
#          ...
# 495    -0.552893
# 496    17.604233
# 497    17.604233
# 498     4.306316
# 499    -0.567855
# Name: GAPDH1ys_M, Length: 500, dtype: float64
# KHKc_M 0      338.951784
# 1      334.602112
# 2      334.602112
# 3      334.602112
# 4      334.602112
#           ...
# 495    233.149948
# 496    345.919944
# 497    345.919944
# 498    332.663770
# 499    338.872134
# Name: KHKc_M, Length: 500, dtype: float64
# FBA2c_M 0      338.951784
# 1      334.602112
# 2      334.602112
# 3      334.602112
# 4      334.602112
#           ...
# 495    233.149948
# 496    345.919944
# 497    345.919944
# 498    332.663770
# 499    338.872134
# Name: FBA2c_M, Length: 500, dtype: float64
# FBAc_M 0      125.462598
# 1      137.982174
# 2      137.982174
# 3      137.982174
# 4      137.982174
#           ...
# 495    219.173009
# 496    122.384919
# 497    122.384919
# 498    148.132715
# 499    125.691854
# Name: FBAc_M, Length: 500, dtype: float64
# FBAs_M 0       0.000000
# 1       0.000000
# 2       0.000000
# 3       0.000000
# 4       0.000000
#          ...
# 495     0.000000
# 496    18.154470
# 497    18.154470
# 498     4.888038
# 499     0.000000
# Name: FBAs_M, Length: 500, dtype: float64
# PRDPARs_M 0      0.569856
# 1      0.579881
# 2      0.579881
# 3      0.579881
# 4      0.579881
#          ...
# 495    0.555019
# 496    0.552353
# 497    0.552353
# 498    0.583960
# 499    0.570039
# Name: PRDPARs_M, Length: 500, dtype: float64
# FUMm_M 0     -31.977427
# 1     -32.539969
# 2     -32.539969
# 3     -32.539969
# 4     -32.539969
#          ...
# 495   -31.144868
# 496   -30.995275
# 497   -30.995275
# 498   -32.768855
# 499   -31.987728
# Name: FUMm_M, Length: 500, dtype: float64
# ADSALs_M 0      0.569856
# 1      0.579881
# 2      0.579881
# 3      0.579881
# 4      0.579881
#          ...
# 495    0.555019
# 496    0.552353
# 497    0.552353
# 498    0.583960
# 499    0.570039
# Name: ADSALs_M, Length: 500, dtype: float64
# GMPRc_M 0     -0.510905
# 1     -0.519893
# 2     -0.519893
# 3     -0.519893
# 4     -0.519893
#          ...
# 495   -0.497603
# 496   -0.495213
# 497   -0.495213
# 498   -0.523550
# 499   -0.511070
# Name: GMPRc_M, Length: 500, dtype: float64
# IMPCs_M 0      0.569856
# 1      0.579881
# 2      0.579881
# 3      0.579881
# 4      0.579881
#          ...
# 495    0.555019
# 496    0.552353
# 497    0.552353
# 498    0.583960
# 499    0.570039
# Name: IMPCs_M, Length: 500, dtype: float64
# GDKc_M 0      0.510905
# 1      0.519893
# 2      0.519893
# 3      0.519893
# 4      0.519893
#          ...
# 495    0.497603
# 496    0.495213
# 497    0.495213
# 498    0.523550
# 499    0.511070
# Name: GDKc_M, Length: 500, dtype: float64
# ADSSs_M 0      0.569856
# 1      0.579881
# 2      0.579881
# 3      0.579881
# 4      0.579881
#          ...
# 495    0.555019
# 496    0.552353
# 497    0.552353
# 498    0.583960
# 499    0.570039
# Name: ADSSs_M, Length: 500, dtype: float64
# MI3PPc_M 0      0.026855
# 1      0.027328
# 2      0.027328
# 3      0.027328
# 4      0.027328
#          ...
# 495    0.026156
# 496    0.026030
# 497    0.026030
# 498    0.027520
# 499    0.026864
# Name: MI3PPc_M, Length: 500, dtype: float64
# MTHFDs_M 0      1.139712
# 1      1.159761
# 2      1.159761
# 3      1.159761
# 4      1.159761
#          ...
# 495    1.110038
# 496    1.104707
# 497    1.104707
# 498    1.167919
# 499    1.140079
# Name: MTHFDs_M, Length: 500, dtype: float64
# MTHFDyc_M 0      623.890456
# 1      639.718758
# 2      639.718758
# 3      639.718758
# 4      639.718758
#           ...
# 495    647.508031
# 496    583.735198
# 497    583.735198
# 498    642.787898
# 499    624.180300
# Name: MTHFDyc_M, Length: 500, dtype: float64
# PRODHm_M 0      0.209602
# 1      0.213289
# 2      0.213289
# 3      0.213289
# 4      0.213289
#          ...
# 495    0.204145
# 496    0.203164
# 497    0.203164
# 498    0.214790
# 499    0.209670
# Name: PRODHm_M, Length: 500, dtype: float64
# UGDCc_M 0      45.693268
# 1      46.497096
# 2      46.497096
# 3      46.497096
# 4      46.497096
#          ...
# 495    44.503605
# 496    44.289848
# 497    44.289848
# 498    46.824157
# 499    45.707987
# Name: UGDCc_M, Length: 500, dtype: float64
# UA4Ec_M 0      8.226884
# 1      8.371610
# 2      8.371610
# 3      8.371610
# 4      8.371610
#          ...
# 495    8.012690
# 496    7.974204
# 497    7.974204
# 498    8.430496
# 499    8.229534
# Name: UA4Ec_M, Length: 500, dtype: float64
# PGKc_M 0      926.498186
# 1      942.796993
# 2      942.796993
# 3      942.796993
# 4      942.796993
#           ...
# 495    902.376015
# 496    952.505198
# 497    952.505198
# 498    964.092748
# 499    926.796646
# Name: PGKc_M, Length: 500, dtype: float64
# PGKs_M 0      -0.567672
# 1      -0.577659
# 2      -0.577659
# 3      -0.577659
# 4      -0.577659
#          ...
# 495    -0.552893
# 496    17.604233
# 497    17.604233
# 498     4.306316
# 499    -0.567855
# Name: PGKs_M, Length: 500, dtype: float64
# PGMc_M 0      925.930514
# 1      942.219335
# 2      942.219335
# 3      942.219335
# 4      942.219335
#           ...
# 495    901.823122
# 496    970.109432
# 497    970.109432
# 498    968.399064
# 499    926.228790
# Name: PGMc_M, Length: 500, dtype: float64
# RPEs_M 0     -1.135345
# 1     -1.155318
# 2     -1.155318
# 3     -1.155318
# 4     -1.155318
#          ...
# 495   -1.105785
# 496   -1.100474
# 497   -1.100474
# 498   -1.163444
# 499   -1.135711
# Name: RPEs_M, Length: 500, dtype: float64
# TKT1s_M 0     -0.567672
# 1     -0.577659
# 2     -0.577659
# 3     -0.577659
# 4     -0.577659
#          ...
# 495   -0.552893
# 496   -0.550237
# 497   -0.550237
# 498   -0.581722
# 499   -0.567855
# Name: TKT1s_M, Length: 500, dtype: float64
# MTHFCc_M 0      623.890456
# 1      639.718758
# 2      639.718758
# 3      639.718758
# 4      639.718758
#           ...
# 495    647.508031
# 496    583.735198
# 497    583.735198
# 498    642.787898
# 499    624.180300
# Name: MTHFCc_M, Length: 500, dtype: float64
# MTHFCs_M 0      1.139712
# 1      1.159761
# 2      1.159761
# 3      1.159761
# 4      1.159761
#          ...
# 495    1.110038
# 496    1.104707
# 497    1.104707
# 498    1.167919
# 499    1.140079
# Name: MTHFCs_M, Length: 500, dtype: float64
# GLUKAc_M 0       86.260016
# 1       87.777489
# 2       87.777489
# 3       87.777489
# 4       87.777489
#           ...
# 495     84.014163
# 496    101.765103
# 497    101.765103
# 498     93.282954
# 499     86.287804
# Name: GLUKAc_M, Length: 500, dtype: float64
# TALAs_M 0     -0.567672
# 1     -0.577659
# 2     -0.577659
# 3     -0.577659
# 4     -0.577659
#          ...
# 495   -0.552893
# 496   -0.550237
# 497   -0.550237
# 498   -0.581722
# 499   -0.567855
# Name: TALAs_M, Length: 500, dtype: float64
# TKT2s_M 0     -0.567672
# 1     -0.577659
# 2     -0.577659
# 3     -0.577659
# 4     -0.577659
#          ...
# 495   -0.552893
# 496   -0.550237
# 497   -0.550237
# 498   -0.581722
# 499   -0.567855
# Name: TKT2s_M, Length: 500, dtype: float64
# ASPCTs_M 0      1.133162
# 1      1.153096
# 2      1.153096
# 3      1.153096
# 4      1.153096
#          ...
# 495    1.103659
# 496    1.098358
# 497    1.098358
# 498    1.161207
# 499    1.133527
# Name: ASPCTs_M, Length: 500, dtype: float64
# ORPRTs_M 0     -1.133162
# 1     -1.153096
# 2     -1.153096
# 3     -1.153096
# 4     -1.153096
#          ...
# 495   -1.103659
# 496   -1.098358
# 497   -1.098358
# 498   -1.161207
# 499   -1.133527
# Name: ORPRTs_M, Length: 500, dtype: float64
# ACONTm_M 0     -348.748178
# 1     -357.309761
# 2     -357.309761
# 3     -357.309761
# 4     -357.309761
#           ...
# 495   -408.687208
# 496   -327.540186
# 497   -327.540186
# 498   -359.107757
# 499   -348.904956
# Name: ACONTm_M, Length: 500, dtype: float64
# ACONm_M 0     -348.748178
# 1     -357.309761
# 2     -357.309761
# 3     -357.309761
# 4     -357.309761
#           ...
# 495   -408.687208
# 496   -327.540186
# 497   -327.540186
# 498   -359.107757
# 499   -348.904956
# Name: ACONm_M, Length: 500, dtype: float64
# DHRs_M 0      1.133162
# 1      1.153096
# 2      1.153096
# 3      1.153096
# 4      1.153096
#          ...
# 495    1.103659
# 496    1.098358
# 497    1.098358
# 498    1.161207
# 499    1.133527
# Name: DHRs_M, Length: 500, dtype: float64
# PFPc_M 0      125.462598
# 1      137.982174
# 2      137.982174
# 3      137.982174
# 4      137.982174
#           ...
# 495    219.173009
# 496    122.384919
# 497    122.384919
# 498    148.132715
# 499    125.691854
# Name: PFPc_M, Length: 500, dtype: float64
# AGSs_M 0      21.281168
# 1      21.655543
# 2      21.655543
# 3      21.655543
# 4      21.655543
#          ...
# 495    20.727094
# 496    20.627540
# 497    20.627540
# 498    21.807868
# 499    21.288023
# Name: AGSs_M, Length: 500, dtype: float64
# CYORm_M 0      366.303668
# 1      375.174084
# 2      375.174084
# 3      375.174084
# 4      375.174084
#           ...
# 495    327.608748
# 496    344.556478
# 497    344.556478
# 498    377.097738
# 499    366.466101
# Name: CYORm_M, Length: 500, dtype: float64
# SUCDH1m_M 0      30.837716
# 1      31.380208
# 2      31.380208
# 3      31.380208
# 4      31.380208
#          ...
# 495    30.034829
# 496    29.890568
# 497    29.890568
# 498    31.600936
# 499    30.847650
# Name: SUCDH1m_M, Length: 500, dtype: float64
# SSs_M 0      42.562336
# 1      43.311086
# 2      43.311086
# 3      43.311086
# 4      43.311086
#          ...
# 495    41.454189
# 496    41.255079
# 497    41.255079
# 498    43.615736
# 499    42.576047
# Name: SSs_M, Length: 500, dtype: float64
# CELLSc_M 0      136.169344
# 1      138.564813
# 2      138.564813
# 3      138.564813
# 4      138.564813
#           ...
# 495    132.624059
# 496    131.987049
# 497    131.987049
# 498    139.539479
# 499    136.213209
# Name: CELLSc_M, Length: 500, dtype: float64
# ...
#          ...
# 495    2.216577
# 496    2.196758
# 497    2.196758
# 498    2.196758
# 499    2.196758
# Name: NH4ts_BS, Length: 500, dtype: float64
# O2tsr_BS 0     -25.927665
# 1     -25.887059
# 2     -25.795083
# 3     -25.795083
# 4     -25.385456
#          ...
# 495   -25.604860
# 496   -25.375922
# 497   -25.375922
# 498   -25.375922
# 499   -25.375922
# Name: O2tsr_BS, Length: 500, dtype: float64
# Pits_BS 0      11.091431
# 1      11.074060
# 2      11.034714
# 3      11.034714
# 4      10.859482
#          ...
# 495    10.953340
# 496    10.855404
# 497    10.855404
# 498    10.855404
# 499    10.855404
# Name: Pits_BS, Length: 500, dtype: float64
# HCYSts_BS 0      1.125495
# 1      1.123732
# 2      1.119740
# 3      1.119740
# 4      1.101958
#          ...
# 495    1.111482
# 496    1.101544
# 497    1.101544
# 498    1.101544
# 499    1.101544
# Name: HCYSts_BS, Length: 500, dtype: float64
# MALFUMts_BS 0     -1.125495
# 1     -1.123732
# 2     -1.119740
# 3     -1.119740
# 4     -1.101958
#          ...
# 495   -1.111482
# 496   -1.101544
# 497   -1.101544
# 498   -1.101544
# 499   -1.101544
# Name: MALFUMts_BS, Length: 500, dtype: float64
# UTPUMPts_BS 0      1.119027
# 1      1.117274
# 2      1.113305
# 3      1.113305
# 4      1.095625
#          ...
# 495    1.105095
# 496    1.095214
# 497    1.095214
# 498    1.095214
# 499    1.095214
# Name: UTPUMPts_BS, Length: 500, dtype: float64
# CTPts_BS 0      8.264756
# 1      8.251813
# 2      8.222494
# 3      8.222494
# 4      8.091920
#          ...
# 495    8.161858
# 496    8.088881
# 497    8.088881
# 498    8.088881
# 499    8.088881
# Name: CTPts_BS, Length: 500, dtype: float64
# UTPts_BS 0      1.144900
# 1      1.143107
# 2      1.139046
# 3      1.139046
# 4      1.120958
#          ...
# 495    1.130646
# 496    1.120537
# 497    1.120537
# 498    1.120537
# 499    1.120537
# Name: UTPts_BS, Length: 500, dtype: float64
# HCO3_LPAREN_h_RPAREN_tsi_BS 0      51.737915
# 1      51.656887
# 2      51.473350
# 3      51.473350
# 4      50.655952
#          ...
# 495    51.093767
# 496    50.636927
# 497    50.636927
# 498    50.636927
# 499    50.636927
# Name: HCO3_LPAREN_h_RPAREN_tsi_BS, Length: 500, dtype: float64
# PYRts_BS 0     -6.476814
# 1     -6.466670
# 2     -6.443694
# 3     -6.443694
# 4     -6.341368
#          ...
# 495   -6.396176
# 496   -6.338987
# 497   -6.338987
# 498   -6.338987
# 499   -6.338987
# Name: PYRts_BS, Length: 500, dtype: float64
# SO3t_BS 0     -6.476814
# 1     -6.466670
# 2     -6.443694
# 3     -6.443694
# 4     -6.341368
#          ...
# 495   -6.396176
# 496   -6.338987
# 497   -6.338987
# 498   -6.338987
# 499   -6.338987
# Name: SO3t_BS, Length: 500, dtype: float64
# FA160s_BS 0      1.976206
# 1      1.973111
# 2      1.966100
# 3      1.966100
# 4      1.934879
#          ...
# 495    1.951602
# 496    1.934152
# 497    1.934152
# 498    1.934152
# 499    1.934152
# Name: FA160s_BS, Length: 500, dtype: float64
# FA180s_BS 0      4.738059
# 1      4.730639
# 2      4.713831
# 3      4.713831
# 4      4.638975
#          ...
# 495    4.679069
# 496    4.637233
# 497    4.637233
# 498    4.637233
# 499    4.637233
# Name: FA180s_BS, Length: 500, dtype: float64
# CITx_BS 0      30.837716
# 1      31.380208
# 2      31.380208
# 3      31.380208
# 4      31.380208
#          ...
# 495    30.034829
# 496    29.890568
# 497    29.890568
# 498    31.600936
# 499    30.847650
# Name: CITx_BS, Length: 500, dtype: float64
# CITtcx_BS 0      30.837716
# 1      31.380208
# 2      31.380208
# 3      31.380208
# 4      31.380208
#          ...
# 495    30.034829
# 496    29.890568
# 497    29.890568
# 498    31.600936
# 499    30.847650
# Name: CITtcx_BS, Length: 500, dtype: float64
# SUCCtx_BS 0     -30.837716
# 1     -31.380208
# 2     -31.380208
# 3     -31.380208
# 4     -31.380208
#          ...
# 495   -30.034829
# 496   -29.890568
# 497   -29.890568
# 498   -31.600936
# 499   -30.847650
# Name: SUCCtx_BS, Length: 500, dtype: float64
# GLXtx_BS 0     -30.837716
# 1     -31.380208
# 2     -31.380208
# 3     -31.380208
# 4     -31.380208
#          ...
# 495   -30.034829
# 496   -29.890568
# 497   -29.890568
# 498   -31.600936
# 499   -30.847650
# Name: GLXtx_BS, Length: 500, dtype: float64
# FA140CoAr_BS 0     -8.080426
# 1     -8.067771
# 2     -8.039107
# 3     -8.039107
# 4     -7.911445
#          ...
# 495   -7.979823
# 496   -7.908474
# 497   -7.908474
# 498   -7.908474
# 499   -7.908474
# Name: FA140CoAr_BS, Length: 500, dtype: float64
# FA160CoAr_BS 0     -1.700222
# 1     -1.697559
# 2     -1.691528
# 3     -1.691528
# 4     -1.664666
#          ...
# 495   -1.679054
# 496   -1.664041
# 497   -1.664041
# 498   -1.664041
# 499   -1.664041
# Name: FA160CoAr_BS, Length: 500, dtype: float64
# FA161CoAr_BS 0     -0.275984
# 1     -0.275552
# 2     -0.274573
# 3     -0.274573
# 4     -0.270212
#          ...
# 495   -0.272548
# 496   -0.270111
# 497   -0.270111
# 498   -0.270111
# 499   -0.270111
# Name: FA161CoAr_BS, Length: 500, dtype: float64
# FA181CoAr_BS 0     -2.281735
# 1     -2.278162
# 2     -2.270068
# 3     -2.270068
# 4     -2.234019
#          ...
# 495   -2.253327
# 496   -2.233180
# 497   -2.233180
# 498   -2.233180
# 499   -2.233180
# Name: FA181CoAr_BS, Length: 500, dtype: float64
# FA182CoAr_BS 0     -2.296508
# 1     -2.292912
# 2     -2.284765
# 3     -2.284765
# 4     -2.248483
#          ...
# 495   -2.267916
# 496   -2.247638
# 497   -2.247638
# 498   -2.247638
# 499   -2.247638
# Name: FA182CoAr_BS, Length: 500, dtype: float64
# FA183CoAr_BS 0     -0.159815
# 1     -0.159565
# 2     -0.158998
# 3     -0.158998
# 4     -0.156473
#          ...
# 495   -0.157826
# 496   -0.156415
# 497   -0.156415
# 498   -0.156415
# 499   -0.156415
# Name: FA183CoAr_BS, Length: 500, dtype: float64
# FA140r_BS 0      8.080426
# 1      8.067771
# 2      8.039107
# 3      8.039107
# 4      7.911445
#          ...
# 495    7.979823
# 496    7.908474
# 497    7.908474
# 498    7.908474
# 499    7.908474
# Name: FA140r_BS, Length: 500, dtype: float64
# AMETt2r_BS 0     -0.659773
# 1     -0.658740
# 2     -0.656399
# 3     -0.656399
# 4     -0.645976
#          ...
# 495   -0.651559
# 496   -0.645733
# 497   -0.645733
# 498   -0.645733
# 499   -0.645733
# Name: AMETt2r_BS, Length: 500, dtype: float64
# ATPtr_BS 0      8.123099
# 1      8.110377
# 2      8.081561
# 3      8.081561
# 4      7.953226
#          ...
# 495    8.021965
# 496    7.950239
# 497    7.950239
# 498    7.950239
# 499    7.950239
# Name: ATPtr_BS, Length: 500, dtype: float64
# ATP2tr_BS 0     -8.264756
# 1     -8.251813
# 2     -8.222494
# 3     -8.222494
# 4     -8.091920
#          ...
# 495   -8.161858
# 496   -8.088881
# 497   -8.088881
# 498   -8.088881
# 499   -8.088881
# Name: ATP2tr_BS, Length: 500, dtype: float64
# H2Otr_BS 0      10.050671
# 1      10.034931
# 2       9.999276
# 3       9.999276
# 4       9.840488
#          ...
# 495     9.925538
# 496     9.836792
# 497     9.836792
# 498     9.836792
# 499     9.836792
# Name: H2Otr_BS, Length: 500, dtype: float64
# CO2tr_BS 0     -0.219924
# 1     -0.219580
# 2     -0.218800
# 3     -0.218800
# 4     -0.215325
#          ...
# 495   -0.217186
# 496   -0.215244
# 497   -0.215244
# 498   -0.215244
# 499   -0.215244
# Name: CO2tr_BS, Length: 500, dtype: float64
# Pitr_BS 0     -2.147496
# 1     -2.144133
# 2     -2.136515
# 3     -2.136515
# 4     -2.102587
#          ...
# 495   -2.120760
# 496   -2.101797
# 497   -2.101797
# 498   -2.101797
# 499   -2.101797
# Name: Pitr_BS, Length: 500, dtype: float64
# SERtr_BS 0      0.335061
# 1      0.334536
# 2      0.333348
# 3      0.333348
# 4      0.328054
#          ...
# 495    0.330890
# 496    0.327931
# 497    0.327931
# 498    0.327931
# 499    0.327931
# Name: SERtr_BS, Length: 500, dtype: float64
# COA_LPAREN_h_RPAREN_tr_BS 0     -14.795345
# 1     -14.772173
# 2     -14.719688
# 3     -14.719688
# 4     -14.485939
#          ...
# 495   -14.611139
# 496   -14.480498
# 497   -14.480498
# 498   -14.480498
# 499   -14.480498
# Name: COA_LPAREN_h_RPAREN_tr_BS, Length: 500, dtype: float64
# GLYC3Ptr_BS 0     -2.301508
# 1     -2.297904
# 2     -2.289739
# 3     -2.289739
# 4     -2.253378
#          ...
# 495   -2.272854
# 496   -2.252532
# 497   -2.252532
# 498   -2.252532
# 499   -2.252532
# Name: GLYC3Ptr_BS, Length: 500, dtype: float64
# CTPtr_BS 0      8.264756
# 1      8.251813
# 2      8.222494
# 3      8.222494
# 4      8.091920
#          ...
# 495    8.161858
# 496    8.088881
# 497    8.088881
# 498    8.088881
# 499    8.088881
# Name: CTPtr_BS, Length: 500, dtype: float64
# CMPtr_BS 0     -8.264756
# 1     -8.251813
# 2     -8.222494
# 3     -8.222494
# 4     -8.091920
#          ...
# 495   -8.161858
# 496   -8.088881
# 497   -8.088881
# 498   -8.088881
# 499   -8.088881
# Name: CMPtr_BS, Length: 500, dtype: float64
# PEtr_BS 0      0.115137
# 1      0.114957
# 2      0.114548
# 3      0.114548
# 4      0.112729
#          ...
# 495    0.113703
# 496    0.112687
# 497    0.112687
# 498    0.112687
# 499    0.112687
# Name: PEtr_BS, Length: 500, dtype: float64
# PStr_BS 0     -0.115137
# 1     -0.114957
# 2     -0.114548
# 3     -0.114548
# 4     -0.112729
#          ...
# 495   -0.113703
# 496   -0.112687
# 497   -0.112687
# 498   -0.112687
# 499   -0.112687
# Name: PStr_BS, Length: 500, dtype: float64
# INOSTtr_BS 0      0.026520
# 1      0.026479
# 2      0.026385
# 3      0.026385
# 4      0.025966
#          ...
# 495    0.026190
# 496    0.025956
# 497    0.025956
# 498    0.025956
# 499    0.025956
# Name: INOSTtr_BS, Length: 500, dtype: float64
# O2tu_BS 0      32.404479
# 1      32.353730
# 2      32.238777
# 3      32.238777
# 4      31.726824
#          ...
# 495    32.001036
# 496    31.714909
# 497    31.714909
# 498    31.714909
# 499    31.714909
# Name: O2tu_BS, Length: 500, dtype: float64
# H2Otu_BS 0     -64.808959
# 1     -64.707459
# 2     -64.477554
# 3     -64.477554
# 4     -63.453648
#          ...
# 495   -64.002073
# 496   -63.429818
# 497   -63.429818
# 498   -63.429818
# 499   -63.429818
# Name: H2Otu_BS, Length: 500, dtype: float64
# DM_COA_LPAREN_c_RPAREN__BS 0      0.000653
# 1      0.000652
# 2      0.000650
# 3      0.000650
# 4      0.000639
#          ...
# 495    0.000645
# 496    0.000639
# 497    0.000639
# 498    0.000639
# 499    0.000639
# Name: DM_COA_LPAREN_c_RPAREN__BS, Length: 500, dtype: float64
# DM_photonDrain_LPAREN_u_RPAREN__BS 0      118.613800
# 1      118.428035
# 2      118.007261
# 3      118.007261
# 4      116.133302
#           ...
# 495    117.137032
# 496    116.089687
# 497    116.089687
# 498    116.089687
# 499    116.089687
# Name: DM_photonDrain_LPAREN_u_RPAREN__BS, Length: 500, dtype: float64
# succ_pd 0     -30.837716
# 1     -31.380208
# 2     -31.380208
# 3     -31.380208
# 4     -31.380208
#          ...
# 495   -30.034829
# 496   -29.890568
# 497   -29.890568
# 498   -31.600936
# 499   -30.847650
# Name: succ_pd, Length: 500, dtype: float64
# [<Group biomass at 0x7fbbfa171040>,
#  <Group Unassigned at 0x7fbbfa171ca0>,
#  <Group Exchange Reactions at 0x7fbbfa171c70>,
#  <Group Spectral decomposition at 0x7fbbfa171cd0>,
#  <Group Transport (Extracellular) at 0x7fbbfa171d30>,
#  <Group Starch and sucrose metabolism (Sucrose) at 0x7fbbfa171e50>,
#  <Group Oxidative phosphorylation at 0x7fbbfa171df0>,
#  <Group Valine, leucine and isoleucine metabolism at 0x7fbbfa171d90>,
#  <Group Glyoxylate Cycle at 0x7fbbfa171eb0>,
#  <Group Nitrogen metabolism; GS-GOGAT Cycle at 0x7fbbfa171f10>,
#  <Group Calvin cycle at 0x7fbbfa171f70>,
#  <Group Purine metabolism at 0x7fbbfa171fd0>,
#  <Group Photosynthesis; Photophosphorylation at 0x7fbbf9c800d0>,
#  <Group Sulfate metabolism (Glutathione) at 0x7fbbf9c80070>,
#  <Group Primary Cell Wall Metabolism (Galactose metabolism) at 0x7fbbf9c80130>,
#  <Group Pantothenate and CoA metabolism at 0x7fbbf9c80190>,
#  <Group Pyrimidine metabolism at 0x7fbbf9c801f0>,
#  <Group Phytohormones biosynthesis (Ethylene) at 0x7fbbf9c80250>,
#  <Group Cysteine and methionine metabolism at 0x7fbbf9c802b0>,
#  <Group Glycolysis/Gluconeogensis at 0x7fbbf9c80310>,
#  <Group Fermentation at 0x7fbbf9c80370>,
#  <Group Arginine and proline metabolism at 0x7fbbf9c803d0>,
#  <Group Alanine, aspartate and glutamate metabolism at 0x7fbbf9c80430>,
#  <Group Photorespiration at 0x7fbbf9c80490>,
#  <Group Glycine, serine and threonine metabolism at 0x7fbbf9c804f0>,
#  <Group TCA Cycle at 0x7fbbf9c80550>,
#  <Group Starch and sucrose metabolism (Cellulose) at 0x7fbbf9c805b0>,
#  <Group Nicotinate and Nicotinamide metabolism at 0x7fbbf9c80610>,
#  <Group Nitrogen metabolism at 0x7fbbf9c80670>,
#  <Group Folates metabolism at 0x7fbbf9c806d0>,
#  <Group Lysine metabolism at 0x7fbbf9c80730>,
#  <Group Sulfate metabolism at 0x7fbbf9c80790>,
#  <Group Phytohormones biosynthesis (IAA) at 0x7fbbf9c807f0>,
#  <Group Phenylalanine, tyrosine and tryptophan metabolism at 0x7fbbf9c80850>,
#  <Group Primary Cell Wall Metabolism (Fructose) at 0x7fbbf9c808b0>,
#  <Group Ascorbate Metabolism at 0x7fbbf9c80910>,
#  <Group Ascorbate Metabolism; Water-water cycle at 0x7fbbf9c80970>,
#  <Group Primary Cell Wall Metabolism (Inositol phosphate) at 0x7fbbf9c809d0>,
#  <Group Primary Cell Wall Metabolism (Amino sugars) at 0x7fbbf9c80a30>,
#  <Group Starch and sucrose metabolism (Starch) at 0x7fbbf9c80a90>,
#  <Group Calvin Cycle at 0x7fbbf9c80af0>,
#  <Group Pentose Phosphate Pathway at 0x7fbbf9c80b50>,
#  <Group Other Vitamins Metabolism (Riboflavin) at 0x7fbbf9c80bb0>,
#  <Group Glycerolipid and Glycerophospholipid metabolism at 0x7fbbf9c80c10>,
#  <Group Histidine metabolism at 0x7fbbf9c80c70>,
#  <Group Terpenoid biosynthesis (MVA Pathway) at 0x7fbbf9c80cd0>,
#  <Group Primary Cell Wall Metabolism (Membrane) at 0x7fbbf9c80d30>,
#  <Group Chlororespiration; Oxidative Phosphorylation at 0x7fbbf9c80d90>,
#  <Group Other Vitamins Metabolism (B6) at 0x7fbbf9c80df0>,
#  <Group Other Vitamins Metabolism (Thiamine) at 0x7fbbf9c80e50>,
#  <Group Phenylpropanoid metabolism at 0x7fbbf9c80eb0>,
#  <Group Flavonoid biosynthesis at 0x7fbbf9c80f10>,
#  <Group Phylloquinone, Plastoquinone and Ubiquinone Metabolism at 0x7fbbf9c80f70>,
#  <Group Porphyrin and Chlorophyll Metabolism at 0x7fbbf9c80fd0>,
#  <Group Other Vitamins Metabolism (Vitamin E) at 0x7fbbf9c870d0>,
#  <Group Terpenoid biosynthesis (MEP Pathway, MVA Pathway) at 0x7fbbf9c87070>,
#  <Group Terpenoid biosynthesis (MEP Pathway) at 0x7fbbf9c87130>,
#  <Group Terpenoid biosynthesis (Monoterpenoid biosynthesis) at 0x7fbbf9c87190>,
#  <Group Terpenoid biosynthesis (Sesquiterpenoid/Triterpenoid biosynthesis) at 0x7fbbf9c871f0>,
#  <Group Terpenoid biosynthesis (Diterpenoid biosynthesis) at 0x7fbbf9c87250>,
#  <Group Phytohormones biosynthesis (Gibberallins) at 0x7fbbf9c872b0>,
#  <Group Terpenoid biosynthesis (Carotenoid biosynthesis) at 0x7fbbf9c87310>,
#  <Group Phytohormones biosynthesis (Abscisic acid) at 0x7fbbf9c87370>,
#  <Group Phytohormones biosynthesis (Brassinosteroids) at 0x7fbbf9c873d0>,
#  <Group Steroid Metabolism at 0x7fbbf9c87430>,
#  <Group Phytohormones biosynthesis (Zeatin) at 0x7fbbf9c87490>,
#  <Group Fatty acid biosynthesis at 0x7fbbf9c874f0>,
#  <Group Secondary Cell Wall Metabolism (Cuticular Wax) at 0x7fbbf9c87550>,
#  <Group Secondary Cell Wall Metabolism (Cutin wax) at 0x7fbbf9c875b0>,
#  <Group Secondary Cell Wall Metabolism (Suberin) at 0x7fbbf9c87610>,
#  <Group Fatty acid biosynthesis (desaturation) at 0x7fbbf9c87670>,
#  <Group Fatty acid biosynthesis (Very long chain) at 0x7fbbf9c876d0>,
#  <Group Fatty acid degradation at 0x7fbbf9c87730>,
#  <Group Fatty acid degradation (Beta oxidation) at 0x7fbbf9c87790>,
#  <Group Fatty acid biosynthesis (elongation in mitochondrion) at 0x7fbbf9c877f0>,
#  <Group Fatty acid biosynthesis (in mitochondrion) at 0x7fbbf9c87850>,
#  <Group Phytohormones biosynthesis (Jasmonic acid) at 0x7fbbf9c878b0>,
#  <Group Sphingolipid metabolism at 0x7fbbf9c87910>,
#  <Group Other Vitamins Metabolism (Biotin) at 0x7fbbf9c87970>,
#  <Group Glycan Biosynthesis (N-Glycan) at 0x7fbbf9c879d0>,
#  <Group Glycan Biosynthesis (Glycolipids) at 0x7fbbf9c87a30>,
#  <Group Aminoacyl-tRNA biosynthesis at 0x7fbbf9c87a90>,
#  <Group Glycan Biosynthesis (Peptidoglycan) at 0x7fbbf9c87af0>,
#  <Group Terpenoid biosynthesis (Terpenophenolics biosynthesis) at 0x7fbbf9c87b50>,
#  <Group Ascorbate metabolism; Water-water cycle at 0x7fbbf9c87bb0>,
#  <Group Photosynthesis; GS-GOGAT Cycle at 0x7fbbf9c87c10>,
#  <Group Photosynthesis; Water-water cycle at 0x7fbbf9c87c70>,
#  <Group Photosynthesis at 0x7fbbf9c87cd0>,
#  <Group Selenoamino acid metabolism at 0x7fbbf9c87d30>,
#  <Group Transport (Mitochondrial) at 0x7fbbf9c87d90>,
#  <Group Transport (Plastidic) at 0x7fbbf9c87df0>,
#  <Group Transport (Vacuolar) at 0x7fbbf9c87e50>,
#  <Group Transport (Peroxisomal) at 0x7fbbf9c87eb0>,
#  <Group Transport (ER) at 0x7fbbf9c87f10>,
#  <Group Transport (Thylakoid) at 0x7fbbf9c87f70>,
#  <Group Demand at 0x7fbbf9c87fd0>]

# %%
reup_twocell.model.groups

for groups in reup_twocell.model.groups:
    print(groups.members)
# Out:
# [<Reaction Straw_Biomass_M at 0x7fbbf9cfd1f0>]
# [<Reaction ACCOAC_OSAr_M at 0x7fbbf9cfd550>, <Reaction FAC_Osr_M at 0x7fbbf9cff1c0>]
# [<Reaction EX_h2o_LPAREN_e_RPAREN__M at 0x7fbbf9cff580>, <Reaction EX_o2_LPAREN_e_RPAREN__M at 0x7fbbf9cffa00>, <Reaction EX_pi_LPAREN_e_RPAREN__M at 0x7fbbf9cffb20>, <Reaction EX_sucr_LPAREN_e_RPAREN__M at 0x7fbbf9cffc40>, <Reaction EX_so4_LPAREN_e_RPAREN__M at 0x7fbbf9cffd60>, <Reaction EX_gln_DASH_L_LPAREN_e_RPAREN__M at 0x7fbbf9cfffa0>, <Reaction EX_etoh_LPAREN_e_RPAREN__M at 0x7fbbfa24d100>, <Reaction EX_ac_LPAREN_e_RPAREN__M at 0x7fbbfa24d220>, <Reaction EX_lac_DASH_L_LPAREN_e_RPAREN__M at 0x7fbbfa24d340>, <Reaction EX_ala_DASH_L_LPAREN_e_RPAREN__M at 0x7fbbfa24d460>, <Reaction EX_arg_DASH_L_LPAREN_e_RPAREN__M at 0x7fbbfa24d580>, <Reaction EX_asp_DASH_L_LPAREN_e_RPAREN__M at 0x7fbbfa24d6a0>, <Reaction EX_cys_DASH_L_LPAREN_e_RPAREN__M at 0x7fbbfa24d7c0>, <Reaction EX_glu_DASH_L_LPAREN_e_RPAREN__M at 0x7fbbfa24d8e0>, <Reaction EX_gly_LPAREN_e_RPAREN__M at 0x7fbbfa24da00>, <Reaction EX_his_DASH_L_LPAREN_e_RPAREN__M at 0x7fbbfa24db20>, <Reaction EX_ile_DASH_L_LPAREN_e_RPAREN__M at 0x7fbbfa24dc40>, <Reaction EX_leu_DASH_L_LPAREN_e_RPAREN__M at 0x7fbbfa24dd60>, <Reaction EX_lys_DASH_L_LPAREN_e_RPAREN__M at 0x7fbbfa24de80>, <Reaction EX_met_DASH_L_LPAREN_e_RPAREN__M at 0x7fbbfa24dfa0>, <Reaction EX_phe_DASH_L_LPAREN_e_RPAREN__M at 0x7fbbfa267100>, <Reaction EX_pro_DASH_L_LPAREN_e_RPAREN__M at 0x7fbbfa267220>, <Reaction EX_ser_DASH_L_LPAREN_e_RPAREN__M at 0x7fbbfa267340>, <Reaction EX_thr_DASH_L_LPAREN_e_RPAREN__M at 0x7fbbfa267460>, <Reaction EX_trp_DASH_L_LPAREN_e_RPAREN__M at 0x7fbbfa267580>, <Reaction EX_tyr_DASH_L_LPAREN_e_RPAREN__M at 0x7fbbfa2676a0>, <Reaction EX_val_DASH_L_LPAREN_e_RPAREN__M at 0x7fbbfa2677c0>, <Reaction EX_photonVis_LPAREN_e_RPAREN__M at 0x7fbbfa2678e0>]
# [<Reaction PRISM_blue_LED_M at 0x7fbbfa267a00>, <Reaction RPSI_410_LPAREN_u_RPAREN__M at 0x7fbbfa267b20>, <Reaction RPSI_430_LPAREN_u_RPAREN__M at 0x7fbbfa267eb0>, <Reaction RPSI_450_LPAREN_u_RPAREN__M at 0x7fbbfa2650a0>, <Reaction RPSII_450_LPAREN_u_RPAREN__M at 0x7fbbfa2651c0>, <Reaction RPSII_470_LPAREN_u_RPAREN__M at 0x7fbbfa265280>, <Reaction RPSII_490_LPAREN_u_RPAREN__M at 0x7fbbfa265370>]
# [<Reaction H2Otex_M at 0x7fbbfa265400>, <Reaction O2tex_M at 0x7fbbfa2655b0>, <Reaction Pitex_M at 0x7fbbfa265670>, <Reaction SUCRtex_M at 0x7fbbfa265760>, <Reaction SO4tex_M at 0x7fbbfa2657f0>, <Reaction GLNtex_M at 0x7fbbfa265970>, <Reaction ETOHtex_M at 0x7fbbfa265a90>, <Reaction ACtex_M at 0x7fbbfa265bb0>, <Reaction LACtex_M at 0x7fbbfa265cd0>, <Reaction ALAtex_M at 0x7fbbfa265df0>, <Reaction ARGtex_M at 0x7fbbfa265f40>, <Reaction ASPtex_M at 0x7fbbfa25e040>, <Reaction CYStex_M at 0x7fbbfa25e0a0>, <Reaction GLUtex_M at 0x7fbbfa25e130>, <Reaction GLYtex_M at 0x7fbbfa25e1c0>, <Reaction HIStex_M at 0x7fbbfa25e250>, <Reaction ILEtex_M at 0x7fbbfa25e2e0>, <Reaction LEUtex_M at 0x7fbbfa25e370>, <Reaction LYStex_M at 0x7fbbfa25e400>, <Reaction METtex_M at 0x7fbbfa25e490>, <Reaction PHEtex_M at 0x7fbbfa25e520>, <Reaction PROtex_M at 0x7fbbfa25e5b0>, <Reaction SERtex_M at 0x7fbbfa25e640>, <Reaction THRtex_M at 0x7fbbfa25e6d0>, <Reaction TRPtex_M at 0x7fbbfa25e760>, <Reaction TYRtex_M at 0x7fbbfa25e7f0>, <Reaction VALtex_M at 0x7fbbfa25e880>]
# [<Reaction PPASs_M at 0x7fbbfa25e910>, <Reaction INVc_M at 0x7fbbfa295040>, <Reaction SUSc_M at 0x7fbbfa295130>, <Reaction FKc_M at 0x7fbbfa295340>, <Reaction PGMTc_M at 0x7fbbfa82f460>]
# [<Reaction CYOO6m_M at 0x7fbbfa25ef40>, <Reaction ATPSm_M at 0x7fbbfa21e3a0>, <Reaction CYORm_M at 0x7fbbfa280d00>]
# []
# [<Reaction CATv_M at 0x7fbbfa25e9a0>, <Reaction CATm_M at 0x7fbbfa25ecd0>]
# []
# [<Reaction RPIs_M at 0x7fbbfa295e50>, <Reaction RPEs_M at 0x7fbbfa2809a0>, <Reaction TKT1s_M at 0x7fbbfa280a00>, <Reaction TALAs_M at 0x7fbbfa280c10>, <Reaction TKT2s_M at 0x7fbbfa280910>]
# [<Reaction ADK1c_M at 0x7fbbfa21e5e0>, <Reaction ATPAPc_M at 0x7fbbfa21e8b0>, <Reaction AMPDc_M at 0x7fbbfa20d910>, <Reaction ATGDc_M at 0x7fbbfab9b4f0>, <Reaction ATGDs_M at 0x7fbbfab9b5b0>, <Reaction PRDPARs_M at 0x7fbbfa280220>, <Reaction ADSALs_M at 0x7fbbfa280370>, <Reaction GMPRc_M at 0x7fbbfa2803d0>, <Reaction IMPCs_M at 0x7fbbfa2804c0>, <Reaction GDKc_M at 0x7fbbfa280520>, <Reaction ADSSs_M at 0x7fbbfa2805b0>, <Reaction PPRGLs_M at 0x7fbbfa82f0d0>, <Reaction PRFGCLs_M at 0x7fbbfa82f0a0>, <Reaction PRAICs_M at 0x7fbbfa82f250>, <Reaction FPGFTs_M at 0x7fbbfa82f2e0>, <Reaction PRFGSs_M at 0x7fbbfa82f340>, <Reaction AIALs_M at 0x7fbbfa82f3d0>, <Reaction FPAIFs_M at 0x7fbbfa82f3a0>, <Reaction PRAISs_M at 0x7fbbfa82f4f0>, <Reaction CBMKs_M at 0x7fbbfa82f5b0>]
# [<Reaction ATPSs_M at 0x7fbbfa21e160>, <Reaction CBFCNCEFs_M at 0x7fbbfa8d6bb0>, <Reaction CCEFs_M at 0x7fbbfa8d69a0>]
# [<Reaction ICDHc_M at 0x7fbbfa203dc0>]
# [<Reaction UPGCDc_M at 0x7fbbfab9b100>, <Reaction UDPG4Ec_M at 0x7fbbfab9b2e0>]
# []
# [<Reaction TMDSc_M at 0x7fbbfa21ea90>, <Reaction CTPRc_M at 0x7fbbfa23d0d0>, <Reaction UTPRc_M at 0x7fbbfa23d2e0>, <Reaction ATPRc_M at 0x7fbbfa23d460>, <Reaction GTPRc_M at 0x7fbbfa23d5b0>, <Reaction UPRTs_M at 0x7fbbfa23d640>, <Reaction UPHs_M at 0x7fbbfa23d6d0>, <Reaction AUPTs_M at 0x7fbbfa23d970>, <Reaction CTPSc_M at 0x7fbbfa23da90>, <Reaction DUTNHc_M at 0x7fbbfa23db20>, <Reaction ATDTDc_M at 0x7fbbfa23de50>, <Reaction DTMPKc_M at 0x7fbbfa20d070>, <Reaction ATCDs_M at 0x7fbbfa20d2b0>, <Reaction CMPKc_M at 0x7fbbfa20d370>, <Reaction ATUDs_M at 0x7fbbfa20d520>, <Reaction UMPKc_M at 0x7fbbfa20d6a0>, <Reaction ORPDCs_M at 0x7fbbfa295c40>, <Reaction ASPCTs_M at 0x7fbbfa280cd0>, <Reaction ORPRTs_M at 0x7fbbfa280ca0>, <Reaction DHRs_M at 0x7fbbfa280ee0>, <Reaction DHRDHm_M at 0x7fbbfa82f5e0>]
# []
# [<Reaction SATc_M at 0x7fbbfa296070>, <Reaction METSMTc_M at 0x7fbbfa2961c0>, <Reaction HCYSMTc_M at 0x7fbbfa296eb0>, <Reaction AMETAHYCSTc_M at 0x7fbbfa296bb0>, <Reaction HCYSMT2c_M at 0x7fbbfa296a60>, <Reaction AATCs_M at 0x7fbbfa2951c0>, <Reaction AATCm_M at 0x7fbbfa2952e0>, <Reaction 3SPYRSPs_M at 0x7fbbfa295460>, <Reaction 3SPYRSPm_M at 0x7fbbfa295520>, <Reaction LCYSTSs_M at 0x7fbbfa295580>, <Reaction LCYSTSm_M at 0x7fbbfa2954f0>, <Reaction CYSSc_M at 0x7fbbfa295640>]
# [<Reaction PYKc_M at 0x7fbbfa20d9d0>, <Reaction MDHs_M at 0x7fbbfab9b760>, <Reaction PPCc_M at 0x7fbbfab9bbe0>, <Reaction ENOc_M at 0x7fbbfa2969d0>, <Reaction PGI1s_M at 0x7fbbfa284c10>, <Reaction PGI2c_M at 0x7fbbfa284d90>, <Reaction TPIc_M at 0x7fbbfa295cd0>, <Reaction GAPDHc_M at 0x7fbbfa295eb0>, <Reaction FBAc_M at 0x7fbbfa280130>, <Reaction FBAs_M at 0x7fbbfa280100>, <Reaction PGKc_M at 0x7fbbfa280670>, <Reaction PGKs_M at 0x7fbbfa2807c0>, <Reaction PGMc_M at 0x7fbbfa280970>, <Reaction GLUKAc_M at 0x7fbbfa2807f0>, <Reaction PFPc_M at 0x7fbbfa280eb0>, <Reaction PFKs_M at 0x7fbbfa82f370>]
# [<Reaction MDHys_M at 0x7fbbfab9b670>, <Reaction LDH_Lc_M at 0x7fbbfa296850>, <Reaction GLYCORc_M at 0x7fbbfa2842b0>, <Reaction ALCDx1c_M at 0x7fbbfa284ac0>, <Reaction ACCOACs_M at 0x7fbbfa82f640>]
# [<Reaction PYR5CDm_M at 0x7fbbfa203520>, <Reaction PRODHm_M at 0x7fbbfa280730>, <Reaction GSCm_M at 0x7fbbfa280fd0>]
# [<Reaction GDHym_M at 0x7fbbfa20df40>, <Reaction ALAATc_M at 0x7fbbfa203b20>]
# [<Reaction GALs_M at 0x7fbbfa203850>, <Reaction GLYDHDm_M at 0x7fbbfa2843a0>, <Reaction DHLDHm_M at 0x7fbbfa284520>, <Reaction MTAMnh4m_M at 0x7fbbfa2847f0>, <Reaction SHMTm_M at 0x7fbbfa2959d0>]
# [<Reaction THRAc_M at 0x7fbbfa2848b0>]
# [<Reaction ICDHm_M at 0x7fbbfa203ee0>, <Reaction MDHm_M at 0x7fbbfab9ba30>, <Reaction CSm_M at 0x7fbbfab9beb0>, <Reaction FUMm_M at 0x7fbbfa2802e0>, <Reaction ACONTm_M at 0x7fbbfa280df0>, <Reaction ACONm_M at 0x7fbbfa280e50>, <Reaction SUCDH1m_M at 0x7fbbfa280e80>]
# [<Reaction UGDCc_M at 0x7fbbfa280790>, <Reaction UA4Ec_M at 0x7fbbfa280880>, <Reaction CELLSc_M at 0x7fbbfa280f70>]
# []
# [<Reaction ASPTAm_M at 0x7fbbfab90340>, <Reaction ASPTAs_M at 0x7fbbfab905b0>, <Reaction CALANc_M at 0x7fbbfa295850>, <Reaction CALASc_M at 0x7fbbfa2958b0>, <Reaction FORMHLc_M at 0x7fbbfa295970>, <Reaction HCO3Ec_M at 0x7fbbfa82f6d0>]
# [<Reaction FDHNc_M at 0x7fbbfab90df0>, <Reaction DHFRc_M at 0x7fbbfa295730>, <Reaction FTHFLc_M at 0x7fbbfa2957c0>, <Reaction FORAc_M at 0x7fbbfa295910>, <Reaction MLTHFRc_M at 0x7fbbfa295550>, <Reaction MLTHFRs_M at 0x7fbbfa295a60>, <Reaction METSc_M at 0x7fbbfa295ac0>, <Reaction METSs_M at 0x7fbbfa295b50>, <Reaction MTHFDs_M at 0x7fbbfa280550>, <Reaction MTHFDyc_M at 0x7fbbfa2806d0>, <Reaction MTHFCc_M at 0x7fbbfa280af0>, <Reaction MTHFCs_M at 0x7fbbfa280b80>]
# []
# [<Reaction SULOm_M at 0x7fbbfab90f40>]
# []
# []
# [<Reaction KHKc_M at 0x7fbbfa295fd0>, <Reaction FBA2c_M at 0x7fbbfa295e20>]
# []
# []
# [<Reaction MI3PSc_M at 0x7fbbfa295100>, <Reaction MI3PPc_M at 0x7fbbfa280460>]
# []
# [<Reaction GLPATs_M at 0x7fbbfa2956d0>, <Reaction AGSs_M at 0x7fbbfa280fa0>, <Reaction SSs_M at 0x7fbbfa280dc0>, <Reaction PGMTs_M at 0x7fbbfa82f490>]
# [<Reaction GAPDH1ys_M at 0x7fbbfa295f40>]
# [<Reaction PPMs_M at 0x7fbbfa295d90>]
# []
# [<Reaction GLYCKr_M at 0x7fbbfa8d61c0>, <Reaction G3PDNc_M at 0x7fbbfa8d6280>, <Reaction G3PATr_M at 0x7fbbfa8d6310>, <Reaction AGPATr_M at 0x7fbbfa8d60a0>, <Reaction PAPAr_M at 0x7fbbfa8d6400>, <Reaction DAGACTr_M at 0x7fbbfa8d6040>, <Reaction CDPDAGSr_M at 0x7fbbfa8d64f0>, <Reaction CDIPTr_M at 0x7fbbfa8d6460>, <Reaction PSSr_M at 0x7fbbfa8d6610>, <Reaction PEDCm_M at 0x7fbbfa8d66d0>, <Reaction ETHAKr_M at 0x7fbbfa8d6760>, <Reaction SERDCr_M at 0x7fbbfa8d6820>, <Reaction PETHAMTr_M at 0x7fbbfa8d68e0>, <Reaction CHOLKr_M at 0x7fbbfa8d6940>, <Reaction CHOLPCTr_M at 0x7fbbfa8d6a00>, <Reaction DAGCPr_M at 0x7fbbfa8d6a90>, <Reaction PLCr_M at 0x7fbbfa8d6af0>]
# []
# [<Reaction HMGCOARc_M at 0x7fbbfa82faf0>, <Reaction HMGCOARyc_M at 0x7fbbfa82fbe0>]
# []
# []
# []
# []
# [<Reaction TYRNH4Lc_M at 0x7fbbfa82f790>, <Reaction COUMCOARc_M at 0x7fbbfa82f820>, <Reaction COUMCOALc_M at 0x7fbbfa82f8b0>, <Reaction FERCOARc_M at 0x7fbbfa82f940>, <Reaction CONOHDHc_M at 0x7fbbfa82f580>, <Reaction SINOHDHc_M at 0x7fbbfa82fa00>, <Reaction FERH2c_M at 0x7fbbfa82f910>, <Reaction CONCMTc_M at 0x7fbbfa82fa90>, <Reaction COUMOHDHc_M at 0x7fbbfa82fb20>, <Reaction TFCOASc_M at 0x7fbbfa82f9d0>, <Reaction CC3H1c_M at 0x7fbbfa8d6970>, <Reaction CAFFMTc_M at 0x7fbbfa8d6ac0>]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [<Reaction MCOATAs_M at 0x7fbbfa82fca0>, <Reaction ACOATAs_M at 0x7fbbfa82fc10>, <Reaction ACMAT1s_M at 0x7fbbfa82fd90>, <Reaction 3OAR40s_M at 0x7fbbfa82fdf0>, <Reaction 3HAD40s_M at 0x7fbbfa82fe50>, <Reaction EAR40ys_M at 0x7fbbfa82feb0>, <Reaction 3OAS60s_M at 0x7fbbfa82ff10>, <Reaction 3OAR60s_M at 0x7fbbfa82ffa0>, <Reaction 3HAD60s_M at 0x7fbbfa82fee0>, <Reaction EAR60ys_M at 0x7fbbfa82ff40>, <Reaction 3OAS80s_M at 0x7fbbf9cfd1c0>, <Reaction 3OAR80s_M at 0x7fbbfa81b190>, <Reaction 3HAD80s_M at 0x7fbbfa81b1f0>, <Reaction EAR80ys_M at 0x7fbbfa81b250>, <Reaction 3OAS100s_M at 0x7fbbfa81b2b0>, <Reaction 3OAR100s_M at 0x7fbbfa81b340>, <Reaction 3HAD100s_M at 0x7fbbfa81b3a0>, <Reaction EAR100ys_M at 0x7fbbfa81b400>, <Reaction 3OAS120s_M at 0x7fbbfa81b460>, <Reaction 3OAR120s_M at 0x7fbbfa81b4f0>, <Reaction 3HAD120s_M at 0x7fbbfa81b550>, <Reaction EAR120ys_M at 0x7fbbfa81b5b0>, <Reaction 3OAS140s_M at 0x7fbbfa81b610>, <Reaction 3OAR140s_M at 0x7fbbfa81b6a0>, <Reaction 3HAD140s_M at 0x7fbbfa81b700>, <Reaction EAR140ys_M at 0x7fbbfa81b760>, <Reaction 3OAS160s_M at 0x7fbbfa81b7c0>, <Reaction 3OAR160s_M at 0x7fbbfa81b850>, <Reaction 3HAD160s_M at 0x7fbbfa81b8b0>, <Reaction EAR160ys_M at 0x7fbbfa81b910>, <Reaction 3OAS180s_M at 0x7fbbfa81b970>, <Reaction 3OAR180s_M at 0x7fbbfa81ba00>, <Reaction 3HAD180s_M at 0x7fbbfa81ba60>, <Reaction EAR180ys_M at 0x7fbbfa81bac0>, <Reaction FA160ACPHs_M at 0x7fbbfa81bb20>, <Reaction FA180ACPHs_M at 0x7fbbfa81bbb0>, <Reaction FACOAL140r_M at 0x7fbbfa81bc10>, <Reaction FACOAL160r_M at 0x7fbbfa81bc70>, <Reaction FACOAL161r_M at 0x7fbbfa81bdc0>, <Reaction FACOAL181r_M at 0x7fbbfa81bd30>, <Reaction FACOAL182r_M at 0x7fbbfa81bb50>, <Reaction FACOAL183r_M at 0x7fbbfa81bca0>, <Reaction FACOAL140c_M at 0x7fbbfa81bdf0>, <Reaction FACOAL160c_M at 0x7fbbfa81be20>, <Reaction FACOAL180c_M at 0x7fbbfa81bf40>]
# []
# []
# []
# [<Reaction FAS161COA_Lc_M at 0x7fbbfa81bfd0>, <Reaction FAS181COA_Lc_M at 0x7fbbfa81bf70>, <Reaction FAS182COA_Lc_M at 0x7fbbfa81be50>, <Reaction FAS183COA_Lc_M at 0x7fbbfa82fbb0>]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [<Reaction FNORs_M at 0x7fbbfa8d6cd0>]
# [<Reaction PSIMR_M at 0x7fbbfa8d6d60>]
# [<Reaction PSIINC_M at 0x7fbbfa8d6c10>]
# []
# [<Reaction PYRt2m_M at 0x7fbbfa8d6d00>, <Reaction ASPt2m_M at 0x7fbbfa8d6e80>, <Reaction CYSt2m_M at 0x7fbbfa8d6c70>, <Reaction PROt2m_M at 0x7fbbfa8d6df0>, <Reaction H2Otm_M at 0x7fbbfa8d6eb0>, <Reaction CO2tm_M at 0x7fbbfa8d6f10>, <Reaction NH4tm_M at 0x7fbbfa8d6f40>, <Reaction O2tmr_M at 0x7fbbfa8d6f70>, <Reaction FADH2tm_M at 0x7fbbfa8d6fa0>, <Reaction FADtm_M at 0x7fbbfa8d6fd0>, <Reaction PItm_M at 0x7fbbfa8d6ee0>, <Reaction H2O2tm_M at 0x7fbbfa8d6d90>, <Reaction ATPtm_M at 0x7fbbfa7e3100>, <Reaction SUCFUMtmr_M at 0x7fbbfa7e3220>, <Reaction GLYtm_M at 0x7fbbfa7e3070>, <Reaction SERtm_M at 0x7fbbfa7e3340>, <Reaction DICtm_M at 0x7fbbfa7e31c0>, <Reaction MALAKGtm_M at 0x7fbbfa7e3190>, <Reaction SO4AKGtm_M at 0x7fbbfa7e3400>, <Reaction AKGICITtm_M at 0x7fbbfa7e31f0>, <Reaction OAAICITtm_M at 0x7fbbfa7e3310>, <Reaction ACCOAtm_M at 0x7fbbfa7e3520>, <Reaction SO3tm_M at 0x7fbbfa7e33d0>, <Reaction PEtm_M at 0x7fbbfa7e3580>, <Reaction PStm_M at 0x7fbbfa7e3550>]
# [<Reaction DHORSts_M at 0x7fbbfa7e3130>, <Reaction OROTts_M at 0x7fbbfa7e3700>, <Reaction ACCOAts_M at 0x7fbbfa7e34f0>, <Reaction ASPts_M at 0x7fbbfa7e3760>, <Reaction CYSts_M at 0x7fbbfa7e3670>, <Reaction GLYts_M at 0x7fbbfa7e37c0>, <Reaction METts_M at 0x7fbbfa7e36d0>, <Reaction G1P_LPAREN_pi_RPAREN_ts_M at 0x7fbbfa7e3880>, <Reaction DHAP_LPAREN_pi_RPAREN_tsr_M at 0x7fbbfa7e37f0>, <Reaction 3PG_LPAREN_pi_RPAREN_tsr_M at 0x7fbbfa7e3940>, <Reaction ATP2ts_M at 0x7fbbfa7e3a00>, <Reaction H2Ots_M at 0x7fbbfa7e3910>, <Reaction CO2ts_M at 0x7fbbfa7e3a60>, <Reaction NH4ts_M at 0x7fbbfa7e3ac0>, <Reaction O2tsr_M at 0x7fbbfa7e39d0>, <Reaction Pits_M at 0x7fbbfa7e3b20>, <Reaction HCYSts_M at 0x7fbbfa7e3a30>, <Reaction ATPts_M at 0x7fbbfa7e3b80>, <Reaction MALFUMts_M at 0x7fbbfa7e3a90>, <Reaction UTPUMPts_M at 0x7fbbfa7e3ca0>, <Reaction CTPts_M at 0x7fbbfa7e3c10>, <Reaction UTPts_M at 0x7fbbfa7e3d60>, <Reaction HCO3_LPAREN_h_RPAREN_tsi_M at 0x7fbbfa7e3c70>, <Reaction PYRts_M at 0x7fbbfa7e3cd0>, <Reaction SO3t_M at 0x7fbbfa7e3e20>, <Reaction FA160s_M at 0x7fbbfa7e3d30>, <Reaction FA180s_M at 0x7fbbfa7e3e80>]
# [<Reaction H2Otv_M at 0x7fbbfa7e3d90>, <Reaction O2tv_M at 0x7fbbfa7e3ee0>, <Reaction H2O2tv_M at 0x7fbbfa7e3df0>]
# []
# [<Reaction FA140CoAr_M at 0x7fbbfa1e4100>, <Reaction FA160CoAr_M at 0x7fbbfa1e4130>, <Reaction FA161CoAr_M at 0x7fbbfa1e4160>, <Reaction FA181CoAr_M at 0x7fbbfa1e4190>, <Reaction FA182CoAr_M at 0x7fbbfa1e41c0>, <Reaction FA183CoAr_M at 0x7fbbfa1e41f0>, <Reaction FA140r_M at 0x7fbbfa1e4220>, <Reaction AMETt2r_M at 0x7fbbfa1e4250>, <Reaction ATPtr_M at 0x7fbbfa1e4280>, <Reaction ATP2tr_M at 0x7fbbfa1e42b0>, <Reaction H2Otr_M at 0x7fbbfa1e42e0>, <Reaction CO2tr_M at 0x7fbbfa1e4310>, <Reaction Pitr_M at 0x7fbbfa1e4340>, <Reaction SERtr_M at 0x7fbbfa1e4370>, <Reaction COA_LPAREN_h_RPAREN_tr_M at 0x7fbbfa1e43a0>, <Reaction GLYC3Ptr_M at 0x7fbbfa1e43d0>, <Reaction CTPtr_M at 0x7fbbfa1e4400>, <Reaction CMPtr_M at 0x7fbbfa1e4430>, <Reaction PEtr_M at 0x7fbbfa1e4460>, <Reaction PStr_M at 0x7fbbfa1e4490>, <Reaction INOSTtr_M at 0x7fbbfa1e44c0>]
# [<Reaction O2tu_M at 0x7fbbfa1e44f0>, <Reaction H2Otu_M at 0x7fbbfa1e4520>]
# [<Reaction DM_COA_LPAREN_c_RPAREN__M at 0x7fbbfa1e4550>, <Reaction DM_photonDrain_LPAREN_u_RPAREN__M at 0x7fbbfa1e4580>]
# /home/rtsantos3/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
