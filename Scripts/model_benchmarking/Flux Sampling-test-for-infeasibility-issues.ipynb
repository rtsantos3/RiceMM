# %%
import sys 
import os
import cobra
import libsbml
import pandas as pd
import copy
from pathlib import Path
import memote
import csv
import pytest
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import xlsxwriter
import path 
import datetime
import scipy.sparse as sp
import warnings
import multiprocessing
from tqdm import tqdm
from functools import partial  
from parallelbar import progress_map


from cobra import sampling
# from cobra import Reaction

#Change working dir first, ty ChatGPT, much loves
cwd = os.getcwd()
# Split the path into a list of directories
directories = cwd.split(os.sep)
# Remove the last two directories from the list
directories = directories[:-2]
# Join the directories back into a path
new_cwd = os.sep.join(directories)
# Change the current working directory to the new path
os.chdir(new_cwd)

sys.path.append("./src")

import model_manipulation  as mm

#Add a log object to scripts
logs_dir ='./logs/'



# Function to get the current date and time in a specific format
def get_current_datetime():
    return datetime.datetime.now().strftime("[%Y%m%d-%H:%M:%S] ")



class Logger(object):
    def __init__(self, file):
        self.terminal = sys.stdout
        self.log = open(file, "a")

    def write(self, message):
        self.terminal.write(message)
        self.log.write(message)
        self.log.flush()  # Ensure the log is immediately written to the file

    def flush(self):
        pass

# %%
#This codeblock is to define some of the functions used for modelling

##UPDATED JULY 28 2023

##NOTES:
##Fixed wrong encoding of reactions for Malate dehydrogenase as well as NADP ME.



#Define linear relationship between PPFD and Cellular maintainance costs
#This formula comes from Topfer et al (2020) where she defined NGAM in a linear relationship with incident light
inf=1e6

def generate_constraint(model,reaction, name, lb, ub):
    reaction_fex = model.reactions.get_by_id(name).flux_expression
    constraint = model.problem.Constraint(reaction_fex, lb=lb, ub=ub)
    constraint.name = name + '_constraint'
    model.add_cons_vars

def compute_ngam_atp(ppfd):
    v_atp = 0.0049*ppfd + 2.7851
    return v_atp


#This function is used to set the inputs to the model used. 
def define_model_medium(model, co2, o2, ppfd, 
                        medium_dir='./misc/photo_medium.csv', no3=inf, h2o=inf, h=inf, 
                        nh4=inf, pi=inf):
    model_photo_media = mm.read_medium_csv(medium_dir, model)
    model_photo_media['EX_no3(e)'] = no3
    model_photo_media['EX_h2o(e)'] = h2o
    model_photo_media['EX_h(e)'] = h
    model_photo_media['EX_nh4(e)'] = nh4
    model_photo_media['EX_co2(e)'] = co2
    model_photo_media['EX_o2(e)'] = o2
    model_photo_media['EX_photonVis(e)'] = ppfd
    model_photo_media['EX_pi(e)'] = pi
    #Set set model medium as model
#     print('Added model medium')
    return model_photo_media

    
def turn_off_cofac_cycles(model, inact_dir='./misc/leaf_inactivated.tsv'):
    file = csv.reader(open(inact_dir), delimiter='\t')
    leaf_inactive_rxns = list()
    for rows in file:
        row_m = str()
        row_bs = str()
        for rxns in rows:
            row_m += str(rxns) + "_M"
            row_bs += str(rxns) + "_BS"
        leaf_inactive_rxns.append(row_m)
        leaf_inactive_rxns.append(row_bs)
        
    for rxns in model.reactions:
        if rxns.id in leaf_inactive_rxns:
            rxns.bounds = (0,0)
#     print('Successfully turned off cofactor-cycling reactions')

    
# #Add constraints to model
#This code block contains constraints that would simulate the assimilation rates of bs and m cells in a two-cell system (such as those seen near the midvein region of rice leaves)
# #BS photon flux must be the same/less than M flux (Adapted from B&B, 2019)
# photon_import = model.reactions.get_by_id("EX_photonVis(e)")
def add_tissue_constraints(model):
    #For input fluxes for light, we will set the flux ratio to 10:1 to reflect the anatomical proportions of our model ()
    
    BS_photon_import = model.reactions.PRISM_white_LED_BS
    M_photon_import = model.reactions.PRISM_white_LED_M

    #Set photon flux ratio to 10:1
    photon_flux = mm.set_fix_flux_ratio({M_photon_import.id:10, BS_photon_import.id:1},model)
    model.add_cons_vars(photon_flux)

    
    #UPDATE: Change CO2 intake to the M Cell instead rather than set a ratio, which is a better assumption overall. Assume na lang that external gasses are assimilated
    #Via the M cell.
    #From Morrison et al 2005 -- Lateral diffusion of Gases is unlikely to support photosynthesis due to the
    #assimilation of diffused CO2 in tissues prior to BS//
    model.reactions.CO2tex_BS.bounds = (0,0)
    model.reactions.O2tex_BS.bounds = (0,0)
    
    #UPDATE: This assumption does not hold considering that recent transcriptomic analysis confirms that 
    #the bundle sheath is involved in the assimilation of inorganic nutrients, including nitrogen (nitrates/ammonia), and 
    #Sulfates. In turn, this will be implemented by simply setting the exchanges to the M cell to 0. (Hua et al, 2021)
    model.reactions.SO3tex_M.bounds = (0,0)
    model.reactions.SO4tex_M.bounds = (0,0)
    model.reactions.NH4tex_M.bounds = (0,0)
    model.reactions.NO3tex_M.bounds = (0,0)
    
    #Model will also constraint H2O input to BS cell only as it is also assumed that BS tissue in rice is specialized for H2O transport (Hua et al. 2021)
    #There is a demand reaction naman for H2O for the M cell which is not connected to the BS H2Otex
    #Restrict H2O transport to be unidirectional from the BS cell
    model.reactions.H2Otex_M.bounds = (0, 0)
    model.reactions.h2o_pd.bounds = (-inf, 0)
    
    #need to turn off HCO import as the model incorrectly transfers fixed HCO to the BS cell via the common pool compartment
    model.reactions.HCO3tex_M.bounds = (0,0)
    model.reactions.HCO3tex_BS.bounds = (0,0)
    
    #Turn off extracellular Glycine transport 
    model.reactions.GLYtex_M.bounds = (0,0)
    model.reactions.GLYtex_BS.bounds = (0,0)
    
    #Turn off other Demand reactions that may serve as sinks for the model except DM_Phloem_BS (Which represents the output of photoassimilate thru the BS cell
    model.reactions.DM_Phloem_M.bounds = (0,0)
    model.reactions.Straw_Biomass_M.bounds = (0,0)
    model.reactions.Straw_Biomass_BS.bounds = (0,0)
    model.reactions.Coleoptile_Biomass_M.bounds = (0,0)
    model.reactions.Coleoptile_Biomass_BS.bounds = (0,0)
    model.reactions.DM_Phloem_BS.bounds = (0, inf)
    

def add_enzyme_constraints(model, 
                           wt_pepc = 0, 
                           wt_mdh = 11.18, 
                           wt_nadp_me = 0.14, 
                           wt_ppdk=0.31,
                          wt_CA=7.5):
    
    
    # #This code block contains constraints specific for enzyme rate constraints
    #This approach is derived from Bogart & Myers (2016) where they constrained the enzyme rate 
    #fluxes in each of the 2-cell segments to a specific upper bound while keeping the lower bound
    #At 0. For reversible reactions the lower bounds are set to the same value
    
    
    #PEPC constraint (Reaction id: PPCc)
    #Need to constrain it to 0 since reaction is only detected in Vascular tissue
    pepc_BS = model.reactions.PPCc_BS
    pepc_M = model.reactions.PPCc_M
    
    pepc_BS.bounds = (0,0)
    pepc_M.bounds = (0,0)

    #PPDK constraints (Reaction id: PPDKs) (note that this is found in the chloroplast?) 
    #Not detected via immunolocalization but enzyme activity is detected

    ppdks_BS = model.reactions.PPDKs_BS
    ppdks_M = model.reactions.PPDKs_M
    ppdkc_BS = model.reactions.PPDKc_BS
    ppdkc_M = model.reactions.PPDKc_M
    wt_ppdks_cons = model.problem.Constraint(ppdks_BS.flux_expression 
                                             + ppdks_M.flux_expression
                                             + ppdkc_BS.flux_expression
                                             + ppdkc_M.flux_expression, 
                                             lb = 0, ub = wt_ppdk)
    wt_ppdks_cons.name = 'wt_ppdks_cons'
    model.add_cons_vars(wt_ppdks_cons)
    
    
    #Malate Dehydrogenase 
    #Only mitochondrial in WT Rice M cells
    #Reactions encoded in the model include MDHs, MDHc, MDHx.
    model.reactions.MDHs_M.bounds = (0,0)
    model.reactions.MDHc_M.bounds = (0,0)
    model.reactions.MDHx_M.bounds = (0,0)
    model.reactions.MDHs_BS.bounds = (0,0)
    model.reactions.MDHc_BS.bounds = (0,0)
    model.reactions.MDHx_BS.bounds = (0,0)
    model.reactions.MDHm_BS.bounds = (0,0)
    #Add constraints to MDHm
    mdhm_M = model.reactions.MDHm_M
    
    wt_mdh_cons = model.problem.Constraint(mdhm_M.flux_expression,
                                           lb= -wt_mdh, ub=wt_mdh)
    wt_mdh_cons.name = "wt_mdh_cons"
    model.add_cons_vars(wt_mdh_cons)

    
    
    #NADP-ME (Since no signal is detected in WT, no locational constraints are imposed)
    #Let's see if I can force it to have a small amount of flux 
    mdh2s_M = model.reactions.MDH2s_M
    mdh2s_BS = model.reactions.MDH2s_BS
    mdh2c_M = model.reactions.MDH2s_M
    mdh2c_BS = model.reactions.MDH2s_BS


    wt_nadpme_cons = model.problem.Constraint(mdh2s_M.flux_expression
                                             + mdh2s_BS.flux_expression
                                              + mdh2c_M.flux_expression
                                              + mdh2c_BS.flux_expression,
                                             lb= 0, ub=wt_nadp_me)
    wt_nadpme_cons.name = "wt_nadpme_cons"
    model.add_cons_vars(wt_nadpme_cons)


    #I should add constraints for Carbonic Anhydrase 
    #I should constrain it to 0.4 ubar, which would constitute ambient CO2 partial pressure
    #Flux is reversible so constraints are bi-directional
    #This should be revised considering that it allows reversible reactions  and an abnormally high flux thru carbonic anhydrase, which shouldn't be the case

    hco3es_m = model.reactions.HCO3Es_M.flux_expression
    hco3ec_m = model.reactions.HCO3Ec_M.flux_expression
    hco3em_m = model.reactions.HCO3Em_M.flux_expression
    hco3es_bs = model.reactions.HCO3Es_BS.flux_expression
    hco3ec_bs = model.reactions.HCO3Ec_BS.flux_expression
    hco3em_bs = model.reactions.HCO3Em_BS.flux_expression

    ca_cons = model.problem.Constraint(hco3es_m + hco3ec_m + hco3em_m 
                                       + hco3es_bs + hco3ec_bs + hco3em_bs,
                                      lb = -wt_CA, ub = wt_CA)
    ca_cons.name = 'Carbonic_anhydrase_constraint'
    model.add_cons_vars(ca_cons)


    #Rbcl constaints
    #Retrieve flux expressions oof each RBCl reaction
    rbpc_M = model.reactions.RBPCs_M.flux_expression
    rbpc_BS = model.reactions.RBPCs_BS.flux_expression
    rbpo_M = model.reactions.RBPOs_M.flux_expression
    rbpo_BS = model.reactions.RBPOs_BS.flux_expression

    #Constraint such that it is limited to 132 umol m-2 s-1
    rbcl_vcmax_cons = model.problem.Constraint(rbpc_M + rbpc_BS, lb = 0, ub= 132)
    rbcl_vcmax_cons.name='rbcl_vcmax_cons'
    model.add_cons_vars(rbcl_vcmax_cons)
    #Constraints for rbcl flux such that v_c/v_o = 3 or higher.
    rbcl_vcvo = model.problem.Constraint(3*(rbpo_M + rbpo_BS) 
                                         - 1*(rbpc_M + rbpc_BS),
                                         lb=0,ub=1000)
    rbcl_vcvo.name = 'rbcl_vc/vo_ratio'
    model.add_cons_vars(rbcl_vcvo)

    #Turn off the RBPC2s reactions since we already defined the constraints above
    model.reactions.RBPC2s_M.bounds = (0,0)
    model.reactions.RBPC2s_BS.bounds = (0,0)
    
    
    
    #What if I simply constrained that of the M cell one to 3:1?
    #This constraint is pretty good actually. 
    #This allows the system to be set at a specific Vc/Vo rate while still allowing local variation 
    #wherein Rubisco may act in an uncoupled fashion and may have favorable internal vc/vo rates.
# #This code block is to set a constraint such that M-to-BS cell NGAM ratio is 10-to-1 
# #Similar to what Moreno-Villena et al (2022) had done 

#This function takes two arguments: the model and the maximal  ppfd input to the system
def add_ngam_cons(model, ppfd): 
    #Turn off other ngam reactions
    model.reactions.ngam_atp_s_M.bounds = (0,0)
    
    model.reactions.ngam_atp_x_M.bounds = (0,0)
    model.reactions.ngam_atp_m_M.bounds = (0,0)
    
    model.reactions.ngam_atp_s_BS.bounds = (0,0)
    model.reactions.ngam_atp_x_BS.bounds = (0,0)
    model.reactions.ngam_atp_m_BS.bounds = (0,0)
    
    ngam_atp_m = mm.get_rxn(model, 'ngam_atp_c_M')
    ngam_atp_bs = mm.get_rxn(model, 'ngam_atp_c_BS')
    
    
    
    ngam_atp_m.bounds = (0,inf)
    ngam_atp_bs.bounds = (0,inf)
    ngam_ratio = mm.set_fix_flux_ratio({ngam_atp_m.id:10, ngam_atp_bs.id:1}, model)
    ngam_ratio.name = 'ngam_BS/M_ratio'
    model.add_cons_vars(ngam_ratio)

    #Retrieve NGAM reactions
    ngam_nadphox_c_M = mm.get_rxn(model, 'ngam_nadphox_c_M')
    ngam_nadphox_s_M = mm.get_rxn(model, 'ngam_nadphox_s_M')
    ngam_nadphox_m_M = mm.get_rxn(model, 'ngam_nadphox_m_M')
    ngam_nadphox_c_BS = mm.get_rxn(model, 'ngam_nadphox_c_BS')
    ngam_nadphox_s_BS = mm.get_rxn(model, 'ngam_nadphox_s_BS')
    ngam_nadphox_m_BS = mm.get_rxn(model, 'ngam_nadphox_m_BS')


    #Set Fixed fluxes
    nadphox_c_s_M = mm.set_fix_flux_ratio({ngam_nadphox_c_M.id:1, ngam_nadphox_s_M.id:1},model)
    nadphox_c_s_M.name = "nadphox_cs_ratio_M"
    nadphox_s_m_M = mm.set_fix_flux_ratio({ngam_nadphox_s_M.id:1, ngam_nadphox_m_M.id:1}, model)
    nadphox_s_m_M.name = "nadphox_sm_ratio_M"

    nadphox_c_s_BS = mm.set_fix_flux_ratio({ngam_nadphox_c_BS.id:1, ngam_nadphox_s_BS.id:1},model)
    nadphox_c_s_BS.name = "nadphox_cs_ratio_BS"
    nadphox_s_m_BS = mm.set_fix_flux_ratio({ngam_nadphox_s_BS.id:1, ngam_nadphox_m_BS.id:1}, model)
    nadphox_s_m_BS.name = "nadphox_sm_ratio_BS"

    #Add constraints
    model.add_cons_vars(nadphox_c_s_M)
    model.add_cons_vars(nadphox_s_m_M)
    model.add_cons_vars(nadphox_c_s_BS)
    model.add_cons_vars(nadphox_s_m_BS)

    #Retrieve flux expressionns
    fex_nadphox_c_M =  mm.get_flux_exp(model, ngam_nadphox_c_M)
    fex_nadphox_s_M = mm.get_flux_exp(model, ngam_nadphox_s_M)
    fex_nadphox_m_M = mm.get_flux_exp(model, ngam_nadphox_m_M)

    fex_nadphox_c_BS =  mm.get_flux_exp(model, ngam_nadphox_c_BS)
    fex_nadphox_s_BS =  mm.get_flux_exp(model, ngam_nadphox_s_BS)
    fex_nadphox_m_BS =  mm.get_flux_exp(model, ngam_nadphox_m_BS)

    fex_atp_c_M = mm.get_flux_exp(model, ngam_atp_m)
    fex_atp_c_BS =  mm.get_flux_exp(model, ngam_atp_bs)

    #Set the constraint between ATP:NADPH NGAM to 3:1
    nadphox_atpase = model.problem.Constraint(3*(fex_nadphox_c_M + fex_nadphox_s_M + fex_nadphox_m_M
                                                       + fex_nadphox_c_BS + fex_nadphox_s_BS + fex_nadphox_m_BS) 
                                         - 1*(fex_atp_c_M + fex_atp_c_BS),
                                         lb=0,ub=0)
    nadphox_atpase.name = "nadphox_atpase_ratio"
    model.add_cons_vars(nadphox_atpase)
    #Compute NGAM value and add constraint as a lower bound/upper bound to model
    ngam_value = compute_ngam_atp(ppfd)
    ngam_cons = model.problem.Constraint(fex_atp_c_M + 
                                        fex_atp_c_BS, lb=ngam_value, ub=ngam_value)
    ngam_cons.name = 'NGAM_ATP_constraint'
    model.add_cons_vars(ngam_cons)
    
#This code  block gives a snapshot of the relevant fluxes on each of the cell types based on the saved sample_fluxes values above

def print_summary(model, sample_fluxes_df):
    print('rbcl M cell: ', sample_fluxes['RBPCs_M'], 'rbcl BS cell: ',sample_fluxes['RBPCs_BS'])
    print('rbcl M cell (photorespiration)', sample_fluxes['RBPOs_M'], 'rbcl BS cell (PR)', sample_fluxes['RBPOs_BS'])
    print('vc/vo M:', sample_fluxes['RBPCs_M']/sample_fluxes['RBPOs_M'], 'vc/vo BS:', sample_fluxes['RBPCs_BS']/sample_fluxes['RBPOs_BS'])
    print('RBPC2s_M', sample_fluxes['RBPC2s_M'], 'RBPC2s_BS', sample_fluxes['RBPC2s_BS'])
    print('PEPC M', sample_fluxes['PPCc_M'], 'PEPC BS', sample_fluxes['PPCc_BS'])
    print('Carbonic Anhydrase (Cytosolic) M', sample_fluxes['HCO3Ec_M'], 'Carbonic Anhydrase (Cytosolic) BS', sample_fluxes['HCO3Ec_BS'])
    print('NADP-ME M', sample_fluxes['MDHys_M'], 'NADP-ME BS', sample_fluxes['MDHys_BS'])
    print('Biomass M: ', sample_fluxes['Straw_Biomass_M'], 'Biomass BS', sample_fluxes['Straw_Biomass_BS'])
    print('Phloem M: ', sample_fluxes['DM_Phloem_M'], 'Phloem BS', sample_fluxes['DM_Phloem_BS'])
    print('co2 consumption M', sample_fluxes['CO2tex_M'], 'co2 consumption BS', sample_fluxes['CO2tex_BS'])
    print('o2 consumption M', sample_fluxes['O2tex_M'], 'o2 consumption BS', sample_fluxes['O2tex_BS'])
    print('Photosystem II M', sample_fluxes['PSIINC_M'], 'PSII BS', sample_fluxes['PSIINC_BS'])
    print('PSI M', sample_fluxes['PSIMR_M'], 'PSI BS', sample_fluxes['PSIMR_BS'])
    print('PPFD M: ', sample_fluxes['PRISM_white_LED_M'], 'PPFD BS: ', sample_fluxes['PRISM_white_LED_BS'])
    print('ATP synthesis (stromal) M', sample_fluxes['ATPSs_M'], 'ATP synthase (mit) M', sample_fluxes['ATPSm_M'])
    pd_rxn = [x for x in model.reactions if "pd" in x.id and "h2o" not in x.id]
    pd_abs_flux = 0
    for pds in pd_rxn:
        pd_abs_flux += abs(sample_fluxes[pds.id])
    
    print('pd_abs_flux: ', pd_abs_flux)
    
#initialize list of transgenic reactions to add  to model

def add_trans_reactions(model):
    '''
    This function is used to add a number of new tissue-specific reactions that were not present in the
    original model to facilitate modelling of the transgenic C4 rice
    '''
    trans_list = list()
    #Transgenic PEPC copy
    #PEPC = Chloroplastic in M & V (rxn id: PPCc)
    trans_ppcs = Reaction('trans_PPCs_M')
    trans_ppcs.name = "Phosphoenolpyruvate carboxylase, plastidic (Transgenic)"
    
    pep_s0 = model.metabolites.pep_s0
    hco3_s0 = model.metabolites.hco3_s0
    oaa_s0 = model.metabolites.oaa_s0
    pi_s0 = model.metabolites.pi_s0


    #Add metabolites, bounds, and subsystem
    trans_ppcs.add_metabolites({hco3_s0:-1, pep_s0:-1, oaa_s0:1, pi_s0:1})
    trans_ppcs.bounds= model.reactions.PPCc_M.bounds
    trans_ppcs.subsystem = model.reactions.PPCc_M.subsystem

    trans_list.append(trans_ppcs)


    #Transgenic PPDK Copy
    trans_ppdks_m = Reaction('trans_PPDKs_M')
    trans_ppdks_m.add_metabolites(model.reactions.PPDKs_M.metabolites)
    trans_ppdks_m.bounds = model.reactions.PPDKs_M.bounds
    trans_ppdks_m.name = "Pyruvate phosphate dikinase, plastidic (Transgenic)"

    trans_ppdks_bs = Reaction('trans_PPDKs_BS')
    trans_ppdks_bs.add_metabolites(model.reactions.PPDKs_BS.metabolites)
    trans_ppdks_bs.bounds = model.reactions.PPDKs_BS.bounds
    trans_ppdks_bs.name = "Pyruvate phosphate dikinase, plastidic (Transgenic)"

    trans_list.append(trans_ppdks_m)
    trans_list.append(trans_ppdks_bs)

    #Transgenic NADP-ME
    #NADP-ME = Mitochondrial in M
    trans_nadp_me = Reaction('trans_MDH2m_M')

    #retrieve reactants
    mal_m0 = model.metabolites.get_by_id('mal-L_m0')
    nadp_m0 = model.metabolites.nadp_m0
    co2_m0 = model.metabolites.co2_m0
    nadph_m0 = model.metabolites.nadph_m0
    pyr_m0 = model.metabolites.pyr_m0

    #Add to rxn
    trans_nadp_me.add_metabolites({mal_m0:-1, nadp_m0:-1, co2_m0:1, nadph_m0:1, pyr_m0:1})
    #Add bounds
    trans_nadp_me.bounds=(-inf, inf)

    trans_list.append(trans_nadp_me)


    #Trans CA
    #Cytosolic in M
    trans_hco3ec_M = Reaction('trans_hco3ec_M')
    trans_hco3ec_M.name = 'carbonic anhydrase, cytosolic'
    trans_hco3ec_M.add_metabolites(model.reactions.HCO3Ec_M.metabolites)
    trans_hco3ec_M.bounds = model.reactions.HCO3Ec_M.bounds

    trans_hco3ec_M.subsystem = model.reactions.HCO3Ec_M.subsystem
    trans_list.append(trans_hco3ec_M)


    #Bulk add to model
    model.add_reactions(trans_list)
    
    model.repair()
####ADDING TRANS CONSTRAINTS

def add_trans_constraints(model,
                         trans_pepc_rates = 7.01,
                         trans_ppdks_rates = 3.66,
                         trans_mdh_rates = 152.87,
                         trans_nadp_me_rates = 0.60,
                         trans_CA_rates = 8):
    '''
    This function is used to add another layer of constraints to parametize model based on the
    Enzyme reaction rates assayed from Ermakova et al (2021) where the locations are based on the 
    each of the transgenic enzyme's tissue-specific localizations. 
    '''
    
    #PEPC constraint
    wt_PPCc_M = mm.get_rxn(model, 'PPCc_M')
    wt_PPCc_BS = mm.get_rxn(model, 'PPCc_BS')
    trans_PPCs_M = mm.get_rxn(model, 'trans_PPCs_M')                           
    trans_PEPC_cons = model.problem.Constraint(trans_PPCs_M.flux_expression
                                            +wt_PPCc_BS.flux_expression 
                                            + wt_PPCc_M.flux_expression, 
                                            lb = 0, ub = trans_pepc_rates)

    model.add_cons_vars(trans_PEPC_cons)

    #PPDK constraint
    trans_PPDKs_M  = mm.get_rxn(model, 'trans_PPDKs_M')
    trans_PPDKs_BS = mm.get_rxn(model, 'trans_PPDKs_BS')
    wt_PPDKs_M = mm.get_rxn(model, 'PPDKs_M')
    wt_PPDKs_BS = mm.get_rxn(model, 'PPDKs_BS')
    
    trans_PPDKs_cons = model.problem.Constraint( 
        trans_PPDKs_BS.flux_expression + trans_PPDKs_M.flux_expression 
        +wt_PPDKs_BS.flux_expression + wt_PPDKs_M.flux_expression, 
                                             lb = 0, ub = trans_ppdks_rates)
    trans_PPDKs_cons.name = 'trans_ppdks_cons'
    model.add_cons_vars(trans_PPDKs_cons)
    


    #Malate Dehydrogenase Constraints
    trans_MDHm_M = mm.get_rxn(model, 'MDHm_M')
    trans_MDHs_M = mm.get_rxn(model, 'MDHs_M')
    trans_MDHs_BS = mm.get_rxn(model, 'MDHs_BS')
    
    #Change bounds to reflect the Trans state (Based on Immunoblotting)
    trans_MDHm_M.bounds = (-inf, inf)
    trans_MDHs_M.bounds = (-inf, inf)
    trans_MDHs_BS.bounds = (-inf, inf)
    
    trans_mdh_cons =  model.problem.Constraint(
       trans_MDHm_M.flux_expression + 
        trans_MDHs_M.flux_expression + 
        trans_MDHs_BS.flux_expression, 
        lb= -trans_mdh_rates, ub=trans_mdh_rates)

    trans_mdh_cons.name = "trans_mdh_cons"
    model.add_cons_vars(trans_mdh_cons)

    
    
#     #Add NADP-ME constraints
#     trans_MDH2m_M = mm.get_rxn(model, 'trans_MDH2m_M')
#     wt_MDH2s_M = mm.get_rxn(model, 'MDH2s_M')
#     wt_MDH2s_BS = mm.get_rxn(model, 'MDH2s_BS')
    
    
    
#     trans_nadpme_cons = model.problem.Constraint(
#         trans_MDH2m_M.flux_expression + 
#         wt_MDH2s_M.flux_expression + 
#         wt_MDH2s_BS.flux_expression,
#         lb= -trans_nadp_me_rates, ub=trans_nadp_me_rates)
    
#     trans_nadpme_cons.name = "trans_nadpme"
#     model.add_cons_vars(trans_nadpme_cons)

    #Add carbonic anhydrase constraints

    trans_hco3ec_M = mm.get_rxn(model, 'trans_hco3ec_M')
    wt_hco3ec_M = mm.get_rxn(model, 'HCO3Ec_M')
    wt_hco3em_M = mm.get_rxn(model, 'HCO3Em_M')
    wt_hco3es_M = mm.get_rxn(model, 'HCO3Es_M')
    wt_hco3ec_BS = mm.get_rxn(model, 'HCO3Ec_BS')
    wt_hco3em_BS = mm.get_rxn(model, 'HCO3Em_BS')
    wt_hco3es_BS = mm.get_rxn(model, 'HCO3Es_BS')
    
    trans_ca_cons = model.problem.Constraint(trans_hco3ec_M.flux_expression + 
                                             wt_hco3es_M.flux_expression + 
                                             wt_hco3ec_M.flux_expression + 
                                             wt_hco3em_M.flux_expression + 
                                             wt_hco3es_BS.flux_expression + 
                                             wt_hco3ec_BS.flux_expression + 
                                             wt_hco3em_BS.flux_expression,
                                      lb = -trans_CA_rates, ub = trans_CA_rates)
    trans_ca_cons.name = 'Trans_CA_cons'
    model.add_cons_vars(trans_ca_cons)
    model.repair()
    


#Read 2-cell model
wt_model = cobra.io.read_sbml_model("./model/ios2164_2cell.xml")
trans_model = cobra.io.read_sbml_model("./model/ios2164_2cell.xml")

wt_model.solver = 'gurobi'
trans_model.solver = 'gurobi'
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-05-09

# %%
def generate_flux_samples(model, num_samples, batch_size, output_filename,thinning,processes=7, nproj=None,output_dir='./flux_results/flux_sampling/'):
    #This function is used to initialize a flux sampler and afterwards generate a csv file containing the sample solutions.
    #default batch size is 1000

    #Generate sampler
    print("generating sampler for model")
    sampler = sampling.OptGPSampler(model, processes=processes, thinning=thinning, nproj=nproj)
    print("done generating OPTGP sampler")
    
    
    #Define output file
    output_dir = str(output_dir)
    output_filename = str(output_filename)

    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
        
    print('saving output to ', f"{output_dir}/{output_filename}")



    for i in range(num_samples // batch_size):
        print(f"Generating batch {i+1}/{num_samples//batch_size}")
        samples = sampler.sample(n=batch_size)
        df = pd.DataFrame(samples, columns=model.reactions.list_attr("id"))
        if i == 0:
            df.to_csv(f"{output_dir}/{output_filename}", index=False)
        else:
            df.to_csv(f"{output_dir}/{output_filename}", index=False, header=False, mode="a")
        
    

def parametrize_model(model, ppfd_low, ppfd_high, co2,if_trans, loopless=False, frac_optimum=1, pruning=False, fva_bounds_file='', intermediate_fva_results='', save_final_bounds_file=''):
    
    
    model_instance=model.copy()
    model_instance.tolerance = 1e-9


    print('start time for parametrize_model(): ' ,datetime.datetime.now())
    model_instance.medium = define_model_medium(model_instance, co2=co2, o2=inf, ppfd=inf, h=inf, nh4=inf, no3=inf)
    turn_off_cofac_cycles(model_instance)
    add_tissue_constraints(model_instance)
    add_enzyme_constraints(model_instance)

    #Adds NGAM (Computed as an average between the high and low instead of directly constraining it to the model, w/c makes the problem non-linear)
    add_ngam_cons(model_instance, (ppfd_high+ppfd_low)/2)

    #Constrain PPFD range to indicated value
    model_instance.reactions.get_by_id('EX_photonVis(e)').bounds = (-1*ppfd_high, -1*ppfd_low)


    #Check if trans then add constraints if true
    if if_trans==True:
        add_trans_reactions(model_instance)
        add_trans_constraints(model_instance)


    #Readd objective coefficient, maybe it'll work?
    model_instance.reactions.get_by_id('DM_Phloem_BS').objective_coefficient = 1

    '''Run FVA to preprocess the model to fix reaction reversibilities as well as to ensure that there are no "extreme" fluxes in the final sampling
     Perform Flux Variability Analysis (FVA)
        This step constrains the upper and lower bounds to the detected "Maximal" and "minimal" fluxes given an objective
        The default fraction of optimum will be implemented
    Will implement pFBA factor to constrain the model to 110% of the detected lowest net fluxes'''


    list_infeasibles = list()

    #flux_variability_analysis produces a Pandas Dataframe that can be taken apart and applied to the model_instance as direct bounds. 

    
    #This function reads the previous bounds to see whether i
    if fva_bounds_file:
        print('reading previous FVA bounds')
        fva_result = pd.read_csv(fva_bounds_file, index_col=0)
        fva_result.columns = ['minimum', 'maximum']

        # Create a list to store the reactions that need to be removed
        reactions_to_remove = []

        # Add reactions that are not in the fva_bounds_file to the rerunning FVA
        for rxn in model_instance.reactions:
            if rxn.id not in fva_result.index:
                # print(f'{rxn.id} not in previous bounds. Removing..')
                reactions_to_remove.append(rxn.id)
            else:
                if (fva_result.loc[rxn.id, 'minimum'] == 0) and (fva_result.loc[rxn.id, 'maximum'] == 0):
                    # print(f'{rxn.id} has 0/0 bounds in the previous result. Removing..')
                    reactions_to_remove.append(rxn.id)
        
        print(f'Reactions to remove: {len(reactions_to_remove)}')
        # Remove reactions from the model_instance
        model_instance.remove_reactions(reactions_to_remove)

        for i in reactions_to_remove:
            fva_result = fva_result.drop(index=i)
                
            
            
    else:
        print('computing Loopless FVA to model from scratch')
        fva_result = cobra.flux_analysis.flux_variability_analysis(model_instance, loopless=loopless, fraction_of_optimum=frac_optimum, pfba_factor=1.1, processes=7)


    # Set FVA constraints in the model
    print('setting FVA constraints to model')


    for reaction_id, bounds in fva_result.iterrows():
        reaction = model_instance.reactions.get_by_id(reaction_id)        



        #This method instead double checks the model per flux range and checks if it returns an infeasible solution/0 objective. 
        #First save old bounds 
        old_bounds = reaction.bounds

        # Check which is higher or lower to avoid Value errors
        lower_bound = float(min(bounds['minimum'], bounds['maximum']))
        upper_bound = float(max(bounds['minimum'], bounds['maximum']))

        #Check reaction if it is unbounded then append to list_infeasibles for rerunning
        if lower_bound==-1e6 or upper_bound==1e6 or np.nan in (lower_bound, upper_bound):
            # reaction.bounds = old_bounds
            print(f'reaction {reaction_id} is unbounded/nan. Adding to rerun list. {lower_bound}{upper_bound}')
            list_infeasibles.append(reaction)
            continue
        
        try:
            reaction.bounds = (lower_bound, upper_bound)
        
        except AttributeError: #For catching NaNs
            print(f'reaction {reaction_id} is has nan bounds. Adding to rerun list. {lower_bound}{upper_bound}')
            reaction.bounds = old_bounds
            list_infeasibles.append(reaction)
            continue
        
        
        else:
            try:
                #Fix the upper and lower bounds
                reaction.bounds = (lower_bound, upper_bound)

                #Generate solution and status for checking if model becomes infeasible due to the bounds. Otherwise recompute it
                solution = model_instance.slim_optimize()
                status= model_instance.optimize().status



                #Revert model to previous flux bounds in case it causes feasibility issues
                if status=='infeasible' or solution==0: #If it causes a 0 obj. function then it's considered broke
                    if reaction_id== 'DM_Phloem_BS':
                        print(f'objective bounds:{lower_bound}{upper_bound}')
                        continue


                    print(f'{reaction_id} causes infeasible status/0 objective!')
                    reaction.bounds=old_bounds
                    list_infeasibles.append(reaction)
                    continue

            except AttributeError:
                print(f'reaction {reaction_id} is unbounded/nan. Adding to rerun list. {lower_bound}{upper_bound}')
                reaction.bounds = old_bounds
                list_infeasibles.append(reaction)
                continue

        #I think this does more harm than good.


    print('Checking done. Length of reactions that cause infeasibility issues/unbounded: ', len(list_infeasibles))


    #Save intermediate FVA results (For debugging)
    if intermediate_fva_results != '':
        save_model_bounds(model_instance, f'{intermediate_fva_results}_before_pruning.csv', directory='./flux_results/flux_sampling/model_bounds/for_debugging/07292023')




    #Checks if there are any infeasible solutions in the model then reruns the non-loopless version on the NaNs list. This in turn reruns the model to use the non-loopless version of the algorithm instead. It would at least relax the bounds set by the loopless option
    #To bounds that are still feasible but still constrained somewhat (rather than setting it to a large value). The rationale behind this is that the first LL-FVA iteration already constrains the model to remove most loops while this iteration would ensure that the model returns a feasible solution

        #Rerun FVA
    if len(list_infeasibles) != 0:
        print('recomputing list_infeasibles')
        fva_non_loopless =  cobra.flux_analysis.flux_variability_analysis(model_instance, reaction_list=list_infeasibles, loopless=True ,fraction_of_optimum=frac_optimum, pfba_factor=1.1, processes=7)

        for reaction_id, bounds in fva_non_loopless.iterrows():
            reaction = model_instance.reactions.get_by_id(reaction_id)        
            # Check which is higher or lower to avoid Value errors
            lower_bound = float(min(bounds['minimum'], bounds['maximum']))
            upper_bound = float(max(bounds['minimum'], bounds['maximum']))
            print(f'setting bounds for rerun reaction {reaction_id}. Bounds: {lower_bound} | {upper_bound}')
            reaction.bounds = (lower_bound, upper_bound)

    #Intermediate check objective
    print('printing model objective:')
    print(model_instance.optimize())


    if pruning==True:
        blocked_reactions =  cobra.flux_analysis.find_blocked_reactions(model_instance, processes=7)
        print('reactions number (before pruning): ', len(model_instance.reactions))
        model_instance.remove_reactions(blocked_reactions)
        print('reactions number (after pruning): ', len(model_instance.reactions))

    # Identify unneeded metabolites
    unneeded_metabolites = []
    for metabolite in model.metabolites:
        if metabolite.reactions == []:
            unneeded_metabolites.append(metabolite)

    # Remove unneeded metabolites from the model
    model.remove_metabolites(unneeded_metabolites)



    #This ensures the model is feasible before passing to the solver (Infeasible models cannot generate any solutions)
    print('final model objective (Final feasibility check):')
    print(model_instance.optimize())

    print('end time for parametrize_model(): ' ,datetime.datetime.now())
    
    if save_final_bounds_file:
        
        save_model_bounds(model_instance, f'{save_final_bounds_file}_before_sampling.csv')


    return model_instance






def save_model_bounds(model, filename, directory='./flux_results/flux_sampling/model_bounds/'):
    # Create the directory if it doesn't exist
    if not os.path.exists(directory):
        os.makedirs(directory)

    # Get the bounds of each reaction in the model
    bounds = []
    for reaction in model.reactions:
        bounds.append([reaction.id, reaction.bounds[0], reaction.bounds[1]])

    # Create a DataFrame with the bounds
    bounds_df = pd.DataFrame(bounds, columns=['Reaction', 'Lower Bound', 'Upper Bound'])

    # Write the DataFrame to a CSV file
    filepath = os.path.join(directory, filename)
    bounds_df.to_csv(filepath, index=False)

    print(f"Model bounds saved to: {filepath}")

# %%
# '''June 22, 2023
# Let's try running this script with the following parameters in mind. Hopefully it doesn't result with infeasibility issues anymore.

# '''

# #Let's try running this script with the following parameters in mind. Hopwefully this doesn't result with infeasibility issues anymore
# #I suspect that the model is overconstrained due to the frac_optimum 
# WT_250_test =  parametrize_model(wt_model, 225,275,co2=29, if_trans=False, frac_optimum=0.90, loopless=True, pruning=True)

# #Generate list of models for flux sampling
# sampling_list = [WT_250_test]

# print('generating flux samples for parametrized models')
# for model in sampling_list:
#     print('start time for sampler generation: ' ,datetime.datetime.now())
#     model_name = str([k for k, v in locals().items() if v == model][0])
#     name_for_file = str('flux_sample_'+model_name+'_relaxed_Loopless_FVA.csv')
    
#     #Output the flux bounds of the model to ./fva_bounds/name_for_file
#     save_model_bounds(model, filename=name_for_file)
    
    
    
#     print('Starting OPTGP sampler:')
#     generate_flux_samples(model, num_samples =500, batch_size=500, thinning=1, output_filename=name_for_file)
#     del model #Deletes model instance to free up memory 
#     print('end time: ', datetime.datetime.now())
    
    
# '''June 23, 2023
# The modifications I've done works marvelously. It even fixes yung consumption ng inorganic nutrients, which was unobservable in the prior attempts. However run times are fairly large so I need to account for that.
# Some of my modifications include the following:
# setting the fraction optimum to 90% of optimum increasing the solution space for the inputs and outputs
# Setting the initial run as loopless then taking into account the reactions with infeasible solutions, and afterwards setting it to non-loopless

# Pruning the reaction set to account only for reactions with non-zero flux bounds

# '''

# %%
# %timeit

#Parametrize models per type by generating model instance

print('Generating parametrized models for flux sampling')
#Let's check if it works as a separate instance per WT and TR?
with wt_model as wt_model:
    WT_250 =  parametrize_model(wt_model, 225,275,co2=29, if_trans=False, frac_optimum=0.90, loopless=True, pruning=True, fva_bounds_file='./flux_results/flux_sampling/model_bounds/Modified-Loopless-FVA/WT_250.csv') #Done
    WT_750 = parametrize_model(wt_model, 725, 775,co2=29, if_trans=False, frac_optimum=0.90, loopless=True, pruning=True, fva_bounds_file='./flux_results/flux_sampling/model_bounds/Modified-Loopless-FVA/WT_750.csv')
    WT_1500 = parametrize_model(wt_model, 1475, 1525,co2=29, if_trans=False, frac_optimum=0.90, loopless=True, pruning=True, fva_bounds_file='./flux_results/flux_sampling/model_bounds/Modified-Loopless-FVA/WT_1500.csv')

    TR_250 = parametrize_model(wt_model, 225, 275,co2=22.2, if_trans=True, frac_optimum=0.90, loopless=True, pruning=True, fva_bounds_file='./flux_results/flux_sampling/model_bounds/Modified-Loopless-FVA/TR_250.csv')
    TR_750 = parametrize_model(wt_model, 725, 775,co2=22.2, if_trans=True, frac_optimum=0.90, loopless=True, pruning=True, fva_bounds_file='./flux_results/flux_sampling/model_bounds/Modified-Loopless-FVA/TR_750.csv')
    TR_1500 = parametrize_model(wt_model, 1475, 1525,co2=22.2, if_trans=True, frac_optimum=0.90, loopless=True, pruning=True, fva_bounds_file='./flux_results/flux_sampling/model_bounds/Modified-Loopless-FVA/TR_1500.csv')

#Generate list of models for flux sampling
sampling_list = [WT_250, WT_750, WT_1500, TR_250, TR_750, TR_1500]

print('generating flux samples for parametrized models')
for model in sampling_list:
    print('start time for sampler generation: ' ,datetime.datetime.now())
    model_name = str([k for k, v in locals().items() if v == model][0])
    name_for_file = str('flux_sample_'+model_name+'_Relaxed_loopless_FVA_100kT.csv')
    #Output the flux bounds of the model to ./fva_bounds/name_for_file
    save_model_bounds(model, filename=name_for_file)
    
    
    #Parametrize OPTGP sampler
    num_samples =10000
    thinning = 100000
    
    print('Starting OPTGP sampler:')
    print('num_samples: ', num_samples)
    print('Thinning coefficient: ', thinning)
    generate_flux_samples(model, num_samples =num_samples, nproj=1, batch_size=5000, thinning=thinning, output_filename=name_for_file)
    del model #Deletes model instance to free up memory 
    print('end time: ', datetime.datetime.now())

#This outputs a set of bounds that we can reuse to re-parametrize a model instead of re-running the parametrization script again.
#June 24, 2023 

#For some reason the Trans model returns an infeasible solution. I'll check specifically what the problem is 
#I checked and some reactions cause numerical issues. I can circumvent that by rerunning the loopless FVA function on the problematic
# Out:
# Generating parametrized models for flux sampling
# Read LP format model from file /tmp/tmpybi8lf4p.lp
# Reading time = 0.02 seconds
# : 3956 rows, 9880 columns, 42914 nonzeros
# start time for parametrize_model():  2023-07-30 06:23:01.951445
# reading previous FVA bounds
# Reactions to remove: 2912
# /home/articulatus/anaconda3/envs/RiceMM/lib/python3.10/site-packages/cobra/core/group.py:147: UserWarning: need to pass in a list
#   warn("need to pass in a list")
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 8
#       6 #Let's check if it works as a separate instance per WT and TR?
#       7 with wt_model as wt_model:
# ----> 8     WT_250 =  parametrize_model(wt_model, 225,275,co2=29, if_trans=False, frac_optimum=0.90, loopless=True, pruning=True, fva_bounds_file='./flux_results/flux_sampling/model_bounds/Modified-Loopless-FVA/WT_250.csv') #Done
#       9     WT_750 = parametrize_model(wt_model, 725, 775,co2=29, if_trans=False, frac_optimum=0.90, loopless=True, pruning=True, fva_bounds_file='./flux_results/flux_sampling/model_bounds/Modified-Loopless-FVA/WT_750.csv')
#      10     WT_1500 = parametrize_model(wt_model, 1475, 1525,co2=29, if_trans=False, frac_optimum=0.90, loopless=True, pruning=True, fva_bounds_file='./flux_results/flux_sampling/model_bounds/Modified-Loopless-FVA/WT_1500.csv')
#
# Cell In[3], line 98, in parametrize_model(model, ppfd_low, ppfd_high, co2, if_trans, loopless, frac_optimum, pruning, fva_bounds_file, intermediate_fva_results, save_final_bounds_file)
#      95     model_instance.remove_reactions(reactions_to_remove)
#      97     for i in reactions_to_remove:
# ---> 98         fva_result = fva_result.drop(index=i)
#     102 else:
#     103     print('computing Loopless FVA to model from scratch')
#
# File ~/anaconda3/envs/RiceMM/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/RiceMM/lib/python3.10/site-packages/pandas/core/frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
#    5260     errors: IgnoreRaise = "raise",
#    5261 ) -> DataFrame | None:
#    5262     """
#    5263     Drop specified labels from rows or columns.
#    5264
#    (...)
#    5397             weight  1.0     0.8
#    5398     """
# -> 5399     return super().drop(
#    5400         labels=labels,
#    5401         axis=axis,
#    5402         index=index,
#    5403         columns=columns,
#    5404         level=level,
#    5405         inplace=inplace,
#    5406         errors=errors,
#    5407     )
#
# File ~/anaconda3/envs/RiceMM/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/RiceMM/lib/python3.10/site-packages/pandas/core/generic.py:4505, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503 for axis, labels in axes.items():
#    4504     if labels is not None:
# -> 4505         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4507 if inplace:
#    4508     self._update_inplace(obj)
#
# File ~/anaconda3/envs/RiceMM/lib/python3.10/site-packages/pandas/core/generic.py:4546, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4544         new_axis = axis.drop(labels, level=level, errors=errors)
#    4545     else:
# -> 4546         new_axis = axis.drop(labels, errors=errors)
#    4547     indexer = axis.get_indexer(new_axis)
#    4549 # Case for non-unique axis
#    4550 else:
#
# File ~/anaconda3/envs/RiceMM/lib/python3.10/site-packages/pandas/core/indexes/base.py:6934, in Index.drop(self, labels, errors)
#    6932 if mask.any():
#    6933     if errors != "ignore":
# -> 6934         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6935     indexer = indexer[~mask]
#    6936 return self.delete(indexer)
#
# KeyError: "['Coleoptile_Biomass_M'] not found in axis"

# %%
# %timeit

#Need to Rerun WT750 and WT1500 due to internal looping issues. Fixed the parametrization script to catch any unexpected errors in the run. We will not be using any previous rerun results for this

#Parametrize models per type by generating model instance

print('Generating parametrized models for flux sampling')
#Let's check if it works as a separate instance per WT and TR?
with wt_model as wt_model:
    WT_750 = parametrize_model(wt_model, 725, 775,co2=29, if_trans=False, frac_optimum=0.90, loopless=True, pruning=True, intermediate_fva_results='WT_750_rerun.csv')
    WT_1500 = parametrize_model(wt_model, 1475, 1525,co2=29, if_trans=False, frac_optimum=0.90, loopless=True, pruning=True, intermediate_fva_results='.WT_1500_rerun.csv')

#Generate list of models for flux sampling
sampling_list = [WT_750, WT_1500]

print('generating flux samples for parametrized models')
for model in sampling_list:
    print('start time for sampler generation: ' ,datetime.datetime.now())
    model_name = str([k for k, v in locals().items() if v == model][0])
    name_for_file = str('flux_sample_'+model_name+'_Relaxed_loopless_FVA_100kT_reran.csv')
    #Output the flux bounds of the model to ./fva_bounds/name_for_file
    save_model_bounds(model, filename=name_for_file)
    
    
    #Parametrize OPTGP sampler
    num_samples =10000
    thinning = 100000
    
    print('Starting OPTGP sampler:')
    print('num_samples: ', num_samples)
    print('Thinning coefficient: ', thinning)
    generate_flux_samples(model, num_samples =num_samples, nproj=1, batch_size=5000, thinning=thinning, output_filename=name_for_file)
    del model #Deletes model instance to free up memory 
    print('end time: ', datetime.datetime.now())
    
    
#No more unbounded reactions ///

#Flux sampling done. Everything seems in order now.

# %%
from cobra import Reaction

def save_model_instance(model, ppfd_low, ppfd_high, co2,if_trans, fva_bounds_file='', sbml_file=''):
    
    
    model_instance=model.copy()
    model_instance.tolerance = 1e-9
    model_instance.solver.configuration.verbosity = 3


    print('start time for parametrize_model(): ' ,datetime.datetime.now())
    model_instance.medium = define_model_medium(model_instance, co2=co2, o2=inf, ppfd=inf, h=inf, nh4=inf, no3=inf)
    turn_off_cofac_cycles(model_instance)
    add_tissue_constraints(model_instance)
    add_enzyme_constraints(model_instance)

    #Adds NGAM (Computed as an average between the high and low instead of directly constraining it to the model, w/c makes the problem non-linear)
    add_ngam_cons(model_instance, (ppfd_high+ppfd_low)/2)

    #Constrain PPFD range to indicated value
    model_instance.reactions.get_by_id('EX_photonVis(e)').bounds = (-1*ppfd_high, -1*ppfd_low)


    #Check if trans then add constraints if true
    if if_trans==True:
        add_trans_reactions(model_instance)
        add_trans_constraints(model_instance)

    print('parameters: ', ppfd_low, ppfd_high, co2, if_trans)
    #Readd objective coefficient, maybe it'll work?
    model_instance.reactions.get_by_id('DM_Phloem_BS').objective_coefficient = 1

    print('solution before adding bounds: ', model_instance.slim_optimize())
    
    
    
    if save_model_instance:
        cobra.io.
#     essential_reactions = cob

#     return  essential_reactions, active_reactions
            
with wt_model as model_instance:

    wt_250 = './flux_results/flux_sampling/model_bounds/working_bounds_07302023/wt_250.csv'
    test_model_feasibility(wt_model, 225,275, 29, False, wt_250)

    wt_750 = './flux_results/flux_sampling/model_bounds/working_bounds_07302023/wt_750.csv'
    test_model_feasibility(wt_model, 725,775, 29, False, wt_750)

    wt_1500 = './flux_results/flux_sampling/model_bounds/working_bounds_07302023/wt_1500.csv'
    test_model_feasibility(wt_model, 1475,1525, 29, False, wt_1500)


    tr_250 = './flux_results/flux_sampling/model_bounds/flux_sample_TR_250_updated_model_cons.csv'

    test_model_feasibility(wt_model, 225,275, 22.2, True, tr_250)

    tr_750 = './flux_results/flux_sampling/model_bounds/working_bounds_07302023/tr_750_before_sampling.csv'
    test_model_feasibility(wt_model, 725,775, 22.2, True, tr_750)

    tr_1500 = './flux_results/flux_sampling/model_bounds/working_bounds_07302023/tr_1500_before_sampling.csv'
    test_model_feasibility(wt_model, 1475,1525, 22.2, True, tr_1500)
# Out:
# Read LP format model from file /tmp/tmpmt_imrbo.lp
# Reading time = 0.01 seconds
# : 3956 rows, 9880 columns, 42914 nonzeros
# Set parameter OutputFlag to value 1
# start time for parametrize_model():  2023-07-30 19:12:25.894997
# parameters:  225 275 29 False
# Discarded solution information
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (linux64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i5-11300H @ 3.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3970 rows, 9886 columns and 43002 nonzeros
# Model fingerprint: 0xc01c67e9
# Coefficient statistics:
#   Matrix range     [2e-04, 3e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e-01, 1e+06]
#   RHS range        [4e+00, 1e+01]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -0.0000000e+00   2.862626e+01   2.350004e+06      0s
#     6741    1.2503131e-01   0.000000e+00   0.000000e+00      1s
#
# Solved in 6741 iterations and 0.56 seconds (0.75 work units)
# Optimal objective  1.250313078e-01
# solution before adding bounds:  0.12503130779888827
# reading previous FVA bounds
# Coleoptile_Biomass_M not in previous bounds. Removing..
# Straw_Biomass_M not in previous bounds. Removing..
# ACCOAC_OSAc_M not in previous bounds. Removing..
# ACPC_OSs_M not in previous bounds. Removing..
# ACPC_OSm_M not in previous bounds. Removing..
# EX_sucr(e) not in previous bounds. Removing..
# EX_fru-B(e) not in previous bounds. Removing..
# EX_glc-A(e) not in previous bounds. Removing..
# EX_hco3(e) not in previous bounds. Removing..
# EX_asn-L(e) not in previous bounds. Removing..
# EX_gln-L(e) not in previous bounds. Removing..
# EX_etoh(e) not in previous bounds. Removing..
# EX_ac(e) not in previous bounds. Removing..
# EX_lac-L(e) not in previous bounds. Removing..
# EX_tsul(e) not in previous bounds. Removing..
# EX_fe2(e) not in previous bounds. Removing..
# EX_fe3(e) not in previous bounds. Removing..
# EX_ala-L(e) not in previous bounds. Removing..
# EX_arg-L(e) not in previous bounds. Removing..
# EX_asp-L(e) not in previous bounds. Removing..
# EX_cys-L(e) not in previous bounds. Removing..
# EX_glu-L(e) not in previous bounds. Removing..
# EX_gly(e) not in previous bounds. Removing..
# EX_his-L(e) not in previous bounds. Removing..
# EX_ile-L(e) not in previous bounds. Removing..
# EX_leu-L(e) not in previous bounds. Removing..
# EX_lys-L(e) not in previous bounds. Removing..
# EX_met-L(e) not in previous bounds. Removing..
# EX_phe-L(e) not in previous bounds. Removing..
# EX_pro-L(e) not in previous bounds. Removing..
# EX_ser-L(e) not in previous bounds. Removing..
# EX_thr-L(e) not in previous bounds. Removing..
# EX_trp-L(e) not in previous bounds. Removing..
# EX_tyr-L(e) not in previous bounds. Removing..
# EX_val-L(e) not in previous bounds. Removing..
# PRISM_blue_LED_M not in previous bounds. Removing..
# PRISM_red_LED_M not in previous bounds. Removing..
# PRISM_green_LED_M not in previous bounds. Removing..
# PRISM_solar_litho_M not in previous bounds. Removing..
# RPSI_410(u)_M not in previous bounds. Removing..
# RPSI_690(u)_M not in previous bounds. Removing..
# RPSII_410(u)_M not in previous bounds. Removing..
# RPSII_590(u)_M not in previous bounds. Removing..
# H2Otex_M not in previous bounds. Removing..
# NO3tex_M not in previous bounds. Removing..
# SUCRtex_M not in previous bounds. Removing..
# FRUtex_M not in previous bounds. Removing..
# GLCtex_M not in previous bounds. Removing..
# SO4tex_M not in previous bounds. Removing..
# SO3tex_M not in previous bounds. Removing..
# HCO3tex_M not in previous bounds. Removing..
# NH4tex_M not in previous bounds. Removing..
# ASNtex_M not in previous bounds. Removing..
# GLNtex_M not in previous bounds. Removing..
# ETOHtex_M not in previous bounds. Removing..
# ACtex_M not in previous bounds. Removing..
# LACtex_M not in previous bounds. Removing..
# TSULtex_M not in previous bounds. Removing..
# FE2tex_M not in previous bounds. Removing..
# FE3tex_M not in previous bounds. Removing..
# ALAtex_M not in previous bounds. Removing..
# ARGtex_M not in previous bounds. Removing..
# ASPtex_M not in previous bounds. Removing..
# CYStex_M not in previous bounds. Removing..
# GLUtex_M not in previous bounds. Removing..
# GLYtex_M not in previous bounds. Removing..
# HIStex_M not in previous bounds. Removing..
# ILEtex_M not in previous bounds. Removing..
# LEUtex_M not in previous bounds. Removing..
# LYStex_M not in previous bounds. Removing..
# METtex_M not in previous bounds. Removing..
# PHEtex_M not in previous bounds. Removing..
# PROtex_M not in previous bounds. Removing..
# SERtex_M not in previous bounds. Removing..
# THRtex_M not in previous bounds. Removing..
# TRPtex_M not in previous bounds. Removing..
# TYRtex_M not in previous bounds. Removing..
# VALtex_M not in previous bounds. Removing..
# PPASc_M not in previous bounds. Removing..
# PPASm_M not in previous bounds. Removing..
# PPASv_M not in previous bounds. Removing..
# PPAIcvc_M not in previous bounds. Removing..
# APLm_M not in previous bounds. Removing..
# CATv_M not in previous bounds. Removing..
# GLUSfm_M not in previous bounds. Removing..
# RBPC2s_M not in previous bounds. Removing..
# NO3Rm_M not in previous bounds. Removing..
# ATPPHc_M not in previous bounds. Removing..
# ATPPHm_M not in previous bounds. Removing..
# ATPPHs_M not in previous bounds. Removing..
# ATPSv_M not in previous bounds. Removing..
# GTHRs_M not in previous bounds. Removing..
# ADK1m_M not in previous bounds. Removing..
# ATPAPc_M not in previous bounds. Removing..
# ADPAc_M not in previous bounds. Removing..
# GAL1PUTc_M not in previous bounds. Removing..
# URIKGc_M not in previous bounds. Removing..
# URIKGs_M not in previous bounds. Removing..
# TMDSc_M not in previous bounds. Removing..
# CYTDc_M not in previous bounds. Removing..
# GTPCYTDPTc_M not in previous bounds. Removing..
# GTPCYTDPTs_M not in previous bounds. Removing..
# DCTPDAc_M not in previous bounds. Removing..
# CTPRc_M not in previous bounds. Removing..
# ATPRc_M not in previous bounds. Removing..
# GTPRc_M not in previous bounds. Removing..
# UPRTc_M not in previous bounds. Removing..
# UPHc_M not in previous bounds. Removing..
# DURIKc_M not in previous bounds. Removing..
# TMDKc_M not in previous bounds. Removing..
# ATCYc_M not in previous bounds. Removing..
# ATCYs_M not in previous bounds. Removing..
# AUPTc_M not in previous bounds. Removing..
# AUPTs_M not in previous bounds. Removing..
# DGSNHc_M not in previous bounds. Removing..
# TPHc_M not in previous bounds. Removing..
# TPHs_M not in previous bounds. Removing..
# CMPc_M not in previous bounds. Removing..
# CMPs_M not in previous bounds. Removing..
# UMPc_M not in previous bounds. Removing..
# UMPs_M not in previous bounds. Removing..
# CTPSc_M not in previous bounds. Removing..
# TDSRs_M not in previous bounds. Removing..
# TDSRm_M not in previous bounds. Removing..
# ATDTDc_M not in previous bounds. Removing..
# DTMPKc_M not in previous bounds. Removing..
# ATDCDc_M not in previous bounds. Removing..
# ATUDv_M not in previous bounds. Removing..
# MATc_M not in previous bounds. Removing..
# AMPDc_M not in previous bounds. Removing..
# AMPPc_M not in previous bounds. Removing..
# ADNKc_M not in previous bounds. Removing..
# APPRTc_M not in previous bounds. Removing..
# ADSHc_M not in previous bounds. Removing..
# PYKs_M not in previous bounds. Removing..
# PPDKs_M not in previous bounds. Removing..
# MDH2c_M not in previous bounds. Removing..
# MDH2s_M not in previous bounds. Removing..
# PDCm_M not in previous bounds. Removing..
# PDCs_M not in previous bounds. Removing..
# GLU5Ks_M not in previous bounds. Removing..
# GDHym_M not in previous bounds. Removing..
# GDHm_M not in previous bounds. Removing..
# PYR5CDm_M not in previous bounds. Removing..
# PYR5CDs_M not in previous bounds. Removing..
# PYR5CDys_M not in previous bounds. Removing..
# GALc_M not in previous bounds. Removing..
# GALm_M not in previous bounds. Removing..
# AGATx_M not in previous bounds. Removing..
# AGATs_M not in previous bounds. Removing..
# ALAATs_M not in previous bounds. Removing..
# ICDHc_M not in previous bounds. Removing..
# GTHPs_M not in previous bounds. Removing..
# GTHPc_M not in previous bounds. Removing..
# UPGCDc_M not in previous bounds. Removing..
# THAc_M not in previous bounds. Removing..
# TPSc_M not in previous bounds. Removing..
# GLCNSc_M not in previous bounds. Removing..
# GLCNGBc_M not in previous bounds. Removing..
# GLCNGBv_M not in previous bounds. Removing..
# GLCNGAc_M not in previous bounds. Removing..
# GLCNGAv_M not in previous bounds. Removing..
# GALUiv_M not in previous bounds. Removing..
# MTGHc_M not in previous bounds. Removing..
# MGHAc_M not in previous bounds. Removing..
# MGHBc_M not in previous bounds. Removing..
# SFHc_M not in previous bounds. Removing..
# RGHc_M not in previous bounds. Removing..
# SYGHc_M not in previous bounds. Removing..
# GRGTc_M not in previous bounds. Removing..
# UDPG4Ec_M not in previous bounds. Removing..
# ATGDc_M not in previous bounds. Removing..
# GTPDPKs_M not in previous bounds. Removing..
# GBDPs_M not in previous bounds. Removing..
# GDTPs_M not in previous bounds. Removing..
# UMPKs_M not in previous bounds. Removing..
# ATDADc_M not in previous bounds. Removing..
# ATDGDc_M not in previous bounds. Removing..
# PPCKc_M not in previous bounds. Removing..
# MDHs_M not in previous bounds. Removing..
# MDHc_M not in previous bounds. Removing..
# MDHx_M not in previous bounds. Removing..
# MDHv_M not in previous bounds. Removing..
# PPCc_M not in previous bounds. Removing..
# OXAODc_M not in previous bounds. Removing..
# ASPO1s_M not in previous bounds. Removing..
# NNDPRs_M not in previous bounds. Removing..
# NNATc_M not in previous bounds. Removing..
# NADS(nh4)c_M not in previous bounds. Removing..
# NADS(gln-L)c_M not in previous bounds. Removing..
# QULNSs_M not in previous bounds. Removing..
# NAMNPPc_M not in previous bounds. Removing..
# NNAMc_M not in previous bounds. Removing..
# NMNDAc_M not in previous bounds. Removing..
# NMNNc_M not in previous bounds. Removing..
# NMNATc_M not in previous bounds. Removing..
# N2PHs_M not in previous bounds. Removing..
# N2PHc_M not in previous bounds. Removing..
# NADKc_M not in previous bounds. Removing..
# NADKs_M not in previous bounds. Removing..
# NADKm_M not in previous bounds. Removing..
# NADHKc_M not in previous bounds. Removing..
# NADHKs_M not in previous bounds. Removing..
# NADHKm_M not in previous bounds. Removing..
# ASPTAm_M not in previous bounds. Removing..
# SUCL(GDP)m_M not in previous bounds. Removing..
# SUCL(ADP)m_M not in previous bounds. Removing..
# CTPCHc_M not in previous bounds. Removing..
# AASADc_M not in previous bounds. Removing..
# SACCDyc_M not in previous bounds. Removing..
# SACCDc_M not in previous bounds. Removing..
# AATAc_M not in previous bounds. Removing..
# PDHam1m_M not in previous bounds. Removing..
# PDHam2m_M not in previous bounds. Removing..
# PDHe2m_M not in previous bounds. Removing..
# PDHe3m_M not in previous bounds. Removing..
# AKGDHam1m_M not in previous bounds. Removing..
# AKGDHam2m_M not in previous bounds. Removing..
# AKGDHe2m_M not in previous bounds. Removing..
# OXADH1m_M not in previous bounds. Removing..
# OXADH2m_M not in previous bounds. Removing..
# MALSs_M not in previous bounds. Removing..
# AMOx_M not in previous bounds. Removing..
# AOBUTDx_M not in previous bounds. Removing..
# THR3DHx_M not in previous bounds. Removing..
# GLYATx_M not in previous bounds. Removing..
# ASPALs_M not in previous bounds. Removing..
# FDHm_M not in previous bounds. Removing..
# FDHNc_M not in previous bounds. Removing..
# SULOx_M not in previous bounds. Removing..
# SULOm_M not in previous bounds. Removing..
# SUATc_M not in previous bounds. Removing..
# SUATs_M not in previous bounds. Removing..
# ARGNc_M not in previous bounds. Removing..
# PTORc_M not in previous bounds. Removing..
# PAOc_M not in previous bounds. Removing..
# AMPORc_M not in previous bounds. Removing..
# SPMDDHc_M not in previous bounds. Removing..
# ABORc_M not in previous bounds. Removing..
# ARG2MO_M not in previous bounds. Removing..
# GABUTAHc_M not in previous bounds. Removing..
# GABUTNAHc_M not in previous bounds. Removing..
# CMPAc_M not in previous bounds. Removing..
# AGDIc_M not in previous bounds. Removing..
# AGMTc_M not in previous bounds. Removing..
# ARDCc_M not in previous bounds. Removing..
# ASNS1c_M not in previous bounds. Removing..
# ASNS1s_M not in previous bounds. Removing..
# SGATs_M not in previous bounds. Removing..
# METSMTc_M not in previous bounds. Removing..
# HCYSMT2c_M not in previous bounds. Removing..
# MSx_M not in previous bounds. Removing..
# MSv_M not in previous bounds. Removing..
# MSc_M not in previous bounds. Removing..
# ACDOc_M not in previous bounds. Removing..
# METLc_M not in previous bounds. Removing..
# ACHYSLc_M not in previous bounds. Removing..
# MOTAc_M not in previous bounds. Removing..
# M5TRKc_M not in previous bounds. Removing..
# MTANc_M not in previous bounds. Removing..
# SPRMSc_M not in previous bounds. Removing..
# ORDCc_M not in previous bounds. Removing..
# SPMSc_M not in previous bounds. Removing..
# AMCLc_M not in previous bounds. Removing..
# ACPCSc_M not in previous bounds. Removing..
# AMCPCOc_M not in previous bounds. Removing..
# M5TRPIc_M not in previous bounds. Removing..
# M5TRPHc_M not in previous bounds. Removing..
# ACRSPc_M not in previous bounds. Removing..
# ORNTAm_M not in previous bounds. Removing..
# TRPMOc_M not in previous bounds. Removing..
# IAOc_M not in previous bounds. Removing..
# TOORc_M not in previous bounds. Removing..
# TRPTAc_M not in previous bounds. Removing..
# ALAADc_M not in previous bounds. Removing..
# INDPYRDc_M not in previous bounds. Removing..
# IAOHLc_M not in previous bounds. Removing..
# NTRLASEc_M not in previous bounds. Removing..
# TRP2MOc_M not in previous bounds. Removing..
# AMID3c_M not in previous bounds. Removing..
# IAAGTc_M not in previous bounds. Removing..
# IAAINOSTc_M not in previous bounds. Removing..
# IAAIGSc_M not in previous bounds. Removing..
# IAAIASc_M not in previous bounds. Removing..
# IAAASPSc_M not in previous bounds. Removing..
# IAAGLUSc_M not in previous bounds. Removing..
# IAAGLNSc_M not in previous bounds. Removing..
# IAALEUHc_M not in previous bounds. Removing..
# IAAAMYHc_M not in previous bounds. Removing..
# TRPS2s_M not in previous bounds. Removing..
# LDH_Lc_M not in previous bounds. Removing..
# MALSADHm_M not in previous bounds. Removing..
# MALSADHym_M not in previous bounds. Removing..
# ACALDHs_M not in previous bounds. Removing..
# GLYCRORc_M not in previous bounds. Removing..
# GLYCORc_M not in previous bounds. Removing..
# TYRDCc_M not in previous bounds. Removing..
# HGDOc_M not in previous bounds. Removing..
# TYRTAs_M not in previous bounds. Removing..
# FAAc_M not in previous bounds. Removing..
# MAAIc_M not in previous bounds. Removing..
# ARGOAT1s_M not in previous bounds. Removing..
# ALCDx2c_M not in previous bounds. Removing..
# BETALDDHc_M not in previous bounds. Removing..
# BETHCYSs_M not in previous bounds. Removing..
# DMTGDHs_M not in previous bounds. Removing..
# SARCOs_M not in previous bounds. Removing..
# ALCDx1c_M not in previous bounds. Removing..
# MAN6PIc_M not in previous bounds. Removing..
# PMANMc_M not in previous bounds. Removing..
# MANKINc_M not in previous bounds. Removing..
# MDHARm_M not in previous bounds. Removing..
# MDHARym_M not in previous bounds. Removing..
# ASCPO2c_M not in previous bounds. Removing..
# ASCPO2s_M not in previous bounds. Removing..
# GGT1v_M not in previous bounds. Removing..
# GGT2c_M not in previous bounds. Removing..
# GGLUCTc_M not in previous bounds. Removing..
# OPAHirc_M not in previous bounds. Removing..
# CYSGLYv_M not in previous bounds. Removing..
# GLUCYSs_M not in previous bounds. Removing..
# GLUCYSm_M not in previous bounds. Removing..
# GTHSs_M not in previous bounds. Removing..
# GTHSm_M not in previous bounds. Removing..
# GTHDHc_M not in previous bounds. Removing..
# GTHDHs_M not in previous bounds. Removing..
# GALLDHm_M not in previous bounds. Removing..
# GALDHc_M not in previous bounds. Removing..
# GDPGPc_M not in previous bounds. Removing..
# GDPME1c_M not in previous bounds. Removing..
# GDPME3c_M not in previous bounds. Removing..
# GAMPGc_M not in previous bounds. Removing..
# GMANDc_M not in previous bounds. Removing..
# GOFUCRc_M not in previous bounds. Removing..
# FUCPGTc_M not in previous bounds. Removing..
# LACDHc_M not in previous bounds. Removing..
# FCPAc_M not in previous bounds. Removing..
# FCKc_M not in previous bounds. Removing..
# FCIc_M not in previous bounds. Removing..
# FUKc_M not in previous bounds. Removing..
# SPSv_M not in previous bounds. Removing..
# PGI2c_M not in previous bounds. Removing..
# PGI2s_M not in previous bounds. Removing..
# NODOy_M not in previous bounds. Removing..
# NITRv_M not in previous bounds. Removing..
# BFFSc_M not in previous bounds. Removing..
# BFFSv_M not in previous bounds. Removing..
# INVv_M not in previous bounds. Removing..
# SPPv_M not in previous bounds. Removing..
# SUSv_M not in previous bounds. Removing..
# MI3PSc_M not in previous bounds. Removing..
# XYL2v_M not in previous bounds. Removing..
# UDPACGEc_M not in previous bounds. Removing..
# UDPACGLPc_M not in previous bounds. Removing..
# ACGAMPMc_M not in previous bounds. Removing..
# ACGAM6PSic_M not in previous bounds. Removing..
# GAMPTc_M not in previous bounds. Removing..
# GAMACTc_M not in previous bounds. Removing..
# ACGAMKc_M not in previous bounds. Removing..
# CAGHc_M not in previous bounds. Removing..
# CHITNc_M not in previous bounds. Removing..
# ACGAM2Ec_M not in previous bounds. Removing..
# UAG2EMAic_M not in previous bounds. Removing..
# ACNMLc_M not in previous bounds. Removing..
# CMPSASc_M not in previous bounds. Removing..
# GF6PTAc_M not in previous bounds. Removing..
# MCPSTm_M not in previous bounds. Removing..
# TSSTm_M not in previous bounds. Removing..
# MCPSTs_M not in previous bounds. Removing..
# TSSTs_M not in previous bounds. Removing..
# SOXs_M not in previous bounds. Removing..
# CYSATs_M not in previous bounds. Removing..
# CYSATm_M not in previous bounds. Removing..
# ALABATc_M not in previous bounds. Removing..
# DHFRc_M not in previous bounds. Removing..
# DHFRm_M not in previous bounds. Removing..
# FPGSc_M not in previous bounds. Removing..
# FTHFLc_M not in previous bounds. Removing..
# FTHFLm_M not in previous bounds. Removing..
# FTHFLs_M not in previous bounds. Removing..
# CALANc_M not in previous bounds. Removing..
# CALASc_M not in previous bounds. Removing..
# MANITL_M not in previous bounds. Removing..
# BG1c_M not in previous bounds. Removing..
# BG2c_M not in previous bounds. Removing..
# FORAc_M not in previous bounds. Removing..
# FORMHLc_M not in previous bounds. Removing..
# FTHDFc_M not in previous bounds. Removing..
# FTHDFm_M not in previous bounds. Removing..
# FTHDFs_M not in previous bounds. Removing..
# SHMTs_M not in previous bounds. Removing..
# MLTHFRc_M not in previous bounds. Removing..
# MLTHFRs_M not in previous bounds. Removing..
# METSc_M not in previous bounds. Removing..
# MLTHFR_Fs_M not in previous bounds. Removing..
# HCGALm_M not in previous bounds. Removing..
# TALc_M not in previous bounds. Removing..
# RPDPKc_M not in previous bounds. Removing..
# PPMc_M not in previous bounds. Removing..
# RBKc_M not in previous bounds. Removing..
# RBKs_M not in previous bounds. Removing..
# AUNORs_M not in previous bounds. Removing..
# RIBFSs_M not in previous bounds. Removing..
# RIBFKc_M not in previous bounds. Removing..
# FMNATs_M not in previous bounds. Removing..
# FMNATc_M not in previous bounds. Removing..
# FMNATm_M not in previous bounds. Removing..
# GTPDHs_M not in previous bounds. Removing..
# DHPAHs_M not in previous bounds. Removing..
# R5PFLs_M not in previous bounds. Removing..
# DLDLBTs_M not in previous bounds. Removing..
# AUSs_M not in previous bounds. Removing..
# RPIc_M not in previous bounds. Removing..
# GAPDHys_M not in previous bounds. Removing..
# GAPDH1c_M not in previous bounds. Removing..
# GAPDH2s_M not in previous bounds. Removing..
# KHKc_M not in previous bounds. Removing..
# FBA2c_M not in previous bounds. Removing..
# FALDTKc_M not in previous bounds. Removing..
# FALDTKs_M not in previous bounds. Removing..
# GLYCNKc_M not in previous bounds. Removing..
# GLYCNKs_M not in previous bounds. Removing..
# HDCs_M not in previous bounds. Removing..
# ADSALc_M not in previous bounds. Removing..
# LATm_M not in previous bounds. Removing..
# GSNPc_M not in previous bounds. Removing..
# ADNPc_M not in previous bounds. Removing..
# INSPc_M not in previous bounds. Removing..
# ADNDAc_M not in previous bounds. Removing..
# IMPc_M not in previous bounds. Removing..
# GMPRc_M not in previous bounds. Removing..
# GMPS2c_M not in previous bounds. Removing..
# GMPS1c_M not in previous bounds. Removing..
# GDKc_M not in previous bounds. Removing..
# ATDGMc_M not in previous bounds. Removing..
# ATDAMc_M not in previous bounds. Removing..
# DGDTc_M not in previous bounds. Removing..
# DADTc_M not in previous bounds. Removing..
# IMPDc_M not in previous bounds. Removing..
# INSKc_M not in previous bounds. Removing..
# HXPRTc_M not in previous bounds. Removing..
# ADSSc_M not in previous bounds. Removing..
# MIOORc_M not in previous bounds. Removing..
# PI45PLCc_M not in previous bounds. Removing..
# PI5P4Kc_M not in previous bounds. Removing..
# PI4P5Kc_M not in previous bounds. Removing..
# PIK4c_M not in previous bounds. Removing..
# PIK3c_M not in previous bounds. Removing..
# PI3P5Kc_M not in previous bounds. Removing..
# MI34Pc_M not in previous bounds. Removing..
# MI346Pc_M not in previous bounds. Removing..
# MI3456Pc_M not in previous bounds. Removing..
# IBPHc_M not in previous bounds. Removing..
# MI14PPc_M not in previous bounds. Removing..
# MI134PPc_M not in previous bounds. Removing..
# MI145PPc_M not in previous bounds. Removing..
# MI1456PKc_M not in previous bounds. Removing..
# MI145PKc_M not in previous bounds. Removing..
# MI134PK1c_M not in previous bounds. Removing..
# MI134PK2c_M not in previous bounds. Removing..
# MI1346PK1c_M not in previous bounds. Removing..
# MI1346PK2c_M not in previous bounds. Removing..
# IPKK2c_M not in previous bounds. Removing..
# IPKK5c_M not in previous bounds. Removing..
# IPKK4c_M not in previous bounds. Removing..
# IPKK6c_M not in previous bounds. Removing..
# PHYTASEc_M not in previous bounds. Removing..
# MIHPPc_M not in previous bounds. Removing..
# MI1345PPc_M not in previous bounds. Removing..
# MI1345PP2c_M not in previous bounds. Removing..
# ITK1Kc_M not in previous bounds. Removing..
# MI4PPc_M not in previous bounds. Removing..
# MI3PPc_M not in previous bounds. Removing..
# HMGCOASm_M not in previous bounds. Removing..
# GCOADx_M not in previous bounds. Removing..
# GCOADCx_M not in previous bounds. Removing..
# ACACTs_M not in previous bounds. Removing..
# ACACTm_M not in previous bounds. Removing..
# HMNOm_M not in previous bounds. Removing..
# MOD_M not in previous bounds. Removing..
# MOD(2mhop)_M not in previous bounds. Removing..
# DHRT(ibcoa)_M not in previous bounds. Removing..
# MMSDm_M not in previous bounds. Removing..
# MCDH1m_M not in previous bounds. Removing..
# HIBHm_M not in previous bounds. Removing..
# ECH1m_M not in previous bounds. Removing..
# DHADm_M not in previous bounds. Removing..
# MTHFDm_M not in previous bounds. Removing..
# MTHFDc_M not in previous bounds. Removing..
# FTHFCLc_M not in previous bounds. Removing..
# FTHFCLm_M not in previous bounds. Removing..
# FTHFCLs_M not in previous bounds. Removing..
# MTHFDym_M not in previous bounds. Removing..
# MTHFDys_M not in previous bounds. Removing..
# MTHFDyc_M not in previous bounds. Removing..
# GMPc_M not in previous bounds. Removing..
# GNSKc_M not in previous bounds. Removing..
# GUAPRTc_M not in previous bounds. Removing..
# DAD2DAc_M not in previous bounds. Removing..
# DGSNPP_M not in previous bounds. Removing..
# DINSPc_M not in previous bounds. Removing..
# DAD2NPc_M not in previous bounds. Removing..
# DAMPHc_M not in previous bounds. Removing..
# ADEDAc_M not in previous bounds. Removing..
# ADNRHc_M not in previous bounds. Removing..
# GTPDPKc_M not in previous bounds. Removing..
# PPPGPPPc_M not in previous bounds. Removing..
# P5CRs_M not in previous bounds. Removing..
# GCALDDc_M not in previous bounds. Removing..
# GLCRPUic_M not in previous bounds. Removing..
# XYLXYLc_M not in previous bounds. Removing..
# XSc_M not in previous bounds. Removing..
# UGEc_M not in previous bounds. Removing..
# PECTNc_M not in previous bounds. Removing..
# UGDCc_M not in previous bounds. Removing..
# HPRs_M not in previous bounds. Removing..
# HPRys_M not in previous bounds. Removing..
# ASPCT1c_M not in previous bounds. Removing..
# AAPTc_M not in previous bounds. Removing..
# UTPUc_M not in previous bounds. Removing..
# UMPUc_M not in previous bounds. Removing..
# ARABFv_M not in previous bounds. Removing..
# ARABFc_M not in previous bounds. Removing..
# UA4Ec_M not in previous bounds. Removing..
# GLCURKc_M not in previous bounds. Removing..
# GLYK2s_M not in previous bounds. Removing..
# G6PEs_M not in previous bounds. Removing..
# GLNKc_M not in previous bounds. Removing..
# GLNKs_M not in previous bounds. Removing..
# GNDc_M not in previous bounds. Removing..
# GNDs_M not in previous bounds. Removing..
# XYLIc_M not in previous bounds. Removing..
# XYLKc_M not in previous bounds. Removing..
# RPEc_M not in previous bounds. Removing..
# 3HPPDc_M not in previous bounds. Removing..
# ABTA2m_M not in previous bounds. Removing..
# MTHFCc_M not in previous bounds. Removing..
# MTHFCs_M not in previous bounds. Removing..
# MTHFCm_M not in previous bounds. Removing..
# GUADc_M not in previous bounds. Removing..
# GSNRHc_M not in previous bounds. Removing..
# ADCSs_M not in previous bounds. Removing..
# UREASEc_M not in previous bounds. Removing..
# ATAHc_M not in previous bounds. Removing..
# ATNAHc_M not in previous bounds. Removing..
# ATSc_M not in previous bounds. Removing..
# HIUHc_M not in previous bounds. Removing..
# UROc_M not in previous bounds. Removing..
# XANDHc_M not in previous bounds. Removing..
# HXANORc_M not in previous bounds. Removing..
# INSRHc_M not in previous bounds. Removing..
# HOMSTs_M not in previous bounds. Removing..
# SHSL4s_M not in previous bounds. Removing..
# SHSL1s_M not in previous bounds. Removing..
# GLUKAc_M not in previous bounds. Removing..
# ADE1c_M not in previous bounds. Removing..
# ADE1s_M not in previous bounds. Removing..
# GLUKBc_M not in previous bounds. Removing..
# GLUKBs_M not in previous bounds. Removing..
# BAMYLs_M not in previous bounds. Removing..
# MGHs_M not in previous bounds. Removing..
# SPPAs_M not in previous bounds. Removing..
# PGLc_M not in previous bounds. Removing..
# PGLs_M not in previous bounds. Removing..
# PFPc_M not in previous bounds. Removing..
# XTSNPc_M not in previous bounds. Removing..
# XSTNRHc_M not in previous bounds. Removing..
# GSNDc_M not in previous bounds. Removing..
# PTOXs_M not in previous bounds. Removing..
# NADOR1u_M not in previous bounds. Removing..
# BCTA3m_M not in previous bounds. Removing..
# DHFSm_M not in previous bounds. Removing..
# G3PLs_M not in previous bounds. Removing..
# PRPNCOAHYDm_M not in previous bounds. Removing..
# XMPc_M not in previous bounds. Removing..
# G6PDHc_M not in previous bounds. Removing..
# G6PDHs_M not in previous bounds. Removing..
# CELLBGc_M not in previous bounds. Removing..
# CELLc_M not in previous bounds. Removing..
# CELLSc_M not in previous bounds. Removing..
# KARAm_M not in previous bounds. Removing..
# DHPSm_M not in previous bounds. Removing..
# 3HPCOAHYDc_M not in previous bounds. Removing..
# G5DHs_M not in previous bounds. Removing..
# HPPKm_M not in previous bounds. Removing..
# PYAM5POc_M not in previous bounds. Removing..
# PDX5POic_M not in previous bounds. Removing..
# PYDXNOc_M not in previous bounds. Removing..
# PYDXOc_M not in previous bounds. Removing..
# PYDXNKc_M not in previous bounds. Removing..
# PYDAMKc_M not in previous bounds. Removing..
# PYDXKc_M not in previous bounds. Removing..
# PYDMPATc_M not in previous bounds. Removing..
# PYDXNSc_M not in previous bounds. Removing..
# DHNPTAc_M not in previous bounds. Removing..
# TMMPKs_M not in previous bounds. Removing..
# TMPPPs_M not in previous bounds. Removing..
# HMPKs_M not in previous bounds. Removing..
# THMKs_M not in previous bounds. Removing..
# PMPKs_M not in previous bounds. Removing..
# THICs_M not in previous bounds. Removing..
# THZPSN3s_M not in previous bounds. Removing..
# TYRLs_M not in previous bounds. Removing..
# ICYSDSs_M not in previous bounds. Removing..
# THMPs_M not in previous bounds. Removing..
# TMDPKc_M not in previous bounds. Removing..
# FPGFTs_M not in previous bounds. Removing..
# FGFTs_M not in previous bounds. Removing..
# MOD(4mop)_M not in previous bounds. Removing..
# MOD(3mhtpp)_M not in previous bounds. Removing..
# DHRT(ivcoa)_M not in previous bounds. Removing..
# IVCDHm_M not in previous bounds. Removing..
# MCTCm_M not in previous bounds. Removing..
# MGCm_M not in previous bounds. Removing..
# HMGLm_M not in previous bounds. Removing..
# PPCOAOc_M not in previous bounds. Removing..
# FPGFTm_M not in previous bounds. Removing..
# FGFTm_M not in previous bounds. Removing..
# DNMPPAc_M not in previous bounds. Removing..
# DNTPPAc_M not in previous bounds. Removing..
# PFKc_M not in previous bounds. Removing..
# PFKs_M not in previous bounds. Removing..
# ADCLs_M not in previous bounds. Removing..
# BPNTs_M not in previous bounds. Removing..
# BPNT2s_M not in previous bounds. Removing..
# ADSKs_M not in previous bounds. Removing..
# ADSKc_M not in previous bounds. Removing..
# PAPSRs_M not in previous bounds. Removing..
# ASRGs_M not in previous bounds. Removing..
# AAs_M not in previous bounds. Removing..
# PPYRDCc_M not in previous bounds. Removing..
# ALCD25c_M not in previous bounds. Removing..
# PGMTv_M not in previous bounds. Removing..
# MOD(3mop)_M not in previous bounds. Removing..
# MOD(2mbdhl)_M not in previous bounds. Removing..
# DHRT(2mbcoa)_M not in previous bounds. Removing..
# MCDH2m_M not in previous bounds. Removing..
# ECH2m_M not in previous bounds. Removing..
# HMNOSm_M not in previous bounds. Removing..
# ACCATm_M not in previous bounds. Removing..
# HCO3Em_M not in previous bounds. Removing..
# ACCOACc_M not in previous bounds. Removing..
# CAFFCMTc_M not in previous bounds. Removing..
# FERCOARc_M not in previous bounds. Removing..
# CONOHDHc_M not in previous bounds. Removing..
# SINOHDHc_M not in previous bounds. Removing..
# FERH2c_M not in previous bounds. Removing..
# CONCMTc_M not in previous bounds. Removing..
# CINNCOARc_M not in previous bounds. Removing..
# CINNCOALc_M not in previous bounds. Removing..
# CINNALDOc_M not in previous bounds. Removing..
# CINNOHDHc_M not in previous bounds. Removing..
# NRGNAORc_M not in previous bounds. Removing..
# TRICINGTc_M not in previous bounds. Removing..
# UPP3MTs_M not in previous bounds. Removing..
# PC2Ds_M not in previous bounds. Removing..
# SHCHFs_M not in previous bounds. Removing..
# CHLOR410s_M not in previous bounds. Removing..
# CHLOR430s_M not in previous bounds. Removing..
# CHLOR450s_M not in previous bounds. Removing..
# CHLOR470s_M not in previous bounds. Removing..
# CHLOR490s_M not in previous bounds. Removing..
# CHLOR510s_M not in previous bounds. Removing..
# CHLOR530s_M not in previous bounds. Removing..
# CHLOR550s_M not in previous bounds. Removing..
# CHLOR570s_M not in previous bounds. Removing..
# CHLOR590s_M not in previous bounds. Removing..
# CHLOR610s_M not in previous bounds. Removing..
# CHLOR630s_M not in previous bounds. Removing..
# CHLOR650s_M not in previous bounds. Removing..
# CHLOR670s_M not in previous bounds. Removing..
# CHLOR690s_M not in previous bounds. Removing..
# DVCHLOR410s_M not in previous bounds. Removing..
# DVCHLOR430s_M not in previous bounds. Removing..
# DVCHLOR450s_M not in previous bounds. Removing..
# DVCHLOR470s_M not in previous bounds. Removing..
# DVCHLOR490s_M not in previous bounds. Removing..
# DVCHLOR510s_M not in previous bounds. Removing..
# DVCHLOR530s_M not in previous bounds. Removing..
# DVCHLOR590s_M not in previous bounds. Removing..
# DVCHLOR670s_M not in previous bounds. Removing..
# DVCHLOR690s_M not in previous bounds. Removing..
# UPP1Rs_M not in previous bounds. Removing..
# UPP3Os_M not in previous bounds. Removing..
# FCLTs_M not in previous bounds. Removing..
# DVPCHLDRs_M not in previous bounds. Removing..
# HEMEOSm_M not in previous bounds. Removing..
# HEMELs_M not in previous bounds. Removing..
# HEMELm_M not in previous bounds. Removing..
# HEMEASm_M not in previous bounds. Removing..
# HOXGs_M not in previous bounds. Removing..
# CHLBSEs_M not in previous bounds. Removing..
# CHLBSNs_M not in previous bounds. Removing..
# CHLDAOs_M not in previous bounds. Removing..
# CHLAOs_M not in previous bounds. Removing..
# CHLASEs_M not in previous bounds. Removing..
# CHLASNs_M not in previous bounds. Removing..
# FRDPFTm_M not in previous bounds. Removing..
# CHORLm_M not in previous bounds. Removing..
# HBZOPT8m_M not in previous bounds. Removing..
# 3OPHBH2m_M not in previous bounds. Removing..
# 3OPHBH1m_M not in previous bounds. Removing..
# DHOPBMTm_M not in previous bounds. Removing..
# OPHMBDCm_M not in previous bounds. Removing..
# COQ6m_M not in previous bounds. Removing..
# COQ5m_M not in previous bounds. Removing..
# COQ7m_M not in previous bounds. Removing..
# COQ3m_M not in previous bounds. Removing..
# HMGCOARc_M not in previous bounds. Removing..
# HMGCOARyc_M not in previous bounds. Removing..
# IPDDIm_M not in previous bounds. Removing..
# DMPPS2s_M not in previous bounds. Removing..
# DMPPS1s_M not in previous bounds. Removing..
# DMATTm_M not in previous bounds. Removing..
# GRTTm_M not in previous bounds. Removing..
# GADO4c_M not in previous bounds. Removing..
# ACAROTORs_M not in previous bounds. Removing..
# CAROTEMOs_M not in previous bounds. Removing..
# CPTXANORs_M not in previous bounds. Removing..
# ZNXANMOs_M not in previous bounds. Removing..
# PHYTDSs_M not in previous bounds. Removing..
# PHYTFLDSs_M not in previous bounds. Removing..
# BCAROTHs_M not in previous bounds. Removing..
# BCPTXANHs_M not in previous bounds. Removing..
# CAROTDSs_M not in previous bounds. Removing..
# ZCARTDSs_M not in previous bounds. Removing..
# CBGL1s_M not in previous bounds. Removing..
# CBGL2s_M not in previous bounds. Removing..
# PHYTS1s_M not in previous bounds. Removing..
# PHYTS2s_M not in previous bounds. Removing..
# NXANSs_M not in previous bounds. Removing..
# LYCOPEC1s_M not in previous bounds. Removing..
# LYCOPBC1s_M not in previous bounds. Removing..
# LYCOPBC2s_M not in previous bounds. Removing..
# LYCOPBC3s_M not in previous bounds. Removing..
# NXANIs_M not in previous bounds. Removing..
# XANXNDHs_M not in previous bounds. Removing..
# EPCDOs_M not in previous bounds. Removing..
# ABSALDOs_M not in previous bounds. Removing..
# ABSH1s_M not in previous bounds. Removing..
# ABSH2s_M not in previous bounds. Removing..
# ECAROTHs_M not in previous bounds. Removing..
# EECAROTLHs_M not in previous bounds. Removing..
# LYCOPEC2s_M not in previous bounds. Removing..
# HSTDHc_M not in previous bounds. Removing..
# DXCSTNMOc_M not in previous bounds. Removing..
# DXSTNORc_M not in previous bounds. Removing..
# DXTSTc_M not in previous bounds. Removing..
# DXTSTOc_M not in previous bounds. Removing..
# DXSTNOc_M not in previous bounds. Removing..
# DHDXSTNOc_M not in previous bounds. Removing..
# TSTNORc_M not in previous bounds. Removing..
# BRS1c_M not in previous bounds. Removing..
# BRS2c_M not in previous bounds. Removing..
# BRS3c_M not in previous bounds. Removing..
# CAMPSTHc_M not in previous bounds. Removing..
# 22HCAMHc_M not in previous bounds. Removing..
# CAMPST43EHc_M not in previous bounds. Removing..
# CAMPSTLHc_M not in previous bounds. Removing..
# 22HCAM43Rc_M not in previous bounds. Removing..
# CAM43Rc_M not in previous bounds. Removing..
# DKSTIc_M not in previous bounds. Removing..
# BRS5c_M not in previous bounds. Removing..
# BRS4c_M not in previous bounds. Removing..
# STR14DMc_M not in previous bounds. Removing..
# CAMPSTc_M not in previous bounds. Removing..
# STISTSc_M not in previous bounds. Removing..
# DHAVESTRc_M not in previous bounds. Removing..
# DHEPISTRc_M not in previous bounds. Removing..
# MERGRc_M not in previous bounds. Removing..
# DHAVESTSc_M not in previous bounds. Removing..
# DHEPISTSc_M not in previous bounds. Removing..
# CYEUOLSc_M not in previous bounds. Removing..
# AVESTSc_M not in previous bounds. Removing..
# METMTc_M not in previous bounds. Removing..
# CYARTMTc_M not in previous bounds. Removing..
# CSTLIc_M not in previous bounds. Removing..
# CYECYCIc_M not in previous bounds. Removing..
# DSTRc_M not in previous bounds. Removing..
# IPDPT1s_M not in previous bounds. Removing..
# IPDPT2s_M not in previous bounds. Removing..
# CYTTHs_M not in previous bounds. Removing..
# TZTNS1s_M not in previous bounds. Removing..
# TZTNS2s_M not in previous bounds. Removing..
# TZTNS6s_M not in previous bounds. Removing..
# IPADEDHs_M not in previous bounds. Removing..
# P450MOc_M not in previous bounds. Removing..
# CKDH3c_M not in previous bounds. Removing..
# CKDH2c_M not in previous bounds. Removing..
# CKDH1c_M not in previous bounds. Removing..
# TRNAIPTc_M not in previous bounds. Removing..
# cZTNS1c_M not in previous bounds. Removing..
# cZTNS2c_M not in previous bounds. Removing..
# CKPc_M not in previous bounds. Removing..
# cZTNS3c_M not in previous bounds. Removing..
# CKGT1c_M not in previous bounds. Removing..
# CKGT2c_M not in previous bounds. Removing..
# CKGT4c_M not in previous bounds. Removing..
# CKGT5c_M not in previous bounds. Removing..
# CKGT6c_M not in previous bounds. Removing..
# CKGT8c_M not in previous bounds. Removing..
# CKOGT1c_M not in previous bounds. Removing..
# CKOGT2c_M not in previous bounds. Removing..
# C3STDH2c_M not in previous bounds. Removing..
# C3STDH1c_M not in previous bounds. Removing..
# C3STKR2c_M not in previous bounds. Removing..
# C3STKR1c_M not in previous bounds. Removing..
# LNS14DMc_M not in previous bounds. Removing..
# C4STMO1c_M not in previous bounds. Removing..
# C4STMO2c_M not in previous bounds. Removing..
# LTHSTRLOc_M not in previous bounds. Removing..
# 7DHCSRc_M not in previous bounds. Removing..
# C14STRc_M not in previous bounds. Removing..
# CHLSTRc_M not in previous bounds. Removing..
# CHLSTIc_M not in previous bounds. Removing..
# D24STR1c_M not in previous bounds. Removing..
# CHLSDDIc_M not in previous bounds. Removing..
# LNSTLSc_M not in previous bounds. Removing..
# SAM24MTc_M not in previous bounds. Removing..
# C8STIc_M not in previous bounds. Removing..
# LATOXc_M not in previous bounds. Removing..
# C22SDc_M not in previous bounds. Removing..
# D24STRc_M not in previous bounds. Removing..
# THFGLUHv_M not in previous bounds. Removing..
# URDGLLc_M not in previous bounds. Removing..
# ALTNDAc_M not in previous bounds. Removing..
# URDGLAHc_M not in previous bounds. Removing..
# PYDXSc_M not in previous bounds. Removing..
# PYAMPPc_M not in previous bounds. Removing..
# PDXPPc_M not in previous bounds. Removing..
# PYDXPPc_M not in previous bounds. Removing..
# MACPCLs_M not in previous bounds. Removing..
# FAS161ACP_Ls_M not in previous bounds. Removing..
# FA140ACPHs_M not in previous bounds. Removing..
# FA160ACPHs_M not in previous bounds. Removing..
# FA161ACPHs_M not in previous bounds. Removing..
# FA180ACPHs_M not in previous bounds. Removing..
# FA181ACPHs_M not in previous bounds. Removing..
# FA182ACPHs_M not in previous bounds. Removing..
# FA183ACPHs_M not in previous bounds. Removing..
# FACOAL140r_M not in previous bounds. Removing..
# FACOAL182r_M not in previous bounds. Removing..
# FA200COAHr_M not in previous bounds. Removing..
# FA220COAHr_M not in previous bounds. Removing..
# FA240COAHr_M not in previous bounds. Removing..
# FA260COAHr_M not in previous bounds. Removing..
# FA280COAHr_M not in previous bounds. Removing..
# FA300COAHr_M not in previous bounds. Removing..
# FACOAL200r_M not in previous bounds. Removing..
# FACOAL220r_M not in previous bounds. Removing..
# FACOAL280r_M not in previous bounds. Removing..
# FACOAL300r_M not in previous bounds. Removing..
# ALFACOAR200r_M not in previous bounds. Removing..
# ALFACOAR220r_M not in previous bounds. Removing..
# ALFACOAR280r_M not in previous bounds. Removing..
# ALFACOAR300r_M not in previous bounds. Removing..
# ALFAACT200r_M not in previous bounds. Removing..
# ALFAACT220r_M not in previous bounds. Removing..
# PALMH1r_M not in previous bounds. Removing..
# FAOH1r_M not in previous bounds. Removing..
# HPALMDHr_M not in previous bounds. Removing..
# OOFADH1r_M not in previous bounds. Removing..
# OLEHr_M not in previous bounds. Removing..
# HOLEDHr_M not in previous bounds. Removing..
# OOFADH2r_M not in previous bounds. Removing..
# FAOH2r_M not in previous bounds. Removing..
# THYDRO91018Sc_M not in previous bounds. Removing..
# OFAFTc_M not in previous bounds. Removing..
# FAOH3r_M not in previous bounds. Removing..
# FAOH4r_M not in previous bounds. Removing..
# FAOH7r_M not in previous bounds. Removing..
# FAOH8r_M not in previous bounds. Removing..
# HARACDHr_M not in previous bounds. Removing..
# HBEHDHr_M not in previous bounds. Removing..
# HMNTDHr_M not in previous bounds. Removing..
# HMLSDHr_M not in previous bounds. Removing..
# OOFADH3r_M not in previous bounds. Removing..
# OOFADH4r_M not in previous bounds. Removing..
# OOFADH7r_M not in previous bounds. Removing..
# OOFADH8r_M not in previous bounds. Removing..
# FACOAL140c_M not in previous bounds. Removing..
# FACOAL160c_M not in previous bounds. Removing..
# FACOAL161c_M not in previous bounds. Removing..
# FACOAL180c_M not in previous bounds. Removing..
# FACOAL181c_M not in previous bounds. Removing..
# FACOAL182c_M not in previous bounds. Removing..
# FAS161COA_Lc_M not in previous bounds. Removing..
# FAS181COA_Lc_M not in previous bounds. Removing..
# FAS182COA_Lc_M not in previous bounds. Removing..
# FAS183COA_Lc_M not in previous bounds. Removing..
# 3OCS280r_M not in previous bounds. Removing..
# 3OCR280r_M not in previous bounds. Removing..
# 3HCD280cr_M not in previous bounds. Removing..
# ECR280yr_M not in previous bounds. Removing..
# 3OCS300r_M not in previous bounds. Removing..
# 3OCR300r_M not in previous bounds. Removing..
# 3HCD300r_M not in previous bounds. Removing..
# ECR300yr_M not in previous bounds. Removing..
# FA140ACOASc_M not in previous bounds. Removing..
# FA160ACOASc_M not in previous bounds. Removing..
# FA161ACOASc_M not in previous bounds. Removing..
# FA180ACOASc_M not in previous bounds. Removing..
# FA181ACOASc_M not in previous bounds. Removing..
# FA182ACOASc_M not in previous bounds. Removing..
# FA183ACOASc_M not in previous bounds. Removing..
# FACOAL140x_M not in previous bounds. Removing..
# FACOAL160x_M not in previous bounds. Removing..
# FACOAL161x_M not in previous bounds. Removing..
# FACOAL180x_M not in previous bounds. Removing..
# FACOAL181x_M not in previous bounds. Removing..
# FACOAL182x_M not in previous bounds. Removing..
# FAOS183yx_M not in previous bounds. Removing..
# FAOS182yx_M not in previous bounds. Removing..
# FAOS181yx_M not in previous bounds. Removing..
# FAOS161yx_M not in previous bounds. Removing..
# FAOS161x_M not in previous bounds. Removing..
# 3OCS60m_M not in previous bounds. Removing..
# 3OCR60m_M not in previous bounds. Removing..
# 3HCD60m_M not in previous bounds. Removing..
# ECR60ym_M not in previous bounds. Removing..
# 3OCS80m_M not in previous bounds. Removing..
# 3OCR80m_M not in previous bounds. Removing..
# 3HCD80m_M not in previous bounds. Removing..
# ECR80ym_M not in previous bounds. Removing..
# 3OCS100m_M not in previous bounds. Removing..
# 3OCR100m_M not in previous bounds. Removing..
# 3HCD100m_M not in previous bounds. Removing..
# ECR100ym_M not in previous bounds. Removing..
# 3OCS120m_M not in previous bounds. Removing..
# 3OCR120m_M not in previous bounds. Removing..
# 3HCD120m_M not in previous bounds. Removing..
# ECR120ym_M not in previous bounds. Removing..
# 3OCS140m_M not in previous bounds. Removing..
# 3OCR140m_M not in previous bounds. Removing..
# 3HCD140m_M not in previous bounds. Removing..
# ECR140ym_M not in previous bounds. Removing..
# 3OCS160m_M not in previous bounds. Removing..
# 3OCR160m_M not in previous bounds. Removing..
# 3HCD160m_M not in previous bounds. Removing..
# ECR160ym_M not in previous bounds. Removing..
# MTE160m_M not in previous bounds. Removing..
# MCOATAc_M not in previous bounds. Removing..
# MCOATAm_M not in previous bounds. Removing..
# ACOATAm_M not in previous bounds. Removing..
# MACPCLm_M not in previous bounds. Removing..
# 3OAR40m_M not in previous bounds. Removing..
# 3HAD40m_M not in previous bounds. Removing..
# EAR40ym_M not in previous bounds. Removing..
# 3OAS60m_M not in previous bounds. Removing..
# 3OAR60m_M not in previous bounds. Removing..
# 3HAD60m_M not in previous bounds. Removing..
# EAR60ym_M not in previous bounds. Removing..
# 3OAS80m_M not in previous bounds. Removing..
# 3OAR80m_M not in previous bounds. Removing..
# 3HAD80m_M not in previous bounds. Removing..
# EAR80ym_M not in previous bounds. Removing..
# 3OAS100m_M not in previous bounds. Removing..
# 3OAR100m_M not in previous bounds. Removing..
# 3HAD100m_M not in previous bounds. Removing..
# EAR100ym_M not in previous bounds. Removing..
# 3OAS120m_M not in previous bounds. Removing..
# 3OAR120m_M not in previous bounds. Removing..
# 3HAD120m_M not in previous bounds. Removing..
# EAR120ym_M not in previous bounds. Removing..
# 3OAS140m_M not in previous bounds. Removing..
# 3OAR140m_M not in previous bounds. Removing..
# 3HAD140m_M not in previous bounds. Removing..
# EAR140ym_M not in previous bounds. Removing..
# 3OAS160m_M not in previous bounds. Removing..
# 3OAR160m_M not in previous bounds. Removing..
# 3HAD160m_M not in previous bounds. Removing..
# EAR160ym_M not in previous bounds. Removing..
# 3OAS180m_M not in previous bounds. Removing..
# 3OAR180m_M not in previous bounds. Removing..
# 3HAD180m_M not in previous bounds. Removing..
# EAR180ym_M not in previous bounds. Removing..
# FAS161ACP_Lm_M not in previous bounds. Removing..
# FAS181ACP_Lm_M not in previous bounds. Removing..
# FAS182ACP_Lm_M not in previous bounds. Removing..
# FAS183ACP_Lm_M not in previous bounds. Removing..
# G3PDc_M not in previous bounds. Removing..
# GLYCKr_M not in previous bounds. Removing..
# GLYCKs_M not in previous bounds. Removing..
# GLYCKm_M not in previous bounds. Removing..
# G3PDNc_M not in previous bounds. Removing..
# G3PATs_M not in previous bounds. Removing..
# G3PATm_M not in previous bounds. Removing..
# AGPATs_M not in previous bounds. Removing..
# AGPATm_M not in previous bounds. Removing..
# PAPAs_M not in previous bounds. Removing..
# PAPAm_M not in previous bounds. Removing..
# DAGKm_M not in previous bounds. Removing..
# DAGLc_M not in previous bounds. Removing..
# MAGLc_M not in previous bounds. Removing..
# CDPDAGSr_M not in previous bounds. Removing..
# CDPDAGSm_M not in previous bounds. Removing..
# CDIPTr_M not in previous bounds. Removing..
# PGPSr_M not in previous bounds. Removing..
# PGPSm_M not in previous bounds. Removing..
# PGPPm_M not in previous bounds. Removing..
# CLPNSm_M not in previous bounds. Removing..
# PSSr_M not in previous bounds. Removing..
# PSSm_M not in previous bounds. Removing..
# PEDCr_M not in previous bounds. Removing..
# PEDCm_M not in previous bounds. Removing..
# ETHAPTr_M not in previous bounds. Removing..
# PETHACTr_M not in previous bounds. Removing..
# ETHAKr_M not in previous bounds. Removing..
# ETHAKs_M not in previous bounds. Removing..
# SERDCr_M not in previous bounds. Removing..
# SERDCs_M not in previous bounds. Removing..
# PETHAMTr_M not in previous bounds. Removing..
# PETHAMTs_M not in previous bounds. Removing..
# CHOLKs_M not in previous bounds. Removing..
# PCHOLPPs_M not in previous bounds. Removing..
# CHOLPCTs_M not in previous bounds. Removing..
# DAGCPs_M not in previous bounds. Removing..
# MGDGSs_M not in previous bounds. Removing..
# DGDGSs_M not in previous bounds. Removing..
# SQTs_M not in previous bounds. Removing..
# UDPSQSs_M not in previous bounds. Removing..
# OCDCYA13LOs_M not in previous bounds. Removing..
# LNL13HPLs_M not in previous bounds. Removing..
# OCDCYA13HPLs_M not in previous bounds. Removing..
# AMETJASMTc_M not in previous bounds. Removing..
# SERPTr_M not in previous bounds. Removing..
# 3DSPHRr_M not in previous bounds. Removing..
# SLCBK1r_M not in previous bounds. Removing..
# SGPL11r_M not in previous bounds. Removing..
# SGPL12r_M not in previous bounds. Removing..
# SLCBK2r_M not in previous bounds. Removing..
# SPHOORr_M not in previous bounds. Removing..
# UGCGr_M not in previous bounds. Removing..
# UGALCGc_M not in previous bounds. Removing..
# GLB1c_M not in previous bounds. Removing..
# OACPSSTm_M not in previous bounds. Removing..
# LACPLTm_M not in previous bounds. Removing..
# MCOAMTc_M not in previous bounds. Removing..
# MACPMMEc_M not in previous bounds. Removing..
# 3HGNORc_M not in previous bounds. Removing..
# 3HGMELc_M not in previous bounds. Removing..
# GLUACPMEORc_M not in previous bounds. Removing..
# GLUMEORc_M not in previous bounds. Removing..
# HPIMMEORc_M not in previous bounds. Removing..
# HPIMMELc_M not in previous bounds. Removing..
# ...
# MALTGAMs_BS not in previous bounds. Removing..
# NRGNMTc_BS not in previous bounds. Removing..
# NADtm_BS not in previous bounds. Removing..
# UACGAMtm_BS not in previous bounds. Removing..
# CKDOtm_BS not in previous bounds. Removing..
# THFtm_BS not in previous bounds. Removing..
# FORtm_BS not in previous bounds. Removing..
# ADENm_BS not in previous bounds. Removing..
# ASPt2m_BS not in previous bounds. Removing..
# CYSt2m_BS not in previous bounds. Removing..
# THRt2m_BS not in previous bounds. Removing..
# LYSt2m_BS not in previous bounds. Removing..
# METt2m_BS not in previous bounds. Removing..
# PHEt2m_BS not in previous bounds. Removing..
# ILEt2m_BS not in previous bounds. Removing..
# VALt2m_BS not in previous bounds. Removing..
# TYRt2m_BS not in previous bounds. Removing..
# PROt2m_BS not in previous bounds. Removing..
# HISt2m_BS not in previous bounds. Removing..
# LEUt2m_BS not in previous bounds. Removing..
# TRPt2m_BS not in previous bounds. Removing..
# ASPGLU2m_BS not in previous bounds. Removing..
# FADH2tm_BS not in previous bounds. Removing..
# FADtm_BS not in previous bounds. Removing..
# 4ABUTtmi_BS not in previous bounds. Removing..
# MALCITtm_BS not in previous bounds. Removing..
# MALAKGtm_BS not in previous bounds. Removing..
# SO4AKGtm_BS not in previous bounds. Removing..
# AKGCITtm_BS not in previous bounds. Removing..
# AKGICITtm_BS not in previous bounds. Removing..
# MALICITtm_BS not in previous bounds. Removing..
# MALOAAtm_BS not in previous bounds. Removing..
# OAAAKGtm_BS not in previous bounds. Removing..
# OAAICITtm_BS not in previous bounds. Removing..
# ASNtm_BS not in previous bounds. Removing..
# ACACt2m_BS not in previous bounds. Removing..
# ORNtm_BS not in previous bounds. Removing..
# CITRtm_BS not in previous bounds. Removing..
# ACtm_BS not in previous bounds. Removing..
# COAtm_BS not in previous bounds. Removing..
# AMETt2m_BS not in previous bounds. Removing..
# IPDPtm_BS not in previous bounds. Removing..
# HCO3(h)tmi_BS not in previous bounds. Removing..
# GCOAtm_BS not in previous bounds. Removing..
# 3HPCOAtm_BS not in previous bounds. Removing..
# CTPtm_BS not in previous bounds. Removing..
# 2AHHMPtm_BS not in previous bounds. Removing..
# 4ABZtm_BS not in previous bounds. Removing..
# THMPPt2m_BS not in previous bounds. Removing..
# FMNtm_BS not in previous bounds. Removing..
# PANTtm_BS not in previous bounds. Removing..
# 2OXOADPTm_BS not in previous bounds. Removing..
# TSULtm_BS not in previous bounds. Removing..
# 5FTHFtm_BS not in previous bounds. Removing..
# MLTHFtm_BS not in previous bounds. Removing..
# ACSERtmi_BS not in previous bounds. Removing..
# NA1ATPasem_BS not in previous bounds. Removing..
# NA1Htm_BS not in previous bounds. Removing..
# PInatm_BS not in previous bounds. Removing..
# PHEMEtm_BS not in previous bounds. Removing..
# FA40COAtm_BS not in previous bounds. Removing..
# MSAtm_BS not in previous bounds. Removing..
# MHDASCBtm_BS not in previous bounds. Removing..
# PINA1tm_BS not in previous bounds. Removing..
# CHORtm_BS not in previous bounds. Removing..
# SO3tm_BS not in previous bounds. Removing..
# GLYCtm_BS not in previous bounds. Removing..
# CDPDAGtm_BS not in previous bounds. Removing..
# PTD1INOtm_BS not in previous bounds. Removing..
# PEtm_BS not in previous bounds. Removing..
# PStm_BS not in previous bounds. Removing..
# PGPtm_BS not in previous bounds. Removing..
# PCtm_BS not in previous bounds. Removing..
# ACALDtm_BS not in previous bounds. Removing..
# H2Stm_BS not in previous bounds. Removing..
# PLIVLPNm_BS not in previous bounds. Removing..
# PLIBTNm_BS not in previous bounds. Removing..
# NADts_BS not in previous bounds. Removing..
# 5FTHFts_BS not in previous bounds. Removing..
# 5MTHFts_BS not in previous bounds. Removing..
# MHDASCBts_BS not in previous bounds. Removing..
# DHORSts_BS not in previous bounds. Removing..
# OROTts_BS not in previous bounds. Removing..
# SUCCOAtz_BS not in previous bounds. Removing..
# TSULts_BS not in previous bounds. Removing..
# CYSts_BS not in previous bounds. Removing..
# GLYts_BS not in previous bounds. Removing..
# HISts_BS not in previous bounds. Removing..
# METts_BS not in previous bounds. Removing..
# PROts_BS not in previous bounds. Removing..
# TRPts_BS not in previous bounds. Removing..
# ARGt2s_BS not in previous bounds. Removing..
# THFts_BS not in previous bounds. Removing..
# FORts_BS not in previous bounds. Removing..
# G3P(pi)tsr_BS not in previous bounds. Removing..
# G6PA(pi)ts_BS not in previous bounds. Removing..
# G6PB(pi)ts_BS not in previous bounds. Removing..
# PEPPIts_BS not in previous bounds. Removing..
# ATP2ts_BS not in previous bounds. Removing..
# FMNts_BS not in previous bounds. Removing..
# 4ABZts_BS not in previous bounds. Removing..
# NICRNTts_BS not in previous bounds. Removing..
# THMt2s_BS not in previous bounds. Removing..
# THMPPt2s_BS not in previous bounds. Removing..
# H2Sts_BS not in previous bounds. Removing..
# SO4ts_BS not in previous bounds. Removing..
# NO2ts_BS not in previous bounds. Removing..
# HCYSts_BS not in previous bounds. Removing..
# MALFUMts_BS not in previous bounds. Removing..
# SUCFUMtsr_BS not in previous bounds. Removing..
# UDPGALts_BS not in previous bounds. Removing..
# UDPGts_BS not in previous bounds. Removing..
# RIBFLVts_BS not in previous bounds. Removing..
# UTPUMPts_BS not in previous bounds. Removing..
# CHOLts_BS not in previous bounds. Removing..
# PCts_BS not in previous bounds. Removing..
# 4ABUTts_BS not in previous bounds. Removing..
# GLU4ABUTtsi_BS not in previous bounds. Removing..
# GLYC3Pts_BS not in previous bounds. Removing..
# GLYCts_BS not in previous bounds. Removing..
# CTPts_BS not in previous bounds. Removing..
# FE2ts_BS not in previous bounds. Removing..
# FE3abcs_BS not in previous bounds. Removing..
# HGENTISts_BS not in previous bounds. Removing..
# PHEMEts_BS not in previous bounds. Removing..
# PINA1ts_BS not in previous bounds. Removing..
# MG2ts_BS not in previous bounds. Removing..
# METHFts_BS not in previous bounds. Removing..
# SO3t_BS not in previous bounds. Removing..
# FA140s_BS not in previous bounds. Removing..
# FA160s_BS not in previous bounds. Removing..
# FA161s_BS not in previous bounds. Removing..
# FA180s_BS not in previous bounds. Removing..
# FA181s_BS not in previous bounds. Removing..
# FA182s_BS not in previous bounds. Removing..
# FA183s_BS not in previous bounds. Removing..
# ARGSUCts_BS not in previous bounds. Removing..
# ACGLUts_BS not in previous bounds. Removing..
# GLYBETts_BS not in previous bounds. Removing..
# CHORts_BS not in previous bounds. Removing..
# 26dap-Mts_BS not in previous bounds. Removing..
# DHZts_BS not in previous bounds. Removing..
# IPADNEts_BS not in previous bounds. Removing..
# TZTNRts_BS not in previous bounds. Removing..
# TZTNts_BS not in previous bounds. Removing..
# IPADNts_BS not in previous bounds. Removing..
# COA(h)ts_BS not in previous bounds. Removing..
# PYRtv_BS not in previous bounds. Removing..
# SUCRtv_BS not in previous bounds. Removing..
# FRUCtv_BS not in previous bounds. Removing..
# GLCAtv_BS not in previous bounds. Removing..
# GLCBtv_BS not in previous bounds. Removing..
# GLYtv_BS not in previous bounds. Removing..
# CYStv_BS not in previous bounds. Removing..
# H2Otv_BS not in previous bounds. Removing..
# GTHRDabcv_BS not in previous bounds. Removing..
# THFtv_BS not in previous bounds. Removing..
# HPGLUtv_BS not in previous bounds. Removing..
# NO2tvr_BS not in previous bounds. Removing..
# NO3tvr_BS not in previous bounds. Removing..
# O2tv_BS not in previous bounds. Removing..
# H2O2tv_BS not in previous bounds. Removing..
# PYRt2v_BS not in previous bounds. Removing..
# FA140COAabcx_BS not in previous bounds. Removing..
# FA160COAabcx_BS not in previous bounds. Removing..
# FA161COAabcx_BS not in previous bounds. Removing..
# FA180COAabcx_BS not in previous bounds. Removing..
# FA181COAabcx_BS not in previous bounds. Removing..
# FA182COAabcx_BS not in previous bounds. Removing..
# FA183COAabcx_BS not in previous bounds. Removing..
# ATPtx_BS not in previous bounds. Removing..
# CO2tx_BS not in previous bounds. Removing..
# ALAtx_BS not in previous bounds. Removing..
# PYRt2x_BS not in previous bounds. Removing..
# NH4tx_BS not in previous bounds. Removing..
# THRtx_BS not in previous bounds. Removing..
# COA(h)tx_BS not in previous bounds. Removing..
# GCOAtx_BS not in previous bounds. Removing..
# FADH2tx_BS not in previous bounds. Removing..
# FADtx_BS not in previous bounds. Removing..
# MTHGXLtx_BS not in previous bounds. Removing..
# B2COAtx_BS not in previous bounds. Removing..
# FA40COAtx_BS not in previous bounds. Removing..
# SO4tx_BS not in previous bounds. Removing..
# FA140CoAr_BS not in previous bounds. Removing..
# FA160CoAr_BS not in previous bounds. Removing..
# FA161CoAr_BS not in previous bounds. Removing..
# FA180CoAr_BS not in previous bounds. Removing..
# FA181CoAr_BS not in previous bounds. Removing..
# FA182CoAr_BS not in previous bounds. Removing..
# FA183CoAr_BS not in previous bounds. Removing..
# FA140r_BS not in previous bounds. Removing..
# FA160r_BS not in previous bounds. Removing..
# FA161r_BS not in previous bounds. Removing..
# FA180r_BS not in previous bounds. Removing..
# FA181r_BS not in previous bounds. Removing..
# FA182r_BS not in previous bounds. Removing..
# FA183r_BS not in previous bounds. Removing..
# NADPH2tr_BS not in previous bounds. Removing..
# NADPtr_BS not in previous bounds. Removing..
# UDPGr_BS not in previous bounds. Removing..
# GLUSIDEr_BS not in previous bounds. Removing..
# HYDRO16tr_BS not in previous bounds. Removing..
# HYDRO18tr_BS not in previous bounds. Removing..
# DHYDRO1016tr_BS not in previous bounds. Removing..
# DHYDRO1018tr_BS not in previous bounds. Removing..
# THYDRO91018tr_BS not in previous bounds. Removing..
# AMETt2r_BS not in previous bounds. Removing..
# ATPtr_BS not in previous bounds. Removing..
# ATP2tr_BS not in previous bounds. Removing..
# H2Otr_BS not in previous bounds. Removing..
# CO2tr_BS not in previous bounds. Removing..
# O2tr_BS not in previous bounds. Removing..
# MALCOAtr_BS not in previous bounds. Removing..
# Pitr_BS not in previous bounds. Removing..
# SERtr_BS not in previous bounds. Removing..
# COA(h)tr_BS not in previous bounds. Removing..
# GLYC3Ptr_BS not in previous bounds. Removing..
# TRIGLYCtr_BS not in previous bounds. Removing..
# CTPtr_BS not in previous bounds. Removing..
# CMPtr_BS not in previous bounds. Removing..
# CDPDAGtr_BS not in previous bounds. Removing..
# PTD1INOtr_BS not in previous bounds. Removing..
# PEtr_BS not in previous bounds. Removing..
# PStr_BS not in previous bounds. Removing..
# PGPtr_BS not in previous bounds. Removing..
# PCtr_BS not in previous bounds. Removing..
# CHOLtr_BS not in previous bounds. Removing..
# INOSTtr_BS not in previous bounds. Removing..
# FADH2tr_BS not in previous bounds. Removing..
# FADtr_BS not in previous bounds. Removing..
# DM_12O9DD(s)_BS not in previous bounds. Removing..
# DM_ACRTNL(s)_BS not in previous bounds. Removing..
# DM_ADE(s)_BS not in previous bounds. Removing..
# DM_AMOB(c)_BS not in previous bounds. Removing..
# DM_AMYGD(c)_BS not in previous bounds. Removing..
# DM_BILIVERD(s)_BS not in previous bounds. Removing..
# DM_BRSNL(c)_BS not in previous bounds. Removing..
# DM_BTN(c)_BS not in previous bounds. Removing..
# DM_CAMP(c)_BS not in previous bounds. Removing..
# DM_CAMPSTFER(c)_BS not in previous bounds. Removing..
# DM_CERDT(r)_BS not in previous bounds. Removing..
# DM_CEROOL(r)_BS not in previous bounds. Removing..
# DM_CHSTEROL(c)_BS not in previous bounds. Removing..
# DM_CHUMU(c)_BS not in previous bounds. Removing..
# DM_COA(c)_BS not in previous bounds. Removing..
# DM_COUMN(c)_BS not in previous bounds. Removing..
# DM_CPP1(s)_BS not in previous bounds. Removing..
# DM_CYTC(m)_BS not in previous bounds. Removing..
# DM_CYTC(s)_BS not in previous bounds. Removing..
# DM_C-ZTN7G(c)_BS not in previous bounds. Removing..
# DM_C-ZTN9G(c)_BS not in previous bounds. Removing..
# DM_ZTNG(c)_BS not in previous bounds. Removing..
# DM_DHBZCAROT(s)_BS not in previous bounds. Removing..
# DM_DHZ7G(c)_BS not in previous bounds. Removing..
# DM_DHZ9G(c)_BS not in previous bounds. Removing..
# DM_DHZG(c)_BS not in previous bounds. Removing..
# DM_DVCHLDA(s)_BS not in previous bounds. Removing..
# DM_ENTB(s)_BS not in previous bounds. Removing..
# DM_ERGTOL(c)_BS not in previous bounds. Removing..
# DM_ETHYLENE(c)_BS not in previous bounds. Removing..
# DM_HUMU(c)_BS not in previous bounds. Removing..
# DM_IPADNE7G(c)_BS not in previous bounds. Removing..
# DM_IPADNE9G(c)_BS not in previous bounds. Removing..
# DM_LACXAN(s)_BS not in previous bounds. Removing..
# DM_LGNCOL(r)_BS not in previous bounds. Removing..
# DM_LGNDT(r)_BS not in previous bounds. Removing..
# DM_LUTEIN(c)_BS not in previous bounds. Removing..
# DM_MNQNNE(s)_BS not in previous bounds. Removing..
# DM_PHAS(s)_BS not in previous bounds. Removing..
# DM_PHOM(c)_BS not in previous bounds. Removing..
# DM_PINBAN(c)_BS not in previous bounds. Removing..
# DM_PQNNE(s)_BS not in previous bounds. Removing..
# DM_SCLGN(c)_BS not in previous bounds. Removing..
# DM_SQ12DGR_OS(s)_BS not in previous bounds. Removing..
# DM_SRNTN(c)_BS not in previous bounds. Removing..
# DM_STCSD(c)_BS not in previous bounds. Removing..
# DM_TRPN(c)_BS not in previous bounds. Removing..
# DM_T-ZTN7G(c)_BS not in previous bounds. Removing..
# DM_T-ZTN9G(c)_BS not in previous bounds. Removing..
# DM_T-ZTNG(c)_BS not in previous bounds. Removing..
# DM_T-ZTNR(c)_BS not in previous bounds. Removing..
# ngam_atp_s_BS not in previous bounds. Removing..
# ngam_atp_x_BS not in previous bounds. Removing..
# ngam_atp_m_BS not in previous bounds. Removing..
# ngam_nadphox_c_BS not in previous bounds. Removing..
# ngam_nadphox_s_BS not in previous bounds. Removing..
# ngam_nadphox_m_BS not in previous bounds. Removing..
# DM_h(c)_BS not in previous bounds. Removing..
# DM_h(s)_BS not in previous bounds. Removing..
# DM_h(x)_BS not in previous bounds. Removing..
# DM_h(m)_BS not in previous bounds. Removing..
# DM_h(u)_BS not in previous bounds. Removing..
# DM_h(v)_BS not in previous bounds. Removing..
# DM_h(r)_BS not in previous bounds. Removing..
# cys-L_pd not in previous bounds. Removing..
# met-L_pd not in previous bounds. Removing..
# trp-L_pd not in previous bounds. Removing..
# udparab_pd not in previous bounds. Removing..
# udpxyl_pd not in previous bounds. Removing..
# udpgal_pd not in previous bounds. Removing..
# udpg_pd not in previous bounds. Removing..
# udpglcur_pd not in previous bounds. Removing..
# accoa_pd not in previous bounds. Removing..
# gal_pd not in previous bounds. Removing..
# tre_pd not in previous bounds. Removing..
# glc-B_pd not in previous bounds. Removing..
# tre6p_pd not in previous bounds. Removing..
# b-glucan_pd not in previous bounds. Removing..
# mnt_pd not in previous bounds. Removing..
# melib_pd not in previous bounds. Removing..
# stc_pd not in previous bounds. Removing..
# raffin_pd not in previous bounds. Removing..
# 1Dgali_pd not in previous bounds. Removing..
# inost_pd not in previous bounds. Removing..
# trans_PPCs_M not in previous bounds. Removing..
# trans_PPDKs_M not in previous bounds. Removing..
# trans_PPDKs_BS not in previous bounds. Removing..
# trans_MDH2m_M not in previous bounds. Removing..
# trans_hco3ec_M not in previous bounds. Removing..
# Reactions to remove: 3612
# /home/articulatus/anaconda3/envs/RiceMM/lib/python3.10/site-packages/cobra/core/group.py:147: UserWarning: need to pass in a list
#   warn("need to pass in a list")
# solution after readding bounds
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (linux64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i5-11300H @ 3.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
#
# Warning: excessive time spent in model updates.
# Consider calling update less frequently.
#
# Optimize a model with 3974 rows, 2676 columns and 11072 nonzeros
# Model fingerprint: 0xc68933d8
# Coefficient statistics:
#   Matrix range     [6e-04, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [3e-03, 2e+03]
#   RHS range        [8e+00, 2e+02]
#        0    3.2174918e-01   2.754944e+03   2.424851e+09      0s
#      572    3.5630589e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 572 iterations and 0.03 seconds (0.01 work units)
# Optimal objective  3.563058869e-01
# 0.3563058868662323

# %% [markdown]
# I am trying to identify which constraints are causing the infeasibility issues in the TR models. The WT models are okay now but the TR models are not.
#
# Checklist:
# -Trans MDH constraints  x
# - Trans PPDK constraints x
# - Trans NADP-ME constraints x
# - NGAM
#
# Notes:
# I've managed to fix the model now to their proper bounds by properly catching the specific reactions that cause infeasibility issues.
# I'm getting solutions for the pre-processed datafrane now which is good.

# %%
wt_model.reactions.OAACITtm_BS

# %% [markdown]
# #Notes:
#
# Which of the constraints cause infeasibility issues?
# NGAM
# Enzyme
# Tissue
#
# Two reactions shown to

# %% [markdown]
# The second part of this script is for post-processing the DFs obtained via flux sampling using the CycleFreeFlux algorithm.

# %% [markdown]
# Notes: needed to repeat sampling due to the following:
# - sampling matrices are too large to load, compensate with the use of thinning instead. Use specifications from Hermann et al (2020) which uses instead a thinning coefficient of 10000 instead of keeping all samples. My original parameters were n = 50000, batch size = 2000 and thinning = 500.
# - Maybe I should use a thinning coefficient of 100000 instead? Since my model has a number of dimensions one exponent higher than the previously benchmarked Arnold Model
#     - I've decided to run my model with a thinning coefficient of 25000. Hopefully autocorrelation and convergence wouldn't be much of an issue. Total samples would be equal in turn to 1.25e8 individual sampling points.
#
# - I needed to reparametrize samples considering that the objective function doesn't apply in flux sampling. INstead of adding an objective coefficient all demand reactions that output biomass are turned off except for "DM_Phloem_BS". What I need to do instead is re-parametrize it to allow photoassimilates to exit at that reaction rather than to others.
# - I'll save the format to ".npz" instead of "csv" since I'm running out of memory whenever I'm loading it out of this script. I think the output of the model is sparse enough that I can instead use this format instead.
#     - Actually I can save my csv to a normal csv once since I can just adjust the thinning number instead of keeping all samples.
#
# - It is still a question whether my samples are uncorrelated or not. I will run the diagnostic tests after I finish running the rest of the scripts.
#
#
#
# Note: May 17 2023
# Flux sampling script was interrupted @ TR750 and was rerun at that point.

# %% [markdown]
# Notes:
# OPTGP Is shown to be faster than ACHR and also converges faster
#
# Let's try with a 10 samples first with 10 batches
#
# I think the model is too large to be loaded into the flux sampler.
#
# It initialized after 30 minutes, let's try sampling na.
#
# It takes 1-2 hours at most to generate 2000 samples with a thinning coefficient of 10000. Extrapolating from that, we need probably 4-6 hours to generate 5000 samples with a TC of 20000. To keep things tractable I'll keep the thinning coefficient at 10000. I can just add more samples if needed.
#
#
# Things to add to the paper:
#
#
# Flux sampling is another constraints-based technique used for characterizing the null space of a given stoichiometric model, providing us insights on the flux distributions of a given metabolic model without the explicit definition of a given cellular objective. Not only does this technique offer advantages over conventional FBA and FVA where it allows researchers to determine the feasibility of solutions within a given defined range, as well as the distribution of these fluxes provided the model constaints.. The latter, in turn, allows statistical analysis to determine whether any given fluxes exist within a single probability distribution or not. This, in turn, allows a more direct comparison of fluxes and to adequately sample a solution space provided the constraints implemented in the model.
#
# The same constraints have been implemented as with the previous set-ups but with a modification with regards to how the objective functions are concerned. Unlike in pFBA where we can set a particular reaction as an objective, no such setting exists for flux sampling. Thus, this setup is in turn reliant on explicitly defined constraints that would define the n reaction-dimensional solution space. To parametrize this, we have turned off all biomass-related demands such as Coleoptile Biomass, Straw_Biomass and the "DM_Phloem_M" reaction to force the model to output flux to the "DM_Phloem_BS" reaction. Additionally, the model is constrained in a similar manner as with the previous pFBA setups that we had done to benchmark and assess our model's performance.
#
# THe benefits of using Flux Sampling compared to other methods such as FVA in characterizing a solution space is that:
# a. We may establish confidence intervals with the use of statistical tests to fully characterize a given solution space and whether
# b. Rather than simply generating representative fluxes showing the maximum and minimum amount of possible flux towards a particular reaction, flux sampling allows summary statistics to be generated, including the probability distribution of each particular reaction.
# c. Lastly, flux sampling allows a detailed comparison of the interdependence of each particular reaction, showing which reactions are coupled to each other in a positive and negative fashion. This is done
#
# Three setups per parametrized model were initialized, each with a representative light treatment of 250, 750 and 1500 PPFD with a defined range of +-25, respectively. The NGAM reactions were instead set at a static value at each representative light point detailed above. A total of 6 treatments were initialized to represent both the WT and Trans models at the selected light points.
#
# The sampling algorithm used was the OPTGP (optimized general parallel) sampler from the Cobrapy.sampling package. The sampler was parametrized to generate 5000 samples with a thinning coefficient of 25000, representing 1.25x10^8 sampling points, and was multithreaded into 7 processes each. Run times varied from between 3-6 hours per model parametrized, which was expected based on the number of reactions in the parametrized model.
#
#
# After the generation of individual sampling points, convergence statistics were done to assess the level of autocorrelation as well as to assess whether the samplers have sufficiently converged to a singular value. The former is done with the use of the "acf" function to assess the level of autocorrelation on each given column, while the latter is assessed with the use of two specific methods -- the Gelman-Rubin and the Geweke statistics. These are two methods that we will use to assess whether the number of sampling points is sufficient to ensure adequate convergence of each reaction in the model. Reactions that have not converged sufficiently will be indicated.
#
# After the assessment of autocorrelation and convergence, each of the pairs between light treatments (225-725, 725-1475, 225-1475) and between models (WT and Trans) are subjected to pairwise Kruskal-Wallis tests to assess which reaction pairs are derived from the same distribution. It is a non-parametric rank-based test test suitable for comparing outputs where there are no assumed distributions behind a population, and has been used in a similar fashion in previous flux sampling setups that involve Plant Metabolism  (Herrmann et al., 2019).
#
# This procedure, in turn, allows us to deduce in finer detail which reactions in particular are positively correlated with CO2 flux into the BS cell's Rubisco reaction. In the previous pFBA experiment we were able to demonstrate a similar approach to this by performing a sensitivity analysis on Glycine Decarboxylase, and had demonstrated the negative relationship between M cell GLYDHD and BS Cell GLYDHD.
#
# Lastly, we can afterwards assess which fluxes are coupled by iterating over the list of fluxes in a single flux sample matrix and computing the spearman correlations between the pairwise comparisons. From here we can assess which particular reactions are positively or negatively correlated or not. A particular focus will then be held. Further Downstream analysis includes determination of reactions that are positively or negatively coupled with each other and corroborating this fact on whether the reaction is disrupted in the "Trans" parametrized model.
#
#
#
# May 19, 2023
# Some observations on the fluxes obtained from initial flux sampling runs:
# - It seems it doesn't maximize CO2 assimilation as with pFBA.
# - It features some reactions with infeasibly large fluxes, particularly those expected to have flux cycling.
#
# I asked the Gitter group on what are their thoughts on how to approach this.
#
# One solution I think is this:
# - Reparametrize a model first and generate FVA solutions to "pre-process" the model, and in turn add directionality and bound constraints to the model to reduce its solution space further.
# - Try readding the objective function for photoassimilate generation as well as the pfba objective, as well as add the "cyclefreeflux" function by Desouki et al (2015).
#
#
#
# I am currently testing the Latter.
#
# May 20, 2023
#
# The latter does not work since it applies MILP, I think. It returns the following error:
#
#     TypeError: Sampling does not work with integer problems.
#
# I will instead to the former instead. I've also implemented pruning to remove any unused reactions and metabolites based on the find_blocked_reactions() function of FVA. This will further constrain the model to sort of "Contextualise" it.
#
#
# May 20, 2023
#
# Based on the Geweke Statistic, and with a z-score of 1.96 (indicating 0.95 confidence  interval) most of the samples have converged on a single statistic. Based on the Gelman Rubin statistic however all of the reactions have not converged to a singular solution. Why?
#
# I've rerun the diagnostic scripts in R using Coda and have produced a more reliable measure of convergence and autocorrelation. In both cases only
#
# I'll test 5000x25000 samples with the reduced and pFVA-constrained models. I think sampling will be faster considering that I've pruned the samples as well as reduced the solution space by a lot.
#
#
# Flux sampling convergence statistics are based on the methods highlighted by Hermmann et al (2019) and by Fallahi et al (2020). It says that we shouldn't use the normal Gelman-Rubin statistic and instead use the Brooks-Gelman formulation instead.
#
# However, for both cases I've instead used the Raftery-Lewis statistic and
# the Geweke Diagnostic to assess convergences for all parameters. I decided to re-run instead the two last samples considering that they both have significant amounts of reactions that haven't converged based on the RL statistic and the GW statistic.
#
# For the RL statistic both 250 and 750 parametrized samplers have converged, although the Geweke diagnostic only reports a convergence rate of around 70 percent. In 1500 the convergence rate falls to 40 percent only which necessitates the re-run scenario. AFterwards I can simply re-run the scripts and re-assess my results. In the meantime however I can analyze both 250 and 750 scenarios as well the highb light scenarios particularly those with significantly varying distributions
#
#
# June 13, 2023
#
# I have rerun both WT andTR 1500 to validate if both have converged. If it hasn't I'll report the results as-is and include it in the discussion.
#
# June 15, 2023
#
# I have an idea in order to ensure convergence as well as to reduce runtimes.
# My idea is to remove all reactions that are not foundd in the model to 0 in order to reduce the nullspace of the model. This will be based on the initial runs for the flux sampling runs.
#
# Afterwards I need to compare their distributions based dun sa mga previous runs to determine if pareho yung distribution. If it is the same or virtually the samme I will use it because I can ensure that it has a higher convergence rate than the one with lower samples.
#
# If in case this works then it should return the same distribution and my samples would've converged faster. Furthermore there isn't need to go for breadth considering that my parametrizations are already fixed. Hopefully it can converge faster but since I've changed the thinning constant to 100k it may change the distribution.
#
# June 15 2023
#
#     Filtering and Increasing the thinning doesn't work apparently. It reduced the convergence rate of my reactions by almost 20 percent -- very alarming. What I should do instead is to increase the thinning coefficient to something more ok (around 35000) while still being relatively fast enough.
#
#     However I'll be re-running my sampling attempt in order to fix some errors with H2O cycling. (Change H2O flux to be unidirectional towards M cell to reflect transpiration mechanism. Before what happened was that )
#
#     Furthermore I fixed the flux bounds for Photon flux. Apparently I had a typo dun sa upper bounds nung TR_1500 which caused it to have 25 lesser flux than normal.
#
#     Hopefully at the end of this ok na siya. Wala na kong problem after nito -- analysis na lang.
#
#
# June 17, 2023
#
# I just discovered how inflated the flux values are for high light conditions, which indicate that there is significant looping in some of my solutions, which I need to reassess considering how central they are to my model, particularly yung reactions involving Malate.
#
# I can try to add Loopless FVA then compare the results with the normal runs. Kahit paspasan lang.
#
#
# # #Notes: June 17
# # #Adding the "Loopless FVA" parameter to the pre-processing step does not work and generates an infeasible solution. It causes the solver to become stuck.
#
# # #Note: it takes 30 minutes to implement Loopless FVA to the model. Upon checking yung mga flux bounds it reduces the max and min values to something closer to their pFBA counterparts.
# # #I'll try to rerun my pipeline to accomodate that.
# # #Note: Loopless FVA produces NaNs in the flux bounds of some reactions. Need to remove that.
#
#
# June 19, 2023:
#
# I think I've finally optimized my Sampling runs. I just need to rerun my scripts kahit 25000 thinning lang since increasing it didn't really affect yung convergence rates.
#
#
# Things I have tested (So far)
# - Filtering out reactions before sampling -- Convergence rates lower almost 20 percent accorss the board.
# - 10000 Thinning
# - 25000 Thinning
# - 35000 Thinning -- little improvement in convergence rates, in fact it lessened percent converged
# - Using add_loopless() function -- doesn't work, turns the model to an MILP problem which breaks Sampling
# - Loopless FVA to define reaction bounds == works so far but it breaks during actual sampling (cannot generate warmup points due to overconstrained model).
# - Using _add_cyclefree_flux() -- doesn't work, breaks the model and causes numerical instability.
# - LOopless FVA with "relaxed option" for NaNs --- I think this method works. Wala na kong nakikitang loops. However this method runs really slow (~2 hours)
#
# June 20, 2023
# - I have problems regarding sampling right now. Sigh. I don't even know the issue behind it rn it just breaks
# - I know now -- apparently using the loopless option overconstrains the model and prevents it from generating warmup points using the sampler. I didn't see that it works. Maybe it'll work if I modify the parametrization to a fraction of the optima instead?
#     - APparently kasi it c
#
# - What I can do is probably to post-process my flux samples using the "loopless_solution" method highlighted in Desouki et al's paper.
#     - This method works. I checked the values for CSm_M and it does deflate the values significantly.
#     - It looks like it might work -- however it is fairly slow when run in series. I'll try to run them in parallel
#         - Multiprocess now works but it keeps doing i/o operations on the models. Can it be modified to just do a single I/O operation?
#             It becomes stuck if I try it
#
#                 It's such a hassle to use multiprocess. I'll just run it on a single thread tutal mabilis lang naman. I'm wasting time on how to run it on a multithread e kaya naman ng isang thread.
#
#
#             June 22, 2023
#
#             - CycleFreeFlux destroys the uniform distribution of my flux solutions, preventing me from inferring any     information based dun sa distributions nung fluxes. Therefore this should be rewritten.
#
#             I've found a methodology similar to Hay et al. (2014) which makes use of loopless FVA to set the bounds for the model. I've implemented this but I've used CFF to generate flux ranges given a set of solutions. However, unlike Hay et al I am ablle to use CFF globally instead of restricting it to certain loop reactions only.
#
# June 24, 2023
#
# I've revised the script so that it properly bypasses infeasibility issues now. Apparently the previous iteration didn't exactly resolve it. However, I've already computed the samples for WT_250 so I can skip that now -- it didn't have too many feasibility issues so I could skip over that.
#
# June 28, 2023
#
# Need to rerun WT_750 and WT1500 due to numerical isseus. I'm not sure why it wasn't caught by the script but I have modified it
#
#
# July 28, 2023
#
# Apparently I've caught an error after reviewing the constraints portion of my model Mali encoding ko of the following:
# -NADP-ME reactions
# -MDH-related reactions
#
# Instead of cosntraining the MDH reactions properly it seems I have constrained it to one direction only, which may explain why no malate is being produced in the model. I've encoded this very early on so di ko napansin. It's a really stupid mistake.
#
# I've encountered some numerical issues that had been fixed simply by increasinng the model tolerance to 1e-9. I think also putting my model as a contextual instance also helped -- I suspect some form of "Batch contamination" being carried over from previous iterations causing the model to be unsolvable once it encounters an infeasible solution.
#
# July 28, 2023
#
# Fixed an issue with Nproj. Default value should be None, not 0 otherwise it causes zero division error.
# ALso what I've noticed is that increasing the tolerance to 1e-9 solves a lot of numerical issues in the model.
#
#
# I've fixed the model accordingly. Same parameters lang and same sampling methodology but I'll resample the model fully with FVA bounds para ok.
#
# Notes:
#
# It seems hindi naayos yung bounds kapag model instance ginamit. I think I just need to use yung model.copy() function

# %% [markdown]
# METHODOLOGY
#
# 1.
# Run convergence statistics on each and generate plots to assess total convergence stats for each CSV. These will include tests such as the
# Raftery-Lewis statistic and the Geweke statistics to assess both autocorrelation as well as assess convergence.
#
# Afterwards get only the flux names of those reactions that have converged
# Run pairwise Kruskal-wallis tests per CSV using the above list of converged reactions
# Identify each reaction with significant and non-significant distributions each
#
#
# Generate histograms/probability densities for relevant reactions with significantly different distributions with WT and Trans models.
# 2. Flux coupling analysis
# Check which fluxes are coupled with each otehr and identify which fluxes are then related to each other, particularly Carbon Fixation reactions in the BS cell such as Rubisco and the DM_Phloem reactions
